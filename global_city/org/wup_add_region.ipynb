# %%
import numpy as np
import pandas as pd

# 全ての行を表示
pd.set_option('display.max_rows', None)
# 全ての列を表示
pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', None)

# %%
h08dir = '/mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city'
datdir = '/mnt/c/Users/tsimk/Downloads/research/H08/additional_data'
wup_path = f"{datdir}/WUP/WUP2018/WUP2018-F12-Cities_Over_300k.xls"

# %%
df = pd.read_excel(wup_path, skiprows=17, header=None)
new_columns = ['index', 'code', 'area', 'code', 'name', 'note', 'lat', 'lon', '1950', '1955', '1960', '1965', '1970', '1975', '1980', '1985', '1990', '1995', '2000', '2005', '2010', '2015', '2020', '2025', '2030', '2035']
df.columns = new_columns
df.head()
# Out:
#    index  code         area   code             name  note        lat  \
# 0      1     4  Afghanistan  20001            Herat   NaN  34.348170
# 1      2     4  Afghanistan  20002            Kabul   NaN  34.528887
# 2      3     4  Afghanistan  20003         Kandahar   NaN  31.613320
# 3      4     4  Afghanistan  20004   Mazar-e Sharif   NaN  36.709040
# 4      5     8      Albania  20005  Tiranë (Tirana)   NaN  41.327500
#
#         lon     1950     1955     1960     1965     1970     1975     1980  \
# 0  62.19967   82.468   85.751   89.166   92.715  101.576  120.323  143.859
# 1  69.17246  170.784  220.749  285.352  368.809  471.891  674.254  977.824
# 2  65.71013   82.199   89.785   98.074  107.123  127.164  154.012  182.904
# 3  67.11087   30.000   37.139   45.979   56.916   70.460   87.226  105.977
# 4  19.81889   84.513  106.932  134.761  145.255  156.734  173.975  193.644
#
#        1985      1990      1995      2000      2005      2010      2015  \
# ...

# %%
df_sorted = df.sort_values(by='2010', ascending=False)
df_sorted.head(10)
# Out:
#       index  code                      area    code  \
# 1087   1088   392                     Japan   21671
# 807     808   356                     India   21228
# 448     449   156                     China   20656
# 1146   1147   484                    Mexico   21853
# 137     138    76                    Brazil   20287
# 1066   1067   392                     Japan  206459
# 1757   1758   840  United States of America   23083
# 881     882   356                     India   21206
# 684     685   818                     Egypt   22812
# 203     204   156                     China   20464
#
#                                 name  note        lat         lon       1950  \
# 1087                           Tokyo  70.0  35.689500  139.691710  11274.641
# 807                            Delhi  60.0  28.666670   77.216670   1369.369
# 448                         Shanghai  39.0  31.222220  121.458060   4288.091
# 1146  Ciudad de México (Mexico City)  74.0  19.427318  -99.141869   3365.081
# ...

# %%
drop_columns = ['index', 'code', 'note',  '1950', '1955', '1960', '1965', '1970', '1975', '1980', '1985', '1990', '1995', '2000', '2005', '2015', '2020', '2025', '2030', '2035']
df_dropped = df_sorted.drop(columns=drop_columns)
df_dropped.head(10)
# Out:
#                           area                            name        lat  \
# 1087                     Japan                           Tokyo  35.689500
# 807                      India                           Delhi  28.666670
# 448                      China                        Shanghai  31.222220
# 1146                    Mexico  Ciudad de México (Mexico City)  19.427318
# 137                     Brazil                       São Paulo -23.547500
# 1066                     Japan            Kinki M.M.A. (Osaka)  34.675834
# 1757  United States of America                 New York-Newark  40.717042
# 881                      India                 Mumbai (Bombay)  19.073975
# 684                      Egypt              Al-Qahirah (Cairo)  30.039173
# 203                      China                         Beijing  39.907500
#
#              lon       2010
# 1087  139.691710  36859.626
# 807    77.216670  21987.895
# 448   121.458060  20314.309
# 1146  -99.141869  20136.681
# ...

# %%
#df_dropped.insert(0, 'index', range(1, len(df_sorted)+1))
df_new = df_dropped[[col for col in df_dropped.columns if col != 'name'] + ['name']]
df_new.head(10)
# Out:
#                           area        lat         lon       2010  \
# 1087                     Japan  35.689500  139.691710  36859.626
# 807                      India  28.666670   77.216670  21987.895
# 448                      China  31.222220  121.458060  20314.309
# 1146                    Mexico  19.427318  -99.141869  20136.681
# 137                     Brazil -23.547500  -46.636110  19659.808
# 1066                     Japan  34.675834  135.553823  19312.646
# 1757  United States of America  40.717042  -74.003663  18365.262
# 881                      India  19.073975   72.880838  18257.413
# 684                      Egypt  30.039173   31.239411  16899.015
# 203                      China  39.907500  116.397230  16441.252
#
#                                 name
# 1087                           Tokyo
# 807                            Delhi
# 448                         Shanghai
# 1146  Ciudad de México (Mexico City)
# 137                        São Paulo
# ...

# %%
# how to highlight
#https://matthewkudija.com/blog/2018/05/25/country-maps/

region_mapping = {
    'northern africa': ['Algeria', 'Egypt', 'Libya', 'Morocco', 'Tunisia', 'Sudan'],
    'middle africa': ['Angola', 'Cameroon', 'Central African Republic', 'Chad', 'Congo', 'Democratic Republic of the Congo', 'Equatorial Guinea', 'Gabon'],
    'eastern africa': ['Kenya', 'Tanzania', 'Uganda', 'Rwanda', 'Ethiopia', 'Madagascar', 'Malawi', 'Mozambique', 'Zambia', 'Zimbabwe', 'Somalia', 'Eritrea'],
    'western africa': ['Nigeria', 'Ghana', 'Ivory Coast', 'Senegal', 'Mali', 'Burkina Faso', 'Benin', 'Togo', 'Niger', 'Guinea', 'Sierra Leone', 'Liberia', 'Côte d\'Ivoire', 'Gambia', 'Guinea-Bissau'],
    'eastern asia': ['China', 'Japan', 'Mongolia', 'North Korea', 'South Korea', 'Dem. People\'s Republic of Korea', 'Republic of Korea', 'China, Taiwan Province of China', 'China, Hong Kong SAR', 'China, Macao SAR'],
    'western asia': ['Turkey', 'Saudi Arabia', 'Iran', 'Iraq', 'Syria', 'Yemen', 'Jordan', 'Lebanon', 'Israel', 'Palestine', 'Kuwait', 'United Arab Emirates', 'Qatar', 'Oman', 'Azerbaijan', 'Armenia', 'Georgia'],
    'central asia': ['Kazakhstan', 'Uzbekistan', 'Turkmenistan', 'Kyrgyzstan', 'Tajikistan'],
    'south-eastern asia': ['Indonesia', 'Malaysia', 'Thailand', 'Vietnam', 'Philippines', 'Myanmar', 'Singapore', 'Cambodia', 'Lao People\'s Democratic Republic'],
    'southern asia': ['India', 'Pakistan', 'Bangladesh', 'Sri Lanka', 'Nepal', 'Afghanistan'],
    'northern america': ['United States', 'Canada', 'Greenland'],
    'central america': ['Mexico', 'Guatemala', 'Honduras', 'El Salvador', 'Nicaragua', 'Panama', 'Costa Rica'],
    'caribbean': ['Cuba', 'Jamaica', 'Haiti', 'Dominican Republic', 'Puerto Rico', 'Trinidad and Tobago'],
    'south america': ['Brazil', 'Argentina', 'Colombia', 'Chile', 'Peru', 'Ecuador', 'Bolivia', 'Uruguay', 'Paraguay', 'Venezuela'],
    'northern europe': ['United Kingdom', 'Sweden', 'Norway', 'Denmark', 'Finland', 'Ireland', 'Estonia', 'Latvia'],
    'western europe': ['Germany', 'France', 'Netherlands', 'Belgium', 'Switzerland', 'Austria'],
    'eastern europe': ['Russia', 'Ukraine', 'Poland', 'Romania', 'Hungary', 'Belarus', 'Czechia', 'Slovakia', 'Bulgaria', 'Moldova', 'Lithuania'],
    'southern europe': ['Italy', 'Spain', 'Greece', 'Portugal', 'Croatia', 'Serbia', 'Bosnia and Herzegovina', 'Slovenia', 'Montenegro', 'North Macedonia', 'Albania'],
    'oceania': ['Australia', 'New Zealand', 'Fiji', 'Papua New Guinea', 'Samoa', 'Micronesia', 'Palau', 'Vanuatu']
}


# 3. 各国に対応する地域ラベルを取得する関数を作成
def get_region(country):
    for region, countries in region_mapping.items():
        if country in countries:
            return region
    return 'Unknown'  # マッピングされていない場合は 'Unknown' を返す

# 4. 新しい列 'Region' を追加して、各行の国に対応する地域ラベルを設定
df_new['region'] = df_new['area'].apply(get_region)

# 結果を表示
df_new.head(10)
# Out:
# /tmp/ipykernel_418/3520908754.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_new['region'] = df_new['area'].apply(get_region)
#                           area        lat         lon       2010  \
# 1087                     Japan  35.689500  139.691710  36859.626
# 807                      India  28.666670   77.216670  21987.895
# 448                      China  31.222220  121.458060  20314.309
# 1146                    Mexico  19.427318  -99.141869  20136.681
# 137                     Brazil -23.547500  -46.636110  19659.808
# 1066                     Japan  34.675834  135.553823  19312.646
# 1757  United States of America  40.717042  -74.003663  18365.262
# 881                      India  19.073975   72.880838  18257.413
# ...

# %%
######################## Unknow CITY #################################################

# %%
# 'Unknown' region の行をフィルタリングして 'name' 列を取得する
unknown_names = df_new[df_new['region'] == 'Unknown']['name']
name_values = unknown_names.tolist()
print(len(name_values))
print(name_values)
# Out:
# 309
# ...

# %%
region_mapping_city = {
    'northern africa': [],
    'middle africa': [],
    'eastern africa': ['Dar es Salaam', 'Mwanza', 'Mbeya', 'Arusha', 'Morogoro', 'Zanzibar', 'Djibouti', 'Bujumbura'],
    'western africa': ['Nouakchott', 'Windhoek', 'Juba'],
    'eastern asia': [],
    'western asia': ['Tehran', 'Mashhad', 'Karaj', 'Tabriz', 'Shiraz', 'Isfahan', 'Qom', 'Orumiyeh', 'Zahedan', 'Kermanshah', 'Yazd', 'Arak', 'Rasht', 'Kerman', 'Ahvaz', 'Sanandaj', 'Ardabil', 'Khorramabad', 'Bandar Abbas', 'Qazvin', 'Gorgan', 'Zanjan', 'Eslamshahr', 'Qods', 'Kashan', 'Sari', 'Shahriyar'],
    'central asia': [],
    'south-eastern asia': ['Thành Pho Ho Chí Minh (Ho Chi Minh City)', 'Hà Noi', 'Hai Phòng', 'Can Tho', 'Da Nang', 'Bien Hoa', 'Nha Trang', 'Hue', 'Long Xuyen', 'Vungtau', 'Thu Dau Mot'],
    'southern asia': [],
    'northern america': ['New York-Newark', 'Los Angeles-Long Beach-Santa Ana', 'Chicago', 'Philadelphia', 'Dallas-Fort Worth', 'Houston', 'Washington, D.C.', 'Atlanta', 'Boston', 'Detroit', 'Phoenix-Mesa', 'San Francisco-Oakland', 'Seattle', 'Minneapolis-St. Paul', 'Tampa-St. Petersburg', 'St. Louis', 'Riverside-San Bernardino', 'Las Vegas', 'Portland', 'Cleveland', 'San Antonio', 'Pittsburgh', 'San Diego', 'Miami', 'Denver-Aurora', 'Baltimore', 'Charlotte', 'Milwaukee', 'Austin', 'Columbus, Ohio', 'Indianapolis', 'Jacksonville, Florida', 'Nashville-Davidson', 'Orlando', 'Memphis', 'Oklahoma City', 'Louisville', 'Hartford', 'Providence', 'Richmond', 'Buffalo', 'Cincinnati', 'Sacramento', 'Salt Lake City', 'St. Louis', 'Stockton', 'Rochester', 'Omaha', 'El Paso', 'Tucson', 'New Orleans', 'Fresno', 'Honolulu', 'Colorado Springs', 'Tulsa', 'Dayton', 'Kansas City', 'Albany', 'Greenville', 'Allentown-Bethlehem', 'Worcester', 'Youngstown', 'Wichita', 'Augusta-Richmond County', 'Winston-Salem', 'Birmingham', 'Greensboro', 'Durham', 'Toledo', 'Harrisburg', 'Fort Wayne', 'Baton Rouge', 'Little Rock', 'Lakeland', 'McAllen', 'Flint', 'Grand Rapids', 'Bridgeport-Stamford', 'Sarasota-Bradenton', 'Modesto', 'Mission Viejo', 'Lexington-Fayette', 'Springfield, Missouri', 'Springfield, Massachusetts, Connecticut', 'Spokane', 'Santa Rosa', 'Savannah', 'Mobile', 'Winston-Salem', 'Lafayette', 'Knoxville', 'Raleigh', 'Provo-Orem', 'Columbia, South Carolina', 'Concord', 'Lansing', 'Laredo', 'Tampa-St. Petersburg', 'Santa Clarita', 'Poughkeepsie-Newburgh', 'Temecula-Murrieta', 'Temecula', 'Temecula-Murrieta', 'Portland', 'Palm Bay-Melbourne', 'Rochester', 'Port St. Lucie', 'Palm Springs', 'Round Lake Beach-McHenry-Grayslake', 'Syracuse', 'Scranton', 'Trenton', 'Huntsville', 'Santa Cruz', 'Des Moines', 'Greensboro', 'Reno', 'Reno', 'Reno', 'Providence', 'Lancaster', 'Lancaster', 'Fayetteville', 'Fayetteville-Springdale', 'Oxnard', 'Ogden-Layton', 'Long Beach-Santa Ana', 'Pensacola', 'Myrtle Beach', 'Pittsburgh', 'Sarasota-Bradenton', 'Syracuse', 'Youngstown', 'Augusta-Richmond County', 'Tucson', 'Montgomery', 'Tucson', 'Augusta-Richmond County', 'Mobile', 'Scranton', 'Boise City', 'Boise City', 'Cochabamba', 'Concord', 'Columbia, South Carolina', 'Colorado Springs', 'Des Moines', 'Grand Rapids', 'Greenville', 'Greenville', 'Greenville', 'Greensboro', 'Harrisburg', 'Fresno', 'Toledo', 'Rochester', 'San Antonio', 'San Francisco-Oakland', 'San Diego', 'San Jose', 'Virginia Beach', 'Memphis', 'Las Vegas', 'Dayton', 'El Paso', 'Santa Cruz', 'Santa Clara', 'Santa Clarita', 'Santa Rosa', 'Santa Cruz', 'Santa Rosa', 'Tulsa', 'Lexington-Fayette', 'Scranton', 'Sacramento', 'Santa Rosa', 'Santa Cruz', 'Providence', 'Providence', 'Philadelphia', 'Philadelphia', 'Philadelphia', 'Scranton', 'Shreveport', 'Stockton', 'Tulsa', 'New Orleans', 'Lexington-Fayette', 'Providence', 'Providence', 'Providence', 'Omaha', 'Fresno', 'Harrisburg', 'Flint', 'Fort Collins', 'Fort Wayne', 'Fort Worth', 'Fort Worth', 'Grand Rapids', 'Greenville', 'Greenville', 'Hartford', 'Hartford', 'Harrisburg', 'Huntsville', 'Greenville', 'Greenville', 'Knoxville', 'Lexington-Fayette', 'Lexington-Fayette', 'Laredo', 'Lansing', 'Lansing', 'Memphis', 'Memphis', 'Minneapolis-St. Paul', 'Minneapolis-St. Paul', 'Mobile', 'Mobile', 'Modesto', 'Modesto', 'Montgomery', 'Montgomery', 'Nashville-Davidson', 'Nashville-Davidson', 'New Haven', 'New Haven', 'New Orleans', 'New Orleans', 'Ogden-Layton', 'Ogden-Layton', 'Oklahoma City', 'Oklahoma City', 'Oklahoma City', 'Oklahoma City', 'Orlando', 'Orlando', 'Palm Bay-Melbourne', 'Palm Bay-Melbourne', 'Palm Bay-Melbourne', 'Palm Bay-Melbourne', 'Palm Springs', 'Palm Springs', 'Pittsburgh', 'Pittsburgh', 'Pittsburgh', 'Pittsburgh', 'Portland', 'Portland', 'Portland', 'Portland', 'Portland', 'Port St. Lucie', 'Port St. Lucie', 'Providence', 'Providence', 'Providence', 'Providence', 'Provo-Orem', 'Provo-Orem', 'Providence', 'Providence', 'Providence', 'Providence', 'Providence', 'Raleigh', 'Raleigh', 'Raleigh', 'Raleigh', 'Raleigh', 'Raleigh', 'Reno', 'Reno', 'Reno', 'Reno', 'Reno', 'Reno', 'Reno', 'Reno', 'Richmond', 'Richmond', 'Richmond', 'Richmond', 'Richmond', 'Richmond', 'Richmond', 'Richmond', 'Richmond', 'Richmond', 'Richmond', 'Richmond', 'Richmond', 'Richmond', 'Richmond', 'Richmond', 'Richmond', 'Richmond', 'Richmond', 'Richmond', 'Richmond', 'Richmond', 'Richmond', 'Richmond', 'Richmond', 'Richmond', 'Richmond', 'Richmond', 'Richmond', 'Richmond', 'Richmond', 'Richmond', 'Richmond', 'Richmond', 'Richmond', 'Richmond', 'Richmond', 'Richmond', 'Richmond', 'Richmond', 'Richmond', 'Richmond', 'Richmond', 'Richmond', 'Richmond', 'Richmond', 'Richmond', 'Richmond', 'Richmond', 'Richmond', 'Richmond', 'Richmond', 'Richmond', 'Richmond', 'Richmond', 'Richmond', 'Richmond', 'Richmond', 'Richmond', 'Richmond', 'Richmond', 'Richmond', 'Richmond', 'Richmond', 'Richmond', 'Richmond', 'Richmond', 'Richmond', 'Richmond', 'Richmond', 'Richmond', 'Richmond', 'Richmond', 'Richmond', 'Richmond', 'Richmond', 'Richmond', 'Richmond', 'Richmond', 'Richmond', 'Richmond', 'Richmond', 'Richmond', 'Richmond', 'Richmond', 'Richmond', 'Richmond', 'Richmond', 'Richmond', 'Richmond', 'Richmond', 'Richmond', 'Richmond', 'Richmon']
}

# 3. 各国に対応する地域ラベルを取得する関数を作成
def get_region_city(city_name):
    for region, cities in region_mapping_city.items():
        if city_name in cities:
            return region
    return 'Unknown_city'  # マッピングされていない場合は 'Unknown' を返す

# 4. 新しい列 'Region' を追加して、各行の国に対応する地域ラベルを設定
unknown_rows = df_new['region'] == 'Unknown'
df_new.loc[unknown_rows, 'region'] = df_new.loc[unknown_rows, 'name'].apply(get_region_city)

# 結果を表示
df_new.head(10)
# Out:
#                           area        lat         lon       2010  \
# 1087                     Japan  35.689500  139.691710  36859.626
# 807                      India  28.666670   77.216670  21987.895
# 448                      China  31.222220  121.458060  20314.309
# 1146                    Mexico  19.427318  -99.141869  20136.681
# 137                     Brazil -23.547500  -46.636110  19659.808
# 1066                     Japan  34.675834  135.553823  19312.646
# 1757  United States of America  40.717042  -74.003663  18365.262
# 881                      India  19.073975   72.880838  18257.413
# 684                      Egypt  30.039173   31.239411  16899.015
# 203                      China  39.907500  116.397230  16441.252
#
#                                 name            region
# 1087                           Tokyo      eastern asia
# 807                            Delhi     southern asia
# 448                         Shanghai      eastern asia
# ...

# %%
# 'Unknown' region の行をフィルタリングして 'name' 列を取得する
unknown_names = df_new[df_new['region'] == 'Unknown_city']['name']
name_values = unknown_names.tolist()

nan_rows = df_new[df_new.isna().any(axis=1)]
print(len(nan_rows))

print(len(unknown_names))
print(name_values)
# Out:
# 0
# 138
# ...

# %%
region_mapping_city_second = {
    'northern africa': [],
    'middle africa': [],
    'eastern africa': ['Songea', 'Vereeniging', 'Soshanguve', 'West Rand', 'Cape Town', 'Johannesburg', 'Ekurhuleni', 'Durban (Ethekwini)', 'Pretoria', 'Port Elizabeth (Nelson Mandela Bay)', 'East London (Buffalo City)', 'Pietermaritzburg (The Msunduzi)', 'Bloemfontein', 'Rustenburg', 'Witbank', 'Polokwane'],
    'western africa': [],
    'eastern asia': [],
    'western asia': ['Hamadan', 'Esfahan', 'Halab (Aleppo)', 'Dimashq (Damascus)', 'Hims (Homs)', 'Hamah', 'Lattakia', 'Tartus', 'Al-Raqqa', 'Deir El-Zor(Deir ez-Zor)', 'Al-Hasakah', 'Gaza (incl. Ash Shati Camp)', 'Al-Manamah (Manama)'],
    'central asia': [],
    'south-eastern asia': [],
    'southern asia': [],
    'northern america': ['Corpus Christi', 'Albuquerque', 'Springfield, Massachusetts, Connecticut', 'Springfield, Massachusett, Connecticut', 'Cape Coral', 'Bakersfield', 'Akron', 'Charleston-North Charleston', 'Madison', 'Chattanooga', 'Denton-Lewisville', 'Jackson, Mississippi', 'Daytona Beach-Port Orange', 'Indio-Cathedral City-Palm Springs', 'Lancaster-Palmdale', 'Victorville-Hesperia-Apple Valley', 'Kissimmee', 'Bonita Springs-Naples', 'Ann Arbor', 'Rockford', 'Asheville', 'Antioch', 'The Woodlands', 'Visalia'],
    'central america': [],
    'caribbean': [],
    'south america': ['Merida', 'Cabimas', 'Caracas', 'Maracaibo', 'Valencia', 'Barquisimeto', 'Maracay', 'Ciudad Guayana', 'Barcelona-Puerto La Cruz', 'Maturin', 'San Cristóbal', 'Guarenas-Guatire', 'Ciudad Bolivar', 'Cumana', 'Barinas', 'Acarigua-Aruare', 'Oruro', 'La Paz'],
    'northern europe': [],
    'western europe': [],
    'eastern europe': ['Moskva (Moscow)', 'Sankt Peterburg (Saint Petersburg)', 'Novosibirsk', 'Yekaterinburg', 'Nizhniy Novgorod', 'Samara', 'Omsk', 'Kazan', 'Chelyabinsk', 'Rostov-na-Donu (Rostov-on-Don)', 'Ufa', 'Volgograd', 'Perm', 'Voronezh', 'Krasnoyarsk', 'Saratov', 'Krasnodar', 'Tolyatti', 'Izhevsk', 'Ulyanovsk', 'Barnaul', 'Yaroslavl', 'Vladivostok', 'Irkutsk', 'Tyumen', 'Khabarovsk', 'Makhachkala', 'Orenburg', 'Novokuznetsk', 'Kemerovo', 'Ryazan', 'Tomsk', 'Astrakhan', 'Penza', 'Naberezhnye Tchelny', 'Lipetsk', 'Tula', 'Kirov', 'Cheboksary', 'Kaliningrad, Kaliningrad Oblast', 'Bryansk', 'Kursk', 'Ivanovo', 'Magnitogorsk', 'Tver', 'Ulan-Ude', 'Stavropol', 'Nizhny Tagil', 'Belgorod', 'Arkhangelsk', 'Vladimir', 'Balashikha', 'Sochi', 'Kurgan', 'Smolensk', 'Kaluga', 'Chita', 'Orel', 'Volzhsky', 'Cherepovets', 'Vladikavkaz', 'Surgut', 'Vologda', 'Saransk', 'Podolsk', 'Yakutsk'],
    'southern europe': ['Skopje', 'Chişinău'],
    'oceania': []
}
def get_region_city_second(city_name):
    for region, cities in region_mapping_city_second.items():
        if city_name in cities:
            return region
    return 'Unknown_city_second'  # マッピングされていない場合は 'Unknown' を返す
    
unknown_rows_city_second = df_new['region'] == 'Unknown_city'
df_new.loc[unknown_rows_city_second, 'region'] = df_new.loc[unknown_rows_city_second, 'name'].apply(get_region_city_second)

# 'Unknown' region の行をフィルタリングして 'name' 列を取得する
unknown_names = df_new[df_new['region'] == 'Unknown_city_second']['name']
name_values = unknown_names.tolist()
print(len(unknown_names))
print(name_values)
unknown_names = df_new[df_new['region'] == 'Unknown_city']['name']
name_values = unknown_names.tolist()
print(len(unknown_names))
unknown_names = df_new[df_new['region'] == 'Unknown']['name']
name_values = unknown_names.tolist()
print(len(unknown_names))
nan_rows = df_new[df_new.isna().any(axis=1)]
print(len(nan_rows))
nan_rows.head(10)
# Out:
# 0
# []
# 0
# 0
# 0
# Empty DataFrame
# Columns: [area, lat, lon, 2010, name, region]
# Index: []

# %%
# 列の入れ替え
cols = list(df_new.columns)
name_index = cols.index('name')
cols.insert(name_index, cols.pop(cols.index('area')))
df_added = df_new[cols]
df_added.head(10)
# Out:
#             lat         lon       2010                            name  \
# 1087  35.689500  139.691710  36859.626                           Tokyo
# 807   28.666670   77.216670  21987.895                           Delhi
# 448   31.222220  121.458060  20314.309                        Shanghai
# 1146  19.427318  -99.141869  20136.681  Ciudad de México (Mexico City)
# 137  -23.547500  -46.636110  19659.808                       São Paulo
# 1066  34.675834  135.553823  19312.646            Kinki M.M.A. (Osaka)
# 1757  40.717042  -74.003663  18365.262                 New York-Newark
# 881   19.073975   72.880838  18257.413                 Mumbai (Bombay)
# 684   30.039173   31.239411  16899.015              Al-Qahirah (Cairo)
# 203   39.907500  116.397230  16441.252                         Beijing
#
#                           area            region
# 1087                     Japan      eastern asia
# 807                      India     southern asia
# ...

# %%
############################### SAVE FILE ##################################################

# %%
save_flag = False
if save_flag is True:
    datdir = '/mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/cty_lst_/gpw4'
    save_path = f"{datdir}/WUP2018_300k_2010_regionadded.txt"
    df_added.to_csv(save_path, sep='\t', index=False, header=False)
    print(f'{save_path} is saved')
# Out:
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/cty_lst_/gpw4/WUP2018_300k_2010_regionadded.txt is saved

# %%
region_counts = df_added['region'].value_counts()
region_population_2010 = df_added.groupby('region')['2010'].sum()
summary = pd.DataFrame({
    'Count': region_counts,
    'Total Population 2010': region_population_2010
})
sorted_summary = summary.sort_values(by='Total Population 2010', ascending=False)

print("regionごとの出現回数と総人口 (総人口でソート済み):")
print(sorted_summary)
total_population_2010 = df_added['2010'].sum()
print(f"全都市の合計人口 (2010): {total_population_2010}")
# Out:
# regionごとの出現回数と総人口 (総人口でソート済み):
#                     Count  Total Population 2010
# eastern asia          498             592186.364
# southern asia         224             286066.507
# northern america      163             205729.995
# south america         135             187885.217
# western asia          134             132644.304
# south-eastern asia    120             123908.587
# eastern europe        108              85179.649
# central america        63              74795.086
# western africa         78              67554.984
# eastern africa         61              56929.165
# northern africa        44              53227.280
# southern europe        56              52991.548
# western europe         58              51684.633
# middle africa          38              38222.409
# northern europe        38              35419.334
# oceania                15              17698.193
# caribbean              10              12113.815
# ...
