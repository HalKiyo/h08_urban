# %%
mcy_pop_water_path = '/mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/cty_lst_/gpw4/mcy_pop_water_12region.txt'
column_names = ['index', 'flag', 'rate', 'wup', 'pop', 'ava', 'mpcy', 'potential', 'region', 'country', 'cityname', '12region']
df = pd.read_csv(mcy_pop_water_path, delimiter='|', header=None, names=column_names)
df.head(10)
# Out:
#    index   flag      rate        wup         pop           ava          mpcy  \
# 0      1  False  0.863325  36859.626  31821850.0  1.424091e+10    447.519821
# 1      2  False  1.003201  21987.895  22058268.0  4.420798e+09    200.414547
# 2      3  False  0.715760  20314.309  14540163.0  1.643563e+10   1130.360505
# 3      4  False  1.002057  20136.681  20178100.0  3.006577e+08     14.900200
# 4      5  False  0.492121  19659.808   9675000.0  2.057520e+09    212.663566
# 5      6  False  0.489232  19312.646   9448362.0  1.272031e+10   1346.297983
# 6      7  False  0.470956  18365.262   8649229.0  6.329261e+08     73.177170
# 7      8  False  0.783200  18257.413  14299211.0  9.254411e+09    647.197295
# 8      9  False  1.006426  16899.015  17007614.0  7.113659e+11  41826.322056
# 9     10  False  0.823952  16441.252  13546804.0  2.355427e+09    173.873265
#
#    potential            region                   country  \
# 0       93.0      eastern asia                     Japan
# 1       39.0     southern asia                     India
# 2       17.0      eastern asia                     China
# 3       43.0   central america                    Mexico
# 4       11.0     south america                    Brazil
# 5       24.0      eastern asia                     Japan
# 6       17.0  northern america  United States of America
# 7       12.0     southern asia                     India
# 8       24.0   northern africa                     Egypt
# 9       24.0      eastern asia                     China
#
#                          cityname         12region
# 0                           Tokyo        East Asia
# 1                           Delhi       South Asia
# 2                        Shanghai        East Asia
# 3  Ciudad de México (Mexico City)  Central America
# 4                       São Paulo    South America
# 5            Kinki M.M.A. (Osaka)        East Asia
# 6                 New York-Newark    North America
# 7                 Mumbai (Bombay)       South Asia
# 8              Al-Qahirah (Cairo)  Northern Africa
# 9                         Beijing        East Asia

# %%
import os
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import cartopy.feature as cfeature
import numpy as np
import pandas as pd
import matplotlib.colors as mcolors

def l_coordinate_to_tuple(lcoordinate, a=2160, b=4320):
    lat_l = ((lcoordinate - 1) // b)
    lon_l = (lcoordinate) % b - 1
    return (lat_l, lon_l)

def nxtl2nxtxy(rgnfile, upperindex, leftindex):
    vfunc = np.vectorize(l_coordinate_to_tuple, otypes=[tuple])
    riv_nxtxy = np.empty(rgnfile.shape, dtype=tuple)
    mask = ~np.isnan(rgnfile)
    riv_nxtxy[mask] = vfunc(rgnfile[mask])
    riv_nxtxy_shape = (riv_nxtxy.shape[0], riv_nxtxy.shape[1], 2)
    
    riv_nxtxy_lst = []
    for row in riv_nxtxy:
        for y, x in row:
            modified_y = y - upperindex
            modified_x = x - leftindex
            riv_nxtxy_lst.append((modified_y, modified_x))

    riv_nxtxy_cropped = np.array(riv_nxtxy_lst).reshape(riv_nxtxy_shape)
    riv_nxtxy_cropped = riv_nxtxy_cropped.astype(int)
    return riv_nxtxy_cropped

h08dir = '/mnt/c/Users/tsimk/Downloads/dotfiles/h08'
pop_path = f'{h08dir}/global_city/dat/pop_tot_/GPW4ag__20100000.gl5'
rivnxl_path = f"{h08dir}/global_city/dat/riv_nxl_/rivnxl.CAMA.gl5"
rivout_path = f'{h08dir}/wsi/dat/riv_out_/W5E5LR__00000000.gl5'
rivnum_path = f'{h08dir}/global_city/dat/riv_num_/rivnum.CAMA.gl5'
rivara_path = f'{h08dir}/global_city/dat/riv_ara_/rivara.CAMA.gl5'
msk_dir = f'{h08dir}/global_city/dat/vld_cty_'
prf_dir = f'{h08dir}/global_city/dat/cty_prf_'

pop_gl5 = np.fromfile(pop_path, dtype='float32').reshape(2160, 4320)
rivout_gl5 = np.fromfile(rivout_path, dtype='float32').reshape(2160, 4320)
rivnum_gl5 = np.fromfile(rivnum_path, dtype='float32').reshape(2160, 4320)
rivara_gl5 = np.fromfile(rivara_path, dtype='float32').reshape(2160, 4320)
rivnxl_gl5 = np.fromfile(rivnxl_path, 'float32').reshape(2160, 4320)
riv_nxlonlat_cropped = nxtl2nxtxy(rivnxl_gl5, 0, 0)

mcy_pop_water_path = '/mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/cty_lst_/gpw4/mcy_pop_water_12region.txt'
column_names = ['index', 'flag', 'rate', 'wup', 'pop', 'ava', 'mpcy', 'potential', 'region', 'country', 'cityname', '12region']
df = pd.read_csv(mcy_pop_water_path, delimiter='|', header=None, names=column_names)
df.head(10)

def updown(new_basin_to_cities, key_index=0):
    # get uid and city list
    keys_list = list(new_basin_to_cities.keys())
    uid = keys_list[key_index]
    rivnum_list = new_basin_to_cities[uid]
    rivnum_list = [int(i) for i in rivnum_list]
    
    # remove overlap
    overlap_path = f'{h08dir}/global_city/dat/cty_lst_/gpw4/overlap_hidden_only.txt'
    with open(overlap_path, 'r') as f:
        numbers = [int(line.strip()) for line in f]
    rivnum_list_removed = [num for num in rivnum_list if num not in numbers]
    rivnum_list_removed = [int(i) for i in rivnum_list_removed]
    
    # coord of purficication
    coords_a = []
    for city_num in rivnum_list_removed:
        prf_path = f'{prf_dir}/vld_cty_/city_{city_num:08}.gl5'
        prf = np.fromfile(prf_path, dtype='float32').reshape(2160, 4320)
        uid = int(float(uid))
        prf_coord = np.where((prf == 1) & (rivnum_gl5 == uid))
        coords_a.append(prf_coord)
    
    # down??
    edges = []
    riv_path_array = np.zeros((2160, 4320))
    for cid in range(len(coords_a)):
        visited_coords = set()
        riv_path_array[coords_a[cid][0][0], coords_a[cid][1][0]] = cid
        
        coords_b = coords_a.copy()
        coords_b.pop(cid) 
        cind_list = rivnum_list_removed.copy()
        cind_list.pop(cid)
        
        if len(coords_a) > 0:
            target_coord = (coords_a[cid][0][0], coords_a[cid][1][0])
            
            while True:
                if target_coord in visited_coords:
                    break
                visited_coords.add(target_coord)
                
                next_coord = riv_nxlonlat_cropped[target_coord[0], target_coord[1]]
                if next_coord.size == 0 or next_coord.shape != (2,):
                    break
                
                next_coord = (next_coord[0], next_coord[1])
                riv_path_array[next_coord[0], next_coord[1]] = cid
                target_coord = next_coord
        
        for cind, coord in enumerate(coords_b):
            standard_coord = (coord[0][0], coord[1][0])
            if standard_coord in visited_coords:
                edges.append((rivnum_list_removed[cid], cind_list[cind]))
            #else:

    # edgesは2都市間のupstreamとdownstreamの関係をすべて保存したリスト
    return edges, riv_path_array, coords_a, rivnum_list_removed
    
def find_upstream_cities(edges, city_number):
    cities_with_upstream = []
    cities_without_upstream = []
    upstream_cities = [edge[0] for edge in edges if edge[1] == city_number]
    uup = np.unique(upstream_cities)
    
    for i in uup:
        if any(edge[1] == i for edge in edges):
            # 上流にさらに都市が存在する場合
            cities_with_upstream.append(i)
        else:
            # 上流にこれ以上都市が存在しない場合
            cities_without_upstream.append(i)
    
    return cities_with_upstream, cities_without_upstream, uup

def make_result_dict(new_basin_to_cities, key_index=1):
    # unique_cties_basin: uniqueなすべての都市
    # uup: 各都市の上流にあるuniqueな都市
    edges, riv_path_array, coords_a, rivnum_list_removed = updown(new_basin_to_cities, key_index=key_index)
    unique_cities_basin = np.unique(edges)
    
    result_dict = {}
    for city_number in unique_cities_basin:
        cities_with_upstream, cities_without_upstream, uup = find_upstream_cities(edges, city_number)
        if cities_with_upstream:
            # [discharge, consumption, potential, flag, uppoer cities]
            result_dict[city_number] = [1, 0.1, 0, True, uup]
        elif not cities_with_upstream and cities_without_upstream:
            result_dict[city_number] = [1, 0.1, 0, False, uup]
        else:
            result_dict[city_number] = [1, 0.1, 0, 'Done', uup]
    
    # 同じ流域に含まれる各都市のwater availability, upstream citiesを保存している．cities_with_upstreamが存在する場合，flag=Trueとなる
    return result_dict
    
def explore(result_dict):
    while True:
        all_done = True  # 全てのflagが'Done'であるかをチェックするためのフラグ
        
        for key in result_dict:
            value = result_dict[key]
            ava = value[0]
            con = value[1]
            pot = value[2]
            flag = value[3]
            uup = value[4]
            
            ava_mod = ava
            pot_mod = pot
            
            if flag != 'Done':
                all_done = False  # まだ'Done'でないflagがある場合、all_doneをFalseに設定
        
            if flag is False:
                flg_lst = []
                for kkk in uup:
                    oth_flg = result_dict[kkk][3]
                    flg_lst.append(oth_flg)
                    
                for kkk in uup:
                    oth_dis = result_dict[kkk][0]
                    oth_con = result_dict[kkk][1]
                    ava_mod = ava_mod - np.abs(oth_con)
                    pot_mod = pot_mod - np.abs(oth_dis)
                result_dict[key][0] = ava_mod
                result_dict[key][2] = pot_mod
                
                if con > ava_mod:
                    result_dict[key][1] = ava_mod
                if pot_mod > ava_mod:
                    result_dict[key][2] = ava_mod
                    
                result_dict[key][3] = 'Done'
                
            elif flag is True:
                flg_lst = []
                for kkk in uup:
                    oth_flg = result_dict[kkk][3]
                    flg_lst.append(oth_flg)
                
                if all(item == 'Done' for item in flg_lst):
                    # 重複を削除する
                    all_upstream = []
                    for kkk in uup:
                        all_upstream.extend(result_dict[kkk][4])
                    mod_uup = [city for city in uup if city not in all_upstream]
                    for kkk in mod_uup:
                        oth_dis = result_dict[kkk][0]
                        oth_con = result_dict[kkk][1]
                        ava_mod = ava_mod - np.abs(oth_con)
                        pot_mod = pot_mod - np.abs(oth_dis)
                    result_dict[key][0] = ava_mod
                    result_dict[key][2] = pot_mod

                    if con > ava_mod:
                        result_dict[key][1] = ava_mod
                    if pot_mod > ava_mod:
                        result_dict[key][2] = ava_mod
                        
                    result_dict[key][3] = 'Done'
    
            else:
                flg_lst = []
                for kkk in uup:
                    oth_flg = result_dict[kkk][3]
                    flg_lst.append(oth_flg)
            print(key, flag, ava, con, pot, flg_lst, uup)
                    
        print('------------------------------------------------------------------------------------------------------------------------------------------------------------------------')
        if all_done:
            print('all_done')
            break  # 全てのflagが'Done'であればループを終了
    return result_dict

def load_json():
    basin_cities_path = f'/mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/riv_num_/basin_to_cities.json'
    with open(basin_cities_path, 'r') as json_file:
        basin_to_cities = json.load(json_file)
    new_basin_to_cities = {rivnum: cities for rivnum, cities in basin_to_cities.items() if len(cities) > 1}
    return new_basin_to_cities

# %%
####################################################################################
# result_dictのavaの中に1流域からの想定取水量を入力する
# これはガンジス流域を対象にしたtoy model
####################################################################################

"""
mcy_pop_water_path = '/mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/cty_lst_/gpw4/mcy_pop_water_12region.txt'
column_names = ['index', 'flag', 'rate', 'wup', 'pop', 'ava', 'mpcy', 'potential', 'region', 'country', 'cityname', '12region']
df = pd.read_csv(mcy_pop_water_path, delimiter='|', header=None, names=column_names)
"""

def discharge_rate(city_num, riv_num):
    city_num = int(city_num)
    riv_num = int(float(riv_num))
    print(f'city_num, riv_num, {city_num}, {riv_num}')
    ctymsk_path = f'{msk_dir}/city_{city_num:08}.gl5'
    prf_path = f'{prf_dir}/vld_cty_/city_{city_num:08}.gl5'
    ctymsk = np.fromfile(ctymsk_path, dtype='float32').reshape(2160, 4320)
    prf = np.fromfile(prf_path, dtype='float32').reshape(2160, 4320)
    rivnum_mask = np.ma.masked_where(prf == 0, rivnum_gl5)
    rivnum_lst = np.unique(rivnum_mask)[:-1]
    rivara_mask = np.ma.masked_where(prf == 0, rivara_gl5)
    rate = rivara_gl5[rivnum_mask== riv_num]/np.sum(rivara_mask)
    discharge = rivout_gl5[(prf==1) & (rivnum_gl5==riv_num)]* 60 * 60 * 24 * 365 / (1000) # m3/year
    return rate, discharge

#
new_basin_to_cities = load_json() # keys = all basins with multiple cities 180?
rate_cities = []
key_index = 1
#
# result_dictは流域に固有で流域ごとに更新される
result_dict =  make_result_dict(new_basin_to_cities, key_index=key_index) # keys = all cities in key_index basin
# result_dictは流域に固有で流域ごとに更新される
#
riv_num = list(new_basin_to_cities.keys())[key_index]
city_num_lst = list(result_dict.keys())

for city_num in city_num_lst:
    #
    rate, discharge = discharge_rate(city_num, riv_num)
    if rate < 1:
        rate_cities.append(city_num)
    print(f'rate, discharge {rate}, {discharge}')
    #
    filtered_df = df[df['index'] == city_num]
    if filtered_df.empty:
        print(f'City number {city_num} not found in the data.')
    #
    mpcy = filtered_df.reset_index(drop=True).loc[0, 'mpcy']
    est_pop = filtered_df.reset_index(drop=True).loc[0, 'pop']
    #
    # take all available water
    if mpcy <= 1000:
        print(f'shortage')
        consumption = discharge
    #
    # take population * ratio * 1000m3/year
    else:
        print(f'no shortage')
        consumption = 1000*est_pop*rate
        if consumption < discharge:
            consumption = consumption
        else:
            consumption = discharge
    #
    print(f'consumption: {consumption}')
    print(f'discharge: {discharge}')
    result_dict[city_num][0] = discharge
    result_dict[city_num][1] = consumption
    result_dict[city_num][2] = discharge
    print(f'--------------------------------------')
    
print(f'**********rivnum{list(new_basin_to_cities.keys())[key_index]}: calculation done***************')
print(f'--------------------------------------')

# exploreによって上流下流の再配分がなされる
result_dict_mod = explore(result_dict)
# exploreによって上流下流の再配分がなされる
# Out:
# city_num, riv_num, 2, 14
# rate, discharge [1.], [4.420798e+09]
# shortage
# consumption: [4.420798e+09]
# --------------------------------------
# city_num, riv_num, 126, 14
# rate, discharge [1.], [89442976.]
# shortage
# consumption: [89442976.]
# --------------------------------------
# city_num, riv_num, 130, 14
# rate, discharge [1.], [8.714595e+10]
# no shortage
# consumption: [2.9605235e+09]
# --------------------------------------
# city_num, riv_num, 133, 14
# rate, discharge [1.], [6.7015393e+09]
# no shortage
# consumption: [2.8753277e+09]
# --------------------------------------
# city_num, riv_num, 188, 14
# rate, discharge [1.], [56511940.]
# shortage
# consumption: [56511940.]
# --------------------------------------
# city_num, riv_num, 197, 14
# rate, discharge [1.], [5.9125085e+11]
# no shortage
# consumption: [2.0274934e+09]
# --------------------------------------
# city_num, riv_num, 217, 14
# rate, discharge [1.], [2.5847798e+08]
# shortage
# consumption: [2.5847798e+08]
# --------------------------------------
# city_num, riv_num, 243, 14
# rate, discharge [1.], [3.0390383e+10]
# no shortage
# consumption: [1.7854246e+09]
# --------------------------------------
# city_num, riv_num, 319, 14
# rate, discharge [1.], [1.3054141e+08]
# shortage
# consumption: [1.3054141e+08]
# --------------------------------------
# city_num, riv_num, 321, 14
# rate, discharge [1.], [1.8618818e+08]
# shortage
# consumption: [1.8618818e+08]
# --------------------------------------
# city_num, riv_num, 363, 14
# rate, discharge [1.], [2.4650745e+11]
# no shortage
# consumption: [1.3975183e+09]
# --------------------------------------
# city_num, riv_num, 406, 14
# rate, discharge [1.], [1.4394014e+08]
# shortage
# consumption: [1.4394014e+08]
# --------------------------------------
# city_num, riv_num, 455, 14
# rate, discharge [1.], [2.041812e+10]
# no shortage
# consumption: [9.836526e+08]
# --------------------------------------
# city_num, riv_num, 463, 14
# rate, discharge [1.], [73121752.]
# shortage
# consumption: [73121752.]
# --------------------------------------
# city_num, riv_num, 473, 14
# rate, discharge [1.], [3.2887685e+11]
# no shortage
# consumption: [9.526492e+08]
# --------------------------------------
# city_num, riv_num, 513, 14
# rate, discharge [1.], [9.8778656e+08]
# no shortage
# consumption: [9.28597e+08]
# --------------------------------------
# city_num, riv_num, 526, 14
# rate, discharge [1.], [2.3453118e+08]
# shortage
# consumption: [2.3453118e+08]
# --------------------------------------
# city_num, riv_num, 588, 14
# rate, discharge [1.], [8.274831e+11]
# no shortage
# consumption: [8.6828934e+08]
# --------------------------------------
# city_num, riv_num, 667, 14
# rate, discharge [1.], [5.1893155e+08]
# shortage
# consumption: [5.1893155e+08]
# --------------------------------------
# city_num, riv_num, 669, 14
# rate, discharge [1.], [2.4661896e+09]
# no shortage
# consumption: [7.32065e+08]
# --------------------------------------
# city_num, riv_num, 673, 14
# rate, discharge [1.], [1.8255382e+09]
# no shortage
# consumption: [6.879159e+08]
# --------------------------------------
# city_num, riv_num, 677, 14
# rate, discharge [1.], [89638072.]
# shortage
# consumption: [89638072.]
# --------------------------------------
# city_num, riv_num, 797, 14
# rate, discharge [1.], [3.1437967e+10]
# no shortage
# consumption: [6.5284736e+08]
# --------------------------------------
# city_num, riv_num, 883, 14
# rate, discharge [1.], [68969152.]
# shortage
# consumption: [68969152.]
# --------------------------------------
# city_num, riv_num, 941, 14
# rate, discharge [1.], [8.5713325e+08]
# no shortage
# consumption: [5.468077e+08]
# --------------------------------------
# city_num, riv_num, 983, 14
# rate, discharge [1.], [48419476.]
# shortage
# consumption: [48419476.]
# --------------------------------------
# city_num, riv_num, 1012, 14
# rate, discharge [1.], [3.0476334e+09]
# no shortage
# consumption: [6.155651e+08]
# --------------------------------------
# city_num, riv_num, 1018, 14
# rate, discharge [0.32598916], [66265424.]
# shortage
# consumption: [66265424.]
# --------------------------------------
# city_num, riv_num, 1067, 14
# rate, discharge [1.], [1.418693e+09]
# no shortage
# consumption: [4.9450672e+08]
# --------------------------------------
# city_num, riv_num, 1089, 14
# rate, discharge [1.], [43959056.]
# shortage
# consumption: [43959056.]
# --------------------------------------
# city_num, riv_num, 1253, 14
# rate, discharge [1.], [2.2121896e+08]
# shortage
# consumption: [2.2121896e+08]
# --------------------------------------
# city_num, riv_num, 1288, 14
# rate, discharge [1.], [1.6124179e+09]
# no shortage
# consumption: [4.1845888e+08]
# --------------------------------------
# city_num, riv_num, 1298, 14
# rate, discharge [1.], [3.670683e+08]
# shortage
# consumption: [3.670683e+08]
# --------------------------------------
# city_num, riv_num, 1337, 14
# rate, discharge [1.], [1.6604492e+09]
# no shortage
# consumption: [3.8576218e+08]
# --------------------------------------
# city_num, riv_num, 1365, 14
# rate, discharge [1.], [1.7475278e+08]
# shortage
# consumption: [1.7475278e+08]
# --------------------------------------
# city_num, riv_num, 1371, 14
# rate, discharge [1.], [66349560.]
# shortage
# consumption: [66349560.]
# --------------------------------------
# city_num, riv_num, 1422, 14
# rate, discharge [1.], [40713512.]
# shortage
# consumption: [40713512.]
# --------------------------------------
# city_num, riv_num, 1578, 14
# rate, discharge [1.], [2.936458e+08]
# shortage
# consumption: [2.936458e+08]
# --------------------------------------
# city_num, riv_num, 1620, 14
# rate, discharge [1.], [2.0057982e+08]
# shortage
# consumption: [2.0057982e+08]
# --------------------------------------
# city_num, riv_num, 1656, 14
# rate, discharge [1.], [49358788.]
# shortage
# consumption: [49358788.]
# --------------------------------------
# city_num, riv_num, 1697, 14
# rate, discharge [1.], [49926980.]
# shortage
# consumption: [49926980.]
# --------------------------------------
# city_num, riv_num, 1712, 14
# rate, discharge [1.], [3.6653942e+09]
# no shortage
# consumption: [3.5924458e+08]
# --------------------------------------
# city_num, riv_num, 1718, 14
# rate, discharge [0.56406516], [1.13018824e+08]
# shortage
# consumption: [1.13018824e+08]
# --------------------------------------
# city_num, riv_num, 1824, 14
# rate, discharge [1.], [9.682586e+08]
# no shortage
# consumption: [2.4737813e+08]
# --------------------------------------
# **********rivnum14.0: calculation done***************
# --------------------------------------
# 2 True [4.420798e+09] [4.420798e+09] [4.420798e+09] ['Done', False, 'Done'] [1253 1288 1620]
# 126 Done [89442976.] [89442976.] [89442976.] [] []
# 130 False [8.714595e+10] [2.9605235e+09] [8.714595e+10] ['Done', 'Done', 'Done', 'Done', 'Done', 'Done'] [ 321  463  526 1371 1656 1824]
# 133 Done [6.7015393e+09] [2.8753277e+09] [6.7015393e+09] [] []
# 188 Done [56511940.] [56511940.] [56511940.] [] []
# 197 True [5.9125085e+11] [2.0274934e+09] [5.9125085e+11] [True, 'Done', 'Done', 'Done', 'Done', 'Done', True, 'Done', 'Done', True, 'Done', False, 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', True, 'Done', 'Done', 'Done', 'Done', False, 'Done', 'Done', False, 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done'] [   2  126  130  133  188  217  243  319  321  363  406  455  463  513
#   526  667  669  677  797  883  941  983 1018 1067 1089 1253 1288 1298
#  1337 1371 1422 1620 1656 1697 1712 1718 1824]
# 217 Done [2.5847798e+08] [2.5847798e+08] [2.5847798e+08] [] []
# 243 True [3.0390383e+10] [1.7854246e+09] [3.0390383e+10] [True, 'Done', 'Done', 'Done', False, 'Done', 'Done', False, 'Done', 'Done'] [   2  667  677  983 1067 1089 1253 1288 1422 1620]
# 319 Done [1.3054141e+08] [1.3054141e+08] [1.3054141e+08] [] []
# 321 Done [1.8618818e+08] [1.8618818e+08] [1.8618818e+08] [] []
# 363 True [2.4650745e+11] [1.3975183e+09] [2.4650745e+11] [True, 'Done', 'Done', 'Done', True, 'Done', False, 'Done', 'Done', 'Done', True, 'Done', 'Done', 'Done', 'Done', False, 'Done', 'Done', False, 'Done', 'Done', 'Done', 'Done', 'Done'] [   2  126  188  217  243  406  455  513  667  677  797  883  941  983
#  1018 1067 1089 1253 1288 1298 1337 1422 1620 1718]
# 406 Done [1.4394014e+08] [1.4394014e+08] [1.4394014e+08] [] []
# 455 False [2.041812e+10] [9.836526e+08] [2.041812e+10] ['Done', 'Done', 'Done'] [ 188  941 1718]
# 463 Done [73121752.] [73121752.] [73121752.] [] []
# 473 False [3.2887685e+11] [9.526492e+08] [3.2887685e+11] ['Done'] [1365]
# 513 Done [9.8778656e+08] [9.28597e+08] [9.8778656e+08] [] []
# 526 Done [2.3453118e+08] [2.3453118e+08] [2.3453118e+08] [] []
# 588 True [8.274831e+11] [8.6828934e+08] [8.274831e+11] [True, 'Done', 'Done', 'Done', 'Done', True, 'Done', True, 'Done', 'Done', True, 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', True, 'Done', 'Done', 'Done', 'Done', 'Done', False, 'Done', 'Done', False, 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done'] [   2  126  130  133  188  197  217  243  319  321  363  406  455  463
#   513  526  667  669  673  677  797  883  941  983 1012 1018 1067 1089
#  1253 1288 1298 1337 1371 1422 1578 1620 1656 1697 1712 1718 1824]
# 667 Done [5.1893155e+08] [5.1893155e+08] [5.1893155e+08] [] []
# 669 Done [2.4661896e+09] [7.32065e+08] [2.4661896e+09] [] []
# 673 Done [1.8255382e+09] [6.879159e+08] [1.8255382e+09] [] []
# 677 Done [89638072.] [89638072.] [89638072.] [] []
# 797 True [3.1437967e+10] [6.5284736e+08] [3.1437967e+10] [True, True, 'Done', 'Done', 'Done', False, 'Done', 'Done', False, 'Done', 'Done'] [   2  243  667  677  983 1067 1089 1253 1288 1422 1620]
# 883 Done [68969152.] [68969152.] [68969152.] [] []
# 941 Done [8.5713325e+08] [5.468077e+08] [8.5713325e+08] [] []
# 983 Done [48419476.] [48419476.] [48419476.] [] []
# 1012 Done [3.0476334e+09] [6.155651e+08] [3.0476334e+09] [] []
# 1018 Done [66265424.] [66265424.] [66265424.] [] []
# 1067 False [1.418693e+09] [4.9450672e+08] [1.418693e+09] ['Done'] [1422]
# 1089 Done [43959056.] [43959056.] [43959056.] [] []
# 1253 Done [2.2121896e+08] [2.2121896e+08] [2.2121896e+08] [] []
# 1288 False [1.6124179e+09] [4.1845888e+08] [1.6124179e+09] ['Done', 'Done'] [1253 1620]
# 1298 Done [3.670683e+08] [3.670683e+08] [3.670683e+08] [] []
# 1337 Done [1.6604492e+09] [3.8576218e+08] [1.6604492e+09] [] []
# 1365 Done [1.7475278e+08] [1.7475278e+08] [1.7475278e+08] [] []
# 1371 Done [66349560.] [66349560.] [66349560.] [] []
# 1422 Done [40713512.] [40713512.] [40713512.] [] []
# 1578 Done [2.936458e+08] [2.936458e+08] [2.936458e+08] [] []
# 1620 Done [2.0057982e+08] [2.0057982e+08] [2.0057982e+08] [] []
# 1656 Done [49358788.] [49358788.] [49358788.] [] []
# 1697 Done [49926980.] [49926980.] [49926980.] [] []
# 1712 Done [3.6653942e+09] [3.5924458e+08] [3.6653942e+09] [] []
# 1718 Done [1.13018824e+08] [1.13018824e+08] [1.13018824e+08] [] []
# 1824 Done [9.682586e+08] [2.4737813e+08] [9.682586e+08] [] []
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 2 True [4.420798e+09] [4.420798e+09] [4.420798e+09] ['Done', 'Done', 'Done'] [1253 1288 1620]
# 126 Done [89442976.] [89442976.] [89442976.] [] []
# 130 Done [8.628902e+10] [2.9605235e+09] [8.556814e+10] ['Done', 'Done', 'Done', 'Done', 'Done', 'Done'] [ 321  463  526 1371 1656 1824]
# 133 Done [6.7015393e+09] [2.8753277e+09] [6.7015393e+09] [] []
# 188 Done [56511940.] [56511940.] [56511940.] [] []
# 197 True [5.9125085e+11] [2.0274934e+09] [5.9125085e+11] ['Done', 'Done', 'Done', 'Done', 'Done', 'Done', True, 'Done', 'Done', True, 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', True, 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done'] [   2  126  130  133  188  217  243  319  321  363  406  455  463  513
#   526  667  669  677  797  883  941  983 1018 1067 1089 1253 1288 1298
#  1337 1371 1422 1620 1656 1697 1712 1718 1824]
# 217 Done [2.5847798e+08] [2.5847798e+08] [2.5847798e+08] [] []
# 243 True [3.0390383e+10] [1.7854246e+09] [3.0390383e+10] ['Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done'] [   2  667  677  983 1067 1089 1253 1288 1422 1620]
# 319 Done [1.3054141e+08] [1.3054141e+08] [1.3054141e+08] [] []
# 321 Done [1.8618818e+08] [1.8618818e+08] [1.8618818e+08] [] []
# 363 True [2.4650745e+11] [1.3975183e+09] [2.4650745e+11] ['Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', True, 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done'] [   2  126  188  217  243  406  455  513  667  677  797  883  941  983
#  1018 1067 1089 1253 1288 1298 1337 1422 1620 1718]
# 406 Done [1.4394014e+08] [1.4394014e+08] [1.4394014e+08] [] []
# 455 Done [1.970178e+10] [9.836526e+08] [1.9391455e+10] ['Done', 'Done', 'Done'] [ 188  941 1718]
# 463 Done [73121752.] [73121752.] [73121752.] [] []
# 473 Done [3.287021e+11] [9.526492e+08] [3.287021e+11] ['Done'] [1365]
# 513 Done [9.8778656e+08] [9.28597e+08] [9.8778656e+08] [] []
# 526 Done [2.3453118e+08] [2.3453118e+08] [2.3453118e+08] [] []
# 588 True [8.274831e+11] [8.6828934e+08] [8.274831e+11] ['Done', 'Done', 'Done', 'Done', 'Done', True, 'Done', 'Done', 'Done', 'Done', True, 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', True, 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done'] [   2  126  130  133  188  197  217  243  319  321  363  406  455  463
#   513  526  667  669  673  677  797  883  941  983 1012 1018 1067 1089
#  1253 1288 1298 1337 1371 1422 1578 1620 1656 1697 1712 1718 1824]
# 667 Done [5.1893155e+08] [5.1893155e+08] [5.1893155e+08] [] []
# 669 Done [2.4661896e+09] [7.32065e+08] [2.4661896e+09] [] []
# 673 Done [1.8255382e+09] [6.879159e+08] [1.8255382e+09] [] []
# 677 Done [89638072.] [89638072.] [89638072.] [] []
# 797 True [3.1437967e+10] [6.5284736e+08] [3.1437967e+10] ['Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done'] [   2  243  667  677  983 1067 1089 1253 1288 1422 1620]
# 883 Done [68969152.] [68969152.] [68969152.] [] []
# 941 Done [8.5713325e+08] [5.468077e+08] [8.5713325e+08] [] []
# 983 Done [48419476.] [48419476.] [48419476.] [] []
# 1012 Done [3.0476334e+09] [6.155651e+08] [3.0476334e+09] [] []
# 1018 Done [66265424.] [66265424.] [66265424.] [] []
# 1067 Done [1.3779795e+09] [4.9450672e+08] [1.3779795e+09] ['Done'] [1422]
# 1089 Done [43959056.] [43959056.] [43959056.] [] []
# 1253 Done [2.2121896e+08] [2.2121896e+08] [2.2121896e+08] [] []
# 1288 Done [1.1906191e+09] [4.1845888e+08] [1.1906191e+09] ['Done', 'Done'] [1253 1620]
# 1298 Done [3.670683e+08] [3.670683e+08] [3.670683e+08] [] []
# 1337 Done [1.6604492e+09] [3.8576218e+08] [1.6604492e+09] [] []
# 1365 Done [1.7475278e+08] [1.7475278e+08] [1.7475278e+08] [] []
# 1371 Done [66349560.] [66349560.] [66349560.] [] []
# 1422 Done [40713512.] [40713512.] [40713512.] [] []
# 1578 Done [2.936458e+08] [2.936458e+08] [2.936458e+08] [] []
# 1620 Done [2.0057982e+08] [2.0057982e+08] [2.0057982e+08] [] []
# 1656 Done [49358788.] [49358788.] [49358788.] [] []
# 1697 Done [49926980.] [49926980.] [49926980.] [] []
# 1712 Done [3.6653942e+09] [3.5924458e+08] [3.6653942e+09] [] []
# 1718 Done [1.13018824e+08] [1.13018824e+08] [1.13018824e+08] [] []
# 1824 Done [9.682586e+08] [2.4737813e+08] [9.682586e+08] [] []
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 2 Done [4.002339e+09] [4.002339e+09] [3.2301788e+09] ['Done', 'Done', 'Done'] [1253 1288 1620]
# 126 Done [89442976.] [89442976.] [89442976.] [] []
# 130 Done [8.628902e+10] [2.9605235e+09] [8.556814e+10] ['Done', 'Done', 'Done', 'Done', 'Done', 'Done'] [ 321  463  526 1371 1656 1824]
# 133 Done [6.7015393e+09] [2.8753277e+09] [6.7015393e+09] [] []
# 188 Done [56511940.] [56511940.] [56511940.] [] []
# 197 True [5.9125085e+11] [2.0274934e+09] [5.9125085e+11] ['Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', True, 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done'] [   2  126  130  133  188  217  243  319  321  363  406  455  463  513
#   526  667  669  677  797  883  941  983 1018 1067 1089 1253 1288 1298
#  1337 1371 1422 1620 1656 1697 1712 1718 1824]
# 217 Done [2.5847798e+08] [2.5847798e+08] [2.5847798e+08] [] []
# 243 Done [2.519259e+10] [1.7854246e+09] [2.4309115e+10] ['Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done'] [   2  667  677  983 1067 1089 1253 1288 1422 1620]
# 319 Done [1.3054141e+08] [1.3054141e+08] [1.3054141e+08] [] []
# 321 Done [1.8618818e+08] [1.8618818e+08] [1.8618818e+08] [] []
# 363 True [2.4650745e+11] [1.3975183e+09] [2.4650745e+11] ['Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done'] [   2  126  188  217  243  406  455  513  667  677  797  883  941  983
#  1018 1067 1089 1253 1288 1298 1337 1422 1620 1718]
# 406 Done [1.4394014e+08] [1.4394014e+08] [1.4394014e+08] [] []
# 455 Done [1.970178e+10] [9.836526e+08] [1.9391455e+10] ['Done', 'Done', 'Done'] [ 188  941 1718]
# 463 Done [73121752.] [73121752.] [73121752.] [] []
# 473 Done [3.287021e+11] [9.526492e+08] [3.287021e+11] ['Done'] [1365]
# 513 Done [9.8778656e+08] [9.28597e+08] [9.8778656e+08] [] []
# 526 Done [2.3453118e+08] [2.3453118e+08] [2.3453118e+08] [] []
# 588 True [8.274831e+11] [8.6828934e+08] [8.274831e+11] ['Done', 'Done', 'Done', 'Done', 'Done', True, 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done'] [   2  126  130  133  188  197  217  243  319  321  363  406  455  463
#   513  526  667  669  673  677  797  883  941  983 1012 1018 1067 1089
#  1253 1288 1298 1337 1371 1422 1578 1620 1656 1697 1712 1718 1824]
# 667 Done [5.1893155e+08] [5.1893155e+08] [5.1893155e+08] [] []
# 669 Done [2.4661896e+09] [7.32065e+08] [2.4661896e+09] [] []
# 673 Done [1.8255382e+09] [6.879159e+08] [1.8255382e+09] [] []
# 677 Done [89638072.] [89638072.] [89638072.] [] []
# 797 Done [2.9652543e+10] [6.5284736e+08] [6.245378e+09] ['Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done'] [   2  243  667  677  983 1067 1089 1253 1288 1422 1620]
# 883 Done [68969152.] [68969152.] [68969152.] [] []
# 941 Done [8.5713325e+08] [5.468077e+08] [8.5713325e+08] [] []
# 983 Done [48419476.] [48419476.] [48419476.] [] []
# 1012 Done [3.0476334e+09] [6.155651e+08] [3.0476334e+09] [] []
# 1018 Done [66265424.] [66265424.] [66265424.] [] []
# 1067 Done [1.3779795e+09] [4.9450672e+08] [1.3779795e+09] ['Done'] [1422]
# 1089 Done [43959056.] [43959056.] [43959056.] [] []
# 1253 Done [2.2121896e+08] [2.2121896e+08] [2.2121896e+08] [] []
# 1288 Done [1.1906191e+09] [4.1845888e+08] [1.1906191e+09] ['Done', 'Done'] [1253 1620]
# 1298 Done [3.670683e+08] [3.670683e+08] [3.670683e+08] [] []
# 1337 Done [1.6604492e+09] [3.8576218e+08] [1.6604492e+09] [] []
# 1365 Done [1.7475278e+08] [1.7475278e+08] [1.7475278e+08] [] []
# 1371 Done [66349560.] [66349560.] [66349560.] [] []
# 1422 Done [40713512.] [40713512.] [40713512.] [] []
# 1578 Done [2.936458e+08] [2.936458e+08] [2.936458e+08] [] []
# 1620 Done [2.0057982e+08] [2.0057982e+08] [2.0057982e+08] [] []
# 1656 Done [49358788.] [49358788.] [49358788.] [] []
# 1697 Done [49926980.] [49926980.] [49926980.] [] []
# 1712 Done [3.6653942e+09] [3.5924458e+08] [3.6653942e+09] [] []
# 1718 Done [1.13018824e+08] [1.13018824e+08] [1.13018824e+08] [] []
# 1824 Done [9.682586e+08] [2.4737813e+08] [9.682586e+08] [] []
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 2 Done [4.002339e+09] [4.002339e+09] [3.2301788e+09] ['Done', 'Done', 'Done'] [1253 1288 1620]
# 126 Done [89442976.] [89442976.] [89442976.] [] []
# 130 Done [8.628902e+10] [2.9605235e+09] [8.556814e+10] ['Done', 'Done', 'Done', 'Done', 'Done', 'Done'] [ 321  463  526 1371 1656 1824]
# 133 Done [6.7015393e+09] [2.8753277e+09] [6.7015393e+09] [] []
# 188 Done [56511940.] [56511940.] [56511940.] [] []
# 197 True [5.9125085e+11] [2.0274934e+09] [5.9125085e+11] ['Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done'] [   2  126  130  133  188  217  243  319  321  363  406  455  463  513
#   526  667  669  677  797  883  941  983 1018 1067 1089 1253 1288 1298
#  1337 1371 1422 1620 1656 1697 1712 1718 1824]
# 217 Done [2.5847798e+08] [2.5847798e+08] [2.5847798e+08] [] []
# 243 Done [2.519259e+10] [1.7854246e+09] [2.4309115e+10] ['Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done'] [   2  667  677  983 1067 1089 1253 1288 1422 1620]
# 319 Done [1.3054141e+08] [1.3054141e+08] [1.3054141e+08] [] []
# 321 Done [1.8618818e+08] [1.8618818e+08] [1.8618818e+08] [] []
# 363 Done [2.4256243e+11] [1.3975183e+09] [1.9351072e+11] ['Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done'] [   2  126  188  217  243  406  455  513  667  677  797  883  941  983
#  1018 1067 1089 1253 1288 1298 1337 1422 1620 1718]
# 406 Done [1.4394014e+08] [1.4394014e+08] [1.4394014e+08] [] []
# 455 Done [1.970178e+10] [9.836526e+08] [1.9391455e+10] ['Done', 'Done', 'Done'] [ 188  941 1718]
# 463 Done [73121752.] [73121752.] [73121752.] [] []
# 473 Done [3.287021e+11] [9.526492e+08] [3.287021e+11] ['Done'] [1365]
# 513 Done [9.8778656e+08] [9.28597e+08] [9.8778656e+08] [] []
# 526 Done [2.3453118e+08] [2.3453118e+08] [2.3453118e+08] [] []
# 588 True [8.274831e+11] [8.6828934e+08] [8.274831e+11] ['Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done'] [   2  126  130  133  188  197  217  243  319  321  363  406  455  463
#   513  526  667  669  673  677  797  883  941  983 1012 1018 1067 1089
#  1253 1288 1298 1337 1371 1422 1578 1620 1656 1697 1712 1718 1824]
# 667 Done [5.1893155e+08] [5.1893155e+08] [5.1893155e+08] [] []
# 669 Done [2.4661896e+09] [7.32065e+08] [2.4661896e+09] [] []
# 673 Done [1.8255382e+09] [6.879159e+08] [1.8255382e+09] [] []
# 677 Done [89638072.] [89638072.] [89638072.] [] []
# 797 Done [2.9652543e+10] [6.5284736e+08] [6.245378e+09] ['Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done'] [   2  243  667  677  983 1067 1089 1253 1288 1422 1620]
# 883 Done [68969152.] [68969152.] [68969152.] [] []
# 941 Done [8.5713325e+08] [5.468077e+08] [8.5713325e+08] [] []
# 983 Done [48419476.] [48419476.] [48419476.] [] []
# 1012 Done [3.0476334e+09] [6.155651e+08] [3.0476334e+09] [] []
# 1018 Done [66265424.] [66265424.] [66265424.] [] []
# 1067 Done [1.3779795e+09] [4.9450672e+08] [1.3779795e+09] ['Done'] [1422]
# 1089 Done [43959056.] [43959056.] [43959056.] [] []
# 1253 Done [2.2121896e+08] [2.2121896e+08] [2.2121896e+08] [] []
# 1288 Done [1.1906191e+09] [4.1845888e+08] [1.1906191e+09] ['Done', 'Done'] [1253 1620]
# 1298 Done [3.670683e+08] [3.670683e+08] [3.670683e+08] [] []
# 1337 Done [1.6604492e+09] [3.8576218e+08] [1.6604492e+09] [] []
# 1365 Done [1.7475278e+08] [1.7475278e+08] [1.7475278e+08] [] []
# 1371 Done [66349560.] [66349560.] [66349560.] [] []
# 1422 Done [40713512.] [40713512.] [40713512.] [] []
# 1578 Done [2.936458e+08] [2.936458e+08] [2.936458e+08] [] []
# 1620 Done [2.0057982e+08] [2.0057982e+08] [2.0057982e+08] [] []
# 1656 Done [49358788.] [49358788.] [49358788.] [] []
# 1697 Done [49926980.] [49926980.] [49926980.] [] []
# 1712 Done [3.6653942e+09] [3.5924458e+08] [3.6653942e+09] [] []
# 1718 Done [1.13018824e+08] [1.13018824e+08] [1.13018824e+08] [] []
# 1824 Done [9.682586e+08] [2.4737813e+08] [9.682586e+08] [] []
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 2 Done [4.002339e+09] [4.002339e+09] [3.2301788e+09] ['Done', 'Done', 'Done'] [1253 1288 1620]
# 126 Done [89442976.] [89442976.] [89442976.] [] []
# 130 Done [8.628902e+10] [2.9605235e+09] [8.556814e+10] ['Done', 'Done', 'Done', 'Done', 'Done', 'Done'] [ 321  463  526 1371 1656 1824]
# 133 Done [6.7015393e+09] [2.8753277e+09] [6.7015393e+09] [] []
# 188 Done [56511940.] [56511940.] [56511940.] [] []
# 197 Done [5.827457e+11] [2.0274934e+09] [2.493858e+11] ['Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done'] [   2  126  130  133  188  217  243  319  321  363  406  455  463  513
#   526  667  669  677  797  883  941  983 1018 1067 1089 1253 1288 1298
#  1337 1371 1422 1620 1656 1697 1712 1718 1824]
# 217 Done [2.5847798e+08] [2.5847798e+08] [2.5847798e+08] [] []
# 243 Done [2.519259e+10] [1.7854246e+09] [2.4309115e+10] ['Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done'] [   2  667  677  983 1067 1089 1253 1288 1422 1620]
# 319 Done [1.3054141e+08] [1.3054141e+08] [1.3054141e+08] [] []
# 321 Done [1.8618818e+08] [1.8618818e+08] [1.8618818e+08] [] []
# 363 Done [2.4256243e+11] [1.3975183e+09] [1.9351072e+11] ['Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done'] [   2  126  188  217  243  406  455  513  667  677  797  883  941  983
#  1018 1067 1089 1253 1288 1298 1337 1422 1620 1718]
# 406 Done [1.4394014e+08] [1.4394014e+08] [1.4394014e+08] [] []
# 455 Done [1.970178e+10] [9.836526e+08] [1.9391455e+10] ['Done', 'Done', 'Done'] [ 188  941 1718]
# 463 Done [73121752.] [73121752.] [73121752.] [] []
# 473 Done [3.287021e+11] [9.526492e+08] [3.287021e+11] ['Done'] [1365]
# 513 Done [9.8778656e+08] [9.28597e+08] [9.8778656e+08] [] []
# 526 Done [2.3453118e+08] [2.3453118e+08] [2.3453118e+08] [] []
# 588 Done [8.238584e+11] [8.6828934e+08] [2.3957055e+11] ['Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done'] [   2  126  130  133  188  197  217  243  319  321  363  406  455  463
#   513  526  667  669  673  677  797  883  941  983 1012 1018 1067 1089
#  1253 1288 1298 1337 1371 1422 1578 1620 1656 1697 1712 1718 1824]
# 667 Done [5.1893155e+08] [5.1893155e+08] [5.1893155e+08] [] []
# 669 Done [2.4661896e+09] [7.32065e+08] [2.4661896e+09] [] []
# 673 Done [1.8255382e+09] [6.879159e+08] [1.8255382e+09] [] []
# 677 Done [89638072.] [89638072.] [89638072.] [] []
# 797 Done [2.9652543e+10] [6.5284736e+08] [6.245378e+09] ['Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done'] [   2  243  667  677  983 1067 1089 1253 1288 1422 1620]
# 883 Done [68969152.] [68969152.] [68969152.] [] []
# 941 Done [8.5713325e+08] [5.468077e+08] [8.5713325e+08] [] []
# 983 Done [48419476.] [48419476.] [48419476.] [] []
# 1012 Done [3.0476334e+09] [6.155651e+08] [3.0476334e+09] [] []
# 1018 Done [66265424.] [66265424.] [66265424.] [] []
# 1067 Done [1.3779795e+09] [4.9450672e+08] [1.3779795e+09] ['Done'] [1422]
# 1089 Done [43959056.] [43959056.] [43959056.] [] []
# 1253 Done [2.2121896e+08] [2.2121896e+08] [2.2121896e+08] [] []
# 1288 Done [1.1906191e+09] [4.1845888e+08] [1.1906191e+09] ['Done', 'Done'] [1253 1620]
# 1298 Done [3.670683e+08] [3.670683e+08] [3.670683e+08] [] []
# 1337 Done [1.6604492e+09] [3.8576218e+08] [1.6604492e+09] [] []
# 1365 Done [1.7475278e+08] [1.7475278e+08] [1.7475278e+08] [] []
# 1371 Done [66349560.] [66349560.] [66349560.] [] []
# 1422 Done [40713512.] [40713512.] [40713512.] [] []
# 1578 Done [2.936458e+08] [2.936458e+08] [2.936458e+08] [] []
# 1620 Done [2.0057982e+08] [2.0057982e+08] [2.0057982e+08] [] []
# 1656 Done [49358788.] [49358788.] [49358788.] [] []
# 1697 Done [49926980.] [49926980.] [49926980.] [] []
# 1712 Done [3.6653942e+09] [3.5924458e+08] [3.6653942e+09] [] []
# 1718 Done [1.13018824e+08] [1.13018824e+08] [1.13018824e+08] [] []
# 1824 Done [9.682586e+08] [2.4737813e+08] [9.682586e+08] [] []
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# all_done

# %%
######################################################
# pot_modにバグがないか確認する
# つまりpotentialがnegativeになっていないかどうか
#####################################################
ppp = 0
for i in result_dict_mod:
    a = result_dict_mod[i][2]
    print(i, a)
    ppp += a/2500
print(ppp)
# Out:
# 2 [3.2301788e+09]
# 126 [89442976.]
# 130 [8.556814e+10]
# 133 [6.7015393e+09]
# 188 [56511940.]
# 197 [2.493858e+11]
# 217 [2.5847798e+08]
# 243 [2.4309115e+10]
# 319 [1.3054141e+08]
# 321 [1.8618818e+08]
# 363 [1.9351072e+11]
# 406 [1.4394014e+08]
# 455 [1.9391455e+10]
# 463 [73121752.]
# 473 [3.287021e+11]
# 513 [9.8778656e+08]
# 526 [2.3453118e+08]
# 588 [2.3957055e+11]
# 667 [5.1893155e+08]
# 669 [2.4661896e+09]
# 673 [1.8255382e+09]
# 677 [89638072.]
# 797 [6.245378e+09]
# 883 [68969152.]
# 941 [8.5713325e+08]
# 983 [48419476.]
# 1012 [3.0476334e+09]
# 1018 [66265424.]
# 1067 [1.3779795e+09]
# 1089 [43959056.]
# 1253 [2.2121896e+08]
# 1288 [1.1906191e+09]
# 1298 [3.670683e+08]
# 1337 [1.6604492e+09]
# 1365 [1.7475278e+08]
# 1371 [66349560.]
# 1422 [40713512.]
# 1578 [2.936458e+08]
# 1620 [2.0057982e+08]
# 1656 [49358788.]
# 1697 [49926980.]
# 1712 [3.6653942e+09]
# 1718 [1.13018824e+08]
# 1824 [9.682586e+08]
# [4.712989e+08]

# %%
####################################################################################
# df_copyみたいなのを作ってavailabilityの部分を更新する
# これが本チャンの計算
####################################################################################

df_new = df.copy()
duplicates_citynum = [3, 35, 52, 73, 77, 85, 97, 108, 128, 129, 167, 246, 335, 345, 350, 486, 490, 502, 508, 543, 550, 627, 654, 658, 764, 790, 1018, 1044, 1045, 1098, 1110, 1169, 1202, 1248, 1280, 1416, 1450, 1718]
discharge_dup_dct = {}
potential_dup_dct = {}
for city_num in duplicates_citynum:
    discharge_dup_dct[city_num] = {}
    potential_dup_dct[city_num] = {}

new_basin_to_cities = load_json() # keys = all basins with multiple cities 180?
for key_index in range(len(new_basin_to_cities.keys())):
    #
    # result_dictは流域に固有で流域ごとに更新される
    result_dict =  make_result_dict(new_basin_to_cities, key_index=key_index) # keys = all cities in key_index basin
    # result_dictは流域に固有で流域ごとに更新される
    #
    riv_num = list(new_basin_to_cities.keys())[key_index]
    city_num_lst = list(result_dict.keys())
    
    for city_num in city_num_lst:
        #
        rate, discharge = discharge_rate(city_num, riv_num)
        if rate < 1:
            rate_cities.append(city_num)
        print(f'rate, discharge {rate}, {discharge}')
        #
        filtered_df = df[df['index'] == city_num]
        if filtered_df.empty:
            print(f'City number {city_num} not found in the data.')
        #
        mpcy = filtered_df.reset_index(drop=True).loc[0, 'mpcy']
        est_pop = filtered_df.reset_index(drop=True).loc[0, 'pop']
        #
        # take all available water
        if mpcy <= 1000:
            print(f'shortage')
            consumption = discharge
        #
        # take population * ratio * 1000m3/year
        else:
            print(f'no shortage')
            consumption = 1000*est_pop*rate
            if consumption < discharge:
                consumption = consumption
            else:
                consumption = discharge
        #
        print(f'consumption: {consumption}')
        print(f'discharge: {discharge}')
        result_dict[city_num][0] = discharge
        result_dict[city_num][1] = consumption
        result_dict[city_num][2] = discharge
        print(f'--------------------------------------')
        
    print(f'**********rivnum{list(new_basin_to_cities.keys())[key_index]}: calculation done***************')
    print(f'--------------------------------------')
    
    # exploreによって上流下流の再配分がなされる
    result_dict_mod = explore(result_dict)
    # exploreによって上流下流の再配分がなされる

    # calculate water availability from multiple basins
    for city_num in result_dict_mod:
        city_num = int(city_num)
        riv_num = int(float(riv_num))
        ctymsk_path = f'{msk_dir}/city_{city_num:08}.gl5'
        prf_path = f'{prf_dir}/vld_cty_/city_{city_num:08}.gl5'
        ctymsk = np.fromfile(ctymsk_path, dtype='float32').reshape(2160, 4320)
        prf = np.fromfile(prf_path, dtype='float32').reshape(2160, 4320)
        
        dis_els = np.sum(rivout_gl5[(prf==1) & (rivnum_gl5!=riv_num)])* 60 * 60 * 24 * 365 / (1000) # m3/year
        dis_mod = result_dict_mod[city_num][0]
        pot_mod = result_dict_mod[city_num][2]
        
        if city_num in duplicates_citynum:
            discharge_dup_dct[city_num][riv_num] = dis_mod
            potential_dup_dct[city_num][riv_num] = pot_mod
        
        if dis_els:
            availability = dis_els + dis_mod
            pot_sum      = dis_els + pot_mod
        else:
            availability = dis_mod
            pot_sum      = pot_mod
        print(f'dis_els:{dis_els}, dis_mod:{dis_mod}, availability:{availability}')
        
        df_new.loc[df_new['index'] == city_num, 'ava'] = availability
        df_new.loc[df_new['index'] == city_num, 'mpcy'] = availability/df_new.loc[df_new['index'] == city_num, 'pop']
        df_new.loc[df_new['index'] == city_num, 'potential'] = pot_sum
        
df_new.head(10)
# Out:
# city_num, riv_num, 1, 848
# rate, discharge [0.7426214], [1.1001185e+10]
# shortage
# consumption: [1.1001185e+10]
# discharge: [1.1001185e+10]
# --------------------------------------
# city_num, riv_num, 1283, 848
# rate, discharge [1.], [4.749225e+09]
# no shortage
# consumption: [4.4535376e+08]
# discharge: [4.749225e+09]
# --------------------------------------
# **********rivnum848.0: calculation done***************
# --------------------------------------
# 1 False [1.1001185e+10] [1.1001185e+10] [1.1001185e+10] ['Done'] [1283]
# 1283 Done [4.749225e+09] [4.4535376e+08] [4.749225e+09] [] []
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 1 Done [1.0555831e+10] [1.0555831e+10] [6.2519603e+09] ['Done'] [1283]
# 1283 Done [4.749225e+09] [4.4535376e+08] [4.749225e+09] [] []
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# all_done
# dis_els:3239722352.25, dis_mod:[1.0555831e+10], availability:[1.3795553e+10]
# dis_els:0.0, dis_mod:[4.749225e+09], availability:[4.749225e+09]
# city_num, riv_num, 2, 14
# rate, discharge [1.], [4.420798e+09]
# shortage
# consumption: [4.420798e+09]
# discharge: [4.420798e+09]
# --------------------------------------
# city_num, riv_num, 126, 14
# rate, discharge [1.], [89442976.]
# shortage
# consumption: [89442976.]
# discharge: [89442976.]
# --------------------------------------
# city_num, riv_num, 130, 14
# rate, discharge [1.], [8.714595e+10]
# no shortage
# consumption: [2.9605235e+09]
# discharge: [8.714595e+10]
# --------------------------------------
# city_num, riv_num, 133, 14
# rate, discharge [1.], [6.7015393e+09]
# no shortage
# consumption: [2.8753277e+09]
# discharge: [6.7015393e+09]
# --------------------------------------
# city_num, riv_num, 188, 14
# rate, discharge [1.], [56511940.]
# shortage
# consumption: [56511940.]
# discharge: [56511940.]
# --------------------------------------
# city_num, riv_num, 197, 14
# rate, discharge [1.], [5.9125085e+11]
# no shortage
# consumption: [2.0274934e+09]
# discharge: [5.9125085e+11]
# --------------------------------------
# city_num, riv_num, 217, 14
# rate, discharge [1.], [2.5847798e+08]
# shortage
# consumption: [2.5847798e+08]
# discharge: [2.5847798e+08]
# --------------------------------------
# city_num, riv_num, 243, 14
# rate, discharge [1.], [3.0390383e+10]
# no shortage
# consumption: [1.7854246e+09]
# discharge: [3.0390383e+10]
# --------------------------------------
# city_num, riv_num, 319, 14
# rate, discharge [1.], [1.3054141e+08]
# shortage
# consumption: [1.3054141e+08]
# discharge: [1.3054141e+08]
# --------------------------------------
# city_num, riv_num, 321, 14
# rate, discharge [1.], [1.8618818e+08]
# shortage
# consumption: [1.8618818e+08]
# discharge: [1.8618818e+08]
# --------------------------------------
# city_num, riv_num, 363, 14
# rate, discharge [1.], [2.4650745e+11]
# no shortage
# consumption: [1.3975183e+09]
# discharge: [2.4650745e+11]
# --------------------------------------
# city_num, riv_num, 406, 14
# rate, discharge [1.], [1.4394014e+08]
# shortage
# consumption: [1.4394014e+08]
# discharge: [1.4394014e+08]
# --------------------------------------
# city_num, riv_num, 455, 14
# rate, discharge [1.], [2.041812e+10]
# no shortage
# consumption: [9.836526e+08]
# discharge: [2.041812e+10]
# --------------------------------------
# city_num, riv_num, 463, 14
# rate, discharge [1.], [73121752.]
# shortage
# consumption: [73121752.]
# discharge: [73121752.]
# --------------------------------------
# city_num, riv_num, 473, 14
# rate, discharge [1.], [3.2887685e+11]
# no shortage
# consumption: [9.526492e+08]
# discharge: [3.2887685e+11]
# --------------------------------------
# city_num, riv_num, 513, 14
# rate, discharge [1.], [9.8778656e+08]
# no shortage
# consumption: [9.28597e+08]
# discharge: [9.8778656e+08]
# --------------------------------------
# city_num, riv_num, 526, 14
# rate, discharge [1.], [2.3453118e+08]
# shortage
# consumption: [2.3453118e+08]
# discharge: [2.3453118e+08]
# --------------------------------------
# city_num, riv_num, 588, 14
# rate, discharge [1.], [8.274831e+11]
# no shortage
# consumption: [8.6828934e+08]
# discharge: [8.274831e+11]
# --------------------------------------
# city_num, riv_num, 667, 14
# rate, discharge [1.], [5.1893155e+08]
# shortage
# consumption: [5.1893155e+08]
# discharge: [5.1893155e+08]
# --------------------------------------
# city_num, riv_num, 669, 14
# rate, discharge [1.], [2.4661896e+09]
# no shortage
# consumption: [7.32065e+08]
# discharge: [2.4661896e+09]
# --------------------------------------
# city_num, riv_num, 673, 14
# rate, discharge [1.], [1.8255382e+09]
# no shortage
# consumption: [6.879159e+08]
# discharge: [1.8255382e+09]
# --------------------------------------
# city_num, riv_num, 677, 14
# rate, discharge [1.], [89638072.]
# shortage
# consumption: [89638072.]
# discharge: [89638072.]
# --------------------------------------
# city_num, riv_num, 797, 14
# rate, discharge [1.], [3.1437967e+10]
# no shortage
# consumption: [6.5284736e+08]
# discharge: [3.1437967e+10]
# --------------------------------------
# city_num, riv_num, 883, 14
# rate, discharge [1.], [68969152.]
# shortage
# consumption: [68969152.]
# discharge: [68969152.]
# --------------------------------------
# city_num, riv_num, 941, 14
# rate, discharge [1.], [8.5713325e+08]
# no shortage
# consumption: [5.468077e+08]
# discharge: [8.5713325e+08]
# --------------------------------------
# city_num, riv_num, 983, 14
# rate, discharge [1.], [48419476.]
# shortage
# consumption: [48419476.]
# discharge: [48419476.]
# --------------------------------------
# city_num, riv_num, 1012, 14
# rate, discharge [1.], [3.0476334e+09]
# no shortage
# consumption: [6.155651e+08]
# discharge: [3.0476334e+09]
# --------------------------------------
# city_num, riv_num, 1018, 14
# rate, discharge [0.32598916], [66265424.]
# shortage
# consumption: [66265424.]
# discharge: [66265424.]
# --------------------------------------
# city_num, riv_num, 1067, 14
# rate, discharge [1.], [1.418693e+09]
# no shortage
# consumption: [4.9450672e+08]
# discharge: [1.418693e+09]
# --------------------------------------
# city_num, riv_num, 1089, 14
# rate, discharge [1.], [43959056.]
# shortage
# consumption: [43959056.]
# discharge: [43959056.]
# --------------------------------------
# city_num, riv_num, 1253, 14
# rate, discharge [1.], [2.2121896e+08]
# shortage
# consumption: [2.2121896e+08]
# discharge: [2.2121896e+08]
# --------------------------------------
# city_num, riv_num, 1288, 14
# rate, discharge [1.], [1.6124179e+09]
# no shortage
# consumption: [4.1845888e+08]
# discharge: [1.6124179e+09]
# --------------------------------------
# city_num, riv_num, 1298, 14
# rate, discharge [1.], [3.670683e+08]
# shortage
# consumption: [3.670683e+08]
# discharge: [3.670683e+08]
# --------------------------------------
# city_num, riv_num, 1337, 14
# rate, discharge [1.], [1.6604492e+09]
# no shortage
# consumption: [3.8576218e+08]
# discharge: [1.6604492e+09]
# --------------------------------------
# city_num, riv_num, 1365, 14
# rate, discharge [1.], [1.7475278e+08]
# shortage
# consumption: [1.7475278e+08]
# discharge: [1.7475278e+08]
# --------------------------------------
# city_num, riv_num, 1371, 14
# rate, discharge [1.], [66349560.]
# shortage
# consumption: [66349560.]
# discharge: [66349560.]
# --------------------------------------
# city_num, riv_num, 1422, 14
# rate, discharge [1.], [40713512.]
# shortage
# consumption: [40713512.]
# discharge: [40713512.]
# --------------------------------------
# city_num, riv_num, 1578, 14
# rate, discharge [1.], [2.936458e+08]
# shortage
# consumption: [2.936458e+08]
# discharge: [2.936458e+08]
# --------------------------------------
# city_num, riv_num, 1620, 14
# rate, discharge [1.], [2.0057982e+08]
# shortage
# consumption: [2.0057982e+08]
# discharge: [2.0057982e+08]
# --------------------------------------
# city_num, riv_num, 1656, 14
# rate, discharge [1.], [49358788.]
# shortage
# consumption: [49358788.]
# discharge: [49358788.]
# --------------------------------------
# city_num, riv_num, 1697, 14
# rate, discharge [1.], [49926980.]
# shortage
# consumption: [49926980.]
# discharge: [49926980.]
# --------------------------------------
# city_num, riv_num, 1712, 14
# rate, discharge [1.], [3.6653942e+09]
# no shortage
# consumption: [3.5924458e+08]
# discharge: [3.6653942e+09]
# --------------------------------------
# city_num, riv_num, 1718, 14
# rate, discharge [0.56406516], [1.13018824e+08]
# shortage
# consumption: [1.13018824e+08]
# discharge: [1.13018824e+08]
# --------------------------------------
# city_num, riv_num, 1824, 14
# rate, discharge [1.], [9.682586e+08]
# no shortage
# consumption: [2.4737813e+08]
# discharge: [9.682586e+08]
# --------------------------------------
# **********rivnum14.0: calculation done***************
# --------------------------------------
# 2 True [4.420798e+09] [4.420798e+09] [4.420798e+09] ['Done', False, 'Done'] [1253 1288 1620]
# 126 Done [89442976.] [89442976.] [89442976.] [] []
# 130
# dis_els:0.0, dis_mod:[8.238584e+11], availability:[8.238584e+11]
# dis_els:0.0, dis_mod:[5.1893155e+08], availability:[5.1893155e+08]
# dis_els:0.0, dis_mod:[2.4661896e+09], availability:[2.4661896e+09]
# dis_els:0.0, dis_mod:[1.8255382e+09], availability:[1.8255382e+09]
# dis_els:0.0, dis_mod:[89638072.], availability:[89638072.]
# dis_els:0.0, dis_mod:[2.9652543e+10], availability:[2.9652543e+10]
# dis_els:0.0, dis_mod:[68969152.], availability:[68969152.]
# dis_els:0.0, dis_mod:[8.5713325e+08], availability:[8.5713325e+08]
# dis_els:0.0, dis_mod:[48419476.], availability:[48419476.]
# dis_els:0.0, dis_mod:[3.0476334e+09], availability:[3.0476334e+09]
# dis_els:142311312.28125, dis_mod:[66265424.], availability:[2.0857674e+08]
# dis_els:0.0, dis_mod:[1.3779795e+09], availability:[1.3779795e+09]
# dis_els:0.0, dis_mod:[43959056.], availability:[43959056.]
# dis_els:0.0, dis_mod:[2.2121896e+08], availability:[2.2121896e+08]
# dis_els:0.0, dis_mod:[1.1906191e+09], availability:[1.1906191e+09]
# dis_els:0.0, dis_mod:[3.670683e+08], availability:[3.670683e+08]
# dis_els:0.0, dis_mod:[1.6604492e+09], availability:[1.6604492e+09]
# dis_els:0.0, dis_mod:[1.7475278e+08], availability:[1.7475278e+08]
# dis_els:0.0, dis_mod:[66349560.], availability:[66349560.]
# dis_els:0.0, dis_mod:[40713512.], availability:[40713512.]
# dis_els:0.0, dis_mod:[2.936458e+08], availability:[2.936458e+08]
# dis_els:0.0, dis_mod:[2.0057982e+08], availability:[2.0057982e+08]
# dis_els:0.0, dis_mod:[49358788.], availability:[49358788.]
# dis_els:0.0, dis_mod:[49926980.], availability:[49926980.]
# dis_els:0.0, dis_mod:[3.6653942e+09], availability:[3.6653942e+09]
# dis_els:57826133.455078125, dis_mod:[1.13018824e+08], availability:[1.7084496e+08]
# dis_els:0.0, dis_mod:[9.682586e+08], availability:[9.682586e+08]
# city_num, riv_num, 3, 480
# rate, discharge [0.9980339], [1.6411617e+10]
# no shortage
# consumption: [1.4511575e+10]
# discharge: [1.6411617e+10]
# --------------------------------------
# city_num, riv_num, 52, 480
# rate, discharge [0.00140544], [58557960.]
# no shortage
# consumption: [6448163.]
# discharge: [58557960.]
# --------------------------------------
# city_num, riv_num, 85, 480
# rate, discharge [0.77816844], [27389676.]
# shortage
# consumption: [27389676.]
# discharge: [27389676.]
# --------------------------------------
# city_num, riv_num, 144, 480
# rate, discharge [1.], [2.6609818e+08]
# shortage
# consumption: [2.6609818e+08]
# discharge: [2.6609818e+08]
# --------------------------------------
# city_num, riv_num, 612, 480
# rate, discharge [1.], [35259608.]
# shortage
# consumption: [35259608.]
# discharge: [35259608.]
# --------------------------------------
# city_num, riv_num, 618, 480
# rate, discharge [1.], [2.0830385e+09]
# no shortage
# consumption: [7.634149e+08]
# discharge: [2.0830385e+09]
# --------------------------------------
# city_num, riv_num, 967, 480
# rate, discharge [1.], [5.8605766e+08]
# no shortage
# consumption: [5.757807e+08]
# discharge: [5.8605766e+08]
# --------------------------------------
# city_num, riv_num, 1200, 480
# rate, discharge [1.], [38287776.]
# shortage
# consumption: [38287776.]
# discharge: [38287776.]
# --------------------------------------
# city_num, riv_num, 1299, 480
# rate, discharge [1.], [7.0344256e+08]
# no shortage
# consumption: [3.8522854e+08]
# discharge: [7.0344256e+08]
# --------------------------------------
# city_num, riv_num, 1376, 480
# rate, discharge [1.], [3.936216e+09]
# no shortage
# consumption: [3.6483702e+08]
# discharge: [3.936216e+09]
# --------------------------------------
# city_num, riv_num, 1687, 480
# rate, discharge [1.], [2.7818566e+08]
# shortage
# consumption: [2.7818566e+08]
# discharge: [2.7818566e+08]
# --------------------------------------
# **********rivnum480.0: calculation done***************
# --------------------------------------
# 3 True [1.6411617e+10] [1.4511575e+10] [1.6411617e+10] ['Done', 'Done', 'Done', 'Done', False, 'Done', 'Done', 'Done', False, 'Done'] [  52   85  144  612  618  967 1200 1299 1376 1687]
# 52 Done [58557960.] [6448163.] [58557960.] [] []
# 85 Done [27389676.] [27389676.] [27389676.] [] []
# 144 Done [2.6609818e+08] [2.6609818e+08] [2.6609818e+08] [] []
# 612 Done [35259608.] [35259608.] [35259608.] [] []
# 618 False [2.0830385e+09] [7.634149e+08] [2.0830385e+09] ['Done', 'Done'] [  52 1200]
# 967 Done [5.8605766e+08] [5.757807e+08] [5.8605766e+08] [] []
# 1200 Done [38287776.] [38287776.] [38287776.] [] []
# 1299 Done [7.0344256e+08] [3.8522854e+08] [7.0344256e+08] [] []
# 1376 False [3.936216e+09] [3.6483702e+08] [3.936216e+09] ['Done', 'Done'] [ 967 1299]
# 1687 Done [2.7818566e+08] [2.7818566e+08] [2.7818566e+08] [] []
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 3 True [1.6411617e+10] [1.4511575e+10] [1.6411617e+10] ['Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done'] [  52   85  144  612  618  967 1200 1299 1376 1687]
# 52 Done [58557960.] [6448163.] [58557960.] [] []
# 85 Done [27389676.] [27389676.] [27389676.] [] []
# 144 Done [2.6609818e+08] [2.6609818e+08] [2.6609818e+08] [] []
# 612 Done [35259608.] [35259608.] [35259608.] [] []
# 618 Done [2.0383026e+09] [7.634149e+08] [1.9861928e+09] ['Done', 'Done'] [  52 1200]
# 967 Done [5.8605766e+08] [5.757807e+08] [5.8605766e+08] [] []
# 1200 Done [38287776.] [38287776.] [38287776.] [] []
# 1299 Done [7.0344256e+08] [3.8522854e+08] [7.0344256e+08] [] []
# 1376 Done [2.975207e+09] [3.6483702e+08] [2.646716e+09] ['Done', 'Done'] [ 967 1299]
# 1687 Done [2.7818566e+08] [2.7818566e+08] [2.7818566e+08] [] []
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 3 Done [1.4676432e+10] [1.4511575e+10] [1.0791174e+10] ['Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done'] [  52   85  144  612  618  967 1200 1299 1376 1687]
# 52 Done [58557960.] [6448163.] [58557960.] [] []
# 85 Done [27389676.] [27389676.] [27389676.] [] []
# 144 Done [2.6609818e+08] [2.6609818e+08] [2.6609818e+08] [] []
# 612 Done [35259608.] [35259608.] [35259608.] [] []
# 618 Done [2.0383026e+09] [7.634149e+08] [1.9861928e+09] ['Done', 'Done'] [  52 1200]
# 967 Done [5.8605766e+08] [5.757807e+08] [5.8605766e+08] [] []
# 1200 Done [38287776.] [38287776.] [38287776.] [] []
# 1299 Done [7.0344256e+08] [3.8522854e+08] [7.0344256e+08] [] []
# 1376 Done [2.975207e+09] [3.6483702e+08] [2.646716e+09] ['Done', 'Done'] [ 967 1299]
# 1687 Done [2.7818566e+08] [2.7818566e+08] [2.7818566e+08] [] []
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# all_done
# dis_els:24007877.138671875, dis_mod:[1.4676432e+10], availability:[1.470044e+10]
# dis_els:39753926820.0, dis_mod:[58557960.], availability:[3.9812485e+10]
# dis_els:30463943.458007812, dis_mod:[27389676.], availability:[57853620.]
# dis_els:0.0, dis_mod:[2.6609818e+08], availability:[2.6609818e+08]
# dis_els:0.0, dis_mod:[35259608.], availability:[35259608.]
# dis_els:0.0, dis_mod:[2.0383026e+09], availability:[2.0383026e+09]
# dis_els:0.0, dis_mod:[5.8605766e+08], availability:[5.8605766e+08]
# dis_els:0.0, dis_mod:[38287776.], availability:[38287776.]
# dis_els:0.0, dis_mod:[7.0344256e+08], availability:[7.0344256e+08]
# dis_els:0.0, dis_mod:[2.975207e+09], availability:[2.975207e+09]
# dis_els:0.0, dis_mod:[2.7818566e+08], availability:[2.7818566e+08]
# **********rivnum5438.0: calculation done***************
# --------------------------------------
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# all_done
# **********rivnum164.0: calculation done***************
# --------------------------------------
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# all_done
# city_num, riv_num, 5, 5
# rate, discharge [1.], [2.05752e+09]
# shortage
# consumption: [2.05752e+09]
# discharge: [2.05752e+09]
# --------------------------------------
# city_num, riv_num, 94, 5
# rate, discharge [1.], [58968220.]
# shortage
# consumption: [58968220.]
# discharge: [58968220.]
# --------------------------------------
# city_num, riv_num, 119, 5
# rate, discharge [1.], [1.1611644e+08]
# shortage
# consumption: [1.1611644e+08]
# discharge: [1.1611644e+08]
# --------------------------------------
# city_num, riv_num, 140, 5
# rate, discharge [1.], [5.6439803e+09]
# no shortage
# consumption: [2.3286392e+09]
# discharge: [5.6439803e+09]
# --------------------------------------
# city_num, riv_num, 155, 5
# rate, discharge [1.], [3.6568593e+11]
# no shortage
# consumption: [2.391847e+09]
# discharge: [3.6568593e+11]
# --------------------------------------
# city_num, riv_num, 196, 5
# rate, discharge [1.], [1.5485046e+09]
# shortage
# consumption: [1.5485046e+09]
# discharge: [1.5485046e+09]
# --------------------------------------
# city_num, riv_num, 257, 5
# rate, discharge [0.4461243], [3.6329418e+08]
# shortage
# consumption: [3.6329418e+08]
# discharge: [3.6329418e+08]
# --------------------------------------
# city_num, riv_num, 343, 5
# rate, discharge [1.], [1.3096351e+12]
# no shortage
# consumption: [1.2335753e+09]
# discharge: [1.3096351e+12]
# --------------------------------------
# city_num, riv_num, 550, 5
# rate, discharge [0.01363457], [40251856.]
# no shortage
# consumption: [11621661.]
# discharge: [40251856.]
# --------------------------------------
# city_num, riv_num, 597, 5
# rate, discharge [1.], [60878728.]
# shortage
# consumption: [60878728.]
# discharge: [60878728.]
# --------------------------------------
# city_num, riv_num, 629, 5
# rate, discharge [1.], [50348384.]
# shortage
# consumption: [50348384.]
# discharge: [50348384.]
# --------------------------------------
# city_num, riv_num, 689, 5
# rate, discharge [1.], [1.1126776e+09]
# no shortage
# consumption: [7.0083974e+08]
# discharge: [1.1126776e+09]
# --------------------------------------
# city_num, riv_num, 789, 5
# rate, discharge [1.], [1.4256282e+08]
# shortage
# consumption: [1.4256282e+08]
# discharge: [1.4256282e+08]
# --------------------------------------
# city_num, riv_num, 803, 5
# rate, discharge [1.], [1.5353775e+09]
# no shortage
# consumption: [5.933191e+08]
# discharge: [1.5353775e+09]
# --------------------------------------
# city_num, riv_num, 836, 5
# rate, discharge [1.], [3.5238752e+08]
# shortage
# consumption: [3.5238752e+08]
# discharge: [3.5238752e+08]
# --------------------------------------
# city_num, riv_num, 837, 5
# rate, discharge [1.], [1.7370333e+10]
# no shortage
# consumption: [5.235159e+08]
# discharge: [1.7370333e+10]
# --------------------------------------
# city_num, riv_num, 866, 5
# rate, discharge [1.], [2.4081056e+10]
# no shortage
# consumption: [6.0273574e+08]
# discharge: [2.4081056e+10]
# --------------------------------------
# city_num, riv_num, 1235, 5
# rate, discharge [1.], [1.6543034e+08]
# shortage
# consumption: [1.6543034e+08]
# discharge: [1.6543034e+08]
# --------------------------------------
# city_num, riv_num, 1327, 5
# rate, discharge [1.], [6.8027986e+09]
# no shortage
# consumption: [3.6748995e+08]
# discharge: [6.8027986e+09]
# --------------------------------------
# city_num, riv_num, 1329, 5
# rate, discharge [1.], [1.1945544e+12]
# no shortage
# consumption: [3.6467834e+08]
# discharge: [1.1945544e+12]
# --------------------------------------
# city_num, riv_num, 1361, 5
# rate, discharge [1.], [48674496.]
# shortage
# consumption: [48674496.]
# discharge: [48674496.]
# --------------------------------------
# city_num, riv_num, 1411, 5
# rate, discharge [1.], [84030664.]
# shortage
# consumption: [84030664.]
# discharge: [84030664.]
# --------------------------------------
# city_num, riv_num, 1453, 5
# rate, discharge [1.], [88369600.]
# shortage
# consumption: [88369600.]
# discharge: [88369600.]
# --------------------------------------
# city_num, riv_num, 1500, 5
# rate, discharge [1.], [1.4562749e+08]
# shortage
# consumption: [1.4562749e+08]
# discharge: [1.4562749e+08]
# --------------------------------------
# city_num, riv_num, 1530, 5
# rate, discharge [1.], [75120336.]
# shortage
# consumption: [75120336.]
# discharge: [75120336.]
# --------------------------------------
# city_num, riv_num, 1573, 5
# rate, discharge [1.], [5.496378e+08]
# no shortage
# consumption: [3.110719e+08]
# discharge: [5.496378e+08]
# --------------------------------------
# city_num, riv_num, 1648, 5
# rate, discharge [1.], [6.761248e+08]
# no shortage
# consumption: [2.5480466e+08]
# discharge: [6.761248e+08]
# --------------------------------------
# city_num, riv_num, 1720, 5
# rate, discharge [1.], [61346924.]
# shortage
# consumption: [61346924.]
# discharge: [61346924.]
# --------------------------------------
# **********rivnum5.0: calculation done***************
# --------------------------------------
# 5 Done [2.05752e+09] [2.05752e+09] [2.05752e+09] [] []
# city_num, riv_num, 246, 11
# rate, discharge [0.18549271], [24620652.]
# shortage
# consumption: [24620652.]
# discharge: [24620652.]
# --------------------------------------
# city_num, riv_num, 275, 11
# rate, discharge [1.], [7.8557413e+11]
# no shortage
# consumption: [1.6360212e+09]
# discharge: [7.8557413e+11]
# --------------------------------------
# city_num, riv_num, 279, 11
# rate, discharge [1.], [50448828.]
# shortage
# consumption: [50448828.]
# discharge: [50448828.]
# --------------------------------------
# city_num, riv_num, 316, 11
# rate, discharge [1.], [6.4264786e+10]
# no shortage
# consumption: [1.3259308e+09]
# discharge: [6.4264786e+10]
# --------------------------------------
# city_num, riv_num, 357, 11
# rate, discharge [1.], [1.5562142e+10]
# no shortage
# consumption: [1.2518785e+09]
# discharge: [1.5562142e+10]
# --------------------------------------
# city_num, riv_num, 395, 11
# rate, discharge [1.], [1.8765756e+10]
# no shortage
# consumption: [1.1444358e+09]
# discharge: [1.8765756e+10]
# --------------------------------------
# city_num, riv_num, 403, 11
# rate, discharge [1.], [6.90336e+11]
# no shortage
# consumption: [1.0965263e+09]
# discharge: [6.90336e+11]
# --------------------------------------
# city_num, riv_num, 424, 11
# rate, discharge [1.], [5.1197455e+09]
# no shortage
# consumption: [1.05691776e+09]
# discharge: [5.1197455e+09]
# --------------------------------------
# city_num, riv_num, 428, 11
# rate, discharge [1.], [1.4288733e+08]
# shortage
# consumption: [1.4288733e+08]
# discharge: [1.4288733e+08]
# --------------------------------------
# city_num, riv_num, 433, 11
# rate, discharge [1.], [3.2230484e+11]
# no shortage
# consumption: [1.05146426e+09]
# discharge: [3.2230484e+11]
# --------------------------------------
# city_num, riv_num, 446, 11
# rate, discharge [1.], [3.5933962e+10]
# no shortage
# consumption: [1.017873e+09]
# discharge: [3.5933962e+10]
# --------------------------------------
# city_num, riv_num, 452, 11
# rate, discharge [1.], [1.0852888e+08]
# shortage
# consumption: [1.0852888e+08]
# discharge: [1.0852888e+08]
# --------------------------------------
# city_num, riv_num, 491, 11
# rate, discharge [1.], [28532312.]
# shortage
# consumption: [28532312.]
# discharge: [28532312.]
# --------------------------------------
# city_num, riv_num, 505, 11
# rate, discharge [1.], [3.4131087e+11]
# no shortage
# consumption: [9.3575443e+08]
# discharge: [3.4131087e+11]
# --------------------------------------
# city_num, riv_num, 514, 11
# rate, discharge [1.], [1.54234e+09]
# no shortage
# consumption: [9.088925e+08]
# discharge: [1.54234e+09]
# --------------------------------------
# city_num, riv_num, 519, 11
# rate, discharge [1.], [5.2533146e+10]
# no shortage
# consumption: [8.9573075e+08]
# discharge: [5.2533146e+10]
# --------------------------------------
# city_num, riv_num, 521, 11
# rate, discharge [1.], [31697172.]
# shortage
# consumption: [31697172.]
# discharge: [31697172.]
# --------------------------------------
# city_num, riv_num, 523, 11
# rate, discharge [1.], [3.3621195e+10]
# no shortage
# consumption: [8.934799e+08]
# discharge: [3.3621195e+10]
# --------------------------------------
# city_num, riv_num, 539, 11
# rate, discharge [1.], [27063400.]
# shortage
# consumption: [27063400.]
# discharge: [27063400.]
# --------------------------------------
# city_num, riv_num, 549, 11
# rate, discharge [1.], [3.6454122e+08]
# shortage
# consumption: [3.6454122e+08]
# discharge: [3.6454122e+08]
# --------------------------------------
# city_num, riv_num, 585, 11
# rate, discharge [1.], [3.205879e+10]
# no shortage
# consumption: [9.006972e+08]
# discharge: [3.205879e+10]
# --------------------------------------
# city_num, riv_num, 593, 11
# rate, discharge [1.], [2.70844e+09]
# no shortage
# consumption: [8.302479e+08]
# discharge: [2.70844e+09]
# --------------------------------------
# city_num, riv_num, 601, 11
# rate, discharge [1.], [8304872.]
# shortage
# consumption: [8304872.]
# discharge: [8304872.]
# --------------------------------------
# city_num, riv_num, 603, 11
# rate, discharge [1.], [30528670.]
# shortage
# consumption: [30528670.]
# discharge: [30528670.]
# --------------------------------------
# city_num, riv_num, 617, 11
# rate, discharge [1.], [1.5511278e+10]
# no shortage
# consumption: [7.566995e+08]
# discharge: [1.5511278e+10]
# --------------------------------------
# city_num, riv_num, 622, 11
# rate, discharge [1.], [1.4558452e+11]
# no shortage
# consumption: [7.493082e+08]
# discharge: [1.4558452e+11]
# --------------------------------------
# city_num, riv_num, 632, 11
# rate, discharge [1.], [21422460.]
# shortage
# consumption: [21422460.]
# discharge: [21422460.]
# --------------------------------------
# city_num, riv_num, 639, 11
# rate, discharge [1.], [45849724.]
# shortage
# consumption: [45849724.]
# discharge: [45849724.]
# --------------------------------------
# city_num, riv_num, 657, 11
# rate, discharge [1.], [2.3090645e+08]
# shortage
# consumption: [2.3090645e+08]
# discharge: [2.3090645e+08]
# --------------------------------------
# city_num, riv_num, 663, 11
# rate, discharge [1.], [5.6403604e+11]
# no shortage
# consumption: [7.39617e+08]
# discharge: [5.6403604e+11]
# --------------------------------------
# city_num, riv_num, 672, 11
# rate, discharge [1.], [36975336.]
# shortage
# consumption: [36975336.]
# discharge: [36975336.]
# --------------------------------------
# city_num, riv_num, 690, 11
# rate, discharge [1.], [1.01852744e+08]
# shortage
# consumption: [1.01852744e+08]
# discharge: [1.01852744e+08]
# --------------------------------------
# city_num, riv_num, 700, 11
# rate, discharge [1.], [1.7961192e+08]
# shortage
# consumption: [1.7961192e+08]
# discharge: [1.7961192e+08]
# --------------------------------------
# city_num, riv_num, 701, 11
# rate, discharge [1.], [8.6692274e+10]
# no shortage
# consumption: [6.712514e+08]
# discharge: [8.6692274e+10]
# --------------------------------------
# city_num, riv_num, 703, 11
# rate, discharge [1.], [1.6307874e+08]
# shortage
# consumption: [1.6307874e+08]
# discharge: [1.6307874e+08]
# --------------------------------------
# city_num, riv_num, 721, 11
# rate, discharge [1.], [2.5993526e+09]
# no shortage
# consumption: [6.688886e+08]
# discharge: [2.5993526e+09]
# --------------------------------------
# city_num, riv_num, 730, 11
# rate, discharge [1.], [1.4299098e+09]
# no shortage
# consumption: [6.429648e+08]
# discharge: [1.4299098e+09]
# --------------------------------------
# city_num, riv_num, 739, 11
# rate, discharge [1.], [4.1985225e+10]
# no shortage
# consumption: [6.3358534e+08]
# discharge: [4.1985225e+10]
# --------------------------------------
# city_num, riv_num, 748, 11
# rate, discharge [1.], [4.340341e+08]
# shortage
# consumption: [4.340341e+08]
# discharge: [4.340341e+08]
# --------------------------------------
# city_num, riv_num, 758, 11
# rate, discharge [1.], [18851116.]
# shortage
# consumption: [18851116.]
# discharge: [18851116.]
# --------------------------------------
# city_num, riv_num, 773, 11
# rate, discharge [1.], [5.534151e+11]
# no shortage
# consumption: [6.0707814e+08]
# discharge: [5.534151e+11]
# --------------------------------------
# city_num, riv_num, 775, 11
# rate, discharge [1.], [7.422632e+10]
# no shortage
# consumption: [6.183208e+08]
# discharge: [7.422632e+10]
# --------------------------------------
# city_num, riv_num, 787, 11
# rate, discharge [1.], [66711540.]
# shortage
# consumption: [66711540.]
# discharge: [66711540.]
# --------------------------------------
# city_num, riv_num, 805, 11
# rate, discharge [1.], [6.6508856e+09]
# no shortage
# consumption: [6.1411315e+08]
# discharge: [6.6508856e+09]
# --------------------------------------
# city_num, riv_num, 819, 11
# rate, discharge [1.], [7.696764e+08]
# no shortage
# consumption: [6.0721414e+08]
# discharge: [7.696764e+08]
# --------------------------------------
# city_num, riv_num, 824, 11
# rate, discharge [1.], [1.3389175e+09]
# no shortage
# consumption: [5.1132067e+08]
# discharge: [1.3389175e+09]
# --------------------------------------
# city_num, riv_num, 826, 11
# rate, discharge [1.], [3.947734e+08]
# shortage
# consumption: [3.947734e+08]
# discharge: [3.947734e+08]
# --------------------------------------
# city_num, riv_num, 829, 11
# rate, discharge [1.], [6.908988e+09]
# no shortage
# consumption: [6.350197e+08]
# discharge: [6.908988e+09]
# --------------------------------------
# city_num, riv_num, 835, 11
# rate, discharge [1.], [42555748.]
# shortage
# consumption: [42555748.]
# discharge: [42555748.]
# --------------------------------------
# city_num, riv_num, 838, 11
# rate, discharge [1.], [18695906.]
# shortage
# consumption: [18695906.]
# discharge: [18695906.]
# --------------------------------------
# city_num, riv_num, 847, 11
# rate, discharge [1.], [2.6010214e+09]
# no shortage
# consumption: [5.720954e+08]
# discharge: [2.6010214e+09]
# --------------------------------------
# city_num, riv_num, 851, 11
# rate, discharge [1.], [86560680.]
# shortage
# consumption: [86560680.]
# discharge: [86560680.]
# --------------------------------------
# city_num, riv_num, 865, 11
# rate, discharge [1.], [1.05839416e+08]
# shortage
# consumption: [1.05839416e+08]
# discharge: [1.05839416e+08]
# --------------------------------------
# city_num, riv_num, 880, 11
# rate, discharge [1.], [1.2247048e+10]
# no shortage
# consumption: [5.784775e+08]
# discharge: [1.2247048e+10]
# --------------------------------------
# city_num, riv_num, 895, 11
# rate, discharge [1.], [1.0821507e+10]
# no shortage
# consumption: [5.485434e+08]
# discharge: [1.0821507e+10]
# --------------------------------------
# city_num, riv_num, 919, 11
# rate, discharge [1.], [1.19760984e+08]
# shortage
# consumption: [1.19760984e+08]
# discharge: [1.19760984e+08]
# --------------------------------------
# city_num, riv_num, 971, 11
# rate, discharge [1.], [1.4259184e+10]
# no shortage
# consumption: [5.2151117e+08]
# discharge: [1.4259184e+10]
# --------------------------------------
# city_num, riv_num, 972, 11
# rate, discharge [1.], [5.778503e+09]
# no shortage
# consumption: [5.7076134e+08]
# discharge: [5.778503e+09]
# --------------------------------------
# city_num, riv_num, 982, 11
# rate, discharge [0.09645622], [47837332.]
# no shortage
# consumption: [47837332.]
# discharge: [47837332.]
# --------------------------------------
# city_num, riv_num, 1022, 11
# rate, discharge [1.], [2.0157998e+09]
# no shortage
# consumption: [4.685678e+08]
# discharge: [2.0157998e+09]
# --------------------------------------
# city_num, riv_num, 1023, 11
# rate, discharge [1.], [4.727974e+09]
# no shortage
# consumption: [4.8847277e+08]
# discharge: [4.727974e+09]
# --------------------------------------
# city_num, riv_num, 1028, 11
# rate, discharge [1.], [2.7380375e+09]
# no shortage
# consumption: [4.7804995e+08]
# discharge: [2.7380375e+09]
# --------------------------------------
# city_num, riv_num, 1029, 11
# rate, discharge [1.], [3.7614044e+09]
# no shortage
# consumption: [4.722453e+08]
# discharge: [3.7614044e+09]
# --------------------------------------
# city_num, riv_num, 1048, 11
# rate, discharge [1.], [8.840293e+09]
# no shortage
# consumption: [5.3234867e+08]
# discharge: [8.840293e+09]
# --------------------------------------
# city_num, riv_num, 1059, 11
# rate, discharge [1.], [1.2289695e+09]
# no shortage
# consumption: [4.5431616e+08]
# discharge: [1.2289695e+09]
# --------------------------------------
# city_num, riv_num, 1082, 11
# rate, discharge [1.], [15417884.]
# shortage
# consumption: [15417884.]
# discharge: [15417884.]
# --------------------------------------
# city_num, riv_num, 1087, 11
# rate, discharge [1.], [86743328.]
# shortage
# consumption: [86743328.]
# discharge: [86743328.]
# --------------------------------------
# city_num, riv_num, 1090, 11
# rate, discharge [1.], [7.280578e+10]
# no shortage
# consumption: [4.390641e+08]
# discharge: [7.280578e+10]
# --------------------------------------
# city_num, riv_num, 1110, 11
# rate, discharge [0.6625924], [24752718.]
# shortage
# consumption: [24752718.]
# discharge: [24752718.]
# --------------------------------------
# city_num, riv_num, 1124, 11
# rate, discharge [1.], [5.0415107e+08]
# no shortage
# consumption: [4.1999194e+08]
# discharge: [5.0415107e+08]
# --------------------------------------
# city_num, riv_num, 1133, 11
# rate, discharge [1.], [69493872.]
# shortage
# consumption: [69493872.]
# discharge: [69493872.]
# --------------------------------------
# city_num, riv_num, 1161, 11
# rate, discharge [1.], [17920292.]
# shortage
# consumption: [17920292.]
# discharge: [17920292.]
# --------------------------------------
# city_num, riv_num, 1180, 11
# rate, discharge [1.], [4.9264865e+09]
# no shortage
# consumption: [4.8112704e+08]
# discharge: [4.9264865e+09]
# --------------------------------------
# city_num, riv_num, 1183, 11
# rate, discharge [1.], [1.2791635e+10]
# no shortage
# consumption: [4.4217453e+08]
# discharge: [1.2791635e+10]
# --------------------------------------
# city_num, riv_num, 1197, 11
# rate, discharge [1.], [15198480.]
# shortage
# consumption: [15198480.]
# discharge: [15198480.]
# --------------------------------------
# city_num, riv_num, 1209, 11
# rate, discharge [1.], [3.2311427e+08]
# shortage
# consumption: [3.2311427e+08]
# discharge: [3.2311427e+08]
# --------------------------------------
# city_num, riv_num, 1221, 11
# rate, discharge [1.], [6.288791e+08]
# no shortage
# consumption: [4.0091834e+08]
# discharge: [6.288791e+08]
# --------------------------------------
# city_num, riv_num, 1256, 11
# rate, discharge [1.], [3.9284097e+10]
# no shortage
# consumption: [4.12484e+08]
# discharge: [3.9284097e+10]
# --------------------------------------
# city_num, riv_num, 1263, 11
# rate, discharge [1.], [6.3332416e+08]
# no shortage
# consumption: [3.91769e+08]
# discharge: [6.3332416e+08]
# --------------------------------------
# city_num, riv_num, 1275, 11
# rate, discharge [1.], [3.3414085e+10]
# no shortage
# consumption: [4.019423e+08]
# discharge: [3.3414085e+10]
# --------------------------------------
# city_num, riv_num, 1276, 11
# rate, discharge [1.], [4.591282e+09]
# no shortage
# consumption: [4.0190944e+08]
# discharge: [4.591282e+09]
# --------------------------------------
# city_num, riv_num, 1310, 11
# rate, discharge [1.], [4.83045e+09]
# no shortage
# consumption: [3.966448e+08]
# discharge: [4.83045e+09]
# --------------------------------------
# city_num, riv_num, 1311, 11
# rate, discharge [1.], [4.1495357e+09]
# no shortage
# consumption: [3.9301088e+08]
# discharge: [4.1495357e+09]
# --------------------------------------
# city_num, riv_num, 1339, 11
# rate, discharge [1.], [50000100.]
# shortage
# consumption: [50000100.]
# discharge: [50000100.]
# --------------------------------------
# city_num, riv_num, 1399, 11
# rate, discharge [1.], [3.16785e+08]
# shortage
# consumption: [3.16785e+08]
# discharge: [3.16785e+08]
# --------------------------------------
# city_num, riv_num, 1418, 11
# rate, discharge [1.], [1.03624376e+08]
# shortage
# consumption: [1.03624376e+08]
# discharge: [1.03624376e+08]
# --------------------------------------
# city_num, riv_num, 1426, 11
# rate, discharge [1.], [3.5333907e+08]
# shortage
# consumption: [3.5333907e+08]
# discharge: [3.5333907e+08]
# --------------------------------------
# city_num, riv_num, 1457, 11
# rate, discharge [1.], [30760166.]
# shortage
# consumption: [30760166.]
# discharge: [30760166.]
# --------------------------------------
# city_num, riv_num, 1462, 11
# rate, discharge [1.], [2.6254427e+08]
# shortage
# consumption: [2.6254427e+08]
# discharge: [2.6254427e+08]
# --------------------------------------
# city_num, riv_num, 1469, 11
# rate, discharge [1.], [3.0249382e+10]
# no shortage
# consumption: [3.8701238e+08]
# discharge: [3.0249382e+10]
# --------------------------------------
# city_num, riv_num, 1479, 11
# rate, discharge [1.], [19625378.]
# shortage
# consumption: [19625378.]
# discharge: [19625378.]
# --------------------------------------
# city_num, riv_num, 1508, 11
# rate, discharge [1.], [1.0316792e+10]
# no shortage
# consumption: [3.4438765e+08]
# discharge: [1.0316792e+10]
# --------------------------------------
# city_num, riv_num, 1520, 11

# %%
######################################################
# modify duplicate city
#####################################################

duplicates_citynum = [3, 35, 52, 73, 77, 85, 97, 108, 128, 129, 167, 246, 335, 345, 350, 486, 490, 502, 508, 543, 550, 627, 654, 658, 764, 790, 1018, 1044, 1045, 1098, 1110, 1169, 1202, 1248, 1280, 1416, 1450, 1718]
for city_num in duplicates_citynum:
    city_num = int(city_num)
    ctymsk_path = f'{msk_dir}/city_{city_num:08}.gl5'
    prf_path = f'{prf_dir}/vld_cty_/city_{city_num:08}.gl5'
    ctymsk = np.fromfile(ctymsk_path, dtype='float32').reshape(2160, 4320)
    prf = np.fromfile(prf_path, dtype='float32').reshape(2160, 4320)
    
    city_rivnum = np.unique(rivnum_gl5[prf==1])
    print(city_rivnum)
    rivnum_keys = list(discharge_dup_dct[city_num].keys())
                            
    dis_els = np.sum(rivout_gl5[(prf==1) & (rivnum_gl5!=riv_num)])* 60 * 60 * 24 * 365 / (1000) # m3/year
    dis_mod = result_dict_mod[city_num][0]

    city_rivnum = np.unique(rivnum
    riv_num = int(float(riv_num))
    dis_mod = discharge_dup_dct[city_num][riv_num]
    pot_mod = potential_dup_dct[city_num][riv_num]
    
    if dis_els:
        availability = dis_els + dis_mod
    print(f'dis_els:{dis_els}, dis_mod:{dis_mod}, availability:{availability}')
    
    df_new.loc[df_new['index'] == city_num, 'ava'] = availability
    df_new.loc[df_new['index'] == city_num, 'mpcy'] = availability/df_new.loc[df_new['index'] == city_num, 'pop']
    
df_new.head(10)

# %%
######################################################
# pandas dfを保存
#####################################################
h08dir = '/mnt/c/Users/tsimk/Downloads/dotfiles/h08'
updown_path = f'{h08dir}/wsi/dat/potential/updown_potential.txt'
df_new.to_csv(updown_path, sep='|', index=False)

# %%
######################################################
# pandas dfを読み込み
#####################################################
df_new = pd.read_csv(updown_path, delimiter='|', header=None)
df_new.columns = df_new.iloc[0]
df_new = df_new[1:].reset_index(drop=True)
df_new = df_new.infer_objects()
df_new.head(10)
# Out:
# 0  index   flag                rate        wup          pop  \
# 0      1  False  0.8633253630951112  36859.626   31821850.0
# 1      2  False  1.0032005337482284  21987.895   22058268.0
# 2      3  False   0.715759664776193  20314.309   14540163.0
# 3      4  False  1.0020568930897795  20136.681   20178100.0
# 4      5  False  0.4921207775782957  19659.808    9675000.0
# 5      6  False  0.4892318742858954  19312.646    9448362.0
# 6      7  False  0.4709559275549676  18365.262    8649229.0
# 7      8  False  0.7832002814418451  18257.413   14299211.0
# 8      9  False   1.006426350884948  16899.015   17007614.0
# 9     10  False  0.8239520931860906  16441.252   13546804.0
# 10    11   True  1.0119829983116029  14730.537   14907053.0
# 11    12  False  0.9315084349703856  14245.871   13270149.0
# 12    13  False  1.0331027413235554  14002.798   14466329.0
# 13    14  False    0.92071970937979  12611.924   11612047.0
# 14    15  False  1.0015019604867268  12584.885   12603787.0
# 15    16  False  0.7696195471042075  12373.884    9523183.0
# 16    17  False  0.4335775929098249  12160.151    5272369.0
# 17    18  False   1.041864144668685  11887.189   12384836.0
# 18    19  False  1.0102298489939678  11461.264   11578511.0
# 19    20  False  0.4916269309647822  11243.667    5527689.5
# 20    21  False  0.8403992192057489  10460.118    8790675.0
# 21    22   True  0.8945989065222693  10441.182    9340670.0
# 22    23  False  1.0119857597592263  10278.197   10401389.0
# 23    24  False  0.6909698270043498  10222.916    7063726.5
# 24    25  False   0.574565944136773  10150.076    5831888.0
# 25    26  False   1.063070351350979   9796.045   10413885.0
# 26    27  False  1.0356745292932508   9625.579    9968967.0
# 27    28  False  0.7659907246820477   9381.673    7186274.5
# 42              China, Hong Kong SAR
# 43                             China
# 44                             Chile
# 45                             India
# 46                          Viet Nam
# 47                             China
# 48                             China
# 49                          Malaysia
# 50                             Spain
# 51                             China
# 52                              Iraq
# 53                             China
# 54                             Japan
# 55          United States of America
# 56                            Canada
# 57          United States of America
# 58                            Brazil
# 59                            Angola
#
# 0                                   cityname                       12region
# 0                                      Tokyo                      East Asia
# 1                                      Delhi                     South Asia
# 2                                   Shanghai                      East Asia
# 3             Ciudad de México (Mexico City)                Central America
# 4                                  São Paulo                  South America
# 5                       Kinki M.M.A. (Osaka)                      East Asia
# 6                            New York-Newark                  North America
# 7                            Mumbai (Bombay)                     South Asia
# 8                         Al-Qahirah (Cairo)                Northern Africa
# 9                                    Beijing                      East Asia
# 10                                     Dhaka                     South Asia
# 11                              Buenos Aires                  South America
# 12                        Kolkata (Calcutta)                     South Asia
# 13                                   Karachi                     South Asia
# 14                                  Istanbul                    Middle East
# 15                            Rio de Janeiro                  South America
# 16          Los Angeles-Long Beach-Santa Ana                  North America
# 17                                    Manila                 Southeast Asia
# 18                           Moskva (Moscow)  Eastern Europe & Central Asia
# 19                                 Chongqing                      East Asia
# 20                                     Paris                    West Europe
# 21                                     Lagos                Southern Africa
# 22                      Guangzhou, Guangdong                      East Asia
# 23                                  Shenzhen                      East Asia
# 24                                   Tianjin                      East Asia
# 25                                     Seoul                      East Asia
# 26                                   Jakarta                 Southeast Asia
# 27                                  Kinshasa                Southern Africa
# 28                    Chukyo M.M.A. (Nagoya)                      East Asia
# 29                                      Lima                  South America
# 30                                   Chicago                  North America
# 31                          Chennai (Madras)                     South Asia
# 32                                    Lahore                     South Asia
# 33                                    Bogotá                  South America
# 34                                 Bangalore                     South Asia
# 35                      Krung Thep (Bangkok)                 Southeast Asia
# 36                                    Tehran                    Middle East
# 37                                    London                    West Europe
# 38                                   Chengdu                      East Asia
# 39                                 Hyderabad                     South Asia
# 40                                     Wuhan                      East Asia
# 41                                  Dongguan                      East Asia
# 42                                 Hong Kong                      East Asia
# 43                                    Foshan                      East Asia
# 44                                  Santiago                  South America
# 45                                 Ahmadabad                     South Asia
# 46  Thành Pho Ho Chí Minh (Ho Chi Minh City)                 Southeast Asia
# 47                          Nanjing, Jiangsu                      East Asia
# 48                                  Shenyang                      East Asia
# 49                              Kuala Lumpur                 Southeast Asia
# 50                                    Madrid                    West Europe
# 51                                  Hangzhou                      East Asia
# 52                                   Baghdad                    Middle East
# 53                            Xi'an, Shaanxi                      East Asia
# 54                 Kitakyushu-Fukuoka M.M.A.                      East Asia
# 55                                     Miami                  North America
# 56                                   Toronto                  North America
# 57                              Philadelphia                  North America
# 58                            Belo Horizonte                  South America
# 59                                    Luanda                Southern Africa

# %%
######################################################
# バグがないか確認する
# つまりdischargeがnegativeになっていないかどうか
#####################################################
if (df_new['ava'] >= 0).all():
    print("The 'ava' column contains only non-negative values.")
else:
    print("The 'ava' column contains negative values.")
    # マイナスの値を含む行を表示
    negative_ava_rows = df_new[df_new['ava'] < 0]
    print("Rows with negative 'ava' values:")
    print(negative_ava_rows)
# Out:
# The 'ava' column contains negative values.
# Rows with negative 'ava' values:
# Empty DataFrame
# Columns: [index, flag, rate, wup, pop, ava, mpcy, potential, region, country, cityname, 12region]
# Index: []

# %%
######################################################
# updownで再計算された都市の数と流域の数を確認
#####################################################
new_basin_to_cities = load_json() # keys = all basins with multiple cities 186?
rivnum_lst = list(new_basin_to_cities.keys())
rivnum_lst = [int(float(i)) for i in rivnum_lst]
print(rivnum_lst)
print(f'len(rivnum_lst): {len(rivnum_lst)}')
print('----------------------------------------------------------------------------------------------------------------------------------')

cities_lst = []
for key_index, key in enumerate(new_basin_to_cities.keys()):
    key_city_list = new_basin_to_cities[key]
    key_city_list = [int(i) for i in key_city_list]

    # remove overlap
    overlap_path = f'{h08dir}/global_city/dat/cty_lst_/gpw4/overlap_hidden_only.txt'
    with open(overlap_path, 'r') as f:
        numbers = [int(line.strip()) for line in f]
    key_city_list_removed = [num for num in key_city_list if num not in numbers]
    key_city_list_removed = [int(i) for i in key_city_list_removed]
    
    cities_lst.extend(key_city_list_removed)
    #print(f'{key_index}: rivnum{key} is done')

print('----------------------------------------------------------------------------------------------------------------------------------')
print(cities_lst)
print(f'len(cities_lst): {len(cities_lst)}')
print('----------------------------------------------------------------------------------------------------------------------------------')

urivnum = np.unique(rivnum_lst)
uctynum, counts = np.unique(cities_lst, return_counts=True)
print(f'len(urivnum): {len(urivnum)}')
print(f'len(uctynum): {len(uctynum)}')
print('----------------------------------------------------------------------------------------------------------------------------------')

duplicates = uctynum[counts > 1]
print(f'duplicates cities {duplicates}')
# Out:
# [848, 14, 480, 5438, 164, 5, 4, 172, 11240, 189, 7763, 3, 11, 191, 138, 382, 376, 413, 2, 17, 23, 63, 182, 970, 88, 325, 955, 64, 494, 177, 343, 1830, 27, 28, 498, 528, 34, 326, 12, 1220, 1749, 228, 3829, 112, 21, 43, 1014, 618, 234, 38, 3429, 878, 82, 35, 473, 6026, 102, 581, 220, 8210, 56, 203, 243, 2370, 9930, 2360, 7178, 45, 37, 2411, 127, 805, 748, 6, 911, 53, 591, 1130, 48, 6057, 282, 6278, 1744, 1298, 25, 10, 32, 416, 1850, 1, 158, 42, 15, 244, 75, 18, 49, 146, 26, 1252, 8, 111, 40, 5127, 338, 475, 576, 696, 143, 314, 374, 74, 667, 5507, 16, 7, 46, 17041, 105, 5046, 670, 385, 166, 1207, 3477, 55, 2152, 657, 478, 10510, 2130, 358, 2753, 394, 3700, 577, 917, 3947, 78, 176, 2087, 1481, 229, 3265, 126, 586, 108, 913, 3464, 10401, 1833, 167, 323, 2715, 1882, 425, 5365, 261, 948, 284, 118, 409, 946, 1752, 359, 273, 393, 123, 231, 750, 1067, 2954, 3102, 206, 807, 65, 317, 33, 197, 1800, 508, 3374, 644, 47, 1720, 107]
# len(rivnum_lst): 186
# ----------------------------------------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------------------------------------
# [1, 936, 1283, 2, 11, 126, 130, 133, 188, 197, 217, 243, 319, 321, 363, 406, 455, 463, 473, 513, 526, 588, 667, 669, 673, 677, 797, 883, 903, 941, 983, 1012, 1018, 1067, 1089, 1181, 1216, 1253, 1288, 1298, 1337, 1365, 1371, 1422, 1578, 1620, 1652, 1656, 1697, 1712, 1718, 1
97, 1343, 97, 530, 103, 232, 355, 912, 917, 107, 177, 1406, 108, 220, 697, 750, 876, 960, 1702, 1770, 110, 592, 114, 627, 688, 1681, 1846, 123, 239, 605, 1078, 1455, 1591, 127, 1165, 1460, 128, 128, 129, 1045, 129, 1045, 138, 271, 310, 467, 594, 640, 716, 726, 736, 908, 959, 1110, 1204, 1272, 1358, 1379, 1427, 1445, 1555, 1612, 1638, 1682, 1831, 139, 219, 441, 595, 693, 978, 1131, 1134, 1316, 1463, 141, 429, 143, 487, 147, 149, 1644, 151, 172, 185, 241, 265, 288, 298, 326, 420, 458, 459, 502, 532, 635, 710, 790, 842, 846, 994, 1056, 1098, 1173, 1227, 1239, 1600, 1609, 1640, 1649, 1680, 1705, 1731, 156, 1368, 164, 287, 371, 621, 882, 1261, 1497, 1550, 1576, 1639, 1683, 167, 234, 637, 679, 949, 1281, 167, 1321, 180, 722, 1058, 181, 192, 1852, 207, 1819, 208, 804, 1064, 210, 212, 240, 244, 333, 337, 361, 670, 1136, 1258, 1392, 1492, 1561, 1584, 213, 224, 451, 469, 598, 627, 680, 989, 1325, 1393, 1416, 1437, 1444, 1655, 1729, 1798, 216, 1219, 1346, 226, 1018, 1718, 228, 263, 327, 453, 1217, 1277, 1410, 1420, 1703, 233, 325, 1487, 238, 802, 1296, 245, 301, 633, 661, 709, 962, 1065, 1359 ...
# len(cities_lst): 1022
# ----------------------------------------------------------------------------------------------------------------------------------
# len(urivnum): 186
# len(uctynum): 983
# ----------------------------------------------------------------------------------------------------------------------------------
# duplicates cities [   3   35   52   73   77   85   97  108  128  129  167  246  335  345
#   350  486  490  502  508  543  550  627  654  658  764  790 1018 1044
#  1045 1098 1110 1169 1202 1248 1280 1416 1450 1718]

# %%
df_new['index'] = df_new['index'].astype(str)
duplicates_lst = list(map(str, duplicates))
mpcy_values = df_new[df_new['index'].isin(duplicates_lst)]['mpcy']
print(mpcy_values)
# Out:
# 2        941.8529506168535
# 34       7.769037635829043
# 51        8096.91174532348
# 72        8432.50937000074
# 76      10.302880930542878
# 84      19.346183389005166
# 96       5234.646262909766
# 107     1604.8806390091847
# 127     14.365305329978847
# 128      302.4333636297578
# 166      8.688201096150761
# 245      70.31971922390305
# 334     217.31024336360318
# 344     35.986495601745546
# 349      56.33714634774938
# 485     43326.187551640374
# 489     10007.036641406761
# 501     1289938.2943092918
# 507     165.30080826404907
# 542      9910.084089415996
# 549      4418.347533398172
# 626     146.59960476002828
# 653     180826.46942545325
# 657     3969.1503013629385
# 763      93572.85228983799
# 789     1782111.0994622197
# 1017     537.0966117262542
# 1043    371.61615266221577
# 1044    119.55885896817638
# 1097    138582.20254251905
# 1109    107.84520933231602
# 1168    1684.7750612598338
# 1201    201.07126985469168
# 1247      94.1711118669255
# 1279    3731.4939874818156
# 1415     885.6684651875955
# 1449     4965.736581533075
# 1717     577.9727772204009
# Name: mpcy, dtype: object

# %%
# city vs basin のグラフを書き直す
# populatoin vs availabilityの散布図を書き直す
