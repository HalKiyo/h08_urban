# %%
import os
import math
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.colors as colors
import cartopy.crs as ccrs
import cartopy.feature as cfea
import cartopy.io.shapereader as shapereader

# %%
def l_coordinate_to_tuple(lcoordinate, a=2160, b=4320):
    lat_l = ((lcoordinate - 1) // b)
    lon_l = (lcoordinate) % b - 1
    return (lat_l, lon_l)

def nxtl2nxtxy(rgnfile, upperindex, leftindex):
    vfunc = np.vectorize(l_coordinate_to_tuple, otypes=[tuple])
    riv_nxtxy = np.empty(rgnfile.shape, dtype=tuple)
    mask = ~np.isnan(rgnfile)
    riv_nxtxy[mask] = vfunc(rgnfile[mask])
    riv_nxtxy_shape = (riv_nxtxy.shape[0], riv_nxtxy.shape[1], 2)
    
    riv_nxtxy_lst = []
    for row in riv_nxtxy:
        for y, x in row:
            modified_y = y - upperindex
            modified_x = x - leftindex
            riv_nxtxy_lst.append((modified_y, modified_x))

    riv_nxtxy_cropped = np.array(riv_nxtxy_lst).reshape(riv_nxtxy_shape)
    riv_nxtxy_cropped = riv_nxtxy_cropped.astype(int)
    return riv_nxtxy_cropped
    
# rivnxl in xy coord
h08dir = '/mnt/c/Users/tsimk/Downloads/dotfiles/h08'
rivnxl_path = f"{h08dir}/global_city/dat/riv_nxl_/rivnxl.CAMA.gl5"
rivnxl_gl5 = np.fromfile(rivnxl_path, 'float32').reshape(2160, 4320)
riv_nxlonlat_cropped = nxtl2nxtxy(rivnxl_gl5, 0, 0)

#######################################
# start ####
#######################################
city_num = 1

def exeption_rivergrid(city_num, riv_nxlonlat_cropped):
    # coord of purficication
    root_dir = '/mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city'
    prf_path = f"{root_dir}/dat/cty_prf_/vld_cty_/city_{city_num:08}.gl5"
        
    prf = np.fromfile(prf_path, dtype='float32').reshape(2160, 4320)
    prf_coords = np.where(prf == 1)
    print(f'citynum: {city_num}, coord of prfs: {prf_coords}')
    
    # save variable
    riv_path_array = np.zeros((2160, 4320))
    
    # initial grid
    for pid in range(len(prf_coords[0])):
        print(f'pid == {pid}, len(prf_coords) == {len(prf_coords[0])}')
        
        # down stream exploration
        target_coord = (prf_coords[0][pid], prf_coords[1][pid])
        visited_coords = set()
        while True:
            if target_coord in visited_coords:
                break
            visited_coords.add(target_coord)
            target_row, target_col = target_coord
            next_coord = riv_nxlonlat_cropped[target_row, target_col]
            if next_coord.size == 0 or next_coord.shape != (2,):
                break
            target_coord = (next_coord[0], next_coord[1])

        # update riv_path_array
        for row, col in visited_coords:
            riv_path_array[row, col] = city_num
    
        # up stream exploration
        def explore_upstream(target_coord, visited_coords, riv_nxlonlat_cropped, city_num):
            while True:
                if target_coord in visited_coords:
                    break
                visited_coords.add(target_coord)
                matched_coords = np.argwhere(np.all(target_coord == riv_nxlonlat_cropped, axis=2))
                if len(matched_coords) == 0:
                    break
                unvisited_matched = [tuple(coord) for coord in matched_coords if tuple(coord) not in visited_coords]
                for up_coord in unvisited_matched:
                    print(f'len(visited_coords): {len(visited_coords)}, len(unvisited_matched): {len(unvisited_matched)}')
                    explore_upstream(up_coord, visited_coords, riv_nxlonlat_cropped, city_num)

        # execute function
        target_coord = (prf_coords[0][pid], prf_coords[1][pid])
        visited_coords = set()
        explore_upstream(target_coord, visited_coords, riv_nxlonlat_cropped, city_num)
        
        # update riv_path_array
        for row, col in visited_coords:
            riv_path_array[row, col] = city_num
    
    return riv_path_array

# %%
# city_num=90 seems to have problem
# it takes too much time to calculate

city_num = 90

root_dir = '/mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city'
savepath = f"{root_dir}/dat/prf_updw/vld_cty_/city_{city_num:08}.gl5"

prf_path = f"{root_dir}/dat/cty_prf_/vld_cty_/city_{city_num:08}.gl5"

if not os.path.exists(prf_path):
    print(f'{i+1} is invalid prf')
else:
    riv_path_array =  exeption_rivergrid(city_num, riv_nxlonlat_cropped)
    
    riv_path_array.astype(np.float32).tofile(savepath)
    print(f"{savepath} saved")
# Out:
# citynum: 90, coord of prfs: (array([534]), array([1274]))
# pid == 0, len(prf_coords) == 1
# len(visited_coords): 1
# len(visited_coords): 2
# len(visited_coords): 3
# len(visited_coords): 4
# len(visited_coords): 5
# len(visited_coords): 6
# len(visited_coords): 7
# len(visited_coords): 8
# len(visited_coords): 9
# len(visited_coords): 10
# len(visited_coords): 11
# len(visited_coords): 12
# len(visited_coords): 13
# len(visited_coords): 14
# len(visited_coords): 15
# len(visited_coords): 16
# len(visited_coords): 17
# len(visited_coords): 18
# len(visited_coords): 19
# len(visited_coords): 20
# len(visited_coords): 21
# len(visited_coords): 22
# len(visited_coords): 23
# len(visited_coords): 24
# len(visited_coords): 25
# len(visited_coords): 26
# len(visited_coords): 27
# len(visited_coords): 28
# len(visited_coords): 29
# len(visited_coords): 30
# len(visited_coords): 31
# len(visited_coords): 32
# len(visited_coords): 33
# len(visited_coords): 34
# len(visited_coords): 35
# len(visited_coords): 36
# len(visited_coords): 37
# len(visited_coords): 38
# len(visited_coords): 39
# len(visited_coords): 40
# len(visited_coords): 41
# len(visited_coords): 42
# len(visited_coords): 43
# len(visited_coords): 44
# len(visited_coords): 45
# len(visited_coords): 46
# len(visited_coords): 47
# len(visited_coords): 48
# len(visited_coords): 49
# len(visited_coords): 50
# len(visited_coords): 51
# len(visited_coords): 52
# len(visited_coords): 53
# len(visited_coords): 54
# len(visited_coords): 55
# len(visited_coords): 56
# len(visited_coords): 57
# len(visited_coords): 58
# len(visited_coords): 59
# len(visited_coords): 60
# len(visited_coords): 61
# len(visited_coords): 62
# len(visited_coords): 63
# len(visited_coords): 64
# len(visited_coords): 65
# len(visited_coords): 66
# len(visited_coords): 67
# len(visited_coords): 68
# len(visited_coords): 69
# len(visited_coords): 70
# len(visited_coords): 71
# len(visited_coords): 72
# len(visited_coords): 73
# len(visited_coords): 74
# len(visited_coords): 75
# len(visited_coords): 76
# len(visited_coords): 77
# len(visited_coords): 78
# len(visited_coords): 79
# len(visited_coords): 80
# len(visited_coords): 81
# len(visited_coords): 82
# len(visited_coords): 83
# len(visited_coords): 84
# len(visited_coords): 85
# len(visited_coords): 86
# len(visited_coords): 87
# len(visited_coords): 88
# len(visited_coords): 89
# len(visited_coords): 90
# len(visited_coords): 91
# len(visited_coords): 92
# len(visited_coords): 93
# len(visited_coords): 94
# len(visited_coords): 95
# len(visited_coords): 96
# len(visited_coords): 97
# len(visited_coords): 98
# len(visited_coords): 99
# len(visited_coords): 100
# len(visited_coords): 101
# len(visited_coords): 102
# len(visited_coords): 103
# len(visited_coords): 104
# len(visited_coords): 105
# len(visited_coords): 106
# len(visited_coords): 107
# len(visited_coords): 108
# len(visited_coords): 109
# len(visited_coords): 110
# len(visited_coords): 111
# len(visited_coords): 112
# len(visited_coords): 113
# len(visited_coords): 114
# len(visited_coords): 115
# len(visited_coords): 116
# len(visited_coords): 117
# len(visited_coords): 118
# len(visited_coords): 119
# len(visited_coords): 120
# len(visited_coords): 121
# len(visited_coords): 122
# len(visited_coords): 123
# len(visited_coords): 124
# len(visited_coords): 125
# len(visited_coords): 126
# len(visited_coords): 127
# len(visited_coords): 128
# len(visited_coords): 129
# len(visited_coords): 130
# len(visited_coords): 131
# len(visited_coords): 132
# len(visited_coords): 133
# len(visited_coords): 134
# len(visited_coords): 135
# len(visited_coords): 136
# len(visited_coords): 137
# len(visited_coords): 138
# len(visited_coords): 139
# len(visited_coords): 140
# len(visited_coords): 141
# len(visited_coords): 142
# len(visited_coords): 143
# len(visited_coords): 144
# len(visited_coords): 145
# len(visited_coords): 146
# len(visited_coords): 147
# len(visited_coords): 148
# len(visited_coords): 149
# len(visited_coords): 150
# len(visited_coords): 151
# len(visited_coords): 152
# len(visited_coords): 153
# len(visited_coords): 154
# len(visited_coords): 155
# len(visited_coords): 156
# len(visited_coords): 157
# len(visited_coords): 158
# len(visited_coords): 159
# len(visited_coords): 160
# len(visited_coords): 161
# len(visited_coords): 162
# len(visited_coords): 163
# len(visited_coords): 164
# len(visited_coords): 165
# len(visited_coords): 166
# len(visited_coords): 167
# len(visited_coords): 168
# len(visited_coords): 169
# len(visited_coords): 170
# len(visited_coords): 171
# len(visited_coords): 172
# len(visited_coords): 173
# len(visited_coords): 174
# len(visited_coords): 175
# len(visited_coords): 176
# len(visited_coords): 177
# len(visited_coords): 178
# len(visited_coords): 179
# len(visited_coords): 180
# len(visited_coords): 181
# len(visited_coords): 182
# len(visited_coords): 183
# len(visited_coords): 184
# len(visited_coords): 185
# len(visited_coords): 186
# len(visited_coords): 187
# len(visited_coords): 188
# len(visited_coords): 189
# len(visited_coords): 190
# len(visited_coords): 191
# len(visited_coords): 192
# len(visited_coords): 193
# len(visited_coords): 194
# len(visited_coords): 195
# len(visited_coords): 196
# len(visited_coords): 197
# len(visited_coords): 198
# len(visited_coords): 199
# len(visited_coords): 200
# len(visited_coords): 201
# len(visited_coords): 202
# len(visited_coords): 203
# len(visited_coords): 204
# len(visited_coords): 205
# len(visited_coords): 206
# len(visited_coords): 207
# len(visited_coords): 208
# len(visited_coords): 209
# len(visited_coords): 210
# len(visited_coords): 211
# len(visited_coords): 212
# len(visited_coords): 213
# len(visited_coords): 214
# len(visited_coords): 215
# len(visited_coords): 216
# len(visited_coords): 217
# len(visited_coords): 218
# len(visited_coords): 219
# len(visited_coords): 220
# len(visited_coords): 221
# len(visited_coords): 222
# len(visited_coords): 223
# len(visited_coords): 224
# len(visited_coords): 225
# len(visited_coords): 226
# len(visited_coords): 227
# len(visited_coords): 228
# len(visited_coords): 229
# len(visited_coords): 230
# len(visited_coords): 231
# len(visited_coords): 232
# len(visited_coords): 233
# len(visited_coords): 234
# len(visited_coords): 235
# len(visited_coords): 236
# len(visited_coords): 237
# len(visited_coords): 238
# len(visited_coords): 239
# len(visited_coords): 240
# len(visited_coords): 241
# len(visited_coords): 242
# len(visited_coords): 243
# len(visited_coords): 244
# len(visited_coords): 245
# len(visited_coords): 246
# len(visited_coords): 247
# len(visited_coords): 248
# len(visited_coords): 249
# len(visited_coords): 250
# len(visited_coords): 251
# len(visited_coords): 252
# len(visited_coords): 253
# len(visited_coords): 254
# len(visited_coords): 255
# len(visited_coords): 256
# len(visited_coords): 257
# len(visited_coords): 258
# len(visited_coords): 259
# len(visited_coords): 260
# len(visited_coords): 261
# len(visited_coords): 262
# len(visited_coords): 263
# len(visited_coords): 264
# len(visited_coords): 265
# len(visited_coords): 266
# len(visited_coords): 267
# len(visited_coords): 268
# len(visited_coords): 269
# len(visited_coords): 270
# len(visited_coords): 271
# len(visited_coords): 272
# len(visited_coords): 273
# len(visited_coords): 274
# len(visited_coords): 275
# len(visited_coords): 276
# len(visited_coords): 277
# len(visited_coords): 278
# len(visited_coords): 279
# len(visited_coords): 280
# len(visited_coords): 281
# len(visited_coords): 282
# len(visited_coords): 283
# len(visited_coords): 284
# len(visited_coords): 285
# len(visited_coords): 286
# len(visited_coords): 287
# len(visited_coords): 288
# len(visited_coords): 289
# len(visited_coords): 290
# len(visited_coords): 291
# len(visited_coords): 292
# len(visited_coords): 293
# len(visited_coords): 294
# len(visited_coords): 295
# len(visited_coords): 296
# len(visited_coords): 297
# len(visited_coords): 298
# len(visited_coords): 299
# len(visited_coords): 300
# len(visited_coords): 301
# len(visited_coords): 302
# len(visited_coords): 303
# len(visited_coords): 304
# len(visited_coords): 305
# len(visited_coords): 306
# len(visited_coords): 307
# len(visited_coords): 308
# len(visited_coords): 309
# len(visited_coords): 310
# len(visited_coords): 311
# len(visited_coords): 312
# len(visited_coords): 313
# len(visited_coords): 314
# len(visited_coords): 315
# len(visited_coords): 316
# len(visited_coords): 317
# len(visited_coords): 318
# len(visited_coords): 319
# len(visited_coords): 320
# len(visited_coords): 321
# len(visited_coords): 322
# len(visited_coords): 323
# len(visited_coords): 324
# len(visited_coords): 325
# len(visited_coords): 326
# len(visited_coords): 327
# len(visited_coords): 328
# len(visited_coords): 329
# len(visited_coords): 330
# len(visited_coords): 331
# len(visited_coords): 332
# len(visited_coords): 333
# len(visited_coords): 334
# len(visited_coords): 335
# len(visited_coords): 336
# len(visited_coords): 337
# len(visited_coords): 338
# len(visited_coords): 339
# len(visited_coords): 340
# len(visited_coords): 341
# len(visited_coords): 342
# len(visited_coords): 343
# len(visited_coords): 344
# len(visited_coords): 345
# len(visited_coords): 346
# len(visited_coords): 347
# len(visited_coords): 348
# len(visited_coords): 349
# len(visited_coords): 350
# len(visited_coords): 351
# len(visited_coords): 352
# len(visited_coords): 353
# len(visited_coords): 354
# len(visited_coords): 355
# len(visited_coords): 356
# len(visited_coords): 357
# len(visited_coords): 358
# len(visited_coords): 359
# len(visited_coords): 360
# len(visited_coords): 361
# len(visited_coords): 362
# len(visited_coords): 363
# len(visited_coords): 364
# len(visited_coords): 365
# len(visited_coords): 366
# len(visited_coords): 367
# len(visited_coords): 368
# len(visited_coords): 369
# len(visited_coords): 370
# len(visited_coords): 371
# len(visited_coords): 372
# len(visited_coords): 373
# len(visited_coords): 374
# len(visited_coords): 375
# len(visited_coords): 376
# len(visited_coords): 377
# len(visited_coords): 378
# len(visited_coords): 379
# len(visited_coords): 380
# len(visited_coords): 381
# len(visited_coords): 382
# len(visited_coords): 383
# len(visited_coords): 384
# len(visited_coords): 385
# len(visited_coords): 386
# len(visited_coords): 387
# len(visited_coords): 388
# len(visited_coords): 389
# len(visited_coords): 390
# len(visited_coords): 391
# len(visited_coords): 392
# len(visited_coords): 393
# len(visited_coords): 394
# len(visited_coords): 395
# len(visited_coords): 396
# len(visited_coords): 397
# len(visited_coords): 398
# len(visited_coords): 399
# len(visited_coords): 400
# len(visited_coords): 401
# len(visited_coords): 402
# len(visited_coords): 403
# len(visited_coords): 404
# len(visited_coords): 405
# len(visited_coords): 406
# len(visited_coords): 407
# len(visited_coords): 408
# len(visited_coords): 409
# len(visited_coords): 410
# len(visited_coords): 411
# len(visited_coords): 412
# len(visited_coords): 413
# len(visited_coords): 414
# len(visited_coords): 415
# len(visited_coords): 416
# len(visited_coords): 417
# len(visited_coords): 418
# len(visited_coords): 419
# len(visited_coords): 420
# len(visited_coords): 421
# len(visited_coords): 422
# len(visited_coords): 423
# len(visited_coords): 424
# len(visited_coords): 425
# len(visited_coords): 426
# len(visited_coords): 427
# len(visited_coords): 428
# len(visited_coords): 429
# len(visited_coords): 430
# len(visited_coords): 431
# len(visited_coords): 432
# len(visited_coords): 433
# len(visited_coords): 434
# len(visited_coords): 435
# len(visited_coords): 436
# len(visited_coords): 437
# len(visited_coords): 438
# len(visited_coords): 439
# len(visited_coords): 440
# len(visited_coords): 441
# len(visited_coords): 442
# len(visited_coords): 443
# len(visited_coords): 444
# len(visited_coords): 445
# len(visited_coords): 446
# len(visited_coords): 447
# len(visited_coords): 448
# len(visited_coords): 449
# len(visited_coords): 450
# len(visited_coords): 451
# len(visited_coords): 452
# len(visited_coords): 453
# len(visited_coords): 454
# len(visited_coords): 455
# len(visited_coords): 456
# len(visited_coords): 457
# len(visited_coords): 458
# len(visited_coords): 459
# len(visited_coords): 460
# len(visited_coords): 461
# len(visited_coords): 462
# len(visited_coords): 463
# len(visited_coords): 464
# len(visited_coords): 465
# len(visited_coords): 466
# len(visited_coords): 467
# len(visited_coords): 468
# len(visited_coords): 469
# len(visited_coords): 470
# len(visited_coords): 471
# len(visited_coords): 472
# len(visited_coords): 473
# len(visited_coords): 474
# len(visited_coords): 475
# len(visited_coords): 476
# len(visited_coords): 477
# len(visited_coords): 478
# len(visited_coords): 479
# len(visited_coords): 480
# len(visited_coords): 481
# len(visited_coords): 482
# len(visited_coords): 483
# len(visited_coords): 484
# len(visited_coords): 485
# len(visited_coords): 486
# len(visited_coords): 487
# len(visited_coords): 488
# len(visited_coords): 489
# len(visited_coords): 490
# len(visited_coords): 491
# len(visited_coords): 492
# len(visited_coords): 493
# len(visited_coords): 494
# len(visited_coords): 495
# len(visited_coords): 496
# len(visited_coords): 497
# len(visited_coords): 498
# len(visited_coords): 499
# len(visited_coords): 500
# len(visited_coords): 501
# len(visited_coords): 502
# len(visited_coords): 503
# len(visited_coords): 504
# len(visited_coords): 505
# len(visited_coords): 506
# len(visited_coords): 507
# len(visited_coords): 508
# len(visited_coords): 509
# len(visited_coords): 510
# len(visited_coords): 511
# len(visited_coords): 512
# len(visited_coords): 513
# len(visited_coords): 514
# len(visited_coords): 515
# len(visited_coords): 516
# len(visited_coords): 517
# len(visited_coords): 518
# len(visited_coords): 519
# len(visited_coords): 520
# len(visited_coords): 521
# len(visited_coords): 522
# len(visited_coords): 523
# len(visited_coords): 524
# len(visited_coords): 525
# len(visited_coords): 526
# len(visited_coords): 527
# len(visited_coords): 528
# len(visited_coords): 529
# len(visited_coords): 530
# len(visited_coords): 531
# len(visited_coords): 532
# len(visited_coords): 533
# len(visited_coords): 534
# len(visited_coords): 535
# len(visited_coords): 536
# len(visited_coords): 537
# len(visited_coords): 538
# len(visited_coords): 539
# len(visited_coords): 540
# len(visited_coords): 541
# len(visited_coords): 542
# len(visited_coords): 543
# len(visited_coords): 544
# len(visited_coords): 545
# len(visited_coords): 546
# len(visited_coords): 547
# len(visited_coords): 548
# len(visited_coords): 549
# len(visited_coords): 550
# len(visited_coords): 551
# len(visited_coords): 552
# len(visited_coords): 553
# len(visited_coords): 554
# len(visited_coords): 555
# len(visited_coords): 556
# len(visited_coords): 557
# len(visited_coords): 558
# len(visited_coords): 559
# len(visited_coords): 560
# len(visited_coords): 561
# len(visited_coords): 562
# len(visited_coords): 563
# len(visited_coords): 564
# len(visited_coords): 565
# len(visited_coords): 566
# len(visited_coords): 567
# len(visited_coords): 568
# len(visited_coords): 569
# len(visited_coords): 570
# len(visited_coords): 571
# len(visited_coords): 572
# len(visited_coords): 573
# len(visited_coords): 574
# len(visited_coords): 575
# len(visited_coords): 576
# len(visited_coords): 577
# len(visited_coords): 578
# len(visited_coords): 579
# len(visited_coords): 580
# len(visited_coords): 581
# len(visited_coords): 582
# len(visited_coords): 583
# len(visited_coords): 584
# len(visited_coords): 585
# len(visited_coords): 586
# len(visited_coords): 587
# len(visited_coords): 588
# len(visited_coords): 589
# len(visited_coords): 590
# len(visited_coords): 591
# len(visited_coords): 592
# len(visited_coords): 593
# len(visited_coords): 594
# len(visited_coords): 595
# len(visited_coords): 596
# len(visited_coords): 597
# len(visited_coords): 598
# len(visited_coords): 599
# len(visited_coords): 600
# len(visited_coords): 601
# len(visited_coords): 602
# len(visited_coords): 603
# len(visited_coords): 604
# len(visited_coords): 605
# len(visited_coords): 606
# len(visited_coords): 607
# len(visited_coords): 608
# len(visited_coords): 609
# len(visited_coords): 610
# len(visited_coords): 611
# len(visited_coords): 612
# len(visited_coords): 613
# len(visited_coords): 614
# len(visited_coords): 615
# len(visited_coords): 616
# len(visited_coords): 617
# len(visited_coords): 618
# len(visited_coords): 619
# len(visited_coords): 620
# len(visited_coords): 621
# len(visited_coords): 622
# len(visited_coords): 623
# len(visited_coords): 624
# len(visited_coords): 625
# len(visited_coords): 626
# len(visited_coords): 627
# len(visited_coords): 628
# len(visited_coords): 629
# len(visited_coords): 630
# len(visited_coords): 631
# len(visited_coords): 632
# len(visited_coords): 633
# len(visited_coords): 634
# len(visited_coords): 635
# len(visited_coords): 636
# len(visited_coords): 637
# len(visited_coords): 638
# len(visited_coords): 639
# len(visited_coords): 640
# len(visited_coords): 641
# len(visited_coords): 642
# len(visited_coords): 643
# len(visited_coords): 644
# len(visited_coords): 645
# len(visited_coords): 646
# len(visited_coords): 647
# len(visited_coords): 648
# len(visited_coords): 649
# len(visited_coords): 650
# len(visited_coords): 651
# len(visited_coords): 652
# len(visited_coords): 653
# len(visited_coords): 654
# len(visited_coords): 655
# len(visited_coords): 656
# len(visited_coords): 657
# len(visited_coords): 658
# len(visited_coords): 659
# len(visited_coords): 660
# len(visited_coords): 661
# len(visited_coords): 662
# len(visited_coords): 663
# len(visited_coords): 664
# len(visited_coords): 665
# len(visited_coords): 666
# len(visited_coords): 667
# len(visited_coords): 668
# len(visited_coords): 669
# len(visited_coords): 670
# len(visited_coords): 671
# len(visited_coords): 672
# len(visited_coords): 673
# len(visited_coords): 674
# len(visited_coords): 675
# len(visited_coords): 676
# len(visited_coords): 677
# len(visited_coords): 678
# len(visited_coords): 679
# len(visited_coords): 680
# len(visited_coords): 681
# len(visited_coords): 682
# len(visited_coords): 683
# len(visited_coords): 684
# len(visited_coords): 685
# len(visited_coords): 686
# len(visited_coords): 687
# len(visited_coords): 688
# len(visited_coords): 689
# len(visited_coords): 690
# len(visited_coords): 691
# len(visited_coords): 692
# len(visited_coords): 693
# len(visited_coords): 694
# len(visited_coords): 695
# len(visited_coords): 696
# len(visited_coords): 697
# len(visited_coords): 698
# len(visited_coords): 699
# len(visited_coords): 700
# len(visited_coords): 701
# len(visited_coords): 702
# len(visited_coords): 703
# len(visited_coords): 704
# len(visited_coords): 705
# len(visited_coords): 706
# len(visited_coords): 707
# len(visited_coords): 708
# len(visited_coords): 709
# len(visited_coords): 710
# len(visited_coords): 711
# len(visited_coords): 712
# len(visited_coords): 713
# len(visited_coords): 714
# len(visited_coords): 715
# len(visited_coords): 716
# len(visited_coords): 717
# len(visited_coords): 718
# len(visited_coords): 719
# len(visited_coords): 720
# len(visited_coords): 721
# len(visited_coords): 722
# len(visited_coords): 723
# len(visited_coords): 724
# len(visited_coords): 725
# len(visited_coords): 726
# len(visited_coords): 727
# len(visited_coords): 728
# len(visited_coords): 729
# len(visited_coords): 730
# len(visited_coords): 731
# len(visited_coords): 732
# len(visited_coords): 733
# len(visited_coords): 734
# len(visited_coords): 735
# len(visited_coords): 736
# len(visited_coords): 737
# len(visited_coords): 738
# len(visited_coords): 739
# len(visited_coords): 740
# len(visited_coords): 741
# len(visited_coords): 742
# len(visited_coords): 743
# len(visited_coords): 744
# len(visited_coords): 745
# len(visited_coords): 746
# len(visited_coords): 747
# len(visited_coords): 748
# len(visited_coords): 749
# len(visited_coords): 750
# len(visited_coords): 751
# len(visited_coords): 752
# len(visited_coords): 753
# len(visited_coords): 754
# len(visited_coords): 755
# len(visited_coords): 756
# len(visited_coords): 757
# len(visited_coords): 758
# len(visited_coords): 759
# len(visited_coords): 760
# len(visited_coords): 761
# len(visited_coords): 762
# len(visited_coords): 763
# len(visited_coords): 764
# len(visited_coords): 765
# len(visited_coords): 766
# len(visited_coords): 767
# len(visited_coords): 768
# len(visited_coords): 769
# len(visited_coords): 770
# len(visited_coords): 771
# len(visited_coords): 772
# len(visited_coords): 773
# len(visited_coords): 774
# len(visited_coords): 775
# len(visited_coords): 776
# len(visited_coords): 777
# len(visited_coords): 778
# len(visited_coords): 779
# len(visited_coords): 780
# len(visited_coords): 781
# len(visited_coords): 782
# len(visited_coords): 783
# len(visited_coords): 784
# len(visited_coords): 785
# len(visited_coords): 786
# len(visited_coords): 787
# len(visited_coords): 788
# len(visited_coords): 789
# len(visited_coords): 790
# len(visited_coords): 791
# len(visited_coords): 792
# len(visited_coords): 793
# len(visited_coords): 794
# len(visited_coords): 795
# len(visited_coords): 796
# len(visited_coords): 797
# len(visited_coords): 798
# len(visited_coords): 799
# len(visited_coords): 800
# len(visited_coords): 801
# len(visited_coords): 802
# len(visited_coords): 803
# len(visited_coords): 804
# len(visited_coords): 805
# len(visited_coords): 806
# len(visited_coords): 807
# len(visited_coords): 808
# len(visited_coords): 809
# len(visited_coords): 810
# len(visited_coords): 811
# len(visited_coords): 812
# len(visited_coords): 813
# len(visited_coords): 814
# len(visited_coords): 815
# len(visited_coords): 816
# len(visited_coords): 817
# len(visited_coords): 818
# len(visited_coords): 819
# len(visited_coords): 820
# len(visited_coords): 821
# len(visited_coords): 822
# len(visited_coords): 823
# len(visited_coords): 824
# len(visited_coords): 825
# len(visited_coords): 826
# len(visited_coords): 827
# len(visited_coords): 828
# len(visited_coords): 829
# len(visited_coords): 830
# len(visited_coords): 831
# len(visited_coords): 832
# len(visited_coords): 833
# len(visited_coords): 834
# len(visited_coords): 835
# len(visited_coords): 836
# len(visited_coords): 837
# len(visited_coords): 838
# len(visited_coords): 839
# len(visited_coords): 840
# len(visited_coords): 841
# len(visited_coords): 842
# len(visited_coords): 843
# len(visited_coords): 844
# len(visited_coords): 845
# len(visited_coords): 846
# len(visited_coords): 847
# len(visited_coords): 848
# len(visited_coords): 849
# len(visited_coords): 850
# len(visited_coords): 851
# len(visited_coords): 852
# len(visited_coords): 853
# len(visited_coords): 854
# len(visited_coords): 855
# len(visited_coords): 856
# len(visited_coords): 857
# len(visited_coords): 858
# len(visited_coords): 859
# len(visited_coords): 860
# len(visited_coords): 861
# len(visited_coords): 862
# len(visited_coords): 863
# len(visited_coords): 864
# len(visited_coords): 865
# len(visited_coords): 866
# len(visited_coords): 867
# len(visited_coords): 868
# len(visited_coords): 869
# len(visited_coords): 870
# len(visited_coords): 871
# len(visited_coords): 872
# len(visited_coords): 873
# len(visited_coords): 874
# len(visited_coords): 875
# len(visited_coords): 876
# len(visited_coords): 877
# len(visited_coords): 878
# len(visited_coords): 879
# len(visited_coords): 880
# len(visited_coords): 881
# len(visited_coords): 882
# len(visited_coords): 883
# len(visited_coords): 884
# len(visited_coords): 885
# len(visited_coords): 886
# len(visited_coords): 887
# len(visited_coords): 888
# len(visited_coords): 889
# len(visited_coords): 890
# len(visited_coords): 891
# len(visited_coords): 892
# len(visited_coords): 893
# len(visited_coords): 894
# len(visited_coords): 895
# len(visited_coords): 896
# len(visited_coords): 897
# len(visited_coords): 898
# len(visited_coords): 899
# len(visited_coords): 900
# len(visited_coords): 901
# len(visited_coords): 902
# len(visited_coords): 903
# len(visited_coords): 904
# len(visited_coords): 905
# len(visited_coords): 906
# len(visited_coords): 907
# len(visited_coords): 908
# len(visited_coords): 909
# len(visited_coords): 910
# len(visited_coords): 911
# len(visited_coords): 912
# len(visited_coords): 913
# len(visited_coords): 914
# len(visited_coords): 915
# len(visited_coords): 916
# len(visited_coords): 917
# len(visited_coords): 918
# len(visited_coords): 919
# len(visited_coords): 920
# len(visited_coords): 921
# len(visited_coords): 922
# len(visited_coords): 923
# len(visited_coords): 924
# len(visited_coords): 925
# len(visited_coords): 926
# len(visited_coords): 927
# len(visited_coords): 928
# len(visited_coords): 929
# len(visited_coords): 930
# len(visited_coords): 931
# len(visited_coords): 932
# len(visited_coords): 933
# len(visited_coords): 934
# len(visited_coords): 935
# len(visited_coords): 936
# len(visited_coords): 937
# len(visited_coords): 938
# len(visited_coords): 939
# len(visited_coords): 940
# len(visited_coords): 941
# len(visited_coords): 942
# len(visited_coords): 943
# len(visited_coords): 944
# len(visited_coords): 945
# len(visited_coords): 946
# len(visited_coords): 947
# len(visited_coords): 948
# len(visited_coords): 949
# len(visited_coords): 950
# len(visited_coords): 951
# len(visited_coords): 952
# len(visited_coords): 953
# len(visited_coords): 954
# len(visited_coords): 955
# len(visited_coords): 956
# len(visited_coords): 957
# len(visited_coords): 958
# len(visited_coords): 959
# len(visited_coords): 960
# len(visited_coords): 961
# len(visited_coords): 962
# len(visited_coords): 963
# len(visited_coords): 964
# len(visited_coords): 965
# len(visited_coords): 966
# len(visited_coords): 967
# len(visited_coords): 968
# len(visited_coords): 969
# len(visited_coords): 970
# len(visited_coords): 971
# len(visited_coords): 972
# len(visited_coords): 973
# len(visited_coords): 974
# len(visited_coords): 975
# len(visited_coords): 976
# len(visited_coords): 977
# len(visited_coords): 978
# len(visited_coords): 979
# len(visited_coords): 980
# len(visited_coords): 981
# len(visited_coords): 982
# len(visited_coords): 983
# len(visited_coords): 984
# len(visited_coords): 985
# len(visited_coords): 986
# len(visited_coords): 987
# len(visited_coords): 988
# len(visited_coords): 989
# len(visited_coords): 990
# len(visited_coords): 991
# len(visited_coords): 992
# len(visited_coords): 993
# len(visited_coords): 994
# len(visited_coords): 995
# len(visited_coords): 996
# len(visited_coords): 997
# len(visited_coords): 998
# len(visited_coords): 999
# len(visited_coords): 1000
# len(visited_coords): 1001
# len(visited_coords): 1002
# len(visited_coords): 1003
# len(visited_coords): 1004
# len(visited_coords): 1005
# len(visited_coords): 1006
# len(visited_coords): 1007
# len(visited_coords): 1008
# len(visited_coords): 1009
# len(visited_coords): 1010
# len(visited_coords): 1011
# len(visited_coords): 1012
# len(visited_coords): 1013
# len(visited_coords): 1014
# len(visited_coords): 1015
# len(visited_coords): 1016
# len(visited_coords): 1017
# len(visited_coords): 1018
# len(visited_coords): 1019
# len(visited_coords): 1020
# len(visited_coords): 1021
# len(visited_coords): 1022
# len(visited_coords): 1023
# len(visited_coords): 1024
# len(visited_coords): 1025
# len(visited_coords): 1026
# len(visited_coords): 1027
# len(visited_coords): 1028
# len(visited_coords): 1029
# len(visited_coords): 1030
# len(visited_coords): 1031
# len(visited_coords): 1032
# len(visited_coords): 1033
# len(visited_coords): 1034
# len(visited_coords): 1035
# len(visited_coords): 1036
# len(visited_coords): 1037
# len(visited_coords): 1038
# len(visited_coords): 1039
# len(visited_coords): 1040
# len(visited_coords): 1041
# len(visited_coords): 1042
# len(visited_coords): 1043
# len(visited_coords): 1044
# len(visited_coords): 1045
# len(visited_coords): 1046
# len(visited_coords): 1047
# len(visited_coords): 1048
# len(visited_coords): 1049
# len(visited_coords): 1050
# len(visited_coords): 1051
# len(visited_coords): 1052
# len(visited_coords): 1053
# len(visited_coords): 1054
# len(visited_coords): 1055
# len(visited_coords): 1056
# len(visited_coords): 1057
# len(visited_coords): 1058
# len(visited_coords): 1059
# len(visited_coords): 1060
# len(visited_coords): 1061
# len(visited_coords): 1062
# len(visited_coords): 1063
# len(visited_coords): 1064
# len(visited_coords): 1065
# len(visited_coords): 1066
# len(visited_coords): 1067
# len(visited_coords): 1068
# len(visited_coords): 1069
# len(visited_coords): 1070
# len(visited_coords): 1071
# len(visited_coords): 1072
# len(visited_coords): 1073
# len(visited_coords): 1074
# len(visited_coords): 1075
# len(visited_coords): 1076
# len(visited_coords): 1077
# len(visited_coords): 1078
# len(visited_coords): 1079
# len(visited_coords): 1080
# len(visited_coords): 1081
# len(visited_coords): 1082
# len(visited_coords): 1083
# len(visited_coords): 1084
# len(visited_coords): 1085
# len(visited_coords): 1086
# len(visited_coords): 1087
# len(visited_coords): 1088
# len(visited_coords): 1089
# len(visited_coords): 1090
# len(visited_coords): 1091
# len(visited_coords): 1092
# len(visited_coords): 1093
# len(visited_coords): 1094
# len(visited_coords): 1095
# len(visited_coords): 1096
# len(visited_coords): 1097
# len(visited_coords): 1098
# len(visited_coords): 1099
# len(visited_coords): 1100
# len(visited_coords): 1101
# len(visited_coords): 1102
# len(visited_coords): 1103
# len(visited_coords): 1104
# len(visited_coords): 1105
# len(visited_coords): 1106
# len(visited_coords): 1107
# len(visited_coords): 1108
# len(visited_coords): 1109
# len(visited_coords): 1110
# len(visited_coords): 1111
# len(visited_coords): 1112
# len(visited_coords): 1113
# len(visited_coords): 1114
# len(visited_coords): 1115
# len(visited_coords): 1116
# len(visited_coords): 1117
# len(visited_coords): 1118
# len(visited_coords): 1119
# len(visited_coords): 1120
# len(visited_coords): 1121
# len(visited_coords): 1122
# len(visited_coords): 1123
# len(visited_coords): 1124
# len(visited_coords): 1125
# len(visited_coords): 1126
# len(visited_coords): 1127
# len(visited_coords): 1128
# len(visited_coords): 1129
# len(visited_coords): 1130
# len(visited_coords): 1131
# len(visited_coords): 1132
# len(visited_coords): 1133
# len(visited_coords): 1134
# len(visited_coords): 1135
# len(visited_coords): 1136
# len(visited_coords): 1137
# len(visited_coords): 1138
# len(visited_coords): 1139
# len(visited_coords): 1140
# len(visited_coords): 1141
# len(visited_coords): 1142
# len(visited_coords): 1143
# len(visited_coords): 1144
# len(visited_coords): 1145
# len(visited_coords): 1146
# len(visited_coords): 1147
# len(visited_coords): 1148
# len(visited_coords): 1149
# len(visited_coords): 1150
# len(visited_coords): 1151
# len(visited_coords): 1152
# len(visited_coords): 1153
# len(visited_coords): 1154
# len(visited_coords): 1155
# len(visited_coords): 1156
# len(visited_coords): 1157
# len(visited_coords): 1158
# len(visited_coords): 1159
# len(visited_coords): 1160
# len(visited_coords): 1161
# len(visited_coords): 1162
# len(visited_coords): 1163
# len(visited_coords): 1164
# len(visited_coords): 1165
# len(visited_coords): 1166
# len(visited_coords): 1167
# len(visited_coords): 1168
# len(visited_coords): 1169
# len(visited_coords): 1170
# len(visited_coords): 1171
# len(visited_coords): 1172
# len(visited_coords): 1173
# len(visited_coords): 1174
# len(visited_coords): 1175
# len(visited_coords): 1176
# len(visited_coords): 1177
# len(visited_coords): 1178
# len(visited_coords): 1179
# len(visited_coords): 1180
# len(visited_coords): 1181
# len(visited_coords): 1182
# len(visited_coords): 1183
# len(visited_coords): 1184
# len(visited_coords): 1185
# len(visited_coords): 1186
# len(visited_coords): 1187
# len(visited_coords): 1188
# len(visited_coords): 1189
# len(visited_coords): 1190
# len(visited_coords): 1191
# len(visited_coords): 1192
# len(visited_coords): 1193
# len(visited_coords): 1194
# len(visited_coords): 1195
# len(visited_coords): 1196
# len(visited_coords): 1197
# len(visited_coords): 1198
# len(visited_coords): 1199
# len(visited_coords): 1200
# len(visited_coords): 1201
# len(visited_coords): 1202
# len(visited_coords): 1203
# len(visited_coords): 1204
# len(visited_coords): 1205
# len(visited_coords): 1206
# len(visited_coords): 1207
# len(visited_coords): 1208
# len(visited_coords): 1209
# len(visited_coords): 1210
# len(visited_coords): 1211
# len(visited_coords): 1212
# len(visited_coords): 1213
# len(visited_coords): 1214
# len(visited_coords): 1215
# len(visited_coords): 1216
# len(visited_coords): 1217
# len(visited_coords): 1218
# len(visited_coords): 1219
# len(visited_coords): 1220
# len(visited_coords): 1221
# len(visited_coords): 1222
# len(visited_coords): 1223
# len(visited_coords): 1224
# len(visited_coords): 1225
# len(visited_coords): 1226
# len(visited_coords): 1227
# len(visited_coords): 1228
# len(visited_coords): 1229
# len(visited_coords): 1230
# len(visited_coords): 1231
# len(visited_coords): 1232
# len(visited_coords): 1233
# len(visited_coords): 1234
# len(visited_coords): 1235
# len(visited_coords): 1236
# len(visited_coords): 1237
# len(visited_coords): 1238
# len(visited_coords): 1239
# len(visited_coords): 1240
# len(visited_coords): 1241
# len(visited_coords): 1242
# len(visited_coords): 1243
# len(visited_coords): 1244
# len(visited_coords): 1245
# len(visited_coords): 1246
# len(visited_coords): 1247
# len(visited_coords): 1248
# len(visited_coords): 1249
# len(visited_coords): 1250
# len(visited_coords): 1251
# len(visited_coords): 1252
# len(visited_coords): 1253
# len(visited_coords): 1254
# len(visited_coords): 1255
# len(visited_coords): 1256
# len(visited_coords): 1257
# len(visited_coords): 1258
# len(visited_coords): 1259
# len(visited_coords): 1260
# len(visited_coords): 1261
# len(visited_coords): 1262
# len(visited_coords): 1263
# len(visited_coords): 1264
# len(visited_coords): 1265
# len(visited_coords): 1266
# len(visited_coords): 1267
# len(visited_coords): 1268
# len(visited_coords): 1269
# len(visited_coords): 1270
# len(visited_coords): 1271
# len(visited_coords): 1272
# len(visited_coords): 1273
# len(visited_coords): 1274
# len(visited_coords): 1275
# len(visited_coords): 1276
# len(visited_coords): 1277
# len(visited_coords): 1278
# len(visited_coords): 1279
# len(visited_coords): 1280
# len(visited_coords): 1281
# len(visited_coords): 1282
# len(visited_coords): 1283
# len(visited_coords): 1284
# len(visited_coords): 1285
# len(visited_coords): 1286
# len(visited_coords): 1287
# len(visited_coords): 1288
# len(visited_coords): 1289
# len(visited_coords): 1290
# len(visited_coords): 1291
# len(visited_coords): 1292
# len(visited_coords): 1293
# len(visited_coords): 1294
# len(visited_coords): 1295
# len(visited_coords): 1296
# len(visited_coords): 1297
# len(visited_coords): 1298
# len(visited_coords): 1299
# len(visited_coords): 1300
# len(visited_coords): 1301
# len(visited_coords): 1302
# len(visited_coords): 1303
# len(visited_coords): 1304
# len(visited_coords): 1305
# len(visited_coords): 1306
# len(visited_coords): 1307
# len(visited_coords): 1308
# len(visited_coords): 1309
# len(visited_coords): 1310
# len(visited_coords): 1311
# len(visited_coords): 1312
# len(visited_coords): 1313
# len(visited_coords): 1314
# len(visited_coords): 1315
# len(visited_coords): 1316
# len(visited_coords): 1317
# len(visited_coords): 1318
# len(visited_coords): 1319
# len(visited_coords): 1320
# len(visited_coords): 1321
# len(visited_coords): 1322
# len(visited_coords): 1323
# len(visited_coords): 1324
# len(visited_coords): 1325
# len(visited_coords): 1326
# len(visited_coords): 1327
# len(visited_coords): 1328
# len(visited_coords): 1329
# len(visited_coords): 1330
# len(visited_coords): 1331
# len(visited_coords): 1332
# len(visited_coords): 1333
# len(visited_coords): 1334
# len(visited_coords): 1335
# len(visited_coords): 1336
# len(visited_coords): 1337
# len(visited_coords): 1338
# len(visited_coords): 1339
# len(visited_coords): 1340
# len(visited_coords): 1341
# len(visited_coords): 1342
# len(visited_coords): 1343
# len(visited_coords): 1344
# len(visited_coords): 1345
# len(visited_coords): 1346
# len(visited_coords): 1347
# len(visited_coords): 1348
# len(visited_coords): 1349
# len(visited_coords): 1350
# len(visited_coords): 1351
# len(visited_coords): 1352
# len(visited_coords): 1353
# len(visited_coords): 1354
# len(visited_coords): 1355
# len(visited_coords): 1356
# len(visited_coords): 1357
# len(visited_coords): 1358
# len(visited_coords): 1359
# len(visited_coords): 1360
# len(visited_coords): 1361
# len(visited_coords): 1362
# len(visited_coords): 1363
# len(visited_coords): 1364
# len(visited_coords): 1365
# len(visited_coords): 1366
# len(visited_coords): 1367
# len(visited_coords): 1368
# len(visited_coords): 1369
# len(visited_coords): 1370
# len(visited_coords): 1371
# len(visited_coords): 1372
# len(visited_coords): 1373
# len(visited_coords): 1374
# len(visited_coords): 1375
# len(visited_coords): 1376
# len(visited_coords): 1377
# len(visited_coords): 1378
# len(visited_coords): 1379
# len(visited_coords): 1380
# len(visited_coords): 1381
# len(visited_coords): 1382
# len(visited_coords): 1383
# len(visited_coords): 1384
# len(visited_coords): 1385
# len(visited_coords): 1386
# len(visited_coords): 1387
# len(visited_coords): 1388
# len(visited_coords): 1389
# len(visited_coords): 1390
# len(visited_coords): 1391
# len(visited_coords): 1392
# len(visited_coords): 1393
# len(visited_coords): 1394
# len(visited_coords): 1395
# len(visited_coords): 1396
# len(visited_coords): 1397
# len(visited_coords): 1398
# len(visited_coords): 1399
# len(visited_coords): 1400
# len(visited_coords): 1401
# len(visited_coords): 1402
# len(visited_coords): 1403
# len(visited_coords): 1404
# len(visited_coords): 1405
# len(visited_coords): 1406
# len(visited_coords): 1407
# len(visited_coords): 1408
# len(visited_coords): 1409
# len(visited_coords): 1410
# len(visited_coords): 1411
# len(visited_coords): 1412
# len(visited_coords): 1413
# len(visited_coords): 1414
# len(visited_coords): 1415
# len(visited_coords): 1416
# len(visited_coords): 1417
# len(visited_coords): 1418
# len(visited_coords): 1419
# len(visited_coords): 1420
# len(visited_coords): 1421
# len(visited_coords): 1422
# len(visited_coords): 1423
# len(visited_coords): 1424
# len(visited_coords): 1425
# len(visited_coords): 1426
# len(visited_coords): 1427
# len(visited_coords): 1428
# len(visited_coords): 1429
# len(visited_coords): 1430
# len(visited_coords): 1431
# len(visited_coords): 1432
# len(visited_coords): 1433
# len(visited_coords): 1434
# len(visited_coords): 1435
# len(visited_coords): 1436
# len(visited_coords): 1437
# len(visited_coords): 1438
# len(visited_coords): 1439
# len(visited_coords): 1440
# len(visited_coords): 1441
# len(visited_coords): 1442
# len(visited_coords): 1443
# len(visited_coords): 1444
# len(visited_coords): 1445
# len(visited_coords): 1446
# len(visited_coords): 1447
# len(visited_coords): 1448
# len(visited_coords): 1449
# len(visited_coords): 1450
# len(visited_coords): 1451
# len(visited_coords): 1452
# len(visited_coords): 1453
# len(visited_coords): 1454
# len(visited_coords): 1455
# len(visited_coords): 1456
# len(visited_coords): 1457
# len(visited_coords): 1458
# len(visited_coords): 1459
# len(visited_coords): 1460
# len(visited_coords): 1461
# len(visited_coords): 1462
# len(visited_coords): 1463
# len(visited_coords): 1464
# len(visited_coords): 1465
# len(visited_coords): 1466
# len(visited_coords): 1467
# len(visited_coords): 1468
# len(visited_coords): 1469
# len(visited_coords): 1470
# len(visited_coords): 1471
# len(visited_coords): 1472
# len(visited_coords): 1473
# len(visited_coords): 1474
# len(visited_coords): 1475
# len(visited_coords): 1476
# len(visited_coords): 1477
# len(visited_coords): 1478
# len(visited_coords): 1479
# len(visited_coords): 1480
# len(visited_coords): 1481
# len(visited_coords): 1482
# len(visited_coords): 1483
# len(visited_coords): 1484
# len(visited_coords): 1485
# len(visited_coords): 1486
# len(visited_coords): 1487
# len(visited_coords): 1488
# len(visited_coords): 1489
# len(visited_coords): 1490
# len(visited_coords): 1491
# len(visited_coords): 1492
# len(visited_coords): 1493
# len(visited_coords): 1494
# len(visited_coords): 1495
# len(visited_coords): 1496
# len(visited_coords): 1497
# len(visited_coords): 1498
# len(visited_coords): 1499
# len(visited_coords): 1500
# len(visited_coords): 1501
# len(visited_coords): 1502
# len(visited_coords): 1503
# len(visited_coords): 1504
# len(visited_coords): 1505
# len(visited_coords): 1506
# len(visited_coords): 1507
# len(visited_coords): 1508
# len(visited_coords): 1509
# len(visited_coords): 1510
# len(visited_coords): 1511
# len(visited_coords): 1512
# len(visited_coords): 1513
# len(visited_coords): 1514
# len(visited_coords): 1515
# len(visited_coords): 1516
# len(visited_coords): 1517
# len(visited_coords): 1518
# len(visited_coords): 1519
# len(visited_coords): 1520
# len(visited_coords): 1521
# len(visited_coords): 1522
# len(visited_coords): 1523
# len(visited_coords): 1524
# len(visited_coords): 1525
# len(visited_coords): 1526
# len(visited_coords): 1527
# len(visited_coords): 1528
# len(visited_coords): 1529
# len(visited_coords): 1530
# len(visited_coords): 1531
# len(visited_coords): 1532
# len(visited_coords): 1533
# len(visited_coords): 1534
# len(visited_coords): 1535
# len(visited_coords): 1536
# len(visited_coords): 1537
# len(visited_coords): 1538
# len(visited_coords): 1539
# len(visited_coords): 1540
# len(visited_coords): 1541
# len(visited_coords): 1542
# len(visited_coords): 1543
# len(visited_coords): 1544
# len(visited_coords): 1545
# len(visited_coords): 1546
# len(visited_coords): 1547
# len(visited_coords): 1548
# len(visited_coords): 1549
# len(visited_coords): 1550
# len(visited_coords): 1551
# len(visited_coords): 1552
# len(visited_coords): 1553
# len(visited_coords): 1554
# len(visited_coords): 1555
# len(visited_coords): 1556
# len(visited_coords): 1557
# len(visited_coords): 1558
# len(visited_coords): 1559
# len(visited_coords): 1560
# len(visited_coords): 1561
# len(visited_coords): 1562
# len(visited_coords): 1563
# len(visited_coords): 1564
# len(visited_coords): 1565
# len(visited_coords): 1566
# len(visited_coords): 1567
# len(visited_coords): 1568
# len(visited_coords): 1569
# len(visited_coords): 1570
# len(visited_coords): 1571
# len(visited_coords): 1572
# len(visited_coords): 1573
# len(visited_coords): 1574
# len(visited_coords): 1575
# len(visited_coords): 1576
# len(visited_coords): 1577
# len(visited_coords): 1578
# len(visited_coords): 1579
# len(visited_coords): 1580
# len(visited_coords): 1581
# len(visited_coords): 1582
# len(visited_coords): 1583
# len(visited_coords): 1584
# len(visited_coords): 1585
# len(visited_coords): 1586
# len(visited_coords): 1587
# len(visited_coords): 1588
# len(visited_coords): 1589
# len(visited_coords): 1590
# len(visited_coords): 1591
# len(visited_coords): 1592
# len(visited_coords): 1593
# len(visited_coords): 1594
# len(visited_coords): 1595
# len(visited_coords): 1596
# len(visited_coords): 1597
# len(visited_coords): 1598
# len(visited_coords): 1599
# len(visited_coords): 1600
# len(visited_coords): 1601
# len(visited_coords): 1602
# len(visited_coords): 1603
# len(visited_coords): 1604
# len(visited_coords): 1605
# len(visited_coords): 1606
# len(visited_coords): 1607
# len(visited_coords): 1608
# len(visited_coords): 1609
# len(visited_coords): 1610
# len(visited_coords): 1611
# len(visited_coords): 1612
# len(visited_coords): 1613
# len(visited_coords): 1614
# len(visited_coords): 1615
# len(visited_coords): 1616
# len(visited_coords): 1617
# len(visited_coords): 1618
# len(visited_coords): 1619
# len(visited_coords): 1620
# len(visited_coords): 1621
# len(visited_coords): 1622
# len(visited_coords): 1623
# len(visited_coords): 1624
# len(visited_coords): 1625
# len(visited_coords): 1626
# len(visited_coords): 1627
# len(visited_coords): 1628
# len(visited_coords): 1629
# len(visited_coords): 1630
# len(visited_coords): 1631
# len(visited_coords): 1632
# len(visited_coords): 1633
# len(visited_coords): 1634
# len(visited_coords): 1635
# len(visited_coords): 1636
# len(visited_coords): 1637
# len(visited_coords): 1638
# len(visited_coords): 1639
# len(visited_coords): 1640
# len(visited_coords): 1641
# len(visited_coords): 1642
# len(visited_coords): 1643
# len(visited_coords): 1644
# len(visited_coords): 1645
# len(visited_coords): 1646
# len(visited_coords): 1647
# len(visited_coords): 1648
# len(visited_coords): 1649
# len(visited_coords): 1650
# len(visited_coords): 1651
# len(visited_coords): 1652
# len(visited_coords): 1653
# len(visited_coords): 1654
# len(visited_coords): 1655
# len(visited_coords): 1656
# len(visited_coords): 1657
# len(visited_coords): 1658
# len(visited_coords): 1659
# len(visited_coords): 1660
# len(visited_coords): 1661
# len(visited_coords): 1662
# len(visited_coords): 1663
# len(visited_coords): 1664
# len(visited_coords): 1665
# len(visited_coords): 1666
# len(visited_coords): 1667
# len(visited_coords): 1668
# len(visited_coords): 1669
# len(visited_coords): 1670
# len(visited_coords): 1671
# len(visited_coords): 1672
# len(visited_coords): 1673
# len(visited_coords): 1674
# len(visited_coords): 1675
# len(visited_coords): 1676
# len(visited_coords): 1677
# len(visited_coords): 1678
# len(visited_coords): 1679
# len(visited_coords): 1680
# len(visited_coords): 1681
# len(visited_coords): 1682
# len(visited_coords): 1683
# len(visited_coords): 1684
# len(visited_coords): 1685
# len(visited_coords): 1686
# len(visited_coords): 1687
# len(visited_coords): 1688
# len(visited_coords): 1689
# len(visited_coords): 1690
# len(visited_coords): 1691
# len(visited_coords): 1692
# len(visited_coords): 1693
# len(visited_coords): 1694
# len(visited_coords): 1695
# len(visited_coords): 1696
# len(visited_coords): 1697
# len(visited_coords): 1698
# len(visited_coords): 1699
# len(visited_coords): 1700
# len(visited_coords): 1701
# len(visited_coords): 1702
# len(visited_coords): 1703
# len(visited_coords): 1704
# len(visited_coords): 1705
# len(visited_coords): 1706
# len(visited_coords): 1707
# len(visited_coords): 1708
# len(visited_coords): 1709
# len(visited_coords): 1710
# len(visited_coords): 1711
# len(visited_coords): 1712
# len(visited_coords): 1713
# len(visited_coords): 1714
# len(visited_coords): 1715
# len(visited_coords): 1716
# len(visited_coords): 1717
# len(visited_coords): 1718
# len(visited_coords): 1719
# len(visited_coords): 1720
# len(visited_coords): 1721
# len(visited_coords): 1722
# len(visited_coords): 1723
# len(visited_coords): 1724
# len(visited_coords): 1725
# len(visited_coords): 1726
# len(visited_coords): 1727
# len(visited_coords): 1728
# len(visited_coords): 1729
# len(visited_coords): 1730
# len(visited_coords): 1731
# len(visited_coords): 1732
# len(visited_coords): 1733
# len(visited_coords): 1734
# len(visited_coords): 1735
# len(visited_coords): 1736
# len(visited_coords): 1737
# len(visited_coords): 1738
# len(visited_coords): 1739
# len(visited_coords): 1740
# len(visited_coords): 1741
# len(visited_coords): 1742
# len(visited_coords): 1743
# len(visited_coords): 1744
# len(visited_coords): 1745
# len(visited_coords): 1746
# len(visited_coords): 1747
# len(visited_coords): 1748
# len(visited_coords): 1749
# len(visited_coords): 1750
# len(visited_coords): 1751
# len(visited_coords): 1752
# len(visited_coords): 1753
# len(visited_coords): 1754
# len(visited_coords): 1755
# len(visited_coords): 1756
# len(visited_coords): 1757
# len(visited_coords): 1758
# len(visited_coords): 1759
# len(visited_coords): 1760
# len(visited_coords): 1761
# len(visited_coords): 1762
# len(visited_coords): 1763
# len(visited_coords): 1764
# len(visited_coords): 1765
# len(visited_coords): 1766
# len(visited_coords): 1767
# len(visited_coords): 1768
# len(visited_coords): 1769
# len(visited_coords): 1770
# len(visited_coords): 1771
# len(visited_coords): 1772
# len(visited_coords): 1773
# len(visited_coords): 1774
# len(visited_coords): 1775
# len(visited_coords): 1776
# len(visited_coords): 1777
# len(visited_coords): 1778
# len(visited_coords): 1779
# len(visited_coords): 1780
# len(visited_coords): 1781
# len(visited_coords): 1782
# len(visited_coords): 1783
# len(visited_coords): 1784
# len(visited_coords): 1785
# len(visited_coords): 1786
# len(visited_coords): 1787
# len(visited_coords): 1788
# len(visited_coords): 1789
# len(visited_coords): 1790
# len(visited_coords): 1791
# len(visited_coords): 1792
# len(visited_coords): 1793
# len(visited_coords): 1794
# len(visited_coords): 1795
# len(visited_coords): 1796
# len(visited_coords): 1797
# len(visited_coords): 1798
# len(visited_coords): 1799
# len(visited_coords): 1800
# len(visited_coords): 1801
# len(visited_coords): 1802
# len(visited_coords): 1803
# len(visited_coords): 1804
# len(visited_coords): 1805
# len(visited_coords): 1806
# len(visited_coords): 1807
# len(visited_coords): 1808
# len(visited_coords): 1809
# len(visited_coords): 1810
# len(visited_coords): 1811
# len(visited_coords): 1812
# len(visited_coords): 1813
# len(visited_coords): 1814
# len(visited_coords): 1815
# len(visited_coords): 1816
# len(visited_coords): 1817
# len(visited_coords): 1818
# len(visited_coords): 1819
# len(visited_coords): 1820
# len(visited_coords): 1821
# len(visited_coords): 1822
# len(visited_coords): 1823
# len(visited_coords): 1824
# len(visited_coords): 1825
# len(visited_coords): 1826
# len(visited_coords): 1827
# len(visited_coords): 1828
# len(visited_coords): 1829
# len(visited_coords): 1830
# len(visited_coords): 1831
# len(visited_coords): 1832
# len(visited_coords): 1833
# len(visited_coords): 1834
# len(visited_coords): 1835
# len(visited_coords): 1836
# len(visited_coords): 1837
# len(visited_coords): 1838
# len(visited_coords): 1839
# len(visited_coords): 1840
# len(visited_coords): 1841
# len(visited_coords): 1842
# len(visited_coords): 1843
# len(visited_coords): 1844
# len(visited_coords): 1845
# len(visited_coords): 1846
# len(visited_coords): 1847
# len(visited_coords): 1848
# len(visited_coords): 1849
# len(visited_coords): 1850
# len(visited_coords): 1851
# len(visited_coords): 1852
# len(visited_coords): 1853
# len(visited_coords): 1854
# len(visited_coords): 1855
# len(visited_coords): 1856
# len(visited_coords): 1857
# len(visited_coords): 1858
# len(visited_coords): 1859
# len(visited_coords): 1860
# len(visited_coords): 1861
# len(visited_coords): 1862
# len(visited_coords): 1863
# len(visited_coords): 1864
# len(visited_coords): 1865
# len(visited_coords): 1866
# len(visited_coords): 1867
# len(visited_coords): 1868
# len(visited_coords): 1869
# len(visited_coords): 1870
# len(visited_coords): 1871
# len(visited_coords): 1872
# len(visited_coords): 1873
# len(visited_coords): 1874
# len(visited_coords): 1875
# len(visited_coords): 1876
# len(visited_coords): 1877
# len(visited_coords): 1878
# len(visited_coords): 1879
# len(visited_coords): 1880
# len(visited_coords): 1881
# len(visited_coords): 1882
# len(visited_coords): 1883
# len(visited_coords): 1884
# len(visited_coords): 1885
# len(visited_coords): 1886
# len(visited_coords): 1887
# len(visited_coords): 1888
# len(visited_coords): 1889
# len(visited_coords): 1890
# len(visited_coords): 1891
# len(visited_coords): 1892
# len(visited_coords): 1893
# len(visited_coords): 1894
# len(visited_coords): 1895
# len(visited_coords): 1896
# len(visited_coords): 1897
# len(visited_coords): 1898
# len(visited_coords): 1899
# len(visited_coords): 1900
# len(visited_coords): 1901
# len(visited_coords): 1902
# len(visited_coords): 1903
# len(visited_coords): 1904
# len(visited_coords): 1905
# len(visited_coords): 1906
# len(visited_coords): 1907
# len(visited_coords): 1908
# len(visited_coords): 1909
# len(visited_coords): 1910
# len(visited_coords): 1911
# len(visited_coords): 1912
# len(visited_coords): 1913
# len(visited_coords): 1914
# len(visited_coords): 1915
# len(visited_coords): 1916
# len(visited_coords): 1917
# len(visited_coords): 1918
# len(visited_coords): 1919
# len(visited_coords): 1920
# len(visited_coords): 1921
# len(visited_coords): 1922
# len(visited_coords): 1923
# len(visited_coords): 1924
# len(visited_coords): 1925
# len(visited_coords): 1926
# len(visited_coords): 1927
# len(visited_coords): 1928
# len(visited_coords): 1929
# len(visited_coords): 1930
# len(visited_coords): 1931
# len(visited_coords): 1932
# len(visited_coords): 1933
# len(visited_coords): 1934
# len(visited_coords): 1935
# len(visited_coords): 1936
# len(visited_coords): 1937
# len(visited_coords): 1938
# len(visited_coords): 1939
# len(visited_coords): 1940
# len(visited_coords): 1941
# len(visited_coords): 1942
# len(visited_coords): 1943
# len(visited_coords): 1944
# len(visited_coords): 1945
# len(visited_coords): 1946
# len(visited_coords): 1947
# len(visited_coords): 1948
# len(visited_coords): 1949
# len(visited_coords): 1950
# len(visited_coords): 1951
# len(visited_coords): 1952
# len(visited_coords): 1953
# len(visited_coords): 1954
# len(visited_coords): 1955
# len(visited_coords): 1956
# len(visited_coords): 1957
# len(visited_coords): 1958
# len(visited_coords): 1959
# len(visited_coords): 1960
# len(visited_coords): 1961
# len(visited_coords): 1962
# len(visited_coords): 1963
# len(visited_coords): 1964
# len(visited_coords): 1965
# len(visited_coords): 1966
# len(visited_coords): 1967
# len(visited_coords): 1968
# len(visited_coords): 1969
# len(visited_coords): 1970
# len(visited_coords): 1971
# len(visited_coords): 1972
# len(visited_coords): 1973
# len(visited_coords): 1974
# len(visited_coords): 1975
# len(visited_coords): 1976
# len(visited_coords): 1977
# len(visited_coords): 1978
# len(visited_coords): 1979
# len(visited_coords): 1980
# len(visited_coords): 1981
# len(visited_coords): 1982
# len(visited_coords): 1983
# len(visited_coords): 1984
# len(visited_coords): 1985
# len(visited_coords): 1986
# len(visited_coords): 1987
# len(visited_coords): 1988
# len(visited_coords): 1989
# len(visited_coords): 1990
# len(visited_coords): 1991
# len(visited_coords): 1992
# len(visited_coords): 1993
# len(visited_coords): 1994
# len(visited_coords): 1995
# len(visited_coords): 1996
# len(visited_coords): 1997
# len(visited_coords): 1998
# len(visited_coords): 1999
# len(visited_coords): 2000
# len(visited_coords): 2001
# len(visited_coords): 2002
# len(visited_coords): 2003
# len(visited_coords): 2004
# len(visited_coords): 2005
# len(visited_coords): 2006
# len(visited_coords): 2007
# len(visited_coords): 2008
# len(visited_coords): 2009
# len(visited_coords): 2010
# len(visited_coords): 2011
# len(visited_coords): 2012
# len(visited_coords): 2013
# len(visited_coords): 2014
# len(visited_coords): 2015
# len(visited_coords): 2016
# len(visited_coords): 2017
# len(visited_coords): 2018
# len(visited_coords): 2019
# len(visited_coords): 2020
# len(visited_coords): 2021
# len(visited_coords): 2022
# len(visited_coords): 2023
# len(visited_coords): 2024
# len(visited_coords): 2025
# len(visited_coords): 2026
# len(visited_coords): 2027
# len(visited_coords): 2028
# len(visited_coords): 2029
# len(visited_coords): 2030
# len(visited_coords): 2031
# len(visited_coords): 2032
# len(visited_coords): 2033
# len(visited_coords): 2034
# len(visited_coords): 2035
# len(visited_coords): 2036
# len(visited_coords): 2037
# len(visited_coords): 2038
# len(visited_coords): 2039
# len(visited_coords): 2040
# len(visited_coords): 2041
# len(visited_coords): 2042
# len(visited_coords): 2043
# len(visited_coords): 2044
# len(visited_coords): 2045
# len(visited_coords): 2046
# len(visited_coords): 2047
# len(visited_coords): 2048
# len(visited_coords): 2049
# len(visited_coords): 2050
# len(visited_coords): 2051
# len(visited_coords): 2052
# len(visited_coords): 2053
# len(visited_coords): 2054
# len(visited_coords): 2055
# len(visited_coords): 2056
# len(visited_coords): 2057
# len(visited_coords): 2058
# len(visited_coords): 2059
# len(visited_coords): 2060
# len(visited_coords): 2061
# len(visited_coords): 2062
# len(visited_coords): 2063
# len(visited_coords): 2064
# len(visited_coords): 2065
# len(visited_coords): 2066
# len(visited_coords): 2067
# len(visited_coords): 2068
# len(visited_coords): 2069
# len(visited_coords): 2070
# len(visited_coords): 2071
# len(visited_coords): 2072
# len(visited_coords): 2073
# len(visited_coords): 2074
# len(visited_coords): 2075
# len(visited_coords): 2076
# len(visited_coords): 2077
# len(visited_coords): 2078
# len(visited_coords): 2079
# len(visited_coords): 2080
# len(visited_coords): 2081
# len(visited_coords): 2082
# len(visited_coords): 2083
# len(visited_coords): 2084
# len(visited_coords): 2085
# len(visited_coords): 2086
# len(visited_coords): 2087
# len(visited_coords): 2088
# len(visited_coords): 2089
# len(visited_coords): 2090
# len(visited_coords): 2091
# len(visited_coords): 2092
# len(visited_coords): 2093
# len(visited_coords): 2094
# len(visited_coords): 2095
# len(visited_coords): 2096
# len(visited_coords): 2097
# len(visited_coords): 2098
# len(visited_coords): 2099
# len(visited_coords): 2100
# len(visited_coords): 2101
# len(visited_coords): 2102
# len(visited_coords): 2103
# len(visited_coords): 2104
# len(visited_coords): 2105
# len(visited_coords): 2106
# len(visited_coords): 2107
# len(visited_coords): 2108
# len(visited_coords): 2109
# len(visited_coords): 2110
# len(visited_coords): 2111
# len(visited_coords): 2112
# len(visited_coords): 2113
# len(visited_coords): 2114
# len(visited_coords): 2115
# len(visited_coords): 2116
# len(visited_coords): 2117
# len(visited_coords): 2118
# len(visited_coords): 2119
# len(visited_coords): 2120
# len(visited_coords): 2121
# len(visited_coords): 2122
# len(visited_coords): 2123
# len(visited_coords): 2124
# len(visited_coords): 2125
# len(visited_coords): 2126
# len(visited_coords): 2127
# len(visited_coords): 2128
# len(visited_coords): 2129
# len(visited_coords): 2130
# len(visited_coords): 2131
# len(visited_coords): 2132
# len(visited_coords): 2133
# len(visited_coords): 2134
# len(visited_coords): 2135
# len(visited_coords): 2136
# len(visited_coords): 2137
# len(visited_coords): 2138
# len(visited_coords): 2139
# len(visited_coords): 2140
# len(visited_coords): 2141
# len(visited_coords): 2142
# len(visited_coords): 2143
# len(visited_coords): 2144
# len(visited_coords): 2145
# len(visited_coords): 2146
# len(visited_coords): 2147
# len(visited_coords): 2148
# len(visited_coords): 2149
# len(visited_coords): 2150
# len(visited_coords): 2151
# len(visited_coords): 2152
# len(visited_coords): 2153
# len(visited_coords): 2154
# len(visited_coords): 2155
# len(visited_coords): 2156
# len(visited_coords): 2157
# len(visited_coords): 2158
# len(visited_coords): 2159
# len(visited_coords): 2160
# len(visited_coords): 2161
# len(visited_coords): 2162
# len(visited_coords): 2163
# len(visited_coords): 2164
# len(visited_coords): 2165
# len(visited_coords): 2166
# len(visited_coords): 2167
# len(visited_coords): 2168
# len(visited_coords): 2169
# len(visited_coords): 2170
# len(visited_coords): 2171
# len(visited_coords): 2172
# len(visited_coords): 2173
# len(visited_coords): 2174
# len(visited_coords): 2175
# len(visited_coords): 2176
# len(visited_coords): 2177
# len(visited_coords): 2178
# len(visited_coords): 2179
# len(visited_coords): 2180
# len(visited_coords): 2181
# len(visited_coords): 2182
# len(visited_coords): 2183
# len(visited_coords): 2184
# len(visited_coords): 2185
# len(visited_coords): 2186
# len(visited_coords): 2187
# len(visited_coords): 2188
# len(visited_coords): 2189
# len(visited_coords): 2190
# len(visited_coords): 2191
# len(visited_coords): 2192
# len(visited_coords): 2193
# len(visited_coords): 2194
# len(visited_coords): 2195
# len(visited_coords): 2196
# len(visited_coords): 2197
# len(visited_coords): 2198
# len(visited_coords): 2199
# len(visited_coords): 2200
# len(visited_coords): 2201
# len(visited_coords): 2202
# len(visited_coords): 2203
# len(visited_coords): 2204
# len(visited_coords): 2205
# len(visited_coords): 2206
# len(visited_coords): 2207
# len(visited_coords): 2208
# len(visited_coords): 2209
# len(visited_coords): 2210
# len(visited_coords): 2211
# len(visited_coords): 2212
# len(visited_coords): 2213
# len(visited_coords): 2214
# len(visited_coords): 2215
# len(visited_coords): 2216
# len(visited_coords): 2217
# len(visited_coords): 2218
# len(visited_coords): 2219
# len(visited_coords): 2220
# len(visited_coords): 2221
# len(visited_coords): 2222
# len(visited_coords): 2223
# len(visited_coords): 2224
# len(visited_coords): 2225
# len(visited_coords): 2226
# len(visited_coords): 2227
# len(visited_coords): 2228

# %%
for city_num in range(1000, 1861):
    root_dir = '/mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city'
    savepath = f"{root_dir}/dat/prf_updw/vld_cty_/city_{city_num:08}.gl5"
    
    prf_path = f"{root_dir}/dat/cty_prf_/vld_cty_/city_{city_num:08}.gl5"
    if not os.path.exists(prf_path):
        print(f'{city_num} is invalid prf')
        continue 
    
    riv_path_array =  exeption_rivergrid(city_num, riv_nxlonlat_cropped)
    
    riv_path_array.astype(np.float32).tofile(savepath)
    print(f"{savepath} saved")
