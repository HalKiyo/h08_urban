# %%
import os
import math
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.colors as colors
import cartopy.crs as ccrs
import cartopy.feature as cfea
import cartopy.io.shapereader as shapereader

# %%
def l_coordinate_to_tuple(lcoordinate, a=2160, b=4320):
    lat_l = ((lcoordinate - 1) // b)
    lon_l = (lcoordinate) % b - 1
    return (lat_l, lon_l)

def nxtl2nxtxy(rgnfile, upperindex, leftindex):
    vfunc = np.vectorize(l_coordinate_to_tuple, otypes=[tuple])
    riv_nxtxy = np.empty(rgnfile.shape, dtype=tuple)
    mask = ~np.isnan(rgnfile)
    riv_nxtxy[mask] = vfunc(rgnfile[mask])
    riv_nxtxy_shape = (riv_nxtxy.shape[0], riv_nxtxy.shape[1], 2)
    
    riv_nxtxy_lst = []
    for row in riv_nxtxy:
        for y, x in row:
            modified_y = y - upperindex
            modified_x = x - leftindex
            riv_nxtxy_lst.append((modified_y, modified_x))

    riv_nxtxy_cropped = np.array(riv_nxtxy_lst).reshape(riv_nxtxy_shape)
    riv_nxtxy_cropped = riv_nxtxy_cropped.astype(int)
    return riv_nxtxy_cropped
    
# rivnxl in xy coord
h08dir = '/mnt/c/Users/tsimk/Downloads/dotfiles/h08'
rivnxl_path = f"{h08dir}/global_city/dat/riv_nxl_/rivnxl.CAMA.gl5"
rivnxl_gl5 = np.fromfile(rivnxl_path, 'float32').reshape(2160, 4320)
riv_nxlonlat_cropped = nxtl2nxtxy(rivnxl_gl5, 0, 0)

#######################################
# start ####
#######################################
city_num = 1

def exeption_rivergrid(city_num, riv_nxlonlat_cropped):
    # coord of purficication
    root_dir = '/mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city'
    prf_path = f"{root_dir}/dat/cty_prf_/vld_cty_/city_{city_num:08}.gl5"
        
    prf = np.fromfile(prf_path, dtype='float32').reshape(2160, 4320)
    prf_coords = np.where(prf == 1)
    print(f'citynum: {city_num}, coord of prfs: {prf_coords}')
    
    # save variable
    riv_path_array = np.zeros((2160, 4320))
    
    # initial grid
    for pid in range(len(prf_coords[0])):
        print(f'pid == {pid}, len(prf_coords) == {len(prf_coords[0])}')
        
        # down stream exploration
        target_coord = (prf_coords[0][pid], prf_coords[1][pid])
        visited_coords = set()
        while True:
            if target_coord in visited_coords:
                break
            visited_coords.add(target_coord)
            target_row, target_col = target_coord
            next_coord = riv_nxlonlat_cropped[target_row, target_col]
            if next_coord.size == 0 or next_coord.shape != (2,):
                break
            target_coord = (next_coord[0], next_coord[1])

        # update riv_path_array
        for row, col in visited_coords:
            riv_path_array[row, col] = city_num
    
        # up stream exploration
        def explore_upstream(target_coord, visited_coords, riv_nxlonlat_cropped, city_num):
            while True:
                if target_coord in visited_coords:
                    break
                visited_coords.add(target_coord)
                matched_coords = np.argwhere(np.all(target_coord == riv_nxlonlat_cropped, axis=2))
                if len(matched_coords) == 0:
                    break
                unvisited_matched = [tuple(coord) for coord in matched_coords if tuple(coord) not in visited_coords]
                for up_coord in unvisited_matched:
                    explore_upstream(up_coord, visited_coords, riv_nxlonlat_cropped, city_num)

        # execute function
        target_coord = (prf_coords[0][pid], prf_coords[1][pid])
        visited_coords = set()
        explore_upstream(target_coord, visited_coords, riv_nxlonlat_cropped, city_num)
        
        # update riv_path_array
        for row, col in visited_coords:
            riv_path_array[row, col] = city_num
    
    return riv_path_array

# %%
for city_num in range(151, 1861):
    root_dir = '/mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city'
    savepath = f"{root_dir}/dat/prf_updw/vld_cty_/city_{city_num:08}.gl5"
    
    prf_path = f"{root_dir}/dat/cty_prf_/vld_cty_/city_{city_num:08}.gl5"
    if not os.path.exists(prf_path):
        print(f'{city_num} is invalid prf')
        continue 
    
    riv_path_array =  exeption_rivergrid(city_num, riv_nxlonlat_cropped)
    
    riv_path_array.astype(np.float32).tofile(savepath)
    print(f"{savepath} saved")
# Out:
# citynum: 151, coord of prfs: (array([538]), array([1039]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000151.gl5 saved
# 152 is invalid prf
# citynum: 153, coord of prfs: (array([857]), array([1322]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000153.gl5 saved
# citynum: 154, coord of prfs: (array([736]), array([3550]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000154.gl5 saved
# citynum: 155, coord of prfs: (array([1381]), array([1470]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000155.gl5 saved
# citynum: 156, coord of prfs: (array([562]), array([3859]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000156.gl5 saved
# citynum: 157, coord of prfs: (array([904, 904]), array([1073, 1074]))
# pid == 0, len(prf_coords) == 2
# pid == 1, len(prf_coords) == 2
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000157.gl5 saved
# citynum: 158, coord of prfs: (array([629]), array([3683]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000158.gl5 saved
# citynum: 159, coord of prfs: (array([436]), array([2132]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000159.gl5 saved
# citynum: 160, coord of prfs: (array([698]), array([3598]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000160.gl5 saved
# citynum: 161, coord of prfs: (array([762]), array([3439]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000161.gl5 saved
# citynum: 162, coord of prfs: (array([1102, 1106]), array([1200, 1197]))
# pid == 0, len(prf_coords) == 2
# pid == 1, len(prf_coords) == 2
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000162.gl5 saved
# citynum: 163, coord of prfs: (array([861, 862]), array([1367, 1366]))
# pid == 0, len(prf_coords) == 2
# pid == 1, len(prf_coords) == 2
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000163.gl5 saved
# citynum: 164, coord of prfs: (array([825]), array([3107]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000164.gl5 saved
# citynum: 165, coord of prfs: (array([741, 742, 745]), array([1170, 1171, 1173]))
# pid == 0, len(prf_coords) == 3
# pid == 1, len(prf_coords) == 3
# pid == 2, len(prf_coords) == 3
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000165.gl5 saved
# citynum: 166, coord of prfs: (array([639]), array([2196]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000166.gl5 saved
# citynum: 167, coord of prfs: (array([448, 450]), array([2135, 2135]))
# pid == 0, len(prf_coords) == 2
# pid == 1, len(prf_coords) == 2
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000167.gl5 saved
# 168 is invalid prf
# citynum: 169, coord of prfs: (array([646]), array([3403]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000169.gl5 saved
# citynum: 170, coord of prfs: (array([677]), array([2594]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000170.gl5 saved
# citynum: 171, coord of prfs: (array([1163]), array([3452]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000171.gl5 saved
# citynum: 172, coord of prfs: (array([605]), array([899]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000172.gl5 saved
# citynum: 173, coord of prfs: (array([1029, 1031]), array([2277, 2277]))
# pid == 0, len(prf_coords) == 2
# pid == 1, len(prf_coords) == 2
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000173.gl5 saved
# 174 is invalid prf
# citynum: 175, coord of prfs: (array([1033]), array([2297]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000175.gl5 saved
# citynum: 176, coord of prfs: (array([1040]), array([1241]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000176.gl5 saved
# citynum: 177, coord of prfs: (array([649]), array([3704]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000177.gl5 saved
# citynum: 178, coord of prfs: (array([487, 489, 491]), array([682, 689, 690]))
# pid == 0, len(prf_coords) == 3
# pid == 1, len(prf_coords) == 3
# pid == 2, len(prf_coords) == 3
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000178.gl5 saved
# citynum: 179, coord of prfs: (array([640]), array([3575]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000179.gl5 saved
# citynum: 180, coord of prfs: (array([585]), array([2992]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000180.gl5 saved
# citynum: 181, coord of prfs: (array([587]), array([2331]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000181.gl5 saved
# citynum: 182, coord of prfs: (array([607, 608]), array([1238, 1238]))
# pid == 0, len(prf_coords) == 2
# pid == 1, len(prf_coords) == 2
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000182.gl5 saved
# citynum: 183, coord of prfs: (array([602, 602]), array([3577, 3580]))
# pid == 0, len(prf_coords) == 2
# pid == 1, len(prf_coords) == 2
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000183.gl5 saved
# citynum: 184, coord of prfs: (array([617, 617, 618, 619, 621]), array([3854, 3855, 3847, 3843, 3848]))
# pid == 0, len(prf_coords) == 5
# pid == 1, len(prf_coords) == 5
# pid == 2, len(prf_coords) == 5
# pid == 3, len(prf_coords) == 5
# pid == 4, len(prf_coords) == 5
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000184.gl5 saved
# citynum: 185, coord of prfs: (array([615]), array([1072]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000185.gl5 saved
# citynum: 186, coord of prfs: (array([803]), array([1174]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000186.gl5 saved
# citynum: 187, coord of prfs: (array([857]), array([1292]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000187.gl5 saved
# citynum: 188, coord of prfs: (array([808]), array([3070]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000188.gl5 saved
# citynum: 189, coord of prfs: (array([1036]), array([3344]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000189.gl5 saved
# citynum: 190, coord of prfs: (array([665, 666, 666, 667]), array([3754, 3745, 3752, 3746]))
# pid == 0, len(prf_coords) == 4
# pid == 1, len(prf_coords) == 4
# pid == 2, len(prf_coords) == 4
# pid == 3, len(prf_coords) == 4
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000190.gl5 saved
# citynum: 191, coord of prfs: (array([948]), array([3080]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000191.gl5 saved
# citynum: 192, coord of prfs: (array([896]), array([2690]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000192.gl5 saved
# citynum: 193, coord of prfs: (array([957]), array([3075]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000193.gl5 saved
# citynum: 194, coord of prfs: (array([594]), array([2756]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000194.gl5 saved
# citynum: 195, coord of prfs: (array([1012]), array([2156]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000195.gl5 saved
# citynum: 196, coord of prfs: (array([1278]), array([1567]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000196.gl5 saved
# citynum: 197, coord of prfs: (array([772]), array([3181]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000197.gl5 saved
# citynum: 198, coord of prfs: (array([1096, 1096]), array([1580, 1581]))
# pid == 0, len(prf_coords) == 2
# pid == 1, len(prf_coords) == 2
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000198.gl5 saved
# citynum: 199, coord of prfs: (array([1307]), array([2730]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000199.gl5 saved
# citynum: 200, coord of prfs: (array([1076]), array([2550]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000200.gl5 saved
# citynum: 201, coord of prfs: (array([639]), array([2282]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000201.gl5 saved
# citynum: 202, coord of prfs: (array([999]), array([2141]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000202.gl5 saved
# citynum: 203, coord of prfs: (array([1407, 1410, 1412]), array([3995, 3993, 3997]))
# pid == 0, len(prf_coords) == 3
# pid == 1, len(prf_coords) == 3
# pid == 2, len(prf_coords) == 3
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000203.gl5 saved
# citynum: 204, coord of prfs: (array([729]), array([2735]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000204.gl5 saved
# citynum: 205, coord of prfs: (array([673, 675]), array([2588, 2587]))
# pid == 0, len(prf_coords) == 2
# pid == 1, len(prf_coords) == 2
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000205.gl5 saved
# citynum: 206, coord of prfs: (array([779]), array([3617]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000206.gl5 saved
# citynum: 207, coord of prfs: (array([943, 944, 948]), array([3070, 3071, 3072]))
# pid == 0, len(prf_coords) == 3
# pid == 1, len(prf_coords) == 3
# pid == 2, len(prf_coords) == 3
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000207.gl5 saved
# citynum: 208, coord of prfs: (array([672]), array([751]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000208.gl5 saved
# citynum: 209, coord of prfs: (array([849]), array([965]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000209.gl5 saved
# citynum: 210, coord of prfs: (array([470]), array([2212]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000210.gl5 saved
# citynum: 211, coord of prfs: (array([644]), array([777]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000211.gl5 saved
# citynum: 212, coord of prfs: (array([546]), array([2471]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000212.gl5 saved
# citynum: 213, coord of prfs: (array([928]), array([2063]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000213.gl5 saved
# citynum: 214, coord of prfs: (array([777, 778]), array([2825, 2824]))
# pid == 0, len(prf_coords) == 2
# pid == 1, len(prf_coords) == 2
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000214.gl5 saved
# citynum: 215, coord of prfs: (array([949]), array([1263]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000215.gl5 saved
# citynum: 216, coord of prfs: (array([533]), array([691]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000216.gl5 saved
# citynum: 217, coord of prfs: (array([801]), array([3087]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000217.gl5 saved
# citynum: 218, coord of prfs: (array([952]), array([1299]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000218.gl5 saved
# citynum: 219, coord of prfs: (array([432]), array([2489]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000219.gl5 saved
# citynum: 220, coord of prfs: (array([638]), array([3533]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000220.gl5 saved
# citynum: 221, coord of prfs: (array([677]), array([3037]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000221.gl5 saved
# citynum: 222, coord of prfs: (array([641]), array([3589]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000222.gl5 saved
# citynum: 223, coord of prfs: (array([1022]), array([2245]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000223.gl5 saved
# citynum: 224, coord of prfs: (array([973]), array([2249]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000224.gl5 saved
# 225 is invalid prf
# citynum: 226, coord of prfs: (array([810]), array([3036]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000226.gl5 saved
# citynum: 227, coord of prfs: (array([948, 949, 954]), array([3072, 3072, 3073]))
# pid == 0, len(prf_coords) == 3
# pid == 1, len(prf_coords) == 3
# pid == 2, len(prf_coords) == 3
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000227.gl5 saved
# citynum: 228, coord of prfs: (array([1117]), array([1439]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000228.gl5 saved
# citynum: 229, coord of prfs: (array([582]), array([1180]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000229.gl5 saved
# citynum: 230, coord of prfs: (array([630, 632]), array([3612, 3617]))
# pid == 0, len(prf_coords) == 2
# pid == 1, len(prf_coords) == 2
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000230.gl5 saved
# citynum: 231, coord of prfs: (array([802]), array([3534]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000231.gl5 saved
# citynum: 232, coord of prfs: (array([438]), array([2283]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000232.gl5 saved
# citynum: 233, coord of prfs: (array([723]), array([982]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000233.gl5 saved
# citynum: 234, coord of prfs: (array([435]), array([2137]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000234.gl5 saved
# citynum: 235, coord of prfs: (array([591]), array([3478]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000235.gl5 saved
# citynum: 236, coord of prfs: (array([687, 690]), array([755, 757]))
# pid == 0, len(prf_coords) == 2
# pid == 1, len(prf_coords) == 2
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000236.gl5 saved
# 237 is invalid prf
# citynum: 238, coord of prfs: (array([931]), array([2140]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000238.gl5 saved
# citynum: 239, coord of prfs: (array([541]), array([2252]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000239.gl5 saved
# citynum: 240, coord of prfs: (array([508]), array([2389]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000240.gl5 saved
# citynum: 241, coord of prfs: (array([593]), array([1202]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000241.gl5 saved
# citynum: 242, coord of prfs: (array([616]), array([701]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000242.gl5 saved
# citynum: 243, coord of prfs: (array([753]), array([3095]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000243.gl5 saved
# citynum: 244, coord of prfs: (array([500]), array([2356]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000244.gl5 saved
# citynum: 245, coord of prfs: (array([1265]), array([2500]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000245.gl5 saved
# citynum: 246, coord of prfs: (array([668, 669]), array([3565, 3565]))
# pid == 0, len(prf_coords) == 2
# pid == 1, len(prf_coords) == 2
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000246.gl5 saved
# citynum: 247, coord of prfs: (array([1462]), array([3552]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000247.gl5 saved
# citynum: 248, coord of prfs: (array([690]), array([2778]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000248.gl5 saved
# citynum: 249, coord of prfs: (array([672]), array([2079]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000249.gl5 saved
# citynum: 250, coord of prfs: (array([664]), array([3508]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000250.gl5 saved
# citynum: 251, coord of prfs: (array([453]), array([2413]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000251.gl5 saved
# citynum: 252, coord of prfs: (array([718]), array([3603]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000252.gl5 saved
# citynum: 253, coord of prfs: (array([866]), array([3158]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000253.gl5 saved
# citynum: 254, coord of prfs: (array([1323, 1325]), array([1676, 1675]))
# pid == 0, len(prf_coords) == 2
# pid == 1, len(prf_coords) == 2
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000254.gl5 saved
# citynum: 255, coord of prfs: (array([632, 633]), array([698, 697]))
# pid == 0, len(prf_coords) == 2
# pid == 1, len(prf_coords) == 2
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000255.gl5 saved
# citynum: 256, coord of prfs: (array([1392]), array([2498]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000256.gl5 saved
# citynum: 257, coord of prfs: (array([1364, 1366]), array([1602, 1602]))
# pid == 0, len(prf_coords) == 2
# pid == 1, len(prf_coords) == 2
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000257.gl5 saved
# citynum: 258, coord of prfs: (array([1496]), array([1488]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000258.gl5 saved
# citynum: 259, coord of prfs: (array([956]), array([1343]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000259.gl5 saved
# citynum: 260, coord of prfs: (array([693]), array([3051]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000260.gl5 saved
# citynum: 261, coord of prfs: (array([1219]), array([2487]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000261.gl5 saved
# citynum: 262, coord of prfs: (array([678]), array([3589]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000262.gl5 saved
# citynum: 263, coord of prfs: (array([1274]), array([1342]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000263.gl5 saved
# citynum: 264, coord of prfs: (array([978]), array([3084]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000264.gl5 saved
# citynum: 265, coord of prfs: (array([611]), array([1148]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000265.gl5 saved
# citynum: 266, coord of prfs: (array([597]), array([2509]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000266.gl5 saved
# citynum: 267, coord of prfs: (array([411]), array([2113]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000267.gl5 saved
# citynum: 268, coord of prfs: (array([947, 949]), array([3072, 3072]))
# pid == 0, len(prf_coords) == 2
# pid == 1, len(prf_coords) == 2
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000268.gl5 saved
# citynum: 269, coord of prfs: (array([825]), array([940]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000269.gl5 saved
# citynum: 270, coord of prfs: (array([936]), array([3064]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000270.gl5 saved
# citynum: 271, coord of prfs: (array([787]), array([3471]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000271.gl5 saved
# citynum: 272, coord of prfs: (array([711]), array([3071]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000272.gl5 saved
# 273 is invalid prf
# citynum: 274, coord of prfs: (array([1084]), array([1217]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000274.gl5 saved
# citynum: 275, coord of prfs: (array([695]), array([3609]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000275.gl5 saved
# citynum: 276, coord of prfs: (array([717]), array([3018]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000276.gl5 saved
# citynum: 277, coord of prfs: (array([529]), array([2217]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000277.gl5 saved
# 278 is invalid prf
# citynum: 279, coord of prfs: (array([690]), array([3592]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000279.gl5 saved
# citynum: 280, coord of prfs: (array([614]), array([3542]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000280.gl5 saved
# citynum: 281, coord of prfs: (array([557, 560]), array([2225, 2226]))
# pid == 0, len(prf_coords) == 2
# pid == 1, len(prf_coords) == 2
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000281.gl5 saved
# citynum: 282, coord of prfs: (array([1164]), array([3483]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000282.gl5 saved
# citynum: 283, coord of prfs: (array([649]), array([2775]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000283.gl5 saved
# citynum: 284, coord of prfs: (array([674]), array([3019]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000284.gl5 saved
# 285 is invalid prf
# citynum: 286, coord of prfs: (array([634]), array([2583]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000286.gl5 saved
# citynum: 287, coord of prfs: (array([841]), array([3045]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000287.gl5 saved
# citynum: 288, coord of prfs: (array([609]), array([1023]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000288.gl5 saved
# citynum: 289, coord of prfs: (array([941]), array([3417]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000289.gl5 saved
# citynum: 290, coord of prfs: (array([740]), array([1182]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000290.gl5 saved
# citynum: 291, coord of prfs: (array([964]), array([1997]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000291.gl5 saved
# citynum: 292, coord of prfs: (array([808]), array([3604]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000292.gl5 saved
# citynum: 293, coord of prfs: (array([658]), array([3580]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000293.gl5 saved
# citynum: 294, coord of prfs: (array([971, 973]), array([1204, 1201]))
# pid == 0, len(prf_coords) == 2
# pid == 1, len(prf_coords) == 2
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000294.gl5 saved
# citynum: 295, coord of prfs: (array([587]), array([3636]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000295.gl5 saved
# citynum: 296, coord of prfs: (array([775]), array([2979]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000296.gl5 saved
# citynum: 297, coord of prfs: (array([642]), array([3689]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000297.gl5 saved
# citynum: 298, coord of prfs: (array([599]), array([1127]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000298.gl5 saved
# citynum: 299, coord of prfs: (array([840]), array([3484]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000299.gl5 saved
# citynum: 300, coord of prfs: (array([589]), array([3500]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000300.gl5 saved
# citynum: 301, coord of prfs: (array([1294]), array([2533]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000301.gl5 saved
# citynum: 302, coord of prfs: (array([421]), array([3156]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000302.gl5 saved
# citynum: 303, coord of prfs: (array([657]), array([3681]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000303.gl5 saved
# citynum: 304, coord of prfs: (array([622]), array([2715]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000304.gl5 saved
# citynum: 305, coord of prfs: (array([1004, 1006]), array([2174, 2175]))
# pid == 0, len(prf_coords) == 2
# pid == 1, len(prf_coords) == 2
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000305.gl5 saved
# citynum: 306, coord of prfs: (array([679]), array([3600]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000306.gl5 saved
# citynum: 307, coord of prfs: (array([1116]), array([3415]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000307.gl5 saved
# citynum: 308, coord of prfs: (array([1455]), array([1388]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000308.gl5 saved
# citynum: 309, coord of prfs: (array([993]), array([3665]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000309.gl5 saved
# citynum: 310, coord of prfs: (array([806]), array([3519]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000310.gl5 saved
# citynum: 311, coord of prfs: (array([479]), array([2596]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000311.gl5 saved
# citynum: 312, coord of prfs: (array([554]), array([3679]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000312.gl5 saved
# citynum: 313, coord of prfs: (array([960, 961]), array([3096, 3096]))
# pid == 0, len(prf_coords) == 2
# pid == 1, len(prf_coords) == 2
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000313.gl5 saved
# citynum: 314, coord of prfs: (array([882]), array([3127]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000314.gl5 saved
# citynum: 315, coord of prfs: (array([639, 639]), array([1243, 1245]))
# pid == 0, len(prf_coords) == 2
# pid == 1, len(prf_coords) == 2
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000315.gl5 saved
# citynum: 316, coord of prfs: (array([695]), array([3504]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000316.gl5 saved
# citynum: 317, coord of prfs: (array([562]), array([3082]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000317.gl5 saved
# citynum: 318, coord of prfs: (array([520]), array([3657]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000318.gl5 saved
# citynum: 319, coord of prfs: (array([776]), array([3152]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000319.gl5 saved
# citynum: 320, coord of prfs: (array([736]), array([3615]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000320.gl5 saved
# citynum: 321, coord of prfs: (array([731]), array([3093]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000321.gl5 saved
# citynum: 322, coord of prfs: (array([696]), array([2590]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000322.gl5 saved
# 323 is invalid prf
# citynum: 324, coord of prfs: (array([560]), array([1104]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000324.gl5 saved
# citynum: 325, coord of prfs: (array([715, 720]), array([984, 985]))
# pid == 0, len(prf_coords) == 2
# pid == 1, len(prf_coords) == 2
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000325.gl5 saved
# citynum: 326, coord of prfs: (array([596]), array([1162]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000326.gl5 saved
# citynum: 327, coord of prfs: (array([1295]), array([1406]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000327.gl5 saved
# citynum: 328, coord of prfs: (array([813, 813, 814]), array([3011, 3012, 3012]))
# pid == 0, len(prf_coords) == 3
# pid == 1, len(prf_coords) == 3
# pid == 2, len(prf_coords) == 3
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000328.gl5 saved
# citynum: 329, coord of prfs: (array([367, 369]), array([2373, 2375]))
# pid == 0, len(prf_coords) == 2
# pid == 1, len(prf_coords) == 2
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000329.gl5 saved
# citynum: 330, coord of prfs: (array([510]), array([3647]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000330.gl5 saved
# citynum: 331, coord of prfs: (array([812]), array([3522]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000331.gl5 saved
# citynum: 332, coord of prfs: (array([1054]), array([2704]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000332.gl5 saved
# citynum: 333, coord of prfs: (array([502]), array([2298]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000333.gl5 saved
# citynum: 334, coord of prfs: (array([598]), array([3519]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000334.gl5 saved
# citynum: 335, coord of prfs: (array([396, 399]), array([2884, 2883]))
# pid == 0, len(prf_coords) == 2
# pid == 1, len(prf_coords) == 2
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000335.gl5 saved
# citynum: 336, coord of prfs: (array([664]), array([2599]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000336.gl5 saved
# citynum: 337, coord of prfs: (array([540]), array([2403]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000337.gl5 saved
# citynum: 338, coord of prfs: (array([1524]), array([4259]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000338.gl5 saved
# citynum: 339, coord of prfs: (array([1142, 1142]), array([3593, 3594]))
# pid == 0, len(prf_coords) == 2
# pid == 1, len(prf_coords) == 2
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000339.gl5 saved
# citynum: 340, coord of prfs: (array([698]), array([882]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000340.gl5 saved
# citynum: 341, coord of prfs: (array([1109]), array([1629]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000341.gl5 saved
# citynum: 342, coord of prfs: (array([806]), array([3194]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000342.gl5 saved
# citynum: 343, coord of prfs: (array([1474]), array([1431]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000343.gl5 saved
# citynum: 344, coord of prfs: (array([577]), array([3647]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000344.gl5 saved
# citynum: 345, coord of prfs: (array([634, 634]), array([2604, 2606]))
# pid == 0, len(prf_coords) == 2
# pid == 1, len(prf_coords) == 2
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000345.gl5 saved
# citynum: 346, coord of prfs: (array([1007]), array([2227]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000346.gl5 saved
# citynum: 347, coord of prfs: (array([654]), array([3557]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000347.gl5 saved
# citynum: 348, coord of prfs: (array([665, 666, 669]), array([3589, 3590, 3590]))
# pid == 0, len(prf_coords) == 3
# pid == 1, len(prf_coords) == 3
# pid == 2, len(prf_coords) == 3
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000348.gl5 saved
# citynum: 349, coord of prfs: (array([585, 586]), array([2057, 2057]))
# pid == 0, len(prf_coords) == 2
# pid == 1, len(prf_coords) == 2
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000349.gl5 saved
# citynum: 350, coord of prfs: (array([656, 657]), array([1190, 1189]))
# pid == 0, len(prf_coords) == 2
# pid == 1, len(prf_coords) == 2
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000350.gl5 saved
# citynum: 351, coord of prfs: (array([511]), array([2264]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000351.gl5 saved
# citynum: 352, coord of prfs: (array([804]), array([3118]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000352.gl5 saved
# citynum: 353, coord of prfs: (array([405]), array([2684]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000353.gl5 saved
# citynum: 354, coord of prfs: (array([672]), array([3059]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000354.gl5 saved
# citynum: 355, coord of prfs: (array([480]), array([2332]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000355.gl5 saved
# citynum: 356, coord of prfs: (array([796]), array([3559]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000356.gl5 saved
# citynum: 357, coord of prfs: (array([687]), array([3562]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000357.gl5 saved
# citynum: 358, coord of prfs: (array([795]), array([3202]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000358.gl5 saved
# citynum: 359, coord of prfs: (array([1498, 1500]), array([3824, 3825]))
# pid == 0, len(prf_coords) == 2
# pid == 1, len(prf_coords) == 2
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000359.gl5 saved
# citynum: 360, coord of prfs: (array([535]), array([1249]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000360.gl5 saved
# citynum: 361, coord of prfs: (array([570]), array([2440]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000361.gl5 saved
# citynum: 362, coord of prfs: (array([961]), array([1151]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000362.gl5 saved
# citynum: 363, coord of prfs: (array([775]), array([3140]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000363.gl5 saved
# citynum: 364, coord of prfs: (array([1165, 1166]), array([1740, 1741]))
# pid == 0, len(prf_coords) == 2
# pid == 1, len(prf_coords) == 2
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000364.gl5 saved
# citynum: 365, coord of prfs: (array([411]), array([2308]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000365.gl5 saved
# citynum: 366, coord of prfs: (array([577, 579]), array([1303, 1301]))
# pid == 0, len(prf_coords) == 2
# pid == 1, len(prf_coords) == 2
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000366.gl5 saved
# citynum: 367, coord of prfs: (array([466]), array([788]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000367.gl5 saved
# citynum: 368, coord of prfs: (array([794]), array([3197]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000368.gl5 saved
# citynum: 369, coord of prfs: (array([645]), array([2673]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000369.gl5 saved
# citynum: 370, coord of prfs: (array([699]), array([3061]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000370.gl5 saved
# citynum: 371, coord of prfs: (array([840]), array([3065]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000371.gl5 saved
# citynum: 372, coord of prfs: (array([438]), array([2760]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000372.gl5 saved
# citynum: 373, coord of prfs: (array([1195]), array([1730]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000373.gl5 saved
# citynum: 374, coord of prfs: (array([421]), array([3041]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000374.gl5 saved
# citynum: 375, coord of prfs: (array([919]), array([3372]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000375.gl5 saved
# citynum: 376, coord of prfs: (array([410]), array([2746]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000376.gl5 saved
# citynum: 377, coord of prfs: (array([640]), array([3380]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000377.gl5 saved
# citynum: 378, coord of prfs: (array([789]), array([3608]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000378.gl5 saved
# citynum: 379, coord of prfs: (array([781]), array([3582]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000379.gl5 saved
# citynum: 380, coord of prfs: (array([505]), array([3442]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000380.gl5 saved
# citynum: 381, coord of prfs: (array([439]), array([795]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000381.gl5 saved
# citynum: 382, coord of prfs: (array([1149]), array([1736]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000382.gl5 saved
# citynum: 383, coord of prfs: (array([618]), array([3435]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000383.gl5 saved
# citynum: 384, coord of prfs: (array([418]), array([2896]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000384.gl5 saved
# citynum: 385, coord of prfs: (array([354]), array([2459]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000385.gl5 saved
# citynum: 386, coord of prfs: (array([591]), array([3536]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000386.gl5 saved
# citynum: 387, coord of prfs: (array([765]), array([3039]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000387.gl5 saved
# citynum: 388, coord of prfs: (array([645]), array([3567]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000388.gl5 saved
# citynum: 389, coord of prfs: (array([1395]), array([1573]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000389.gl5 saved
# citynum: 390, coord of prfs: (array([711]), array([2732]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000390.gl5 saved
# citynum: 391, coord of prfs: (array([817]), array([3313]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000391.gl5 saved
# citynum: 392, coord of prfs: (array([799]), array([3183]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000392.gl5 saved
# 393 is invalid prf
# citynum: 394, coord of prfs: (array([1484]), array([2464]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000394.gl5 saved
# citynum: 395, coord of prfs: (array([757]), array([3511]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000395.gl5 saved
# citynum: 396, coord of prfs: (array([439]), array([2082]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000396.gl5 saved
# citynum: 397, coord of prfs: (array([832]), array([956]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000397.gl5 saved
# citynum: 398, coord of prfs: (array([804]), array([3234]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000398.gl5 saved
# citynum: 399, coord of prfs: (array([1389]), array([2550]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000399.gl5 saved
# citynum: 400, coord of prfs: (array([686]), array([2318]))
# pid == 0, len(prf_coords) == 1
# ...
# citynum: 701, coord of prfs: (array([735]), array([3414]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000701.gl5 saved
# 702 is invalid prf
# citynum: 703, coord of prfs: (array([728]), array([3416]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000703.gl5 saved
# 704 is invalid prf
# citynum: 705, coord of prfs: (array([1024]), array([3375]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000705.gl5 saved
# citynum: 706, coord of prfs: (array([647]), array([3573]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000706.gl5 saved
# citynum: 707, coord of prfs: (array([648]), array([3574]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000707.gl5 saved
# citynum: 708, coord of prfs: (array([884]), array([3125]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000708.gl5 saved
# citynum: 709, coord of prfs: (array([1321]), array([2503]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000709.gl5 saved
# citynum: 710, coord of prfs: (array([646]), array([1006]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000710.gl5 saved
# citynum: 711, coord of prfs: (array([654]), array([2591]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000711.gl5 saved
# citynum: 712, coord of prfs: (array([835]), array([3190]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000712.gl5 saved
# citynum: 713, coord of prfs: (array([472]), array([2225]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000713.gl5 saved
# citynum: 714, coord of prfs: (array([637]), array([722]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000714.gl5 saved
# citynum: 715, coord of prfs: (array([686]), array([3059]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000715.gl5 saved
# citynum: 716, coord of prfs: (array([803]), array([3474]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000716.gl5 saved
# citynum: 717, coord of prfs: (array([900]), array([3383]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000717.gl5 saved
# citynum: 718, coord of prfs: (array([668]), array([3465]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000718.gl5 saved
# citynum: 719, coord of prfs: (array([1075]), array([2274]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000719.gl5 saved
# citynum: 720, coord of prfs: (array([649]), array([3685]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000720.gl5 saved
# citynum: 721, coord of prfs: (array([698]), array([3556]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000721.gl5 saved
# citynum: 722, coord of prfs: (array([572]), array([2996]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000722.gl5 saved
# citynum: 723, coord of prfs: (array([646]), array([3518]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000723.gl5 saved
# citynum: 724, coord of prfs: (array([893]), array([1102]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000724.gl5 saved
# citynum: 725, coord of prfs: (array([937]), array([3116]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000725.gl5 saved
# citynum: 726, coord of prfs: (array([795]), array([3517]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000726.gl5 saved
# citynum: 727, coord of prfs: (array([751]), array([1170]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000727.gl5 saved
# 728 is invalid prf
# citynum: 729, coord of prfs: (array([1109]), array([2506]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000729.gl5 saved
# citynum: 730, coord of prfs: (array([745]), array([3555]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000730.gl5 saved
# citynum: 731, coord of prfs: (array([591, 592]), array([3609, 3608]))
# pid == 0, len(prf_coords) == 2
# pid == 1, len(prf_coords) == 2
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000731.gl5 saved
# citynum: 732, coord of prfs: (array([826]), array([3093]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000732.gl5 saved
# citynum: 733, coord of prfs: (array([693]), array([2692]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000733.gl5 saved
# citynum: 734, coord of prfs: (array([455]), array([2211]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000734.gl5 saved
# citynum: 735, coord of prfs: (array([744]), array([3041]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000735.gl5 saved
# citynum: 736, coord of prfs: (array([772]), array([3406]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000736.gl5 saved
# citynum: 737, coord of prfs: (array([466]), array([2365]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000737.gl5 saved
# citynum: 738, coord of prfs: (array([1019]), array([2254]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000738.gl5 saved
# citynum: 739, coord of prfs: (array([760]), array([3378]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000739.gl5 saved
# citynum: 740, coord of prfs: (array([518]), array([3724]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000740.gl5 saved
# citynum: 741, coord of prfs: (array([396]), array([2796]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000741.gl5 saved
# citynum: 742, coord of prfs: (array([534]), array([2302]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000742.gl5 saved
# citynum: 743, coord of prfs: (array([1119]), array([3534]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000743.gl5 saved
# 744 is invalid prf
# citynum: 745, coord of prfs: (array([572]), array([1288]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000745.gl5 saved
# citynum: 746, coord of prfs: (array([1110]), array([2554]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000746.gl5 saved
# citynum: 747, coord of prfs: (array([665]), array([3577]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000747.gl5 saved
# citynum: 748, coord of prfs: (array([692]), array([3526]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000748.gl5 saved
# citynum: 749, coord of prfs: (array([573, 574, 577]), array([3719, 3719, 3716]))
# pid == 0, len(prf_coords) == 3
# pid == 1, len(prf_coords) == 3
# pid == 2, len(prf_coords) == 3
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000749.gl5 saved
# citynum: 750, coord of prfs: (array([625]), array([3521]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000750.gl5 saved
# citynum: 751, coord of prfs: (array([532, 534]), array([2306, 2304]))
# pid == 0, len(prf_coords) == 2
# pid == 1, len(prf_coords) == 2
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000751.gl5 saved
# citynum: 752, coord of prfs: (array([924]), array([3059]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000752.gl5 saved
# citynum: 753, coord of prfs: (array([625]), array([695]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000753.gl5 saved
# citynum: 754, coord of prfs: (array([634]), array([2755]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000754.gl5 saved
# 755 is invalid prf
# citynum: 756, coord of prfs: (array([427]), array([2740]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000756.gl5 saved
# citynum: 757, coord of prfs: (array([586, 587]), array([2360, 2360]))
# pid == 0, len(prf_coords) == 2
# pid == 1, len(prf_coords) == 2
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000757.gl5 saved
# citynum: 758, coord of prfs: (array([667]), array([3546]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000758.gl5 saved
# citynum: 759, coord of prfs: (array([462]), array([2130]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000759.gl5 saved
# citynum: 760, coord of prfs: (array([441]), array([3165]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000760.gl5 saved
# 761 is invalid prf
# citynum: 762, coord of prfs: (array([1474, 1475]), array([2493, 2491]))
# pid == 0, len(prf_coords) == 2
# pid == 1, len(prf_coords) == 2
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000762.gl5 saved
# citynum: 763, coord of prfs: (array([759]), array([3417]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000763.gl5 saved
# citynum: 764, coord of prfs: (array([726, 729]), array([3022, 3017]))
# pid == 0, len(prf_coords) == 2
# pid == 1, len(prf_coords) == 2
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000764.gl5 saved
# citynum: 765, coord of prfs: (array([874]), array([999]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000765.gl5 saved
# citynum: 766, coord of prfs: (array([494]), array([2270]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000766.gl5 saved
# citynum: 767, coord of prfs: (array([1359]), array([1608]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000767.gl5 saved
# citynum: 768, coord of prfs: (array([785]), array([3571]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000768.gl5 saved
# 769 is invalid prf
# citynum: 770, coord of prfs: (array([532]), array([2266]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000770.gl5 saved
# citynum: 771, coord of prfs: (array([865]), array([3391]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000771.gl5 saved
# citynum: 772, coord of prfs: (array([699]), array([3725]))
# pid == 0, len(prf_coords) == 1
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/prf_updw/vld_cty_/city_00000772.gl5 saved
# citynum: 773, coord of prfs: (array([713]), array([3538]))
# pid == 0, len(prf_coords) == 1
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 13
#      10     print(f'{city_num} is invalid prf')
#      11     continue
# ---> 13 riv_path_array =  exeption_rivergrid(city_num, riv_nxlonlat_cropped)
#      15 riv_path_array.astype(np.float32).tofile(savepath)
#      16 print(f"{savepath} saved")
#
# Cell In[2], line 85, in exeption_rivergrid(city_num, riv_nxlonlat_cropped)
#      83 target_coord = (prf_coords[0][pid], prf_coords[1][pid])
#      84 visited_coords = set()
# ---> 85 explore_upstream(target_coord, visited_coords, riv_nxlonlat_cropped, city_num)
#      87 # update riv_path_array
#      88 for row, col in visited_coords:
#
# Cell In[2], line 80, in exeption_rivergrid.<locals>.explore_upstream(target_coord, visited_coords, riv_nxlonlat_cropped, city_num)
#      78 unvisited_matched = [tuple(coord) for coord in matched_coords if tuple(coord) not in visited_coords]
#      79 for up_coord in unvisited_matched:
# ---> 80     explore_upstream(up_coord, visited_coords, riv_nxlonlat_cropped, city_num)
#
# Cell In[2], line 80, in exeption_rivergrid.<locals>.explore_upstream(target_coord, visited_coords, riv_nxlonlat_cropped, city_num)
#      78 unvisited_matched = [tuple(coord) for coord in matched_coords if tuple(coord) not in visited_coords]
#      79 for up_coord in unvisited_matched:
# ---> 80     explore_upstream(up_coord, visited_coords, riv_nxlonlat_cropped, city_num)
#
#     [... skipping similar frames: exeption_rivergrid.<locals>.explore_upstream at line 80 (528 times)]
#
# Cell In[2], line 80, in exeption_rivergrid.<locals>.explore_upstream(target_coord, visited_coords, riv_nxlonlat_cropped, city_num)
#      78 unvisited_matched = [tuple(coord) for coord in matched_coords if tuple(coord) not in visited_coords]
#      79 for up_coord in unvisited_matched:
# ---> 80     explore_upstream(up_coord, visited_coords, riv_nxlonlat_cropped, city_num)
#
# Cell In[2], line 75, in exeption_rivergrid.<locals>.explore_upstream(target_coord, visited_coords, riv_nxlonlat_cropped, city_num)
#      73 visited_coords.add(target_coord)
#      74 target_row, target_col = target_coord
# ---> 75 matched_coords = np.argwhere(np.all(target_coord == riv_nxlonlat_cropped, axis=2))
#      76 if len(matched_coords) == 0:
#      77     break
#
# File /usr/local/lib/python3.10/dist-packages/numpy/core/fromnumeric.py:2416, in _all_dispatcher(a, axis, out, keepdims, where)
#    2324     """
#    2325     Test whether any array element along a given axis evaluates to True.
#    2326
#    (...)
#    2410
#    2411     """
#    2412     return _wrapreduction(a, np.logical_or, 'any', axis, None, out,
#    2413                           keepdims=keepdims, where=where)
# -> 2416 def _all_dispatcher(a, axis=None, out=None, keepdims=None, *,
#    2417                     where=None):
#    2418     return (a, where, out)
#    2421 @array_function_dispatch(_all_dispatcher)
#    2422 def all(a, axis=None, out=None, keepdims=np._NoValue, *, where=np._NoValue):
#
# KeyboardInterrupt:

# %%
import cartopy.crs as ccrs
import cartopy.feature as cfeature
import matplotlib.colors as mcolors

#---------------------------------------------------------------------------------------------------------------
#  city maskの枠だけを表示
#---------------------------------------------------------------------------------------------------------------
def draw_mask_sotowaku(extent, mask_cropped, ax=None, sotowaku_color='#dc143c', linewidth=3):
    """
    zorder = 0: デフォルトの最背面(gridをzorder=0に設定)
    zorder = 1: 赤色の外枠(citymask)
    zorder = 2: 白色の内枠が最前面(citymask)
    """

    # delta
    delta = 360/4320
    x_left = extent[0]
    y_top = extent[3]
    
    # outer
    upper_indices = []
    lower_indices = []
    left_indices = []
    right_indices = []
    rows, cols = mask_cropped.shape
    for i in range(rows):
        for j in range(cols):
            if mask_cropped[i, j] == 1:
                if mask_cropped[i-1, j] == 0:
                    upper_indices.append((i, j))
                if mask_cropped[i+1, j] == 0:
                    lower_indices.append((i, j))
                if mask_cropped[i, j-1] == 0:
                    left_indices.append((i, j))
                if mask_cropped[i, j+1] == 0:
                    right_indices.append((i, j))

    # extent
    projection = ccrs.PlateCarree()

    # city mask
    for up in upper_indices:
        x_index = x_left + delta*(up[1])
        y_index = y_top - delta*(up[0])
        ax.plot([x_index, x_index+delta], [y_index, y_index], color=sotowaku_color, transform=projection, linewidth=linewidth, zorder=1) # top
        ax.plot([x_index, x_index+delta], [y_index, y_index], color='white', transform=projection, linewidth=linewidth-2, zorder=2) # top
    for lo in lower_indices:
        x_index = x_left + delta*(lo[1])
        y_index = y_top - delta*(lo[0]+1)
        ax.plot([x_index, x_index+delta], [y_index, y_index], color=sotowaku_color, transform=projection, linewidth=linewidth, zorder=1) # bottom
        ax.plot([x_index, x_index+delta], [y_index, y_index], color='white', transform=projection, linewidth=linewidth-2, zorder=2) # bottom
    for le in left_indices:
        x_index = x_left + delta*(le[1])
        y_index = y_top - delta*(le[0]+1)
        ax.plot([x_index, x_index], [y_index, y_index+delta], color=sotowaku_color, transform=projection, linewidth=linewidth, zorder=1) # left
        ax.plot([x_index, x_index], [y_index, y_index+delta], color='white', transform=projection, linewidth=linewidth-2, zorder=2) # left
    for ri in right_indices:
        x_index = x_left + delta*(ri[1]+1)
        y_index = y_top - delta*(ri[0]+1)
        ax.plot([x_index, x_index], [y_index, y_index+delta], color=sotowaku_color, transform=projection, linewidth=linewidth, zorder=1) # right
        ax.plot([x_index, x_index], [y_index, y_index+delta], color='white', transform=projection, linewidth=linewidth-2, zorder=2) # right

    return ax

def grid_to_latlon(row, col, extent):
    delta = 360/4320
    x_left, y_top = extent[0], extent[3]
    lon = x_left + (col+0.5) * delta
    lat = y_top - (row+0.5) * delta
    return lon, lat

# %%
#
rgndir = '/mnt/c/Users/tsimk/Downloads/dotfiles/h08/region'
glbdir = '/mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city'
#
tag = '.tk5'
city_num = 1
#
resolution = 12
POP='vld_cty_'
#
SUF = '.gl5'
dtype = 'float32'
gl5shape = (2160, 4320)
#
# region
left = 138
right = 141
bottom = 34
top = 38
#
nx, ny = (right - left)*resolution, (top - bottom)*resolution
rgnshape = (ny, nx)
img_extent = (left, right, bottom, top)
#
upperindex = (90-top)*resolution
lowerindex = (90-bottom)*resolution
leftindex = (180+left)*resolution
rightindex = (180+right)*resolution

# %%
projection = ccrs.PlateCarree(central_longitude=0)
fig, ax = plt.subplots(figsize=(5,5), subplot_kw={'projection': projection})
ax.add_feature(cfeature.LAND, edgecolor='none', facecolor='#ffffff')
ax.add_feature(cfeature.OCEAN, edgecolor='none', facecolor='#d0cfd4')
ax.add_feature(cfeature.COASTLINE, linewidth=0.1,edgecolor='#d0cfd4')
ax.add_feature(cfeature.BORDERS, linestyle='-', linewidth=1.5, edgecolor='#d0cfd4')
ax.gridlines(visible=False)

# draw riv_path_array
riv_path_array =  exeption_rivergrid(city_num, riv_nxlonlat_cropped)
tmp = np.ma.masked_where(riv_path_array == 0, riv_path_array)
im = ax.imshow(tmp, extent=(-180,180,-90,90), transform=ccrs.PlateCarree(), cmap='tab20')

h08dir = '/mnt/c/Users/tsimk/Downloads/dotfiles/h08'
msk_dir = f'{h08dir}/global_city/dat/vld_cty_'
ctymsk_path = f'{msk_dir}/city_{city_num:08}.gl5'
mask = np.fromfile(ctymsk_path, dtype='float32').reshape(2160, 4320)
draw_mask_sotowaku((-180,180,-90,90), mask, ax=ax, sotowaku_color='black', linewidth=3)

root_dir = '/mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city'
prf_path = f"{root_dir}/dat/cty_prf_/vld_cty_/city_{city_num:08}.gl5"
prf = np.fromfile(prf_path, dtype='float32').reshape(2160, 4320)
prf_coords = np.where(prf == 1)
latlon_coords = [grid_to_latlon(row, col, (-180,180,-90,90)) for row, col in zip(prf_coords[0], prf_coords[1])]

for lon, lat in latlon_coords:
    ax.plot(lon, lat, marker='o', color='blue', markersize=2.5, transform=ccrs.PlateCarree())

ax.set_xlim(left, right)
ax.set_ylim(bottom, top)

plt.show()
# Out:
# citynum: 1, coord of prfs: (array([646, 648, 651, 652]), array([3836, 3834, 3831, 3829]))
# pid == 0, len(prf_coords) == 4
# pid == 1, len(prf_coords) == 4
# pid == 2, len(prf_coords) == 4
# pid == 3, len(prf_coords) == 4
