# %%
####################################################################################
# create and save for samebasin intake files
#cityrivnum = f'{h08dir}/global_city/dat/riv_num_/city_basins.json'
#city_basins_list
####################################################################################
    
import os
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import cartopy.feature as cfeature
import numpy as np
import pandas as pd
import matplotlib.colors as mcolors

####################################################################################
city_len = 1860
distance = 100
####################################################################################

# paths
h08dir = '/mnt/c/Users/tsimk/Downloads/dotfiles/h08'
pop_path = f'{h08dir}/global_city/dat/pop_tot_/GPW4ag__20100000.gl5'
riv_path = f'{h08dir}/wsi/dat/riv_out_/W5E5LR__00000000.gl5'
rivnum_path = f'{h08dir}/global_city/dat/riv_num_/rivnum.CAMA.gl5'
rivnxl_path = f"{h08dir}/global_city/dat/riv_nxl_/rivnxl.CAMA.gl5"
msk_dir = f'{h08dir}/global_city/dat/vld_cty_'
cnt_dir = f'{h08dir}/global_city/dat/cty_cnt_/gpw4'
prf_dir = f'{h08dir}/global_city/dat/cty_prf_'

# intake
int_dir = f'{h08dir}/global_city/dat/cty_int_/{distance}km_samebasin'

# rivpath
rivnxl_gl5 = np.fromfile(rivnxl_path, 'float32').reshape(2160, 4320)
pop = np.fromfile(pop_path, dtype='float32').reshape(2160, 4320)
rivout = np.fromfile(riv_path, dtype='float32').reshape(2160, 4320)
rivnum_gl5 = np.fromfile(rivnum_path, dtype='float32').reshape(2160, 4320)

# lonlat
lonlat_path = f'{h08dir}/global_city/dat/cty_lst_/gpw4/WUP2018_300k_2010.txt'
with open(lonlat_path, "r") as input_file:
    lines = input_file.readlines()

# identifying same rivnum cities into list?
city_basins = {}
for i in range(city_len):
    city_num = i+1
    ctymsk_path = f'{msk_dir}/city_{city_num:08}.gl5'
    prf_path = f'{prf_dir}/vld_cty_/city_{city_num:08}.gl5'
    int_path = f'{int_dir}/city_{city_num:08}.gl5'

    if not os.path.exists(prf_path):
        print(f'{city_num} is invalid prf')

    else:
        ctymsk = np.fromfile(ctymsk_path, dtype='float32').reshape(2160, 4320)
        prf = np.fromfile(prf_path, dtype='float32').reshape(2160, 4320)
        intake = np.fromfile(int_path, dtype='float32').reshape(2160, 4320)
        rivnum_mask = np.ma.masked_where((intake+prf) == 0, rivnum_gl5)
        rivnum_lst = np.unique(rivnum_mask)[:-1]
        city_basins[city_num] = rivnum_lst.filled(1e20) # filledは必要?
        
        print(f'{city_num} done')

print(city_basins)

"""
basin_to_cities = {}
for city, basins in city_basins.items():
    for rivnum in basins:
        if rivnum not in basin_to_cities:
            basin_to_cities[rivnum] = []
        basin_to_cities[rivnum].append(city)

# 集計結果を出力
for rivnum, cities in basin_to_cities.items():
    if len(cities) > 1:  # 複数の都市に共有されている流域番号のみ表示
        print(f"rivnum {rivnum}: {cities}")

import json
city_basins_list = {city: basins.tolist() for city, basins in city_basins.items()}
cityrivnum = f'{h08dir}/global_city/dat/riv_num_/city_basins_{distance}km.json'
with open(cityrivnum, 'w') as json_file:
    json.dump(city_basins_list, json_file)
print(f'{cityrivnum} saved')
"""
# Out:
# 1 done
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 57
#      55 else:
#      56     ctymsk = np.fromfile(ctymsk_path, dtype='float32').reshape(2160, 4320)
# ---> 57     prf = np.fromfile(prf_path, dtype='float32').reshape(2160, 4320)
#      58     intake = np.fromfile(int_path, dtype='float32').reshape(2160, 4320)
#      59     rivnum_mask = np.ma.masked_where((intake+prf) == 0, rivnum_gl5)
#
# KeyboardInterrupt:

# %%
####################################################################################
# create and save below files
#basin_cities_path = f'{h08dir}/global_city/dat/riv_num_/basin_to_cities.json'
#new_basin_to_cities
####################################################################################

import os
import numpy as np
import pandas as pd

################################################################################
# load files
################################################################################
city_len = 1860
distance = 100
h08dir = '/mnt/c/Users/tsimk/Downloads/dotfiles/h08'
################################################################################

# basin at each city
cityrivnum = f'{h08dir}/global_city/dat/riv_num_/city_basins_{distance}km.json'
with open(cityrivnum, 'r') as json_file:
    city_basins = json.load(json_file)
print(len(city_basins.keys()))

# cities at same basin
basin_to_cities = {}
for city, basins in city_basins.items():
    for rivnum in basins:
        if rivnum not in basin_to_cities:
            basin_to_cities[rivnum] = []
        basin_to_cities[rivnum].append(city)
        
for rivnum, cities in basin_to_cities.items():
    if len(cities) > 1:  # 複数の都市に共有されている流域番号のみ表示
        print(f"rivnum {rivnum}: {cities}")
        
new_basin_to_cities = {rivnum: cities for rivnum, cities in basin_to_cities.items() if len(cities) > 1}
basin_cities_path = f'{h08dir}/global_city/dat/riv_num_/basin_to_cities_{distance}km.json'

"""
with open(basin_cities_path, 'w') as json_file:
    json.dump(new_basin_to_cities, json_file)
    print(f'{basin_cities_path} saved')
"""
# Out:
# 1553
# rivnum 848.0: ['1', '936', '1283', '1400']
# rivnum 14.0: ['2', '11', '126', '130', '133', '188', '197', '217', '243', '319', '321', '363', '398', '406', '455', '463', '473', '513', '526', '588', '667', '669', '673', '677', '797', '874', '883', '903', '941', '983', '1012', '1018', '1067', '1089', '1181', '1216', '1253', '1288', '1298', '1337', '1365', '1371', '1381', '1422', '1575', '1578', '1620', '1652', '1656', '1668', '1697', '1712', '1718', '1824']
# rivnum 480.0: ['3', '52', '85', '144', '160', '275', '612', '618', '873', '967', '1200', '1299', '1376', '1687']
# rivnum 5438.0: ['3', '85']
# rivnum 9439.0: ['3', '1212']
# rivnum 112.0: ['4', '74', '209', '269', '397', '431', '483', '557', '779', '1104']
# rivnum 164.0: ['4', '537', '929', '933', '1569']
# rivnum 1366.0: ['4', '143', '487', '933', '953', '1094']
# rivnum 5.0: ['5', '94', '119', '140', '155', '196', '257', '343', '550', '597', '629', '689', '767', '789', '803', '836', '837', '866', '939', '1125', '1235', '1327', '1329', '1361', '1411', '1453', '1500', '1530', '1573', '1627', '1648', '1717', '1720']
# rivnum 528.0: ['7', '58', '696', '1070', '1113', '1242', '1610']
# rivnum 4.0: ['9', '71', '76', '118', '200', '579', '691', '729', '746', '1333', '1551', '1579', '1667', '1675', '1676', '1747']
# rivnum 172.0: ['10', '183', '334', '386', '900', '910', '1265', '1439', '1755']
# rivnum 81.0: ['12', '589']
# rivnum 11240.0: ['12', '589']
# rivnum 189.0: ['13', '342', '358', '368', '822', '848', '1390', '1617', '1853']
# rivnum 23.0: ['14', '33', '111', '146', '221', '260', '272', '276', '284', '296', '354', '370', '466', '536', '578', '715', '764', '813', '849', '1091', '1103', '1196', '1220', '1295', '1405', '1430', '1519', '1535', '1536', '1563', '1582', '1636', '1689']
# rivnum 234.0: ['15', '81', '266', '970', '1151', '1597']
# rivnum 7763.0: ['15', '970']
# rivnum 261.0: ['16', '767', '939', '1100', '1126', '1717']
# rivnum 1744.0: ['17', '208', '804', '1064', '1364', '1432']
# rivnum 1503.0: ['18', '1495']
# rivnum 2583.0: ['18', '1562']
# rivnum 3.0: ['19', '37', '150', '194', '283', '304', '335', '353', '372', '376', '407', '416', '421', '437', '553', '648', '694', '741', '754', '756', '794', '832', '868', '909', '920', '924', '934', '954', '1001', '1052', '1131', '1154', '1159', '1172', '1248', '1269', '1320', '1380', '1463', '1470', '1496', '1510', '1515', '1523', '1534', '1538', '1608', '1660']
# rivnum 11.0: ['20', '39', '41', '48', '96', '102', '116', '125', '154', '160', '161', '246', '262', '275', '279', '306', '316', '348', '357', '395', '403', '424', '428', '433', '446', '452', '467', '477', '491', '505', '507', '514', '519', '521', '523', '534', '539', '549', '585', '593', '601', '603', '617', '622', '632', '639', '657', '663', '672', '690', '700', '701', '703', '721', '730', '739', '748', '758', '773', '775', '787', '805', '819', '824', '826', '829', '831', '835', '838', '847', '851', '865', '873', '880', '888', '895', '919', '967', '971', '972', '982', '1022', '1023', '1028', '1029', '1036', '1048', '1059', '1066', '1082', '1083', '1087', '1090', '1092', '1110', '1124', '1133', '1161', '1180', '1183', '1197', '1204', '1209', '1221', '1256', '1263', '1272', '1275', '1276', '1299', '1305', '1310', '1311', '1339', '1376', '1399', '1418', '1426', '1457', '1462', '1469', '1479', '1508', '1520', '1529', '1544', '1547', '1588', '1624', '1643', '1659', '1671', '1672', '1678', '1695', '1704', '1715', '1721', '1726', '1735', '1753', '1762', '1765', '1803', '1808', '1811', '1831', '1837', '1840', '1843', '1848']
# rivnum 118.0: ['21', '786', '1280', '1369', '1528']
# rivnum 191.0: ['21', '1027', '1336']
# rivnum 138.0: ['22', '134', '598', '796', '1030', '1043', '1355', '1414', '1450', '1481', '1686', '1761', '1783', '1826']
# rivnum 45.0: ['23', '42', '44', '138', '148', '271', '310', '331', '467', '594', '640', '716', '726', '736', '763', '826', '878', '908', '959', '981', '1110', '1204', '1272', '1358', '1379', '1427', '1440', '1445', '1555', '1612', '1638', '1658', '1682', '1800', '1831', '1843']
# rivnum 382.0: ['23', '24', '42', '43', '44', '231', '1086', '1287']
# rivnum 220.0: ['25', '108', '117', '220', '280', '697', '750', '876', '960', '1116', '1214', '1702', '1764', '1770', '1805']
# rivnum 376.0: ['25', '108', '280', '1116', '1214', '1755', '1764', '1805']
# rivnum 413.0: ['26', '158', '297', '698', '827', '1406', '1438']
# rivnum 1818.0: ['27', '171', '807']
# rivnum 2.0: ['28', '261', '480', '650', '729', '1101', '1333', '1434', '1491']
# rivnum 2113.0: ['29', '145', '1264']
# rivnum 1.0: ['30', '228', '263', '274', '327', '453', '872', '1217', '1277', '1410', '1420', '1703']
# rivnum 6.0: ['31', '151', '172', '185', '229', '241', '265', '288', '298', '326', '420', '458', '459', '482', '502', '532', '635', '641', '710', '790', '830', '842', '846', '994', '1056', '1098', '1173', '1175', '1202', '1227', '1239', '1600', '1609', '1635', '1640', '1649', '1680', '1705', '1731', '1766']
# rivnum 17.0: ['31', '57', '90', '93', '229', '324', '360', '482', '608', '646', '653', '828', '830', '944', '1003', '1006', '1143', '1208', '1330', '1349', '1489', '1514', '1518', '1560', '1635']
# rivnum 750.0: ['32', '988', '1063', '1750']
# rivnum 63.0: ['34', '106', '176', '215', '411', '492', '881', '945', '1127', '1177', '1357']
# rivnum 182.0: ['35', '191', '313', '439', '457', '484', '498', '725', '928', '1605', '1650', '1654', '1661', '1819', '1821', '1828']
# rivnum 970.0: ['35', '988', '1750', '1836']
# rivnum 88.0: ['36', '472', '1302', '1413', '1751', '1813', '1822']
# rivnum 501.0: ['36', '1505']
# rivnum 325.0: ['37', '283']
# rivnum 955.0: ['38', '545', '858', '1032', '1502', '1628']
# rivnum 5869.0: ['38', '545']
# rivnum 53.0: ['40', '164', '287', '352', '371', '621', '833', '882', '894', '1088', '1119', '1255', '1261', '1273', '1497', '1550', '1576', '1639', '1683']
# rivnum 64.0: ['40', '66', '287', '314', '475', '485', '708', '778', '852', '894', '940', '1000', '1106', '1174', '1255', '1429', '1478', '1493', '1758']
# rivnum 864.0: ['45', '518']
# rivnum 416.0: ['46', '226', '1018', '1677', '1718']
# rivnum 492.0: ['46', '785', '1018']
# rivnum 328.0: ['47', '547', '1621']
# rivnum 78.0: ['49', '99', '344', '510', '524', '543', '613', '631', '892', '946', '1234', '1246', '1417', '1531']
# rivnum 494.0: ['49', '295', '344', '445', '524', '543', '631', '678', '1234', '1531']
# rivnum 485.0: ['50', '1236', '1274']
# rivnum 177.0: ['51', '135']
# rivnum 343.0: ['52', '252', '531', '593', '618', '666', '782', '1135', '1224', '1282', '1384', '1673', '1848']
# rivnum 1830.0: ['52', '141', '252', '429', '612', '906', '961', '1200', '1212', '1224', '1384', '1687']
# rivnum 27.0: ['53', '120', '248', '345', '369', '390', '561', '733', '821', '825', '1115', '1189', '1248', '1467', '1809']
# rivnum 28.0: ['54', '86', '96', '117', '169', '179', '235', '250', '300', '347', '377', '383', '388', '470', '493', '521', '534', '602', '643', '654', '662', '671', '700', '706', '707', '718', '723', '750', '758', '781', '841', '888', '904', '957', '979', '992', '995', '1011', '1013', '1040', '1057', '1095', '1111', '1168', '1182', '1187', '1190', '1265', '1308', '1313', '1339', '1348', '1394', '1412', '1426', '1449', '1589', '1623', '1659', '1702', '1704', '1706', '1789', '1845']
# rivnum 3431.0: ['55', '998', '1075', '1581']
# rivnum 498.0: ['56', '165', '290', '891', '1251', '1498', '1527']
# rivnum 34.0: ['59', '566', '1250']
# rivnum 326.0: ['62', '65', '1290', '1788']
# rivnum 12.0: ['63', '99', '312', '318', '330', '554', '587', '664', '740', '784', '818', '950', '965', '985', '1246', '1307', '1338', '1417', '1473', '1699', '1709', '1710', '1785', '1844']
# rivnum 1220.0: ['65', '1788']
# rivnum 441.0: ['69', '182']
# rivnum 126.0: ['70', '611', '1397', '1465', '1733']
# rivnum 392.0: ['70', '1744']
# rivnum 1749.0: ['72', '230', '1044', '1185', '1324', '1387', '1692', '1794']
# rivnum 1752.0: ['72', '815', '1044', '1117', '1185', '1249', '1328', '1679']
# rivnum 148.0: ['73', '226', '352', '1312']
# rivnum 228.0: ['73', '732', '833', '1051', '1119', '1273', '1696']
# rivnum 3829.0: ['73', '1696']
# rivnum 46.0: ['75', '391', '1153']
# rivnum 21.0: ['77', '122', '256', '656', '1060', '1513', '1625']
# rivnum 43.0: ['77', '256', '655', '1625', '1646', '1792']
# rivnum 478.0: ['78', '366', '486', '490', '745', '791', '839']
# rivnum 1014.0: ['78', '977']
# rivnum 4642.0: ['79', '1145']
# rivnum 618.0: ['80', '1543', '1700']
# rivnum 38.0: ['82', '340', '541', '560', '573', '616', '624', '634', '1232', '1501']
# rivnum 623.0: ['83', '1652']
# rivnum 3429.0: ['84', '206']
# rivnum 878.0: ['86', '179', '995', '1245']
# rivnum 788.0: ['87', '1223']
# rivnum 2500.0: ['87', '1342']
# rivnum 19.0: ['89', '1191']
# rivnum 357.0: ['91', '1684']
# rivnum 82.0: ['92', '1125', '1564']
# rivnum 35.0: ['95', '172', '211', '481', '548']
# rivnum 473.0: ['97', '356', '530', '644', '768', '1343']
# rivnum 2386.0: ['97', '356', '644']
# rivnum 6026.0: ['97', '530']
# rivnum 667.0: ['100', '364', '1293']
# rivnum 1577.0: ['100', '364']
# rivnum 102.0: ['103', '232', '355', '912', '917']
# rivnum 401.0: ['105', '522']
# rivnum 581.0: ['107', '177', '423', '511', '1406', '1441']
# rivnum 6429.0: ['107', '423', '1441']
# rivnum 278.0: ['109', '938']
# rivnum 338.0: ['110', '322', '592', '1292']
# rivnum 8210.0: ['110', '592']
# rivnum 205.0: ['112', '242', '753', '1279', '1552', '1694']
# rivnum 390.0: ['113', '478']
# rivnum 56.0: ['114', '627', '688', '1681', '1846']
# rivnum 1471.0: ['121', '178']
# rivnum 203.0: ['123', '239', '586', '605', '660', '751', '770', '810', '1078', '1079', '1455', '1484', '1591', '1657']
# rivnum 948.0: ['124', '379', '768', '793', '1128']
# rivnum 1829.0: ['126', '874']
# rivnum 243.0: ['127', '405', '1020', '1165', '1460', '1480', '1778']
# rivnum 2370.0: ['128', '236', '1691']
# rivnum 4555.0: ['128', '236']
# rivnum 9930.0: ['128', '236']
# rivnum 2360.0: ['129', '1045']
# rivnum 7178.0: ['129', '1045']
# rivnum 1770.0: ['131', '417']
# rivnum 103.0: ['136', '517']
# rivnum 178.0: ['137', '1521']
# rivnum 37.0: ['139', '219', '311', '441', '464', '595', '693', '952', '978', '1131', '1134', '1297', '1306', '1316', '1332', '1354', '1463']
# rivnum 2411.0: ['141', '429', '886', '906']
# rivnum 876.0: ['142', '282']
# rivnum 127.0: ['143', '487', '953', '1094', '1109', '1506', '1611']
# rivnum 805.0: ['147', '1630']
# rivnum 748.0: ['149', '567', '651', '1282', '1366', '1644']
# rivnum 1789.0: ['149', '320', '620', '961']
# rivnum 911.0: ['156', '1368']
# rivnum 4424.0: ['159', '1281']
# rivnum 9647.0: ['163', '1565']
# rivnum 318.0: ['166', '1335']
# rivnum 591.0: ['167', '234', '637', '679', '949', '1267', '1281', '1522']
# rivnum 1130.0: ['167', '535', '637', '759', '1321', '1539', '1598']
# rivnum 2502.0: ['167', '1076', '1568']
# rivnum 1511.0: ['170', '1292']
# rivnum 4051.0: ['170', '205', '427']
# rivnum 107.0: ['173', '175', '1416', '1651', '1825']
# rivnum 69.0: ['178', '1391']
# rivnum 48.0: ['180', '722', '1058', '1230']
# rivnum 1945.0: ['181', '1163', '1549']
# rivnum 6057.0: ['181', '1549']
# rivnum 331.0: ['183', '410', '900']
# rivnum 1571.0: ['184', '569', '936', '1408']
# rivnum 1671.0: ['184', '1474']
# rivnum 2927.0: ['190', '658', '925', '991', '1039', '1123', '1385']
# rivnum 1807.0: ['191', '193', '227', '268', '484', '1085', '1398', '1650', '1661']
# rivnum 282.0: ['192', '1852']
# rivnum 1850.0: ['193', '207', '227', '268']
# rivnum 42.0: ['195', '238', '802', '1296', '1798']
# rivnum 588.0: ['201', '1375']
# rivnum 585.0: ['202', '899']
# rivnum 961.0: ['203', '834', '1708']
# rivnum 6278.0: ['207', '227', '268', '1819']
# rivnum 417.0: ['208', '1064', '1378', '1432']
# rivnum 74.0: ['210', '351', '418', '443', '444', '447', '681', '713', '734', '766', '800', '808', '811', '923', '947', '968', '1026', '1061', '1093', '1169', '1226', '1260', '1284', '1345', '1425', '1452', '1509', '1577', '1626']
# rivnum 1298.0: ['210', '447']
# rivnum 25.0: ['212', '240', '244', '333', '337', '361', '670', '766', '859', '947', '1136', '1258', '1392', '1492', '1561', '1584']
# rivnum 10.0: ['213', '223', '224', '451', '469', '598', '627', '680', '783', '935', '989', '1325', '1393', '1416', '1437', '1444', '1655', '1681', '1686', '1729', '1798', '1826', '1857']
# rivnum 3700.0: ['214', '504', '1779']
# rivnum 32.0: ['216', '1219', '1346']
# rivnum 123.0: ['219', '907', '1102', '1442']
# rivnum 358.0: ['220', '493', '512', '654', '662', '671', '697', '723', '876', '992', '1394', '1494', '1845']
# rivnum 244.0: ['222', '246', '293', '347', '348', '388', '456', '515', '602', '603', '643', '706', '707', '747', '815', '1192', '1245', '1328', '1589']
# rivnum 3908.0: ['230', '495', '1309']
# rivnum 359.0: ['232', '870', '915', '1448', '1664']
# rivnum 131.0: ['233', '325']
# rivnum 158.0: ['233', '325', '1487']
# rivnum 4649.0: ['234', '1267']
# rivnum 15.0: ['245', '301', '633', '661', '709', '962', '1065', '1359', '1373', '1818', '1854']
# rivnum 385.0: ['249', '432', '1186']
# rivnum 1257.0: ['249', '1186']
# rivnum 75.0: ['251', '607', '625', '628', '1041', '1300', '1356', '1442', '1525']
# rivnum 323.0: ['255', '714', '1279', '1318', '1694']
# rivnum 18.0: ['259', '408', '596', '615', '1127', '1130', '1690']
# rivnum 98.0: ['263', '1756', '1780']
# rivnum 2025.0: ['264', '969', '1179']
# rivnum 3202.0: ['267', '986']
# rivnum 2430.0: ['270', '752']
# rivnum 49.0: ['272', '387', '466', '735', '764', '874', '1091', '1103', '1405', '1574', '1689']
# rivnum 146.0: ['277', '281', '476', '843', '889', '923', '951', '1073', '1176', '1226', '1280', '1284']
# rivnum 593.0: ['286', '580']
# rivnum 646.0: ['286', '345', '1115']
# rivnum 26.0: ['289', '547', '717', '771', '984', '1144', '1155', '1305', '1795']
# rivnum 1892.0: ['290', '727', '1739']
# rivnum 3036.0: ['292', '591']
# rivnum 1252.0: ['297', '698', '720']
# rivnum 1624.0: ['299', '1781', '1835']
# rivnum 8.0: ['302', '335', '374', '384', '760', '812', '869', '898', '914', '1428']
# rivnum 288.0: ['307', '897', '1548']
# rivnum 111.0: ['308', '550', '837']
# rivnum 706.0: ['309', '776', '885', '1476']
# rivnum 40.0: ['311', '402', '437', '461', '553', '924', '942', '1096', '1194', '1332', '1515']
# rivnum 5127.0: ['314', '708']
# rivnum 555.0: ['315', '468', '508', '1360']
# rivnum 475.0: ['328', '1784', '1802']
# rivnum 1516.0: ['328', '788', '1512']
# rivnum 4017.0: ['328', '1784']
# rivnum 29.0: ['332', '1730']
# rivnum 576.0: ['336', '345', '489', '711', '1112']
# rivnum 696.0: ['342', '392', '848']
# rivnum 978.0: ['346', '796', '1325', '1414', '1783']
# rivnum 143.0: ['349', '1533']
# rivnum 314.0: ['350', '1202', '1524', '1541', '1833', '1834']
# rivnum 374.0: ['350', '861', '864', '1175', '1222', '1833']
# rivnum 5507.0: ['366', '977']
# rivnum 16.0: ['367', '381', '642', '1763']
# rivnum 720.0: ['375', '1081']
# rivnum 7.0: ['380', '462', '799', '1178']
# rivnum 395.0: ['385', '1554']
# rivnum 877.0: ['389', '440', '1627']
# rivnum 311.0: ['392', '871']
# rivnum 334.0: ['399', '529']
# rivnum 17041.0: ['399', '529']
# rivnum 105.0: ['401', '426', '527', '712', '871', '1074', '1312']
# rivnum 740.0: ['404', '430']
# rivnum 763.0: ['408', '1009', '1690']
# rivnum 2571.0: ['413', '969', '1138']
# rivnum 5046.0: ['413', '1138']
# rivnum 608.0: ['414', '1050', '1347']
# rivnum 670.0: ['418', '1026']
# rivnum 320.0: ['419', '974']
# rivnum 421.0: ['419', '974', '1546']
# rivnum 1417.0: ['434', '878', '1034', '1458', '1707']
# rivnum 166.0: ['435', '867', '976']
# rivnum 1207.0: ['438', '943', '1093', '1169', '1336', '1425']
# rivnum 202.0: ['442', '628', '859']
# rivnum 3477.0: ['444', '734']
# rivnum 55.0: ['454', '964']
# rivnum 2152.0: ['464', '1021', '1306']
# rivnum 586.0: ['479', '613', '731', '990']
# rivnum 657.0: ['481', '1364']
# rivnum 2130.0: ['486', '490', '745', '839']
# rivnum 10510.0: ['486', '490', '839']
# rivnum 2753.0: ['496', '1804', '1829']
# rivnum 65.0: ['502', '790', '1098', '1290', '1601', '1766']
# rivnum 394.0: ['502', '790', '1341']
# rivnum 4503.0: ['504', '1779']
# rivnum 577.0: ['508', '1202', '1360', '1524', '1541']
# rivnum 917.0: ['508', '1360']
# rivnum 1720.0: ['509', '1435', '1440', '1458', '1742']
# rivnum 3947.0: ['509', '1435', '1742']
# rivnum 176.0: ['516', '542']
# rivnum 1481.0: ['525', '559', '738', '801', '1097', '1322', '1729', '1769']
# rivnum 2087.0: ['527', '712']
# rivnum 812.0: ['554', '795']
# rivnum 346.0: ['556', '897']
# rivnum 2691.0: ['558', '1334']
# rivnum 317.0: ['568', '1109', '1326', '1506', '1611']
# rivnum 1188.0: ['569', '1121', '1240', '1283', '1400']
# rivnum 558.0: ['575', '918']
# rivnum 632.0: ['590', '1477']
# rivnum 229.0: ['599', '777', '965', '997', '1653']
# rivnum 1812.0: ['599', '1593']
# rivnum 2145.0: ['600', '1423']
# rivnum 3265.0: ['600', '1423']
# rivnum 1356.0: ['605', '668', '1455']
# rivnum 381.0: ['610', '676']
# rivnum 293.0: ['619', '1194']
# rivnum 108.0: ['625', '737', '853', '1150']
# rivnum 4489.0: ['626', '772', '1184']
# rivnum 192.0: ['630', '850']
# rivnum 913.0: ['654', '781']
# rivnum 3464.0: ['658', '991']
# rivnum 10401.0: ['658', '991']
# rivnum 259.0: ['665', '855']
# rivnum 1800.0: ['674', '1211', '1285', '1800']
# rivnum 1833.0: ['674', '1211', '1285', '1658']
# rivnum 231.0: ['693', '952', '1297']
# rivnum 167.0: ['699', '1354']
# rivnum 393.0: ['714', '905', '1827']
# rivnum 2715.0: ['738', '1769']
# rivnum 946.0: ['742', '810', '1078', '1436', '1590', '1591']
# rivnum 1882.0: ['742', '751']
# rivnum 425.0: ['749', '955']
# rivnum 5365.0: ['751', '1436']
# rivnum 3085.0: ['757', '1419']
# rivnum 5545.0: ['763', '1110', '1133']
# rivnum 284.0: ['783', '1266', '1322', '1416', '1421']
# rivnum 1195.0: ['786', '1528']
# rivnum 409.0: ['791', '1113']
# rivnum 1539.0: ['817', '1852']
# rivnum 1368.0: ['854', '937']
# rivnum 1058.0: ['870', '1664']
# rivnum 273.0: ['875', '1409', '1429']
# rivnum 3285.0: ['875', '1063']
# rivnum 758.0: ['918', '1157']
# rivnum 1067.0: ['1030', '1450']
# rivnum 3205.0: ['1032', '1502']
# rivnum 3409.0: ['1035', '1121']
# rivnum 2954.0: ['1044', '1117']
# rivnum 3102.0: ['1050', '1251']
# rivnum 2147.0: ['1069', '1838']
# rivnum 206.0: ['1070', '1171', '1242']
# rivnum 807.0: ['1080', '1665', '1743']
# rivnum 1015.0: ['1104', '1243']
# rivnum 33.0: ['1129', '1688']
# rivnum 630.0: ['1149', '1543']
# rivnum 971.0: ['1160', '1352']
# rivnum 197.0: ['1187', '1774', '1842']
# rivnum 508.0: ['1222', '1744']
# rivnum 3374.0: ['1229', '1324', '1387', '1754']
# rivnum 62.0: ['1233', '1320']
# rivnum 893.0: ['1319', '1395']
# rivnum 644.0: ['1326', '1367']
# rivnum 47.0: ['1362', '1585']
# rivnum 66.0: ['1602', '1665']
# rivnum 1384.0: ['1804', '1829']
# "\nwith open(basin_cities_path, 'w') as json_file:\n    json.dump(new_basin_to_cities, json_file)\n    print(f'{basin_cities_path} saved')\n"

# %%
####################################################################################
# This test code shows how new_basin_cities looks like
# basin at each city
distance=100
####################################################################################

h08dir = '/mnt/c/Users/tsimk/Downloads/dotfiles/h08'
basin_cities_path = f'{h08dir}/global_city/dat/riv_num_/basin_to_cities_{distance}km.json'
with open(basin_cities_path, 'r') as json_file:
    tmp = json.load(json_file)
for key, value in tmp.items():
    print(key)
    print(value)
# Out:
# 848.0
# ['1', '936', '1283', '1400']
# 14.0
# ['2', '11', '126', '130', '133', '188', '197', '217', '243', '319', '321', '363', '398', '406', '455', '463', '473', '513', '526', '588', '667', '669', '673', '677', '797', '874', '883', '903', '941', '983', '1012', '1018', '1067', '1089', '1181', '1216', '1253', '1288', '1298', '1337', '1365', '1371', '1381', '1422', '1575', '1578', '1620', '1652', '1656', '1668', '1697', '1712', '1718', '1824']
# 480.0
# ['3', '52', '85', '144', '160', '275', '612', '618', '873', '967', '1200', '1299', '1376', '1687']
# 5438.0
# ['3', '85']
# 9439.0
# ['3', '1212']
# 112.0
# ['4', '74', '209', '269', '397', '431', '483', '557', '779', '1104']
# 164.0
# ['4', '537', '929', '933', '1569']
# 1366.0
# ['4', '143', '487', '933', '953', '1094']
# 5.0
# ['5', '94', '119', '140', '155', '196', '257', '343', '550', '597', '629', '689', '767', '789', '803', '836', '837', '866', '939', '1125', '1235', '1327', '1329', '1361', '1411', '1453', '1500', '1530', '1573', '1627', '1648', '1717', '1720']
# 528.0
# ['7', '58', '696', '1070', '1113', '1242', '1610']
# 4.0
# ['9', '71', '76', '118', '200', '579', '691', '729', '746', '1333', '1551', '1579', '1667', '1675', '1676', '1747']
# 172.0
# ['10', '183', '334', '386', '900', '910', '1265', '1439', '1755']
# 81.0
# ['12', '589']
# 11240.0
# ['12', '589']
# 189.0
# ['13', '342', '358', '368', '822', '848', '1390', '1617', '1853']
# 23.0
# ['14', '33', '111', '146', '221', '260', '272', '276', '284', '296', '354', '370', '466', '536', '578', '715', '764', '813', '849', '1091', '1103', '1196', '1220', '1295', '1405', '1430', '1519', '1535', '1536', '1563', '1582', '1636', '1689']
# 234.0
# ['15', '81', '266', '970', '1151', '1597']
# 7763.0
# ['15', '970']
# 261.0
# ['16', '767', '939', '1100', '1126', '1717']
# 1744.0
# ['17', '208', '804', '1064', '1364', '1432']
# 1503.0
# ['18', '1495']
# 2583.0
# ['18', '1562']
# 3.0
# ['19', '37', '150', '194', '283', '304', '335', '353', '372', '376', '407', '416', '421', '437', '553', '648', '694', '741', '754', '756', '794', '832', '868', '909', '920', '924', '934', '954', '1001', '1052', '1131', '1154', '1159', '1172', '1248', '1269', '1320', '1380', '1463', '1470', '1496', '1510', '1515', '1523', '1534', '1538', '1608', '1660']
# 11.0
# ['20', '39', '41', '48', '96', '102', '116', '125', '154', '160', '161', '246', '262', '275', '279', '306', '316', '348', '357', '395', '403', '424', '428', '433', '446', '452', '467', '477', '491', '505', '507', '514', '519', '521', '523', '534', '539', '549', '585', '593', '601', '603', '617', '622', '632', '639', '657', '663', '672', '690', '700', '701', '703', '721', '730', '739', '748', '758', '773', '775', '787', '805', '819', '824', '826', '829', '831', '835', '838', '847', '851', '865', '873', '880', '888', '895', '919', '967', '971', '972', '982', '1022', '1023', '1028', '1029', '1036', '1048', '1059', '1066', '1082', '1083', '1087', '1090', '1092', '1110', '1124', '1133', '1161', '1180', '1183', '1197', '1204', '1209', '1221', '1256', '1263', '1272', '1275', '1276', '1299', '1305', '1310', '1311', '1339', '1376', '1399', '1418', '1426', '1457', '1462', '1469', '1479', '1508', '1520', '1529', '1544', '1547', '1588', '1624', '1643', '1659', '1671', '1672', '1678', '1695', '1704', '1715', '1721', '1726', '1735', '1753', '1762', '1765', '1803', '1808', '1811', '1831', '1837', '1840', '1843', '1848']
# 118.0
# ['21', '786', '1280', '1369', '1528']
# 191.0
# ['21', '1027', '1336']
# 138.0
# ['22', '134', '598', '796', '1030', '1043', '1355', '1414', '1450', '1481', '1686', '1761', '1783', '1826']
# 45.0
# ['23', '42', '44', '138', '148', '271', '310', '331', '467', '594', '640', '716', '726', '736', '763', '826', '878', '908', '959', '981', '1110', '1204', '1272', '1358', '1379', '1427', '1440', '1445', '1555', '1612', '1638', '1658', '1682', '1800', '1831', '1843']
# 382.0
# ['23', '24', '42', '43', '44', '231', '1086', '1287']
# 220.0
# ['25', '108', '117', '220', '280', '697', '750', '876', '960', '1116', '1214', '1702', '1764', '1770', '1805']
# 376.0
# ['25', '108', '280', '1116', '1214', '1755', '1764', '1805']
# 413.0
# ['26', '158', '297', '698', '827', '1406', '1438']
# 1818.0
# ['27', '171', '807']
# 2.0
# ['28', '261', '480', '650', '729', '1101', '1333', '1434', '1491']
# 2113.0
# ['29', '145', '1264']
# 1.0
# ['30', '228', '263', '274', '327', '453', '872', '1217', '1277', '1410', '1420', '1703']
# 6.0
# ['31', '151', '172', '185', '229', '241', '265', '288', '298', '326', '420', '458', '459', '482', '502', '532', '635', '641', '710', '790', '830', '842', '846', '994', '1056', '1098', '1173', '1175', '1202', '1227', '1239', '1600', '1609', '1635', '1640', '1649', '1680', '1705', '1731', '1766']
# 17.0
# ['31', '57', '90', '93', '229', '324', '360', '482', '608', '646', '653', '828', '830', '944', '1003', '1006', '1143', '1208', '1330', '1349', '1489', '1514', '1518', '1560', '1635']
# 750.0
# ['32', '988', '1063', '1750']
# 63.0
# ['34', '106', '176', '215', '411', '492', '881', '945', '1127', '1177', '1357']
# 182.0
# ['35', '191', '313', '439', '457', '484', '498', '725', '928', '1605', '1650', '1654', '1661', '1819', '1821', '1828']
# 970.0
# ['35', '988', '1750', '1836']
# 88.0
# ['36', '472', '1302', '1413', '1751', '1813', '1822']
# 501.0
# ['36', '1505']
# 325.0
# ['37', '283']
# 955.0
# ['38', '545', '858', '1032', '1502', '1628']
# 5869.0
# ['38', '545']
# 53.0
# ['40', '164', '287', '352', '371', '621', '833', '882', '894', '1088', '1119', '1255', '1261', '1273', '1497', '1550', '1576', '1639', '1683']
# 64.0
# ['40', '66', '287', '314', '475', '485', '708', '778', '852', '894', '940', '1000', '1106', '1174', '1255', '1429', '1478', '1493', '1758']
# 864.0
# ['45', '518']
# 416.0
# ['46', '226', '1018', '1677', '1718']
# 492.0
# ['46', '785', '1018']
# 328.0
# ['47', '547', '1621']
# 78.0
# ['49', '99', '344', '510', '524', '543', '613', '631', '892', '946', '1234', '1246', '1417', '1531']
# 494.0
# ['49', '295', '344', '445', '524', '543', '631', '678', '1234', '1531']
# 485.0
# ['50', '1236', '1274']
# 177.0
# ['51', '135']
# 343.0
# ['52', '252', '531', '593', '618', '666', '782', '1135', '1224', '1282', '1384', '1673', '1848']
# 1830.0
# ['52', '141', '252', '429', '612', '906', '961', '1200', '1212', '1224', '1384', '1687']
# 27.0
# ['53', '120', '248', '345', '369', '390', '561', '733', '821', '825', '1115', '1189', '1248', '1467', '1809']
# 28.0
# ['54', '86', '96', '117', '169', '179', '235', '250', '300', '347', '377', '383', '388', '470', '493', '521', '534', '602', '643', '654', '662', '671', '700', '706', '707', '718', '723', '750', '758', '781', '841', '888', '904', '957', '979', '992', '995', '1011', '1013', '1040', '1057', '1095', '1111', '1168', '1182', '1187', '1190', '1265', '1308', '1313', '1339', '1348', '1394', '1412', '1426', '1449', '1589', '1623', '1659', '1702', '1704', '1706', '1789', '1845']
# 3431.0
# ['55', '998', '1075', '1581']
# 498.0
# ['56', '165', '290', '891', '1251', '1498', '1527']
# 34.0
# ['59', '566', '1250']
# 326.0
# ['62', '65', '1290', '1788']
# 12.0
# ['63', '99', '312', '318', '330', '554', '587', '664', '740', '784', '818', '950', '965', '985', '1246', '1307', '1338', '1417', '1473', '1699', '1709', '1710', '1785', '1844']
# 1220.0
# ['65', '1788']
# 441.0
# ['69', '182']
# 126.0
# ['70', '611', '1397', '1465', '1733']
# 392.0
# ['70', '1744']
# 1749.0
# ['72', '230', '1044', '1185', '1324', '1387', '1692', '1794']
# 1752.0
# ['72', '815', '1044', '1117', '1185', '1249', '1328', '1679']
# 148.0
# ['73', '226', '352', '1312']
# 228.0
# ['73', '732', '833', '1051', '1119', '1273', '1696']
# 3829.0
# ['73', '1696']
# 46.0
# ['75', '391', '1153']
# 21.0
# ['77', '122', '256', '656', '1060', '1513', '1625']
# 43.0
# ['77', '256', '655', '1625', '1646', '1792']
# 478.0
# ['78', '366', '486', '490', '745', '791', '839']
# 1014.0
# ['78', '977']
# 4642.0
# ['79', '1145']
# 618.0
# ['80', '1543', '1700']
# 38.0
# ['82', '340', '541', '560', '573', '616', '624', '634', '1232', '1501']
# 623.0
# ['83', '1652']
# 3429.0
# ['84', '206']
# 878.0
# ['86', '179', '995', '1245']
# 788.0
# ['87', '1223']
# 2500.0
# ['87', '1342']
# 19.0
# ['89', '1191']
# 357.0
# ['91', '1684']
# 82.0
# ['92', '1125', '1564']
# 35.0
# ['95', '172', '211', '481', '548']
# 473.0
# ['97', '356', '530', '644', '768', '1343']
# 2386.0
# ['97', '356', '644']
# 6026.0
# ['97', '530']
# 667.0
# ['100', '364', '1293']
# 1577.0
# ['100', '364']
# 102.0
# ['103', '232', '355', '912', '917']
# 401.0
# ['105', '522']
# 581.0
# ['107', '177', '423', '511', '1406', '1441']
# 6429.0
# ['107', '423', '1441']
# 278.0
# ['109', '938']
# 338.0
# ['110', '322', '592', '1292']
# 8210.0
# ['110', '592']
# 205.0
# ['112', '242', '753', '1279', '1552', '1694']
# 390.0
# ['113', '478']
# 56.0
# ['114', '627', '688', '1681', '1846']
# 1471.0
# ['121', '178']
# 203.0
# ['123', '239', '586', '605', '660', '751', '770', '810', '1078', '1079', '1455', '1484', '1591', '1657']
# 948.0
# ['124', '379', '768', '793', '1128']
# 1829.0
# ['126', '874']
# 243.0
# ['127', '405', '1020', '1165', '1460', '1480', '1778']
# 2370.0
# ['128', '236', '1691']
# 4555.0
# ['128', '236']
# 9930.0
# ['128', '236']
# 2360.0
# ['129', '1045']
# 7178.0
# ['129', '1045']
# 1770.0
# ['131', '417']
# 103.0
# ['136', '517']
# 178.0
# ['137', '1521']
# 37.0
# ['139', '219', '311', '441', '464', '595', '693', '952', '978', '1131', '1134', '1297', '1306', '1316', '1332', '1354', '1463']
# 2411.0
# ['141', '429', '886', '906']
# 876.0
# ['142', '282']
# 127.0
# ['143', '487', '953', '1094', '1109', '1506', '1611']
# 805.0
# ['147', '1630']
# 748.0
# ['149', '567', '651', '1282', '1366', '1644']
# 1789.0
# ['149', '320', '620', '961']
# 911.0
# ['156', '1368']
# 4424.0
# ['159', '1281']
# 9647.0
# ['163', '1565']
# 318.0
# ['166', '1335']
# 591.0
# ['167', '234', '637', '679', '949', '1267', '1281', '1522']
# 1130.0
# ['167', '535', '637', '759', '1321', '1539', '1598']
# 2502.0
# ['167', '1076', '1568']
# 1511.0
# ['170', '1292']
# 4051.0
# ['170', '205', '427']
# 107.0
# ['173', '175', '1416', '1651', '1825']
# 69.0
# ['178', '1391']
# 48.0
# ['180', '722', '1058', '1230']
# 1945.0
# ['181', '1163', '1549']
# 6057.0
# ['181', '1549']
# 331.0
# ['183', '410', '900']
# 1571.0
# ['184', '569', '936', '1408']
# 1671.0
# ['184', '1474']
# 2927.0
# ['190', '658', '925', '991', '1039', '1123', '1385']
# 1807.0
# ['191', '193', '227', '268', '484', '1085', '1398', '1650', '1661']
# 282.0
# ['192', '1852']
# 1850.0
# ['193', '207', '227', '268']
# 42.0
# ['195', '238', '802', '1296', '1798']
# 588.0
# ['201', '1375']
# 585.0
# ['202', '899']
# 961.0
# ['203', '834', '1708']
# 6278.0
# ['207', '227', '268', '1819']
# 417.0
# ['208', '1064', '1378', '1432']
# 74.0
# ['210', '351', '418', '443', '444', '447', '681', '713', '734', '766', '800', '808', '811', '923', '947', '968', '1026', '1061', '1093', '1169', '1226', '1260', '1284', '1345', '1425', '1452', '1509', '1577', '1626']
# 1298.0
# ['210', '447']
# 25.0
# ['212', '240', '244', '333', '337', '361', '670', '766', '859', '947', '1136', '1258', '1392', '1492', '1561', '1584']
# 10.0
# ['213', '223', '224', '451', '469', '598', '627', '680', '783', '935', '989', '1325', '1393', '1416', '1437', '1444', '1655', '1681', '1686', '1729', '1798', '1826', '1857']
# 3700.0
# ['214', '504', '1779']
# 32.0
# ['216', '1219', '1346']
# 123.0
# ['219', '907', '1102', '1442']
# 358.0
# ['220', '493', '512', '654', '662', '671', '697', '723', '876', '992', '1394', '1494', '1845']
# 244.0
# ['222', '246', '293', '347', '348', '388', '456', '515', '602', '603', '643', '706', '707', '747', '815', '1192', '1245', '1328', '1589']
# 3908.0
# ['230', '495', '1309']
# 359.0
# ['232', '870', '915', '1448', '1664']
# 131.0
# ['233', '325']
# 158.0
# ['233', '325', '1487']
# 4649.0
# ['234', '1267']
# 15.0
# ['245', '301', '633', '661', '709', '962', '1065', '1359', '1373', '1818', '1854']
# 385.0
# ['249', '432', '1186']
# 1257.0
# ['249', '1186']
# 75.0
# ['251', '607', '625', '628', '1041', '1300', '1356', '1442', '1525']
# 323.0
# ['255', '714', '1279', '1318', '1694']
# 18.0
# ['259', '408', '596', '615', '1127', '1130', '1690']
# 98.0
# ['263', '1756', '1780']
# 2025.0
# ['264', '969', '1179']
# 3202.0
# ['267', '986']
# 2430.0
# ['270', '752']
# 49.0
# ['272', '387', '466', '735', '764', '874', '1091', '1103', '1405', '1574', '1689']
# 146.0
# ['277', '281', '476', '843', '889', '923', '951', '1073', '1176', '1226', '1280', '1284']
# 593.0
# ['286', '580']
# 646.0
# ['286', '345', '1115']
# 26.0
# ['289', '547', '717', '771', '984', '1144', '1155', '1305', '1795']
# 1892.0
# ['290', '727', '1739']
# 3036.0
# ['292', '591']
# 1252.0
# ['297', '698', '720']
# 1624.0
# ['299', '1781', '1835']
# 8.0
# ['302', '335', '374', '384', '760', '812', '869', '898', '914', '1428']
# 288.0
# ['307', '897', '1548']
# 111.0
# ['308', '550', '837']
# 706.0
# ['309', '776', '885', '1476']
# 40.0
# ['311', '402', '437', '461', '553', '924', '942', '1096', '1194', '1332', '1515']
# 5127.0
# ['314', '708']
# 555.0
# ['315', '468', '508', '1360']
# 475.0
# ['328', '1784', '1802']
# 1516.0
# ['328', '788', '1512']
# 4017.0
# ['328', '1784']
# 29.0
# ['332', '1730']
# 576.0
# ['336', '345', '489', '711', '1112']
# 696.0
# ['342', '392', '848']
# 978.0
# ['346', '796', '1325', '1414', '1783']
# 143.0
# ['349', '1533']
# 314.0
# ['350', '1202', '1524', '1541', '1833', '1834']
# 374.0
# ['350', '861', '864', '1175', '1222', '1833']
# 5507.0
# ['366', '977']
# 16.0
# ['367', '381', '642', '1763']
# 720.0
# ['375', '1081']
# 7.0
# ['380', '462', '799', '1178']
# 395.0
# ['385', '1554']
# 877.0
# ['389', '440', '1627']
# 311.0
# ['392', '871']
# 334.0
# ['399', '529']
# 17041.0
# ['399', '529']
# 105.0
# ['401', '426', '527', '712', '871', '1074', '1312']
# 740.0
# ['404', '430']
# 763.0
# ['408', '1009', '1690']
# 2571.0
# ['413', '969', '1138']
# 5046.0
# ['413', '1138']
# 608.0
# ['414', '1050', '1347']
# 670.0
# ['418', '1026']
# 320.0
# ['419', '974']
# 421.0
# ['419', '974', '1546']
# 1417.0
# ['434', '878', '1034', '1458', '1707']
# 166.0
# ['435', '867', '976']
# 1207.0
# ['438', '943', '1093', '1169', '1336', '1425']
# 202.0
# ['442', '628', '859']
# 3477.0
# ['444', '734']
# 55.0
# ['454', '964']
# 2152.0
# ['464', '1021', '1306']
# 586.0
# ['479', '613', '731', '990']
# 657.0
# ['481', '1364']
# 2130.0
# ['486', '490', '745', '839']
# 10510.0
# ['486', '490', '839']
# 2753.0
# ['496', '1804', '1829']
# 65.0
# ['502', '790', '1098', '1290', '1601', '1766']
# 394.0
# ['502', '790', '1341']
# 4503.0
# ['504', '1779']
# 577.0
# ['508', '1202', '1360', '1524', '1541']
# 917.0
# ['508', '1360']
# 1720.0
# ['509', '1435', '1440', '1458', '1742']
# 3947.0
# ['509', '1435', '1742']
# 176.0
# ['516', '542']
# 1481.0
# ['525', '559', '738', '801', '1097', '1322', '1729', '1769']
# 2087.0
# ['527', '712']
# 812.0
# ['554', '795']
# 346.0
# ['556', '897']
# 2691.0
# ['558', '1334']
# 317.0
# ['568', '1109', '1326', '1506', '1611']
# 1188.0
# ['569', '1121', '1240', '1283', '1400']
# 558.0
# ['575', '918']
# 632.0
# ['590', '1477']
# 229.0
# ['599', '777', '965', '997', '1653']
# 1812.0
# ['599', '1593']
# 2145.0
# ['600', '1423']
# 3265.0
# ['600', '1423']
# 1356.0
# ['605', '668', '1455']
# 381.0
# ['610', '676']
# 293.0
# ['619', '1194']
# 108.0
# ['625', '737', '853', '1150']
# 4489.0
# ['626', '772', '1184']
# 192.0
# ['630', '850']
# 913.0
# ['654', '781']
# 3464.0
# ['658', '991']
# 10401.0
# ['658', '991']
# 259.0
# ['665', '855']
# 1800.0
# ['674', '1211', '1285', '1800']
# 1833.0
# ['674', '1211', '1285', '1658']
# 231.0
# ['693', '952', '1297']
# 167.0
# ['699', '1354']
# 393.0
# ['714', '905', '1827']
# 2715.0
# ['738', '1769']
# 946.0
# ['742', '810', '1078', '1436', '1590', '1591']
# 1882.0
# ['742', '751']
# 425.0
# ['749', '955']
# 5365.0
# ['751', '1436']
# 3085.0
# ['757', '1419']
# 5545.0
# ['763', '1110', '1133']
# 284.0
# ['783', '1266', '1322', '1416', '1421']
# 1195.0
# ['786', '1528']
# 409.0
# ['791', '1113']
# 1539.0
# ['817', '1852']
# 1368.0
# ['854', '937']
# 1058.0
# ['870', '1664']
# 273.0
# ['875', '1409', '1429']
# 3285.0
# ['875', '1063']
# 758.0
# ['918', '1157']
# 1067.0
# ['1030', '1450']
# 3205.0
# ['1032', '1502']
# 3409.0
# ['1035', '1121']
# 2954.0
# ['1044', '1117']
# 3102.0
# ['1050', '1251']
# 2147.0
# ['1069', '1838']
# 206.0
# ['1070', '1171', '1242']
# 807.0
# ['1080', '1665', '1743']
# 1015.0
# ['1104', '1243']
# 33.0
# ['1129', '1688']
# 630.0
# ['1149', '1543']
# 971.0
# ['1160', '1352']
# 197.0
# ['1187', '1774', '1842']
# 508.0
# ['1222', '1744']
# 3374.0
# ['1229', '1324', '1387', '1754']
# 62.0
# ['1233', '1320']
# 893.0
# ['1319', '1395']
# 644.0
# ['1326', '1367']
# 47.0
# ['1362', '1585']
# 66.0
# ['1602', '1665']
# 1384.0
# ['1804', '1829']

# %%
####################################################################################
# テストする場合はここから始めてください
# coords_a is multiple city's [prf and int coordinates] in the same basin
# This test code shows how coords_a looks like
key_index=1
distance=100
####################################################################################

import json
import os
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import cartopy.feature as cfeature
import numpy as np
import pandas as pd
import matplotlib.colors as mcolors

h08dir = '/mnt/c/Users/tsimk/Downloads/dotfiles/h08'
basin_cities_path = f'{h08dir}/global_city/dat/riv_num_/basin_to_cities_{distance}km.json'
with open(basin_cities_path, 'r') as json_file:
    new_basin_to_cities = json.load(json_file)

# get uid and city list
keys_list = list(new_basin_to_cities.keys())
uid = keys_list[key_index]
print(f'uid: {uid}')
rivnum_list = new_basin_to_cities[uid]
rivnum_list = [int(i) for i in rivnum_list]

# remove overlap
h08dir = '/mnt/c/Users/tsimk/Downloads/dotfiles/h08'
overlap_path = f'{h08dir}/global_city/dat/cty_lst_/gpw4/overlap_hidden_only.txt'
with open(overlap_path, 'r') as f:
    numbers = [int(line.strip()) for line in f]
rivnum_list_removed = [num for num in rivnum_list if num not in numbers]
rivnum_list_removed = [int(i) for i in rivnum_list_removed]
print('cities in uid')
print(rivnum_list_removed)

# rivout
rivout_path = f'{h08dir}/wsi/dat/riv_out_/W5E5LR__00000000.gl5'
rivout_gl5 = np.fromfile(rivout_path, dtype='float32').reshape(2160, 4320)

# coord of purficication
coords_a = []
for city_num in rivnum_list_removed:
    # rivnum
    rivnum_path = f'{h08dir}/global_city/dat/riv_num_/rivnum.CAMA.gl5'
    rivnum_gl5 = np.fromfile(rivnum_path, dtype='float32').reshape(2160, 4320)

    # prf
    prf_dir = f'{h08dir}/global_city/dat/cty_prf_'
    prf_path = f'{prf_dir}/vld_cty_/city_{city_num:08}.gl5'
    prf = np.fromfile(prf_path, dtype='float32').reshape(2160, 4320)

    # int
    int_dir = f'{h08dir}/global_city/dat/cty_int_/{distance}km_samebasin'
    int_path = f'{int_dir}/city_{city_num:08}.gl5'
    intake = np.fromfile(int_path, dtype='float32').reshape(2160, 4320)

    # 1. prfのみが対象流域内
    # 2. intのみが対象流域内
    # 3. prfとintどちらもが対象領域内 -> runoutの多い方を採用する
    uid = int(float(uid))
    prf_coord = np.where((prf == 1) & (rivnum_gl5 == uid))
    int_coord = np.where((intake==1) & (rivnum_gl5 == uid))

    if prf_coord[0].size != 0 and int_coord[0].size == 0:
        coords_a.append([prf_coord, city_num])
    elif prf_coord[0].size == 0 and int_coord[0].size != 0:
        coords_a.append([int_coord, city_num])
    elif prf_coord[0].size != 0 and int_coord[0].size != 0:
        prf_runout = rivout_gl5[prf_coord][0] * 60 * 60 * 24 * 365 / (1000)
        int_runout = rivout_gl5[int_coord][0] * 60 * 60 * 24 * 365 / (1000)
        print(f"prf: {prf_runout/1e9}, int: {int_runout/1e9}")
        if prf_runout > int_runout:
            larger_coord = prf_coord
        else:
            larger_coord = int_coord
        coords_a.append([larger_coord, city_num])
    else:
        continue
        
print('coords_a')
#print(coords_a)

print(coords_a[0])
print(coords_a[0][0][0][0]) #737
print(coords_a[0][0][1][0]) #3082
print(coords_a[0][1]) # 2
# Out:
# uid: 14.0
# cities in uid
# [2, 11, 126, 130, 133, 188, 197, 217, 243, 319, 321, 363, 398, 406, 455, 463, 473, 513, 526, 588, 667, 669, 673, 677, 797, 874, 883, 903, 941, 983, 1012, 1018, 1067, 1089, 1181, 1216, 1253, 1288, 1298, 1337, 1365, 1371, 1422, 1578, 1620, 1652, 1656, 1697, 1712, 1718, 1824]
# prf: 4.42079778375, int: 19.248677595
# prf: 0.0956541544453125, int: 478.240570224
# prf: 87.145943796, int: 6.65100300825
# prf: 6.701539941, int: 87.196582728
# prf: 0.0565119422578125, int: 0.056030028908203126
# prf: 591.25080384, int: 56.497291938
# prf: 0.25847798709375, int: 0.2720333548125
# prf: 30.390383844, int: 3.641325674625
# prf: 0.1305414087890625, int: 45.876459888
# prf: 0.1861881898359375, int: 33.889220262
# prf: 246.507466968, int: 92.2232871
# prf: 0.1439401436015625, int: 6.8335545645
# prf: 20.418117228, int: 12.1408761195
# prf: 0.07312175173828125, int: 22.907352258
# prf: 328.876834176, int: 19.687177791
# prf: 0.98778654478125, int: 39.661944192
# prf: 0.2345311840078125, int: 39.496202802
# prf: 827.483069376, int: 19.038458619
# prf: 0.51893159371875, int: 5.756583411
# prf: 2.466189851625, int: 86.406873984
# prf: 1.825538229, int: 14.289763797
# prf: 0.08963806960546875, int: 32.667907851
# prf: 31.437966402, int: 41.93014734
# prf: 0.06896914730859376, int: 22.908410685
# prf: 6.895955439, int: 41.618386386
# prf: 0.8571333279375, int: 0.993544882875
# prf: 0.048419474361328124, int: 32.990188032
# prf: 3.04763361975, int: 65.844716076
# prf: 1.418693032125, int: 28.304519877
# prf: 0.04395905131640625, int: 18.263201247
# prf: 4.50879406425, int: 477.148131648
# prf: 0.84838917121875, int: 54.376247592
# prf: 0.2212189576171875, int: 32.667907851
# prf: 1.612417941, int: 19.048786659
# prf: 0.367068291890625, int: 0.09287203405078125
# prf: 1.66044924, int: 1.1367674746875
# prf: 0.174752771203125, int: 1.7296509268125
# prf: 0.06634956512109375, int: 42.139175832
# prf: 0.04071351109570313, int: 0.731685706875
# prf: 0.29364580096875, int: 59.087260836
# prf: 0.2005798158984375, int: 18.263201247
# prf: 0.0493587828984375, int: 42.139175832
# prf: 0.04992697754296875, int: 11.6460999315
# prf: 3.66539429475, int: 89.842256028
# prf: 0.11301882612890625, int: 1.4944801995
# prf: 0.96825861590625, int: 22.105640124
# coords_a
# [(array([732]), array([3086])), 2]
# 732
# 3086
# 2

# %%
####################################################################################
# this test code shows how edges looks like
# edgesは2都市間のupstreamとdownstreamの関係をすべて保存したリスト
####################################################################################
####################################################################################
# check what's happening in 1089, 1288, 1620
# 取水点がかぶっているバグを発見してしまった．(おそらくintakeが原因)
# 取水点がかぶっている場合は，city_numが大きい方が，一つ下流にずれることとする．(実際にずらさなくてもよい)
# 1. 同流域内で取水点がかぶっている都市を取水点ごとにリストにする
# 2. edgesの関係性を整理する
####################################################################################

import json
from collections import defaultdict

h08dir = '/mnt/c/Users/tsimk/Downloads/dotfiles/h08'
basin_cities_path = f'{h08dir}/global_city/dat/riv_num_/basin_to_cities_{distance}km.json'
with open(basin_cities_path, 'r') as json_file:
    new_basin_to_cities = json.load(json_file)
    
def l_coordinate_to_tuple(lcoordinate, a=2160, b=4320):
    lat_l = ((lcoordinate - 1) // b)
    lon_l = (lcoordinate) % b - 1
    return (lat_l, lon_l)

def nxtl2nxtxy(rgnfile, upperindex, leftindex):
    vfunc = np.vectorize(l_coordinate_to_tuple, otypes=[tuple])
    riv_nxtxy = np.empty(rgnfile.shape, dtype=tuple)
    mask = ~np.isnan(rgnfile)
    riv_nxtxy[mask] = vfunc(rgnfile[mask])
    riv_nxtxy_shape = (riv_nxtxy.shape[0], riv_nxtxy.shape[1], 2)
    
    riv_nxtxy_lst = []
    for row in riv_nxtxy:
        for y, x in row:
            modified_y = y - upperindex
            modified_x = x - leftindex
            riv_nxtxy_lst.append((modified_y, modified_x))

    riv_nxtxy_cropped = np.array(riv_nxtxy_lst).reshape(riv_nxtxy_shape)
    riv_nxtxy_cropped = riv_nxtxy_cropped.astype(int)
    return riv_nxtxy_cropped
    
rivnxl_path = f"{h08dir}/global_city/dat/riv_nxl_/rivnxl.CAMA.gl5"
rivnxl_gl5 = np.fromfile(rivnxl_path, 'float32').reshape(2160, 4320)
riv_nxlonlat_cropped = nxtl2nxtxy(rivnxl_gl5, 0, 0)

def is_valid_edge(city1, city2, coords_dict):
    for coord, city_list in coords_dict.items():
        if len(city_list) > 1:
            if city1 in city_list and city2 in city_list:
                if city1 > city2:
                    continue
                else:
                    city1, city2 = None, None
                    
    if city1 and city2:
        return True
    else:
        return False

def updown(new_basin_to_cities, key_index=0, distance=100):
    # get uid and city list
    keys_list = list(new_basin_to_cities.keys())
    uid = keys_list[key_index]
    rivnum_list = new_basin_to_cities[uid]
    rivnum_list = [int(i) for i in rivnum_list]
    
    # remove overlap
    h08dir = '/mnt/c/Users/tsimk/Downloads/dotfiles/h08'
    overlap_path = f'{h08dir}/global_city/dat/cty_lst_/gpw4/overlap_hidden_only.txt'
    with open(overlap_path, 'r') as f:
        numbers = [int(line.strip()) for line in f]
    rivnum_list_removed = [num for num in rivnum_list if num not in numbers]
    rivnum_list_removed = [int(i) for i in rivnum_list_removed]
    
    # rivout
    rivout_path = f'{h08dir}/wsi/dat/riv_out_/W5E5LR__00000000.gl5'
    rivout_gl5 = np.fromfile(rivout_path, dtype='float32').reshape(2160, 4320)
    
    # coord of purficication
    coords_a = []
    #special_lst = [2, 1089, 1288, 1620]
    for city_num in rivnum_list_removed:
    #for city_num in special_lst:
        # rivnum
        rivnum_path = f'{h08dir}/global_city/dat/riv_num_/rivnum.CAMA.gl5'
        rivnum_gl5 = np.fromfile(rivnum_path, dtype='float32').reshape(2160, 4320)

        # prf
        prf_dir = f'{h08dir}/global_city/dat/cty_prf_'
        prf_path = f'{prf_dir}/vld_cty_/city_{city_num:08}.gl5'
        prf = np.fromfile(prf_path, dtype='float32').reshape(2160, 4320)

        # int
        int_dir = f'{h08dir}/global_city/dat/cty_int_/{distance}km_samebasin'
        int_path = f'{int_dir}/city_{city_num:08}.gl5'
        intake = np.fromfile(int_path, dtype='float32').reshape(2160, 4320)
        
        # 1. prfのみが対象流域内(uid)
        # 2. intのみが対象流域内(uid)
        # 3. prfとintどちらもが対象領域内(uid)
        uid = int(float(uid))
        prf_coord = np.where((prf == 1) & (rivnum_gl5 == uid))
        int_coord = np.where((intake == 1) & (rivnum_gl5 == uid))
        
        if prf_coord[0].size != 0 and int_coord[0].size != 0:
            
            prf_runout = rivout_gl5[prf_coord][0] * 60 * 60 * 24 * 365 / (1000)
            int_runout = rivout_gl5[int_coord][0] * 60 * 60 * 24 * 365 / (1000)
            
            if prf_runout > int_runout:
                larger_coord = prf_coord
            else:
                larger_coord = int_coord
                
        elif prf_coord[0].size != 0 and int_coord[0].size == 0:
            larger_coord = prf_coord
            
        elif prf_coord[0].size == 0 and int_coord[0].size != 0:
            larger_coord = int_coord
            
        else:
            larger_coord = prf_coord
            continue
            
        coords_a.append([larger_coord, city_num])
        
####################################################################################
# 1. 同流域内で取水点がかぶっている都市を取水点ごとにリストにする
####################################################################################

    # 同じ座標に対して city_num のリストを作成するための辞書
    coords_dict = defaultdict(list)

    # coords_a の要素をループして座標をキーに city_num をリストに追加
    for coord, city_num in coords_a:
        coord_tuple = (tuple(coord[0]), tuple(coord[1]))
        coords_dict[coord_tuple].append(city_num)

####################################################################################
# check what's happening in 1089, 1288, 1620
####################################################################################
        
    # down
    edges = []
    riv_path_array = np.zeros((2160, 4320))
    
    # city_num loop 
    for idx in range(len(coords_a)):
        
        cityup = coords_a[idx][1]
        print(f'-----------------------------------------------------------')
        print(f'cityup: {cityup}')
        print(f'coord: {(coords_a[idx][0][0][0], coords_a[idx][0][1][0])}')
        
        visited_coords = set()
        
        # coords_a[idx][0] = (array([732]), array([3086]))
        riv_path_array[coords_a[idx][0][0][0], coords_a[idx][0][1][0]] = idx

        # coordinates of prf and intake
        coords_b = coords_a.copy()
        coords_b.pop(idx) 
        
        if len(coords_a) > 0:
            target_coord = (coords_a[idx][0][0][0], coords_a[idx][0][1][0])
            
            while True:
                if target_coord in visited_coords:
                    break
                visited_coords.add(target_coord)
                
                next_coord = riv_nxlonlat_cropped[target_coord[0], target_coord[1]]
                if next_coord.size == 0 or next_coord.shape != (2,):
                    break
                
                next_coord = (next_coord[0], next_coord[1])
                riv_path_array[next_coord[0], next_coord[1]] = idx
                target_coord = next_coord

        for coord in coords_b:
            citydwn = coord[1]
            
            if coord[0][0].size == 0:
                continue
            else:
                standard_coord = (coord[0][0][0], coord[0][1][0])
                if standard_coord in visited_coords:
                    edge_flag = is_valid_edge(cityup, citydwn, coords_dict)
                    if edge_flag:
                        print(f'citydwn: {citydwn}')
                        edges.append((cityup, citydwn))
                    else:
                        #print(f'invalid: {citydwn}')
                        continue
                else:
                    #print(f'No: {citydwn}')
                    continue
                    
    # edgesは2都市間のupstreamとdownstreamの関係をすべて保存したリスト
    return edges, riv_path_array, coords_a, rivnum_list_removed
    
# uup: 各都市の上流にあるuniqueな都市
edges, riv_path_array, coords_a, rivnum_list_removed = updown(new_basin_to_cities, key_index=1)
# Out:
# -----------------------------------------------------------
# cityup: 2
# coord: (732, 3086)
# citydwn: 197
# citydwn: 243
# citydwn: 363
# citydwn: 398
# citydwn: 588
# citydwn: 1067
# -----------------------------------------------------------
# cityup: 11
# coord: (786, 3237)
# citydwn: 398
# -----------------------------------------------------------
# cityup: 126
# coord: (755, 3068)
# citydwn: 197
# citydwn: 363
# citydwn: 398
# citydwn: 588
# -----------------------------------------------------------
# cityup: 130
# coord: (761, 3123)
# citydwn: 133
# citydwn: 197
# citydwn: 398
# citydwn: 588
# -----------------------------------------------------------
# cityup: 133
# coord: (762, 3124)
# citydwn: 197
# citydwn: 398
# citydwn: 588
# -----------------------------------------------------------
# cityup: 188
# coord: (808, 3070)
# citydwn: 197
# citydwn: 363
# citydwn: 398
# citydwn: 455
# citydwn: 588
# citydwn: 1718
# -----------------------------------------------------------
# cityup: 197
# coord: (772, 3181)
# citydwn: 398
# citydwn: 588
# -----------------------------------------------------------
# cityup: 217
# coord: (798, 3098)
# citydwn: 197
# citydwn: 363
# citydwn: 398
# citydwn: 588
# citydwn: 883
# -----------------------------------------------------------
# cityup: 243
# coord: (753, 3095)
# citydwn: 197
# citydwn: 363
# citydwn: 398
# citydwn: 588
# -----------------------------------------------------------
# cityup: 319
# coord: (786, 3156)
# citydwn: 197
# citydwn: 398
# citydwn: 588
# citydwn: 1012
# -----------------------------------------------------------
# cityup: 321
# coord: (724, 3097)
# citydwn: 130
# citydwn: 133
# citydwn: 197
# citydwn: 398
# citydwn: 513
# citydwn: 526
# citydwn: 588
# citydwn: 797
# citydwn: 1371
# citydwn: 1656
# -----------------------------------------------------------
# cityup: 363
# coord: (775, 3140)
# citydwn: 197
# citydwn: 398
# citydwn: 588
# -----------------------------------------------------------
# cityup: 398
# coord: (795, 3238)
# -----------------------------------------------------------
# cityup: 406
# coord: (773, 3094)
# citydwn: 197
# citydwn: 363
# citydwn: 398
# citydwn: 588
# -----------------------------------------------------------
# cityup: 455
# coord: (779, 3068)
# citydwn: 197
# citydwn: 363
# citydwn: 398
# citydwn: 588
# -----------------------------------------------------------
# cityup: 463
# coord: (734, 3121)
# citydwn: 197
# citydwn: 398
# citydwn: 588
# citydwn: 669
# citydwn: 1712
# -----------------------------------------------------------
# cityup: 473
# coord: (765, 3261)
# citydwn: 11
# citydwn: 398
# citydwn: 1181
# -----------------------------------------------------------
# cityup: 513
# coord: (738, 3099)
# citydwn: 130
# citydwn: 133
# citydwn: 197
# citydwn: 398
# citydwn: 588
# citydwn: 797
# citydwn: 1371
# citydwn: 1656
# -----------------------------------------------------------
# cityup: 526
# coord: (734, 3097)
# citydwn: 130
# citydwn: 133
# citydwn: 197
# citydwn: 398
# citydwn: 513
# citydwn: 588
# citydwn: 797
# citydwn: 1371
# citydwn: 1656
# -----------------------------------------------------------
# cityup: 588
# coord: (787, 3222)
# citydwn: 398
# -----------------------------------------------------------
# cityup: 667
# coord: (711, 3101)
# citydwn: 130
# citydwn: 133
# citydwn: 197
# citydwn: 321
# citydwn: 398
# citydwn: 513
# citydwn: 526
# citydwn: 588
# citydwn: 677
# citydwn: 797
# citydwn: 983
# citydwn: 1253
# citydwn: 1371
# citydwn: 1656
# -----------------------------------------------------------
# cityup: 669
# coord: (762, 3155)
# citydwn: 197
# citydwn: 398
# citydwn: 588
# citydwn: 1712
# -----------------------------------------------------------
# cityup: 673
# coord: (758, 3222)
# citydwn: 11
# citydwn: 398
# citydwn: 1181
# -----------------------------------------------------------
# cityup: 677
# coord: (719, 3097)
# citydwn: 130
# citydwn: 133
# citydwn: 197
# citydwn: 321
# citydwn: 398
# citydwn: 513
# citydwn: 526
# citydwn: 588
# citydwn: 797
# citydwn: 983
# citydwn: 1371
# citydwn: 1656
# -----------------------------------------------------------
# cityup: 797
# coord: (745, 3106)
# citydwn: 130
# citydwn: 133
# citydwn: 197
# citydwn: 398
# citydwn: 588
# citydwn: 1371
# citydwn: 1656
# -----------------------------------------------------------
# cityup: 874
# coord: (771, 3051)
# citydwn: 197
# citydwn: 363
# citydwn: 398
# citydwn: 588
# -----------------------------------------------------------
# cityup: 883
# coord: (779, 3100)
# citydwn: 197
# citydwn: 363
# citydwn: 398
# citydwn: 588
# -----------------------------------------------------------
# cityup: 903
# coord: (781, 3265)
# citydwn: 1216
# -----------------------------------------------------------
# cityup: 941
# coord: (804, 3065)
# citydwn: 197
# citydwn: 363
# citydwn: 398
# citydwn: 455
# citydwn: 588
# -----------------------------------------------------------
# cityup: 983
# coord: (721, 3098)
# citydwn: 130
# citydwn: 133
# citydwn: 197
# citydwn: 321
# citydwn: 398
# citydwn: 513
# citydwn: 526
# citydwn: 588
# citydwn: 797
# citydwn: 1371
# citydwn: 1656
# -----------------------------------------------------------
# cityup: 1012
# coord: (782, 3169)
# citydwn: 197
# citydwn: 398
# citydwn: 588
# -----------------------------------------------------------
# cityup: 1018
# coord: (784, 3043)
# citydwn: 197
# citydwn: 363
# citydwn: 398
# citydwn: 588
# -----------------------------------------------------------
# cityup: 1067
# coord: (742, 3089)
# citydwn: 197
# citydwn: 243
# citydwn: 363
# citydwn: 398
# citydwn: 588
# -----------------------------------------------------------
# cityup: 1089
# coord: (723, 3085)
# citydwn: 2
# citydwn: 197
# citydwn: 243
# citydwn: 363
# citydwn: 398
# citydwn: 588
# citydwn: 1067
# citydwn: 1288
# -----------------------------------------------------------
# cityup: 1181
# coord: (785, 3236)
# citydwn: 11
# citydwn: 398
# -----------------------------------------------------------
# cityup: 1216
# coord: (783, 3257)
# -----------------------------------------------------------
# cityup: 1253
# coord: (719, 3097)
# citydwn: 130
# citydwn: 133
# citydwn: 197
# citydwn: 321
# citydwn: 398
# citydwn: 513
# citydwn: 526
# citydwn: 588
# citydwn: 677
# citydwn: 797
# citydwn: 983
# citydwn: 1371
# citydwn: 1656
# -----------------------------------------------------------
# cityup: 1288
# coord: (728, 3085)
# citydwn: 2
# citydwn: 197
# citydwn: 243
# citydwn: 363
# citydwn: 398
# citydwn: 588
# citydwn: 1067
# -----------------------------------------------------------
# cityup: 1298
# coord: (796, 3103)
# citydwn: 197
# citydwn: 363
# citydwn: 398
# citydwn: 588
# -----------------------------------------------------------
# cityup: 1337
# coord: (777, 3053)
# citydwn: 197
# citydwn: 363
# citydwn: 398
# citydwn: 588
# -----------------------------------------------------------
# cityup: 1365
# coord: (774, 3255)
# -----------------------------------------------------------
# cityup: 1371
# coord: (747, 3110)
# citydwn: 130
# citydwn: 133
# citydwn: 197
# citydwn: 398
# citydwn: 588
# -----------------------------------------------------------
# cityup: 1422
# coord: (744, 3077)
# citydwn: 197
# citydwn: 243
# citydwn: 363
# citydwn: 398
# citydwn: 588
# citydwn: 1067
# -----------------------------------------------------------
# cityup: 1578
# coord: (762, 3202)
# citydwn: 398
# citydwn: 588
# -----------------------------------------------------------
# cityup: 1620
# coord: (723, 3085)
# citydwn: 2
# citydwn: 197
# citydwn: 243
# citydwn: 363
# citydwn: 398
# citydwn: 588
# citydwn: 1067
# citydwn: 1089
# citydwn: 1288
# -----------------------------------------------------------
# cityup: 1652
# coord: (796, 3272)
# citydwn: 903
# citydwn: 1216
# -----------------------------------------------------------
# cityup: 1656
# coord: (747, 3110)
# citydwn: 130
# citydwn: 133
# citydwn: 197
# citydwn: 398
# citydwn: 588
# citydwn: 1371
# -----------------------------------------------------------
# cityup: 1697
# coord: (792, 3132)
# citydwn: 197
# citydwn: 319
# citydwn: 398
# citydwn: 588
# citydwn: 1012
# -----------------------------------------------------------
# cityup: 1712
# coord: (763, 3158)
# citydwn: 197
# citydwn: 398
# citydwn: 588
# -----------------------------------------------------------
# cityup: 1718
# coord: (802, 3069)
# citydwn: 197
# citydwn: 363
# citydwn: 398
# citydwn: 455
# citydwn: 588
# -----------------------------------------------------------
# cityup: 1824
# coord: (730, 3121)
# citydwn: 197
# citydwn: 398
# citydwn: 463
# citydwn: 588
# citydwn: 669
# citydwn: 1712

# %%
####################################################################################
# すべての流域を含むresult_dictの雛形を作成
# result dictは 同じ流域に含まれる各都市の
# water availability(not updated yet), update_flag, upstream citiesを保存している．
# cities_with_upstreamが存在する場合，flag=Trueとなる
####################################################################################

def find_upstream_cities(edges, city_number):
    cities_with_upstream = []
    cities_without_upstream = []
    upstream_cities = [edge[0] for edge in edges if edge[1] == city_number]
    uup = np.unique(upstream_cities)
    
    for i in uup:
        if any(edge[1] == i for edge in edges):
            # 上流にさらに都市が存在する場合
            cities_with_upstream.append(i)
        else:
            # 上流にこれ以上都市が存在しない場合
            cities_without_upstream.append(i)
    
    return cities_with_upstream, cities_without_upstream, uup
    
# save file
result_dict = {}

# job
# True: cities in upstream あり
# False: cities in upstream なし
# Done: TrueでもFalseでもない
for city_number in rivnum_list_removed:
    cities_with_upstream, cities_without_upstream, uup = find_upstream_cities(edges, city_number)
    if cities_with_upstream:
        result_dict[city_number] = [1, True, uup]
    elif not cities_with_upstream and cities_without_upstream:
        result_dict[city_number] = [1, False, uup]
    else:
        result_dict[city_number] = [1, 'Done', uup]

# 同じ流域に含まれる各都市のwater availability, upstream citiesを保存している．cities_with_upstreamが存在する場合，flag=Trueとなる
for city_number in result_dict:
    value = result_dict[city_number]
    print(city_number, value)
# Out:
# 2 [1, True, array([1089, 1288, 1620])]
# 11 [1, True, array([ 473,  673, 1181])]
# 126 [1, 'Done', array([], dtype=float64)]
# 130 [1, True, array([ 321,  513,  526,  667,  677,  797,  983, 1253, 1371, 1656])]
# 133 [1, True, array([ 130,  321,  513,  526,  667,  677,  797,  983, 1253, 1371, 1656])]
# 188 [1, 'Done', array([], dtype=float64)]
# 197 [1, True, array([   2,  126,  130,  133,  188,  217,  243,  319,  321,  363,  406,
#         455,  463,  513,  526,  667,  669,  677,  797,  874,  883,  941,
#         983, 1012, 1018, 1067, 1089, 1253, 1288, 1298, 1337, 1371, 1422,
#        1620, 1656, 1697, 1712, 1718, 1824])]
# 217 [1, 'Done', array([], dtype=float64)]
# 243 [1, True, array([   2, 1067, 1089, 1288, 1422, 1620])]
# 319 [1, False, array([1697])]
# 321 [1, True, array([ 667,  677,  983, 1253])]
# 363 [1, True, array([   2,  126,  188,  217,  243,  406,  455,  874,  883,  941, 1018,
#        1067, 1089, 1288, 1298, 1337, 1422, 1620, 1718])]
# 398 [1, True, array([   2,   11,  126,  130,  133,  188,  197,  217,  243,  319,  321,
#         363,  406,  455,  463,  473,  513,  526,  588,  667,  669,  673,
#         677,  797,  874,  883,  941,  983, 1012, 1018, 1067, 1089, 1181,
#        1253, 1288, 1298, 1337, 1371, 1422, 1578, 1620, 1656, 1697, 1712,
#        1718, 1824])]
# 406 [1, 'Done', array([], dtype=float64)]
# 455 [1, True, array([ 188,  941, 1718])]
# 463 [1, False, array([1824])]
# 473 [1, 'Done', array([], dtype=float64)]
# 513 [1, True, array([ 321,  526,  667,  677,  983, 1253])]
# 526 [1, True, array([ 321,  667,  677,  983, 1253])]
# 588 [1, True, array([   2,  126,  130,  133,  188,  197,  217,  243,  319,  321,  363,
#         406,  455,  463,  513,  526,  667,  669,  677,  797,  874,  883,
#         941,  983, 1012, 1018, 1067, 1089, 1253, 1288, 1298, 1337, 1371,
#        1422, 1578, 1620, 1656, 1697, 1712, 1718, 1824])]
# 667 [1, 'Done', array([], dtype=float64)]
# 669 [1, True, array([ 463, 1824])]
# 673 [1, 'Done', array([], dtype=float64)]
# 677 [1, True, array([ 667, 1253])]
# 797 [1, True, array([ 321,  513,  526,  667,  677,  983, 1253])]
# 874 [1, 'Done', array([], dtype=float64)]
# 883 [1, False, array([217])]
# 903 [1, False, array([1652])]
# 941 [1, 'Done', array([], dtype=float64)]
# 983 [1, True, array([ 667,  677, 1253])]
# 1012 [1, True, array([ 319, 1697])]
# 1018 [1, 'Done', array([], dtype=float64)]
# 1067 [1, True, array([   2, 1089, 1288, 1422, 1620])]
# 1089 [1, False, array([1620])]
# 1181 [1, False, array([473, 673])]
# 1216 [1, True, array([ 903, 1652])]
# 1253 [1, False, array([667])]
# 1288 [1, True, array([1089, 1620])]
# 1298 [1, 'Done', array([], dtype=float64)]
# 1337 [1, 'Done', array([], dtype=float64)]
# 1365 [1, 'Done', array([], dtype=float64)]
# 1371 [1, True, array([ 321,  513,  526,  667,  677,  797,  983, 1253, 1656])]
# 1422 [1, 'Done', array([], dtype=float64)]
# 1578 [1, 'Done', array([], dtype=float64)]
# 1620 [1, 'Done', array([], dtype=float64)]
# 1652 [1, 'Done', array([], dtype=float64)]
# 1656 [1, True, array([ 321,  513,  526,  667,  677,  797,  983, 1253])]
# 1697 [1, 'Done', array([], dtype=float64)]
# 1712 [1, True, array([ 463,  669, 1824])]
# 1718 [1, False, array([188])]
# 1824 [1, 'Done', array([], dtype=float64)]

# %%
######################################################################
# JOB START 
#(初めてでなければここまでの計算を飛ばして，ここからスタートしてもよい)
######################################################################

import os
import json
import copy
import numpy as np
import pandas as pd
from collections import defaultdict
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import cartopy.crs as ccrs
import cartopy.feature as cfeature

def l_coordinate_to_tuple(lcoordinate, a=2160, b=4320):
    lat_l = ((lcoordinate - 1) // b)
    lon_l = (lcoordinate) % b - 1
    return (lat_l, lon_l)

def nxtl2nxtxy(rgnfile, upperindex, leftindex):
    vfunc = np.vectorize(l_coordinate_to_tuple, otypes=[tuple])
    riv_nxtxy = np.empty(rgnfile.shape, dtype=tuple)
    mask = ~np.isnan(rgnfile)
    riv_nxtxy[mask] = vfunc(rgnfile[mask])
    riv_nxtxy_shape = (riv_nxtxy.shape[0], riv_nxtxy.shape[1], 2)
    
    riv_nxtxy_lst = []
    for row in riv_nxtxy:
        for y, x in row:
            modified_y = y - upperindex
            modified_x = x - leftindex
            riv_nxtxy_lst.append((modified_y, modified_x))

    riv_nxtxy_cropped = np.array(riv_nxtxy_lst).reshape(riv_nxtxy_shape)
    riv_nxtxy_cropped = riv_nxtxy_cropped.astype(int)
    return riv_nxtxy_cropped

# init
h08dir = '/mnt/c/Users/tsimk/Downloads/dotfiles/h08'
pop_path = f'{h08dir}/global_city/dat/pop_tot_/GPW4ag__20100000.gl5'
rivnxl_path = f"{h08dir}/global_city/dat/riv_nxl_/rivnxl.CAMA.gl5"
rivout_path = f'{h08dir}/wsi/dat/riv_out_/W5E5LR__00000000.gl5'
rivnum_path = f'{h08dir}/global_city/dat/riv_num_/rivnum.CAMA.gl5'
rivara_path = f'{h08dir}/global_city/dat/riv_ara_/rivara.CAMA.gl5'
msk_dir = f'{h08dir}/global_city/dat/vld_cty_'
prf_dir = f'{h08dir}/global_city/dat/cty_prf_'

pop_gl5 = np.fromfile(pop_path, dtype='float32').reshape(2160, 4320)
rivout_gl5 = np.fromfile(rivout_path, dtype='float32').reshape(2160, 4320)
rivnum_gl5 = np.fromfile(rivnum_path, dtype='float32').reshape(2160, 4320)
rivara_gl5 = np.fromfile(rivara_path, dtype='float32').reshape(2160, 4320)
rivnxl_gl5 = np.fromfile(rivnxl_path, 'float32').reshape(2160, 4320)
riv_nxlonlat_cropped = nxtl2nxtxy(rivnxl_gl5, 0, 0)

def load_json(distance=100):
    basin_cities_path = f'{h08dir}/global_city/dat/riv_num_/basin_to_cities_{distance}km.json'
    with open(basin_cities_path, 'r') as json_file:
        basin_to_cities = json.load(json_file)
    new_basin_to_cities = {rivnum: cities for rivnum, cities in basin_to_cities.items() if len(cities) > 1}
    return new_basin_to_cities
    
def is_valid_edge(city1, city2, coords_dict):
    for coord, city_list in coords_dict.items():
        if len(city_list) > 1:
            if city1 in city_list and city2 in city_list:
                if city1 > city2:
                    continue
                else:
                    city1, city2 = None, None
                    
    if city1 and city2:
        return True
    else:
        return False

def updown(new_basin_to_cities, key_index=0, distance=100):
    # get uid and city list
    keys_list = list(new_basin_to_cities.keys())
    uid = keys_list[key_index]
    rivnum_list = new_basin_to_cities[uid]
    rivnum_list = [int(i) for i in rivnum_list]
    print(f'uid: {uid}')
    
    # remove overlap
    h08dir = '/mnt/c/Users/tsimk/Downloads/dotfiles/h08'
    overlap_path = f'{h08dir}/global_city/dat/cty_lst_/gpw4/overlap_hidden_only.txt'
    with open(overlap_path, 'r') as f:
        numbers = [int(line.strip()) for line in f]
    rivnum_list_removed = [num for num in rivnum_list if num not in numbers]
    rivnum_list_removed = [int(i) for i in rivnum_list_removed]
    print(f'city_list: {rivnum_list_removed}')
    
    # rivout
    rivout_path = f'{h08dir}/wsi/dat/riv_out_/W5E5LR__00000000.gl5'
    rivout_gl5 = np.fromfile(rivout_path, dtype='float32').reshape(2160, 4320)
    
    # coord of purficication
    coords_a = []
    for city_num in rivnum_list_removed:
        # rivnum
        rivnum_path = f'{h08dir}/global_city/dat/riv_num_/rivnum.CAMA.gl5'
        rivnum_gl5 = np.fromfile(rivnum_path, dtype='float32').reshape(2160, 4320)

        # prf
        prf_dir = f'{h08dir}/global_city/dat/cty_prf_'
        prf_path = f'{prf_dir}/vld_cty_/city_{city_num:08}.gl5'
        prf = np.fromfile(prf_path, dtype='float32').reshape(2160, 4320)

        # int
        int_dir = f'{h08dir}/global_city/dat/cty_int_/{distance}km_samebasin'
        int_path = f'{int_dir}/city_{city_num:08}.gl5'
        intake = np.fromfile(int_path, dtype='float32').reshape(2160, 4320)
        
        # 1. prfのみが対象流域内(uid)
        # 2. intのみが対象流域内(uid)
        # 3. prfとintどちらもが対象領域内(uid)
        uid = int(float(uid))
        prf_coord = np.where((prf == 1) & (rivnum_gl5 == uid))
        int_coord = np.where((intake == 1) & (rivnum_gl5 == uid))
        
        if prf_coord[0].size != 0 and int_coord[0].size != 0:
            
            prf_runout = rivout_gl5[prf_coord][0] * 60 * 60 * 24 * 365 / (1000)
            int_runout = rivout_gl5[int_coord][0] * 60 * 60 * 24 * 365 / (1000)
            
            if prf_runout > int_runout:
                larger_coord = prf_coord
            else:
                larger_coord = int_coord
                
        elif prf_coord[0].size != 0 and int_coord[0].size == 0:
            larger_coord = prf_coord
            
        elif prf_coord[0].size == 0 and int_coord[0].size != 0:
            larger_coord = int_coord
            
        else:
            larger_coord = prf_coord
            continue
            
        coords_a.append([larger_coord, city_num])
        
####################################################################################
# 1. 同流域内で取水点がかぶっている都市を取水点ごとにリストにする
####################################################################################

    # 同じ座標に対して city_num のリストを作成するための辞書
    coords_dict = defaultdict(list)

    # coords_a の要素をループして座標をキーに city_num をリストに追加
    for coord, city_num in coords_a:
        coord_tuple = (tuple(coord[0]), tuple(coord[1]))
        coords_dict[coord_tuple].append(city_num)

####################################################################################
# check what's happening in 1089, 1288, 1620
####################################################################################
        
    # down
    edges = []
    riv_path_array = np.zeros((2160, 4320))
    
    # city_num loop 
    for idx in range(len(coords_a)):
        
        cityup = coords_a[idx][1]
        #print(f'-----------------------------------------------------------')
        #print(f'cityup: {cityup}')
        #print(f'coord: {(coords_a[idx][0][0][0], coords_a[idx][0][1][0])}')
        
        visited_coords = set()
        
        # coords_a[idx][0] = (array([732]), array([3086]))
        riv_path_array[coords_a[idx][0][0][0], coords_a[idx][0][1][0]] = idx

        # coordinates of prf and intake
        coords_b = coords_a.copy()
        coords_b.pop(idx) 
        
        if len(coords_a) > 0:
            target_coord = (coords_a[idx][0][0][0], coords_a[idx][0][1][0])
            
            while True:
                if target_coord in visited_coords:
                    break
                visited_coords.add(target_coord)
                
                next_coord = riv_nxlonlat_cropped[target_coord[0], target_coord[1]]
                if next_coord.size == 0 or next_coord.shape != (2,):
                    break
                
                next_coord = (next_coord[0], next_coord[1])
                riv_path_array[next_coord[0], next_coord[1]] = idx
                target_coord = next_coord

        for coord in coords_b:
            citydwn = coord[1]
            
            if coord[0][0].size == 0:
                continue
            else:
                standard_coord = (coord[0][0][0], coord[0][1][0])
                if standard_coord in visited_coords:
                    edge_flag = is_valid_edge(cityup, citydwn, coords_dict)
                    if edge_flag:
                        #print(f'citydwn: {citydwn}')
                        edges.append((cityup, citydwn))
                    else:
                        #print(f'invalid: {citydwn}')
                        continue
                else:
                    #print(f'No: {citydwn}')
                    continue
                    
    # edgesは2都市間のupstreamとdownstreamの関係をすべて保存したリスト
    return edges, riv_path_array, coords_a, rivnum_list_removed

def find_upstream_cities(edges, city_number):
    cities_with_upstream = []
    cities_without_upstream = []
    upstream_cities = [edge[0] for edge in edges if edge[1] == city_number]
    uup = np.unique(upstream_cities)
    
    for i in uup:
        if any(edge[1] == i for edge in edges):
            # 上流にさらに都市が存在する場合
            cities_with_upstream.append(i)
        else:
            # 上流にこれ以上都市が存在しない場合
            cities_without_upstream.append(i)
    
    return cities_with_upstream, cities_without_upstream, uup

# この参照ファイル(df['mpcy'])のmpcyを計算に使用してはいけない
# mpcyはupdownを実行する前のavaを参照している + intを考慮していない = 取水モデルでエラーが発生する
mcy_pop_water_path = '/mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/cty_lst_/gpw4/mcy_pop_water_12region.txt'
column_names = ['index', 'flag', 'rate', 'wup', 'pop', 'ava', 'mpcy', 'potential', 'region', 'country', 'cityname', '12region']
df = pd.read_csv(mcy_pop_water_path, delimiter='|', header=None, names=column_names)
df.head(10)
# Out:
#    index   flag      rate        wup         pop           ava          mpcy  \
# 0      1  False  0.863325  36859.626  31821850.0  1.424091e+10    447.519821
# 1      2  False  1.003201  21987.895  22058268.0  4.420798e+09    200.414547
# 2      3  False  0.715760  20314.309  14540163.0  1.643563e+10   1130.360505
# 3      4  False  1.002057  20136.681  20178100.0  3.006577e+08     14.900200
# 4      5  False  0.492121  19659.808   9675000.0  2.057520e+09    212.663566
# 5      6  False  0.489232  19312.646   9448362.0  1.272031e+10   1346.297983
# 6      7  False  0.470956  18365.262   8649229.0  6.329261e+08     73.177170
# 7      8  False  0.783200  18257.413  14299211.0  9.254411e+09    647.197295
# 8      9  False  1.006426  16899.015  17007614.0  7.113659e+11  41826.322056
# 9     10  False  0.823952  16441.252  13546804.0  2.355427e+09    173.873265
#
#    potential            region                   country  \
# 0       93.0      eastern asia                     Japan
# 1       39.0     southern asia                     India
# 2       17.0      eastern asia                     China
# 3       43.0   central america                    Mexico
# 4       11.0     south america                    Brazil
# 5       24.0      eastern asia                     Japan
# 6       17.0  northern america  United States of America
# 7       12.0     southern asia                     India
# 8       24.0   northern africa                     Egypt
# 9       24.0      eastern asia                     China
#
#                          cityname         12region
# 0                           Tokyo        East Asia
# 1                           Delhi       South Asia
# 2                        Shanghai        East Asia
# 3  Ciudad de México (Mexico City)  Central America
# 4                       São Paulo    South America
# 5            Kinki M.M.A. (Osaka)        East Asia
# 6                 New York-Newark    North America
# 7                 Mumbai (Bombay)       South Asia
# 8              Al-Qahirah (Cairo)  Northern Africa
# 9                         Beijing        East Asia

# %%
####################################################################################
# key_index=1を探索する
# result_dictのavaの中に1流域からの想定取水量を入力する
# result_dictを作成する
####################################################################################
def make_result_dict(new_basin_to_cities, key_index=1):
    # unique_cties_basin: uniqueなすべての都市
    # uup: 各都市の上流にあるuniqueな都市
    edges, riv_path_array, coords_a, rivnum_list_removed = updown(new_basin_to_cities, key_index=key_index)
    unique_cities_basin = np.unique(edges)
    
    result_dict = {}
    for city_number in unique_cities_basin:
        cities_with_upstream, cities_without_upstream, uup = find_upstream_cities(edges, city_number)
        if cities_with_upstream:
            # [discharge, consumption, flag, upper cities]
            result_dict[city_number] = [1, 0.1, True, uup]
        elif not cities_with_upstream and cities_without_upstream:
            result_dict[city_number] = [1, 0.1, False, uup]
        else:
            result_dict[city_number] = [1, 0.1, 'Done', uup]
    
    # 同じ流域に含まれる各都市のwater availability, upstream citiesを保存している．cities_with_upstreamが存在する場合，flag=Trueとなる
    return result_dict
    
####################################################################################
# result_dictのavaの中に1流域からの想定取水量を入力する
# 一つの流域に二つ取水点がある可能性がある→prfかintakeの流量が多い方を選ぶ(abandon)
####################################################################################
def discharge_rate(city_num, riv_num, distance=100):
    # riv_num以外からの取水がupdownでどのような影響を受けるかを考慮できない?
    # largestはriv_numでの理想流量を計算するためのもの．(prfかintかいずれかから1つのみ)
    # all_intはcityが複数のriv_numから取水している場合のすべての取水点
    
    city_num = int(city_num)
    riv_num = int(float(riv_num))
    print(f'city_num, riv_num, {city_num}, {riv_num}')
    
    h08dir = '/mnt/c/Users/tsimk/Downloads/dotfiles/h08'
    msk_dir = f'{h08dir}/global_city/dat/vld_cty_'
    ctymsk_path = f'{msk_dir}/city_{city_num:08}.gl5'
    ctymsk = np.fromfile(ctymsk_path, dtype='float32').reshape(2160, 4320)
    
    prf_dir = f'{h08dir}/global_city/dat/cty_prf_'
    prf_path = f'{prf_dir}/vld_cty_/city_{city_num:08}.gl5'
    prf = np.fromfile(prf_path, dtype='float32').reshape(2160, 4320)
    prf_copy = np.copy(prf)
    
    int_dir = f'{h08dir}/global_city/dat/cty_int_/{distance}km_samebasin'
    int_path = f'{int_dir}/city_{city_num:08}.gl5'
    intake = np.fromfile(int_path, dtype='float32').reshape(2160, 4320)

    prf_coord = np.where((prf == 1) & (rivnum_gl5 == riv_num))
    int_coord = np.where((intake==1) & (rivnum_gl5 == riv_num))
    
    if prf_coord[0].size != 0 and int_coord[0].size != 0:
        
        prf_runout = rivout_gl5[prf_coord][0] * 60 * 60 * 24 * 365 / (1000)
        int_runout = rivout_gl5[int_coord][0] * 60 * 60 * 24 * 365 / (1000)
        
        print(f"city_num: {city_num}, prf: {prf_runout/1e9}, int: {int_runout/1e9}")
        
        if prf_runout > int_runout:
            print(f'city_num: {city_num}, PRF > int')
            largest = prf
            all_int = prf
            
        else:
            print(f'city_num: {city_num}, INT > prf')
            prf_copy[prf_coord] = 0
            largest = intake
            all_int = intake
            
    elif prf_coord[0].size != 0 and int_coord[0].size == 0:
        print(f'PRF only')
        largest = prf
        all_int = prf + intake
        
    elif prf_coord[0].size == 0 and int_coord[0].size != 0:
        print(f'INT only')
        largest = intake
        all_int = prf + intake
        
    else:
        print('Error no prf no int')

    # rateを計算するための変数群
    rivnum_mask = np.ma.masked_where(all_int == 0, rivnum_gl5)
    rivara_mask = np.ma.masked_where(all_int == 0, rivara_gl5) # 複数ある

    # rateはcityが有するprfとintの中で，対象のriv_numがどれだけの割合を担っているかを示す
    rate = np.sum(rivara_gl5[rivnum_mask== riv_num])/np.sum(rivara_mask)
    
    # dischargeはupdownを考慮しない理想化されたdischarge
    # かつ対象riv_numでのdischargeのみをreturnする
    discharge = np.sum(rivout_gl5[(largest!=0) & (rivnum_gl5==riv_num)])* 60 * 60 * 24 * 365 / (1000) # m3/year
    
    return rate, discharge
    
####################################################################################
# JOB
# mpcyについて計算方法を見直さなくてはいけない
# 従来(df['mpcy'])→修正(discharge/pop)
####################################################################################
key_index = 1
####################################################################################

# load basins
new_basin_to_cities = load_json() # keys = all basins with multiple cities 180?
rate_cities = []

# result_dictが更新されないことが大事
result_dict =  make_result_dict(new_basin_to_cities, key_index=key_index) # keys = all cities in key_index basin

# rivnumを取得する
riv_num = list(new_basin_to_cities.keys())[key_index]
city_num_lst = list(result_dict.keys())

# city_numを取得する
for city_num in city_num_lst:

    # get default discharge(without updown)
    print(f'---------------------------------------------')
    rate, discharge = discharge_rate(city_num, riv_num)

    # multiple basin cities
    if rate < 1:
        rate_cities.append(city_num)
    print(f'city_num: {city_num}, riv_num: {riv_num}')
    print(f'rate {rate}')
    print(f'discharge {discharge/1e9}')

    # check if df works OK
    filtered_df = df[df['index'] == city_num]
    if filtered_df.empty:
        print(f'City number {city_num} not found in the data.')
        
    # population in downtown
    est_pop = filtered_df.reset_index(drop=True).loc[0, 'pop']

    # calc demand from one basin(riv_num)
    demand = est_pop*rate*1000
    
    # ロジックを考える
    #demandが1000m3/year * populationだとして
    #consumptionはsupply > demand or supply < demandによって変化するべき
    #consumptionについてはexplore内で計算する必要がある
    
    print(f'demand: {demand/1e9}')
    result_dict[city_num][0] = discharge
    result_dict[city_num][1] = demand
# Out:
# uid: 14.0
# city_list: [2, 11, 126, 130, 133, 188, 197, 217, 243, 319, 321, 363, 398, 406, 455, 463, 473, 513, 526, 588, 667, 669, 673, 677, 797, 874, 883, 903, 941, 983, 1012, 1018, 1067, 1089, 1181, 1216, 1253, 1288, 1298, 1337, 1365, 1371, 1422, 1578, 1620, 1652, 1656, 1697, 1712, 1718, 1824]
# city_num, riv_num, 2, 14
# city_num: 2, prf: 4.42079778375, int: 19.248677595
# city_num: 2, INT > prf
# city_num: 2, riv_num: 14.0
# rate 1.0
# discharge 19.248677595
# supply: 19.248677595
# demand: 22.058268
# --------------------------------------
# city_num, riv_num, 11, 14
# city_num: 11, prf: 0.0956541544453125, int: 478.240570224
# city_num: 11, INT > prf
# city_num: 11, riv_num: 14.0
# rate 1.0
# discharge 478.240570224
# supply: 478.240570224
# demand: 14.907053
# --------------------------------------
# city_num, riv_num, 126, 14
# PRF only
# city_num: 126, riv_num: 14.0
# rate 0.4661909341812134
# discharge 0.08944297140234375
# supply: 0.08944297140234375
# demand: 1.4207207179924548
# --------------------------------------
# city_num, riv_num, 130, 14
# city_num: 130, prf: 87.145943796, int: 6.65100300825
# city_num: 130, PRF > int
# city_num: 130, riv_num: 14.0
# rate 1.0
# discharge 87.145943796
# supply: 87.145943796
# demand: 2.9605235
# --------------------------------------
# city_num, riv_num, 133, 14
# city_num: 133, prf: 6.701539941, int: 87.196582728
# city_num: 133, INT > prf
# city_num: 133, riv_num: 14.0
# rate 1.0
# discharge 87.196582728
# supply: 87.196582728
# demand: 2.87532775
# --------------------------------------
# city_num, riv_num, 188, 14
# city_num: 188, prf: 0.0565119422578125, int: 0.056030028908203126
# city_num: 188, PRF > int
# city_num: 188, riv_num: 14.0
# rate 1.0
# discharge 0.0565119422578125
# supply: 0.0565119422578125
# demand: 2.17459375
# --------------------------------------
# city_num, riv_num, 197, 14
# city_num: 197, prf: 591.25080384, int: 56.497291938
# city_num: 197, PRF > int
# city_num: 197, riv_num: 14.0
# rate 1.0
# discharge 591.25080384
# supply: 591.25080384
# demand: 2.027493375
# --------------------------------------
# city_num, riv_num, 217, 14
# city_num: 217, prf: 0.25847798709375, int: 0.2720333548125
# city_num: 217, INT > prf
# city_num: 217, riv_num: 14.0
# rate 1.0
# discharge 0.2720333548125
# supply: 0.2720333548125
# demand: 1.90916525
# --------------------------------------
# city_num, riv_num, 243, 14
# city_num: 243, prf: 30.390383844, int: 3.641325674625
# city_num: 243, PRF > int
# city_num: 243, riv_num: 14.0
# rate 1.0
# discharge 30.390383844
# supply: 30.390383844
# demand: 1.785424625
# --------------------------------------
# city_num, riv_num, 319, 14
# city_num: 319, prf: 0.1305414087890625, int: 45.876459888
# city_num: 319, INT > prf
# city_num: 319, riv_num: 14.0
# rate 1.0
# discharge 45.876459888
# supply: 45.876459888
# demand: 1.654334375
# --------------------------------------
# city_num, riv_num, 321, 14
# city_num: 321, prf: 0.1861881898359375, int: 33.889220262
# city_num: 321, INT > prf
# city_num: 321, riv_num: 14.0
# rate 1.0
# discharge 33.889220262
# supply: 33.889220262
# demand: 1.426092375
# --------------------------------------
# city_num, riv_num, 363, 14
# city_num: 363, prf: 246.507466968, int: 92.2232871
# city_num: 363, PRF > int
# city_num: 363, riv_num: 14.0
# rate 1.0
# discharge 246.507466968
# supply: 246.507466968
# demand: 1.397518375
# --------------------------------------
# city_num, riv_num, 398, 14
# INT only
# city_num: 398, riv_num: 14.0
# rate 0.9969676733016968
# discharge 1333.421298432
# supply: 1333.421298432
# demand: 1.1541453595618307
# --------------------------------------
# city_num, riv_num, 406, 14
# city_num: 406, prf: 0.1439401436015625, int: 6.8335545645
# city_num: 406, INT > prf
# city_num: 406, riv_num: 14.0
# rate 1.0
# discharge 6.8335545645
# supply: 6.8335545645
# demand: 0.50544159375
# --------------------------------------
# city_num, riv_num, 455, 14
# city_num: 455, prf: 20.418117228, int: 12.1408761195
# city_num: 455, PRF > int
# city_num: 455, riv_num: 14.0
# rate 1.0
# discharge 20.418117228
# supply: 20.418117228
# demand: 0.983652625
# --------------------------------------
# city_num, riv_num, 463, 14
# city_num: 463, prf: 0.07312175173828125, int: 22.907352258
# city_num: 463, INT > prf
# city_num: 463, riv_num: 14.0
# rate 1.0
# discharge 22.907352258
# supply: 22.907352258
# demand: 0.97701
# --------------------------------------
# city_num, riv_num, 473, 14
# city_num: 473, prf: 328.876834176, int: 19.687177791
# city_num: 473, PRF > int
# city_num: 473, riv_num: 14.0
# rate 1.0
# discharge 328.876834176
# supply: 328.876834176
# demand: 0.9526491875
# --------------------------------------
# city_num, riv_num, 513, 14
# city_num: 513, prf: 0.98778654478125, int: 39.661944192
# city_num: 513, INT > prf
# city_num: 513, riv_num: 14.0
# rate 1.0
# discharge 39.661944192
# supply: 39.661944192
# demand: 0.928597
# --------------------------------------
# city_num, riv_num, 526, 14
# city_num: 526, prf: 0.2345311840078125, int: 39.496202802
# city_num: 526, INT > prf
# city_num: 526, riv_num: 14.0
# rate 1.0
# discharge 39.496202802
# supply: 39.496202802
# demand: 0.875343
# --------------------------------------
# city_num, riv_num, 588, 14
# city_num: 588, prf: 827.483069376, int: 19.038458619
# city_num: 588, PRF > int
# city_num: 588, riv_num: 14.0
# rate 1.0
# discharge 827.483069376
# supply: 827.483069376
# demand: 0.868289375
# --------------------------------------
# city_num, riv_num, 667, 14
# city_num: 667, prf: 0.51893159371875, int: 5.756583411
# city_num: 667, INT > prf
# city_num: 667, riv_num: 14.0
# rate 1.0
# discharge 5.756583411
# supply: 5.756583411
# demand: 0.728069625
# --------------------------------------
# city_num, riv_num, 669, 14
# city_num: 669, prf: 2.466189851625, int: 86.406873984
# city_num: 669, INT > prf
# city_num: 669, riv_num: 14.0
# rate 1.0
# discharge 86.406873984
# supply: 86.406873984
# demand: 0.732065
# --------------------------------------
# city_num, riv_num, 673, 14
# city_num: 673, prf: 1.825538229, int: 14.289763797
# city_num: 673, INT > prf
# city_num: 673, riv_num: 14.0
# rate 1.0
# discharge 14.289763797
# supply: 14.289763797
# demand: 0.687915875
# --------------------------------------
# city_num, riv_num, 677, 14
# city_num: 677, prf: 0.08963806960546875, int: 32.667907851
# city_num: 677, INT > prf
# city_num: 677, riv_num: 14.0
# rate 1.0
# discharge 32.667907851
# supply: 32.667907851
# demand: 0.8112646875
# --------------------------------------
# city_num, riv_num, 797, 14
# city_num: 797, prf: 31.437966402, int: 41.93014734
# city_num: 797, INT > prf
# city_num: 797, riv_num: 14.0
# rate 1.0
# discharge 41.93014734
# supply: 41.93014734
# demand: 0.652847375
# --------------------------------------
# city_num, riv_num, 874, 14
# INT only
# city_num: 874, riv_num: 14.0
# rate 0.8270241022109985
# discharge 0.1784292559453125
# supply: 0.1784292559453125
# demand: 0.4965534378304928
# --------------------------------------
# city_num, riv_num, 883, 14
# city_num: 883, prf: 0.06896914730859376, int: 22.908410685
# city_num: 883, INT > prf
# city_num: 883, riv_num: 14.0
# rate 1.0
# discharge 22.908410685
# supply: 22.908410685
# demand: 0.594775375
# --------------------------------------
# city_num, riv_num, 903, 14
# city_num: 903, prf: 6.895955439, int: 41.618386386
# city_num: 903, INT > prf
# city_num: 903, riv_num: 14.0
# rate 1.0
# discharge 41.618386386
# supply: 41.618386386
# demand: 0.5489111875
# --------------------------------------
# city_num, riv_num, 941, 14
# city_num: 941, prf: 0.8571333279375, int: 0.993544882875
# city_num: 941, INT > prf
# city_num: 941, riv_num: 14.0
# rate 1.0
# discharge 0.993544882875
# supply: 0.993544882875
# demand: 0.5468076875
# --------------------------------------
# city_num, riv_num, 983, 14
# city_num: 983, prf: 0.048419474361328124, int: 32.990188032
# city_num: 983, INT > prf
# city_num: 983, riv_num: 14.0
# rate 1.0
# discharge 32.990188032
# supply: 32.990188032
# demand: 0.4931126875
# --------------------------------------
# city_num, riv_num, 1012, 14
# city_num: 1012, prf: 3.04763361975, int: 65.844716076
# city_num: 1012, INT > prf
# city_num: 1012, riv_num: 14.0
# rate 1.0
# discharge 65.844716076
# supply: 65.844716076
# demand: 0.615565125
# --------------------------------------
# city_num, riv_num, 1018, 14
# PRF only
# city_num: 1018, riv_num: 14.0
# rate 0.09329782426357269
# discharge 0.066265420359375
# supply: 0.066265420359375
# demand: 0.036231387865682134
# --------------------------------------
# city_num, riv_num, 1067, 14
# city_num: 1067, prf: 1.418693032125, int: 28.304519877
# city_num: 1067, INT > prf
# city_num: 1067, riv_num: 14.0
# rate 1.0
# discharge 28.304519877
# supply: 28.304519877
# demand: 0.49450671875
# --------------------------------------
# city_num, riv_num, 1089, 14
# city_num: 1089, prf: 0.04395905131640625, int: 18.263201247
# city_num: 1089, INT > prf
# city_num: 1089, riv_num: 14.0
# rate 1.0
# discharge 18.263201247
# supply: 18.263201247
# demand: 0.450800375
# --------------------------------------
# city_num, riv_num, 1181, 14
# city_num: 1181, prf: 4.50879406425, int: 477.148131648
# city_num: 1181, INT > prf
# city_num: 1181, riv_num: 14.0
# rate 1.0
# discharge 477.148131648
# supply: 477.148131648
# demand: 0.47610184375
# --------------------------------------
# city_num, riv_num, 1216, 14
# city_num: 1216, prf: 0.84838917121875, int: 54.376247592
# city_num: 1216, INT > prf
# city_num: 1216, riv_num: 14.0
# rate 1.0
# discharge 54.376247592
# supply: 54.376247592
# demand: 0.47925225
# --------------------------------------
# city_num, riv_num, 1253, 14
# city_num: 1253, prf: 0.2212189576171875, int: 32.667907851
# city_num: 1253, INT > prf
# city_num: 1253, riv_num: 14.0
# rate 1.0
# discharge 32.667907851
# supply: 32.667907851
# demand: 0.3866038125
# --------------------------------------
# city_num, riv_num, 1288, 14
# city_num: 1288, prf: 1.612417941, int: 19.048786659
# city_num: 1288, INT > prf
# city_num: 1288, riv_num: 14.0
# rate 1.0
# discharge 19.048786659
# supply: 19.048786659
# demand: 0.418458875
# --------------------------------------
# city_num, riv_num, 1298, 14
# city_num: 1298, prf: 0.367068291890625, int: 0.09287203405078125
# city_num: 1298, PRF > int
# city_num: 1298, riv_num: 14.0
# rate 1.0
# discharge 0.367068291890625
# supply: 0.367068291890625
# demand: 0.39378015625
# --------------------------------------
# city_num, riv_num, 1337, 14
# city_num: 1337, prf: 1.66044924, int: 1.1367674746875
# city_num: 1337, PRF > int
# city_num: 1337, riv_num: 14.0
# rate 1.0
# discharge 1.66044924
# supply: 1.66044924
# demand: 0.3857621875
# --------------------------------------
# city_num, riv_num, 1371, 14
# city_num: 1371, prf: 0.06634956512109375, int: 42.139175832
# city_num: 1371, INT > prf
# city_num: 1371, riv_num: 14.0
# rate 1.0
# discharge 42.139175832
# supply: 42.139175832
# demand: 0.386752125
# --------------------------------------
# city_num, riv_num, 1422, 14
# city_num: 1422, prf: 0.04071351109570313, int: 0.731685706875
# city_num: 1422, INT > prf
# city_num: 1422, riv_num: 14.0
# rate 1.0
# discharge 0.731685706875
# supply: 0.731685706875
# demand: 0.364646125
# --------------------------------------
# city_num, riv_num, 1578, 14
# city_num: 1578, prf: 0.29364580096875, int: 59.087260836
# city_num: 1578, INT > prf
# city_num: 1578, riv_num: 14.0
# rate 1.0
# discharge 59.087260836
# supply: 59.087260836
# demand: 0.3930796875
# --------------------------------------
# city_num, riv_num, 1620, 14
# city_num: 1620, prf: 0.2005798158984375, int: 18.263201247
# city_num: 1620, INT > prf
# city_num: 1620, riv_num: 14.0
# rate 1.0
# discharge 18.263201247
# supply: 18.263201247
# demand: 0.33221628125
# --------------------------------------
# city_num, riv_num, 1652, 14
# PRF only
# city_num: 1652, riv_num: 14.0
# rate 0.07755784690380096
# discharge 2.25428640975
# supply: 2.25428640975
# demand: 0.02330718002552539
# --------------------------------------
# city_num, riv_num, 1656, 14
# city_num: 1656, prf: 0.0493587828984375, int: 42.139175832
# city_num: 1656, INT > prf
# city_num: 1656, riv_num: 14.0
# rate 1.0
# discharge 42.139175832
# supply: 42.139175832
# demand: 0.35678103125
# --------------------------------------
# city_num, riv_num, 1697, 14
# city_num: 1697, prf: 0.04992697754296875, int: 11.6460999315
# city_num: 1697, INT > prf
# city_num: 1697, riv_num: 14.0
# rate 1.0
# discharge 11.6460999315
# supply: 11.6460999315
# demand: 0.30726871875
# --------------------------------------
# city_num, riv_num, 1712, 14
# city_num: 1712, prf: 3.66539429475, int: 89.842256028
# city_num: 1712, INT > prf
# city_num: 1712, riv_num: 14.0
# rate 1.0
# discharge 89.842256028
# supply: 89.842256028
# demand: 0.3592445625
# --------------------------------------
# city_num, riv_num, 1718, 14
# city_num: 1718, prf: 0.11301882612890625, int: 1.4944801995
# city_num: 1718, INT > prf
# city_num: 1718, riv_num: 14.0
# rate 1.0
# discharge 1.4944801995
# supply: 1.4944801995
# demand: 0.2955934375
# --------------------------------------
# city_num, riv_num, 1824, 14
# city_num: 1824, prf: 0.96825861590625, int: 22.105640124
# city_num: 1824, INT > prf
# city_num: 1824, riv_num: 14.0
# rate 1.0
# discharge 22.105640124
# supply: 22.105640124
# demand: 0.247378125
# --------------------------------------

# %%
# key_index=1を探索する # finish above block first(to make result_dict with discharge)
# この計算は一瞬で終わらないといけない．もし終わらないなら無限ループなので強制終了して，while文をfor文に直す→じゃないとメモリ不足になる
####################################################################################
# 上流と下流の取水の関係をrecursiveに探索
# result_dictのavaの部分を更新してreturn
# 二つの都市で，互いが互いの都市の更新を待っている状態だと，whileが無限になる

# ロジックを考える
#demandが1000m3/year * populationだとして
#consumptionはsupply > demand or supply < demandによって変化するべき
#consumptionについてはexplore内で計算する必要がある

#result_dict[city_num][0] = discharge
#result_dict[city_num][1] = demand
####################################################################################

def explore(result_dict):
    while True:
        all_done = True  # Flag to check if all cities are marked as 'Done'
        
        for key, value in result_dict.items():
            ava, dem, flag, uup = value
            ava_mod = ava
            upstream_dem = 0
            
            if flag != 'Done':
                all_done = False  # Mark that not all cities are 'Done'

            # No multi-layer upstream cities; solve individually
            if flag is False:
                flg_lst = [result_dict[kkk][2] for kkk in uup]
                
                for kkk in uup:

                    # demand
                    up_ava = result_dict[kkk][0]
                    up_dem = result_dict[kkk][1]
                    up_dem_mod = min(up_ava, up_dem)
                    
                    upstream_dem += min(up_dem_mod, ava_mod)
                    ava_mod -= min(up_dem_mod, ava_mod)

                result_dict[key][0] = ava_mod
                result_dict[key][1] = min(dem, ava_mod)
                result_dict[key][2] = 'Done'

            # Multi-layer upstream cities; wait for others to update
            elif flag is True:
                flg_lst = [result_dict[kkk][2] for kkk in uup]
                    
                for kkk in uup:
                    up_ava = result_dict[kkk][0]
                    up_dem = result_dict[kkk][1]
                    up_dem_mod = min(up_ava, up_dem)
                    
                    upstream_dem += min(up_dem_mod, ava_mod)
                    ava_mod -= min(up_dem_mod, ava_mod)

                result_dict[key][0] = ava_mod
                result_dict[key][1] = min(dem, ava_mod)
                result_dict[key][2] = 'Done'

            else:
                flg_lst = [result_dict[kkk][2] for kkk in uup]
            
            print(
                f'city_num: {key}, flag: {flag}, uup: {uup}, flg_lst: {flg_lst}, '
                f'dem: {np.round(dem/1e9, 4)}, '
                f'ava: {np.round(ava/1e9,4)}, '
                f'upstream_dem: {np.round(upstream_dem/1e9, 4)}, '
                f'ava_mod: {np.round(ava_mod/1e9, 4)}'
            )
                    
        print('-' * 150)
        if all_done:
            print('********** explore all done ***************')
            break
    return result_dict

result_dict_mod = explore(result_dict)
print(f'**********rivnum{list(new_basin_to_cities.keys())[key_index]}: calculation done***************')
print(f'--------------------------------------')
# Out:
# city_num: 2, flag: Done, uup: [1089 1288 1620], flg_lst: ['Done', 'Done', 'Done'],
# dem: 18.0472, ava: 18.0472, upstream_dem: 0.0, ava_mod: 18.0472
# city_num: 11, flag: Done, uup: [ 473  673 1181], flg_lst: ['Done', 'Done', 'Done'],
# dem: 14.9071, ava: 476.1239, upstream_dem: 0.0, ava_mod: 476.1239
# city_num: 126, flag: Done, uup: [], flg_lst: [],
# dem: 1.4207, ava: 0.0894, upstream_dem: 0.0, ava_mod: 0.0894
# city_num: 130, flag: Done, uup: [ 321  513  526  667  677  797  983 1253 1371 1656], flg_lst: ['Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done'],
# dem: 2.9605, ava: 80.1005, upstream_dem: 0.0, ava_mod: 80.1005
# city_num: 133, flag: Done, uup: [ 130  321  513  526  667  677  797  983 1253 1371 1656], flg_lst: ['Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done'],
# dem: 2.8753, ava: 77.1906, upstream_dem: 0.0, ava_mod: 77.1906
# city_num: 188, flag: Done, uup: [], flg_lst: [],
# dem: 2.1746, ava: 0.0565, upstream_dem: 0.0, ava_mod: 0.0565
# city_num: 197, flag: Done, uup: [   2  126  130  133  188  217  243  319  321  363  406  455  463  513
#   526  667  669  677  797  874  883  941  983 1012 1018 1067 1089 1253
#  1288 1298 1337 1371 1422 1620 1656 1697 1712 1718 1824], flg_lst: ['Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done'],
# dem: 2.0275, ava: 545.8741, upstream_dem: 0.0, ava_mod: 545.8741
# city_num: 217, flag: Done, uup: [], flg_lst: [],
# dem: 1.9092, ava: 0.272, upstream_dem: 0.0, ava_mod: 0.272
# city_num: 243, flag: Done, uup: [   2 1067 1089 1288 1422 1620], flg_lst: ['Done', 'Done', 'Done', 'Done', 'Done', 'Done'],
# dem: 1.7854, ava: 10.2826, upstream_dem: 0.0, ava_mod: 10.2826
# city_num: 319, flag: Done, uup: [1697], flg_lst: ['Done'],
# dem: 1.6543, ava: 45.5692, upstream_dem: 0.0, ava_mod: 45.5692
# city_num: 321, flag: Done, uup: [ 667  677  983 1253], flg_lst: ['Done', 'Done', 'Done', 'Done'],
# dem: 1.4261, ava: 31.4702, upstream_dem: 0.0, ava_mod: 31.4702
# city_num: 363, flag: Done, uup: [   2  126  188  217  243  406  455  874  883  941 1018 1067 1089 1288
#  1298 1337 1422 1620 1718], flg_lst: ['Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done'],
# dem: 1.3975, ava: 220.3025, upstream_dem: 0.0, ava_mod: 220.3025
# city_num: 398, flag: Done, uup: [   2   11  126  130  133  188  197  217  243  319  321  363  406  455
#   463  473  513  526  588  667  669  673  677  797  874  883  941  983
#  1012 1018 1067 1089 1181 1253 1288 1298 1337 1371 1422 1578 1620 1656
#  1697 1712 1718 1824], flg_lst: ['Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done'],
# dem: 1.1541, ava: 1267.732, upstream_dem: 0.0, ava_mod: 1267.732
# city_num: 406, flag: Done, uup: [], flg_lst: [],
# dem: 0.5054, ava: 6.8336, upstream_dem: 0.0, ava_mod: 6.8336
# city_num: 455, flag: Done, uup: [ 188  941 1718], flg_lst: ['Done', 'Done', 'Done'],
# dem: 0.9837, ava: 19.5192, upstream_dem: 0.0, ava_mod: 19.5192
# city_num: 463, flag: Done, uup: [1824], flg_lst: ['Done'],
# dem: 0.977, ava: 22.66, upstream_dem: 0.0, ava_mod: 22.66
# city_num: 473, flag: Done, uup: [], flg_lst: [],
# dem: 0.9526, ava: 328.8768, upstream_dem: 0.0, ava_mod: 328.8768
# city_num: 513, flag: Done, uup: [ 321  526  667  677  983 1253], flg_lst: ['Done', 'Done', 'Done', 'Done', 'Done', 'Done'],
# dem: 0.9286, ava: 34.9415, upstream_dem: 0.0, ava_mod: 34.9415
# city_num: 526, flag: Done, uup: [ 321  667  677  983 1253], flg_lst: ['Done', 'Done', 'Done', 'Done', 'Done'],
# dem: 0.8753, ava: 35.6511, upstream_dem: 0.0, ava_mod: 35.6511
# city_num: 588, flag: Done, uup: [   2  126  130  133  188  197  217  243  319  321  363  406  455  463
#   513  526  667  669  677  797  874  883  941  983 1012 1018 1067 1089
#  1253 1288 1298 1337 1371 1422 1578 1620 1656 1697 1712 1718 1824], flg_lst: ['Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done'],
# dem: 0.8683, ava: 779.6858, upstream_dem: 0.0, ava_mod: 779.6858
# city_num: 667, flag: Done, uup: [], flg_lst: [],
# dem: 0.7281, ava: 5.7566, upstream_dem: 0.0, ava_mod: 5.7566
# city_num: 669, flag: Done, uup: [ 463 1824], flg_lst: ['Done', 'Done'],
# dem: 0.7321, ava: 85.1825, upstream_dem: 0.0, ava_mod: 85.1825
# city_num: 673, flag: Done, uup: [], flg_lst: [],
# dem: 0.6879, ava: 14.2898, upstream_dem: 0.0, ava_mod: 14.2898
# city_num: 677, flag: Done, uup: [ 667 1253], flg_lst: ['Done', 'Done'],
# dem: 0.8113, ava: 31.5532, upstream_dem: 0.0, ava_mod: 31.5532
# city_num: 797, flag: Done, uup: [ 321  513  526  667  677  983 1253], flg_lst: ['Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done'],
# dem: 0.6528, ava: 36.2811, upstream_dem: 0.0, ava_mod: 36.2811
# city_num: 874, flag: Done, uup: [], flg_lst: [],
# dem: 0.4966, ava: 0.1784, upstream_dem: 0.0, ava_mod: 0.1784
# city_num: 883, flag: Done, uup: [217], flg_lst: ['Done'],
# dem: 0.5948, ava: 22.6364, upstream_dem: 0.0, ava_mod: 22.6364
# city_num: 903, flag: Done, uup: [1652], flg_lst: ['Done'],
# dem: 0.5489, ava: 41.5951, upstream_dem: 0.0, ava_mod: 41.5951
# city_num: 941, flag: Done, uup: [], flg_lst: [],
# dem: 0.5468, ava: 0.9935, upstream_dem: 0.0, ava_mod: 0.9935
# city_num: 983, flag: Done, uup: [ 667  677 1253], flg_lst: ['Done', 'Done', 'Done'],
# dem: 0.4931, ava: 31.0642, upstream_dem: 0.0, ava_mod: 31.0642
# city_num: 1012, flag: Done, uup: [ 319 1697], flg_lst: ['Done', 'Done'],
# dem: 0.6156, ava: 63.8831, upstream_dem: 0.0, ava_mod: 63.8831
# city_num: 1018, flag: Done, uup: [], flg_lst: [],
# dem: 0.0362, ava: 0.0663, upstream_dem: 0.0, ava_mod: 0.0663
# city_num: 1067, flag: Done, uup: [   2 1089 1288 1422 1620], flg_lst: ['Done', 'Done', 'Done', 'Done', 'Done'],
# dem: 0.4945, ava: 8.6912, upstream_dem: 0.0, ava_mod: 8.6912
# city_num: 1089, flag: Done, uup: [1620], flg_lst: ['Done'],
# dem: 0.4508, ava: 17.931, upstream_dem: 0.0, ava_mod: 17.931
# city_num: 1181, flag: Done, uup: [473 673], flg_lst: ['Done', 'Done'],
# dem: 0.4761, ava: 475.5076, upstream_dem: 0.0, ava_mod: 475.5076
# city_num: 1216, flag: Done, uup: [ 903 1652], flg_lst: ['Done', 'Done'],
# dem: 0.4793, ava: 53.804, upstream_dem: 0.0, ava_mod: 53.804
# city_num: 1253, flag: Done, uup: [667], flg_lst: ['Done'],
# dem: 0.3866, ava: 31.9398, upstream_dem: 0.0, ava_mod: 31.9398
# city_num: 1288, flag: Done, uup: [1089 1620], flg_lst: ['Done', 'Done'],
# dem: 0.4185, ava: 18.2658, upstream_dem: 0.0, ava_mod: 18.2658
# city_num: 1298, flag: Done, uup: [], flg_lst: [],
# dem: 0.3938, ava: 0.3671, upstream_dem: 0.0, ava_mod: 0.3671
# city_num: 1337, flag: Done, uup: [], flg_lst: [],
# dem: 0.3858, ava: 1.6604, upstream_dem: 0.0, ava_mod: 1.6604
# city_num: 1371, flag: Done, uup: [ 321  513  526  667  677  797  983 1253 1656], flg_lst: ['Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done'],
# dem: 0.3868, ava: 35.4805, upstream_dem: 0.0, ava_mod: 35.4805
# city_num: 1422, flag: Done, uup: [], flg_lst: [],
# dem: 0.3646, ava: 0.7317, upstream_dem: 0.0, ava_mod: 0.7317
# city_num: 1578, flag: Done, uup: [], flg_lst: [],
# dem: 0.3931, ava: 59.0873, upstream_dem: 0.0, ava_mod: 59.0873
# city_num: 1620, flag: Done, uup: [], flg_lst: [],
# dem: 0.3322, ava: 18.2632, upstream_dem: 0.0, ava_mod: 18.2632
# city_num: 1652, flag: Done, uup: [], flg_lst: [],
# dem: 0.0233, ava: 2.2543, upstream_dem: 0.0, ava_mod: 2.2543
# city_num: 1656, flag: Done, uup: [ 321  513  526  667  677  797  983 1253], flg_lst: ['Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done'],
# dem: 0.3568, ava: 35.8372, upstream_dem: 0.0, ava_mod: 35.8372
# city_num: 1697, flag: Done, uup: [], flg_lst: [],
# dem: 0.3073, ava: 11.6461, upstream_dem: 0.0, ava_mod: 11.6461
# city_num: 1712, flag: Done, uup: [ 463  669 1824], flg_lst: ['Done', 'Done', 'Done'],
# dem: 0.3592, ava: 87.8858, upstream_dem: 0.0, ava_mod: 87.8858
# city_num: 1718, flag: Done, uup: [188], flg_lst: ['Done'],
# dem: 0.2956, ava: 1.438, upstream_dem: 0.0, ava_mod: 1.438
# city_num: 1824, flag: Done, uup: [], flg_lst: [],
# dem: 0.2474, ava: 22.1056, upstream_dem: 0.0, ava_mod: 22.1056
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# ********** explore all done ***************
# **********rivnum14.0: calculation done***************
# --------------------------------------

# %%
####################################################################################
# ここからが本番
# explore all key_index & make df_new
# it takes soooo long time(4 hours?)
# df_newを作ってdfのavailabilityの部分を更新する
distance = 100
####################################################################################
import time
start_time = time.time()

def prf_int_flag(prf, intake, riv_num, rivnum_gl5, rivout_gl5):
    prf_coord = np.where((prf == 1) & (rivnum_gl5 == riv_num))
    int_coord = np.where((intake == 1) & (rivnum_gl5 == riv_num))
    
    # Create copies of prf and intake to avoid modifying original inputs
    prf_copy = np.copy(prf)
    intake_copy = np.copy(intake)

    if prf_coord[0].size != 0 and int_coord[0].size != 0:
        prf_runout = rivout_gl5[prf_coord][0] * 60 * 60 * 24 * 365 / 1000
        int_runout = rivout_gl5[int_coord][0] * 60 * 60 * 24 * 365 / 1000
        
        if prf_runout > int_runout:
            print('prf_runout > int_runout')
            largest = prf_copy
            all_int = prf_copy
            flag = 'both-prf'
        else:
            print('int_runout > prf_runout')
            prf_copy[prf_coord] = 0 
            largest = intake_copy
            all_int = intake_copy
            flag = 'both-intake'
            
    elif prf_coord[0].size != 0 and int_coord[0].size == 0:
        flag = 'prf'
        largest = prf_copy
        all_int = prf_copy + intake_copy
        
    elif prf_coord[0].size == 0 and int_coord[0].size != 0:
        flag = 'intake'
        largest = intake_copy
        all_int = prf_copy + intake_copy
        
    else:
        print('Error no prf no int')

    return flag, largest, all_int, prf_copy

####################################################################################
# JOB
####################################################################################
# 保存用変数を作る
df_new = df.copy()

# 複数都市を有する流域データを読み込む
new_basin_to_cities = load_json() # keys = all basins with multiple cities 180?

h08dir = '/mnt/c/Users/tsimk/Downloads/dotfiles/h08'
rivout_path = f'{h08dir}/wsi/dat/riv_out_/W5E5LR__00000000.gl5'
rivnum_path = f'{h08dir}/global_city/dat/riv_num_/rivnum.CAMA.gl5'
rivout_gl5 = np.fromfile(rivout_path, dtype='float32').reshape(2160, 4320)
rivnum_gl5 = np.fromfile(rivnum_path, dtype='float32').reshape(2160, 4320)

# basin loop
for key_index in range(len(new_basin_to_cities.keys())):
    
    # result_dictが更新されないことが大事
    result_dict =  make_result_dict(new_basin_to_cities, key_index=key_index) # keys = all cities in key_index basin
    
    # rivnumを取得する
    riv_num = list(new_basin_to_cities.keys())[key_index]
    city_num_lst = list(result_dict.keys())

    # city_numを取得する
    for city_num in city_num_lst:

        # get default discharge
        rate, discharge = discharge_rate(city_num, riv_num)

        # multiple basin cities
        if rate < 1:
            rate_cities.append(city_num)
        print(f'city_num: {city_num}, riv_num: {riv_num}')
        print(f'rate {rate}')
        print(f'discharge {discharge/1e9}')

        # check if df works OK
        filtered_df = df[df['index'] == city_num]
        if filtered_df.empty:
            print(f'City number {city_num} not found in the data.')
            
        # population in downtown
        est_pop = filtered_df.reset_index(drop=True).loc[0, 'pop']

        # calc demand from one basin(riv_num)
        demand = est_pop*rate*1000
        
        # ロジックを考える
        #demandが1000m3/year * populationだとして
        #consumptionはsupply > demand or supply < demandによって変化するべき
        #consumptionについてはexplore内で計算する必要がある
        
        print(f'supply: {discharge/1e9}')
        print(f'demand: {demand/1e9}')
        result_dict[city_num][0] = discharge
        result_dict[city_num][1] = demand
        print(f'--------------------------------------')
        
    print(f'**********rivnum{list(new_basin_to_cities.keys())[key_index]}: discharge done***************')
    print(f'--------------------------------------')

    # explore
    result_dict_mod = explore(result_dict)

    # update availability of cities in result_dict_mod
    for city_num in result_dict_mod:
        city_num = int(city_num)
        riv_num = int(float(riv_num))
        
        h08dir = '/mnt/c/Users/tsimk/Downloads/dotfiles/h08'
        msk_dir = f'{h08dir}/global_city/dat/vld_cty_'
        ctymsk_path = f'{msk_dir}/city_{city_num:08}.gl5'
        ctymsk = np.fromfile(ctymsk_path, dtype='float32').reshape(2160, 4320)
        
        prf_dir = f'{h08dir}/global_city/dat/cty_prf_'
        prf_path = f'{prf_dir}/vld_cty_/city_{city_num:08}.gl5'
        prf = np.fromfile(prf_path, dtype='float32').reshape(2160, 4320)
        
        int_dir = f'{h08dir}/global_city/dat/cty_int_/{distance}km_samebasin'
        int_path = f'{int_dir}/city_{city_num:08}.gl5'
        intake = np.fromfile(int_path, dtype='float32').reshape(2160, 4320)
        
        flag, largest, all_int, prf_copy = prf_int_flag(prf, intake, riv_num, rivnum_gl5, rivout_gl5)

        # discharge of prfs and intake not in riv_num
        # primary_dischargeはdischarge_rateの (largest & rivnum)で計算されている
        dis_sprf = np.sum(rivout_gl5[(prf==1) & (rivnum_gl5!=riv_num)])* 60 * 60 * 24 * 365 / (1000) # m3/year
        dis_int = np.sum(rivout_gl5[(intake==1) & (rivnum_gl5!=riv_num)])* 60 * 60 * 24 * 365 / (1000) # m3/year
        
        # 対象流域にintakeとprfがあり: prfを選択(intakeはabandon)
        if flag == 'both-prf':
            dis_els = dis_sprf
            ibt = 0
        # 対象流域にintakeとprfがあり: intakeを選択(intakeはrivnumにある)
        if flag == 'both-intake':
            dis_els = dis_sprf
            ibt = dis_int # 0
        # 対象流域にprfのみがある: prfを選択
        if flag == 'prf':
            dis_els = dis_sprf # 0?
            ibt = dis_int
        # 対象流域にintのみがある: intakeを選択
        if flag == 'intake':
            dis_els = dis_sprf
            ibt = dis_int # 0

        # 都市がriv_num以外にprfを持つ場合
        dis_mod = result_dict_mod[city_num][0] # updown後の discharge
        availability = dis_els + dis_mod # sprfを足した discharge

        # update
        new_mpcy = availability/df_new.loc[df_new['index'] == city_num, 'pop']
        new_mpcy = new_mpcy.iloc[0]
        
        ava_int = availability + ibt
        mpcy_int = ava_int/df_new.loc[df_new['index'] == city_num, 'pop']
        mpcy_int = mpcy_int.iloc[0]
        
        print(f'city_num: {city_num}')
        print(f'dis_els:{dis_els/1e9} billion m3/year') 
        print(f'dis_mod:{dis_mod/1e9} billion m3/year')
        print(f'ibt: {ibt/1e9} billion m3/year')
        print(f'availability:{availability/1e9} billion m3/year')
        print(f"new_mpcy: {new_mpcy}")
        print(f'ava_int: {ava_int/1e9} billion m3/year')
        print(f"mpcy_int: {mpcy_int}")
        print(f'--------------------------------------')

        # overwrite df_new
        df_new.loc[df_new['index'] == city_num, 'ava'] = availability
        df_new.loc[df_new['index'] == city_num, 'mpcy'] = new_mpcy
        df_new.loc[df_new['index'] == city_num, 'ava_int'] = ava_int
        df_new.loc[df_new['index'] == city_num, 'mpcy_int'] = mpcy_int
        
    print(f'**********rivnum{list(new_basin_to_cities.keys())[key_index]}: update done***************')

end_time = time.time()
total_time = end_time - start_time
hours, rem = divmod(total_time, 3600)
minutes, seconds = divmod(rem, 60)
print(f"Total execution time: {int(hours):02}:{int(minutes):02}:{seconds:05.2f} (HH:MM:SS)")
# Out:
# uid: 848.0
# city_list: [1, 936, 1283]
# city_num, riv_num, 1, 848
# PRF only
# city_num: 1, riv_num: 848.0
# rate 0.598730742931366
# discharge 11.001185775
# supply: 11.001185775
# demand: 19.05271989195049
# --------------------------------------
# city_num, riv_num, 1283, 848
# PRF only
# city_num: 1283, riv_num: 848.0
# rate 0.28908848762512207
# discharge 4.749225021
# supply: 4.749225021
# demand: 0.1287466420456767
# --------------------------------------
# **********rivnum848.0: discharge done***************
# --------------------------------------
# city_num: 1, flag: False, uup: [1283], flg_lst: ['Done'],
# dem: 19.0527, ava: 11.0012, upstream_dem: 0.1287, ava_mod: 10.8724
# city_num: 1283, flag: Done, uup: [], flg_lst: [],
# dem: 0.1287, ava: 4.7492, upstream_dem: 0.0, ava_mod: 4.7492
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# city_num: 1, flag: Done, uup: [1283], flg_lst: ['Done'],
# dem: 10.8724, ava: 10.8724, upstream_dem: 0.0, ava_mod: 10.8724
# city_num: 1283, flag: Done, uup: [], flg_lst: [],
# dem: 0.1287, ava: 4.7492, upstream_dem: 0.0, ava_mod: 4.7492
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# ********** explore all done ***************
# city_num: 1
# dis_els:3.23972235225 billion m3/year
# dis_mod:10.872439132954323 billion m3/year
# ibt: 3.295762070625 billion m3/year
# availability:14.112161485204323 billion m3/year
# new_mpcy: 443.4739490382967
# ava_int: 17.407923555829324 billion m3/year
# mpcy_int: 547.0431026426597
# --------------------------------------
# city_num: 1283
# dis_els:0.0 billion m3/year
# dis_mod:4.749225021 billion m3/year
# ibt: 9.980259021 billion m3/year
# availability:4.749225021 billion m3/year
# new_mpcy: 10663.938545482102
# ava_int: 14.729484042 billion m3/year
# mpcy_int: 33073.67242781721
# --------------------------------------
# **********rivnum848.0: update done***************
# uid: 14.0
# city_list: [2, 11, 126, 130, 133, 188, 197, 217, 243, 319, 321, 363, 398, 406, 455, 463, 473, 513, 526, 588, 667, 669, 673, 677, 797, 874, 883, 903, 941, 983, 1012, 1018, 1067, 1089, 1181, 1216, 1253, 1288, 1298, 1337, 1365, 1371, 1422, 1578, 1620, 1652, 1656, 1697, 1712, 1718, 1824]
# city_num, riv_num, 2, 14
# city_num: 2, prf: 4.42079778375, int: 19.248677595
# city_num: 2, INT > prf
# city_num: 2, riv_num: 14.0
# rate 1.0
# discharge 19.248677595
# supply: 19.248677595
# demand: 22.058268
# --------------------------------------
# city_num, riv_num, 11, 14
# city_num: 11, prf: 0.0956541544453125, int: 478.240570224
# city_num: 11, INT > prf
# city_num: 11, riv_num: 14.0
# rate 1.0
# discharge 478.240570224
# supply: 478.240570224
# demand: 14.907053
# --------------------------------------
# city_num, riv_num, 126, 14
# PRF only
# city_num: 126, riv_num: 14.0
# rate 0.4661909341812134
# discharge 0.08944297140234375
# supply: 0.08944297140234375
# demand: 1.4207207179924548
# --------------------------------------
# city_num, riv_num, 130, 14
# city_num: 130, prf: 87.145943796, int: 6.65100300825
# city_num: 130, PRF > int
# city_num: 130, riv_num: 14.0
# rate 1.0
# discharge 87.145943796
# supply: 87.145943796
# demand: 2.9605235
# --------------------------------------
# city_num, riv_num, 133, 14
# city_num: 133, prf: 6.701539941, int: 87.196582728
# city_num: 133, INT > prf
# city_num: 133, riv_num: 14.0
# rate 1.0
# discharge 87.196582728
# supply: 87.196582728
# demand: 2.87532775
# --------------------------------------
# city_num, riv_num, 188, 14
# city_num: 188, prf: 0.0565119422578125, int: 0.056030028908203126
# city_num: 188, PRF > int
# city_num: 188, riv_num: 14.0
# rate 1.0
# discharge 0.0565119422578125
# supply: 0.0565119422578125
# demand: 2.17459375
# --------------------------------------
# city_num, riv_num, 197, 14
# city_num: 197, prf: 591.25080384, int: 56.497291938
# city_num: 197, PRF > int
# city_num: 197, riv_num: 14.0
# rate 1.0
# discharge 591.25080384
# supply: 591.25080384
# demand: 2.027493375
# --------------------------------------
# city_num, riv_num, 217, 14
# city_num: 217, prf: 0.25847798709375, int: 0.2720333548125
# city_num: 217, INT > prf
# city_num: 217, riv_num: 14.0
# rate 1.0
# discharge 0.2720333548125
# supply: 0.2720333548125
# demand: 1.90916525
# --------------------------------------
# city_num, riv_num, 243, 14
# city_num: 243, prf: 30.390383844, int: 3.641325674625
# city_num: 243, PRF > int
# city_num: 243, riv_num: 14.0
# rate 1.0
# discharge 30.390383844
# supply: 30.390383844
# demand: 1.785424625
# --------------------------------------
# city_num, riv_num, 319, 14
# city_num: 319, prf: 0.1305414087890625, int: 45.876459888
# city_num: 319, INT > prf
# city_num: 319, riv_num: 14.0
# rate 1.0
# discharge 45.876459888
# supply: 45.876459888
# demand: 1.654334375
# --------------------------------------
# city_num, riv_num, 321, 14
# city_num: 321, prf: 0.1861881898359375, int: 33.889220262
# city_num: 321, INT > prf
# city_num: 321, riv_num: 14.0
# rate 1.0
# discharge 33.889220262
# supply: 33.889220262
# demand: 1.426092375
# --------------------------------------
# city_num, riv_num, 363, 14
# city_num: 363, prf: 246.507466968, int: 92.2232871
# city_num: 363, PRF > int
# city_num: 363, riv_num: 14.0
# rate 1.0
# discharge 246.507466968
# supply: 246.507466968
# demand: 1.397518375
# --------------------------------------
# city_num, riv_num, 398, 14
# INT only
# city_num: 398, riv_num: 14.0
# rate 0.9969676733016968
# discharge 1333.421298432
# supply: 1333.421298432
# demand: 1.1541453595618307
# --------------------------------------
# city_num, riv_num, 406, 14
# city_num: 406, prf: 0.1439401436015625, int: 6.8335545645
# city_num: 406, INT > prf
# city_num: 406, riv_num: 14.0
# rate 1.0
# discharge 6.8335545645
# supply: 6.8335545645
# demand: 0.50544159375
# --------------------------------------
# city_num, riv_num, 455, 14
# city_num: 455, prf: 20.418117228, int: 12.1408761195
# city_num: 455, PRF > int
# city_num: 455, riv_num: 14.0
# rate 1.0
# discharge 20.418117228
# supply: 20.418117228
# demand: 0.983652625
# --------------------------------------
# city_num, riv_num, 463, 14
# city_num: 463, prf: 0.07312175173828125, int: 22.907352258
# city_num: 463, INT > prf
# city_num: 463, riv_num: 14.0
# rate 1.0
# discharge 22.907352258
# supply: 22.907352258
# demand: 0.97701
# --------------------------------------
# city_num, riv_num, 473, 14
# city_num: 473, prf: 328.876834176, int: 19.687177791
# city_num: 473, PRF > int
# city_num: 473, riv_num: 14.0
# rate 1.0
# discharge 328.876834176
# supply: 328.876834176
# demand: 0.9526491875
# --------------------------------------
# city_num, riv_num, 513, 14
# city_num: 513, prf: 0.98778654478125, int: 39.661944192
# city_num: 513, INT > prf
# city_num: 513, riv_num: 14.0
# rate 1.0
# discharge 39.661944192
# supply: 39.661944192
# demand: 0.928597
# --------------------------------------
# city_num, riv_num, 526, 14
# city_num: 526, prf: 0.2345311840078125, int: 39.496202802
# city_num: 526, INT > prf
# city_num: 526, riv_num: 14.0
# rate 1.0
# discharge 39.496202802
# supply: 39.496202802
# demand: 0.875343
# --------------------------------------
# city_num, riv_num, 588, 14
# city_num: 588, prf: 827.483069376, int: 19.038458619
# city_num: 588, PRF > int
# city_num: 588, riv_num: 14.0
# rate 1.0
# discharge 827.483069376
# supply: 827.483069376
# demand: 0.868289375
# --------------------------------------
# city_num, riv_num, 667, 14
# city_num: 667, prf: 0.51893159371875, int: 5.756583411
# city_num: 667, INT > prf
# city_num: 667, riv_num: 14.0
# rate 1.0
# discharge 5.756583411
# supply: 5.756583411
# demand: 0.728069625
# --------------------------------------
# city_num, riv_num, 669, 14
# city_num: 669, prf: 2.466189851625, int: 86.406873984
# city_num: 669, INT > prf
# city_num: 669, riv_num: 14.0
# rate 1.0
# discharge 86.406873984
# supply: 86.406873984
# demand: 0.732065
# --------------------------------------
# city_num, riv_num, 673, 14
# city_num: 673, prf: 1.825538229, int: 14.289763797
# city_num: 673, INT > prf
# city_num: 673, riv_num: 14.0
# rate 1.0
# discharge 14.289763797
# supply: 14.289763797
# demand: 0.687915875
# --------------------------------------
# city_num, riv_num, 677, 14
# city_num: 677, prf: 0.08963806960546875, int: 32.667907851
# city_num: 677, INT > prf
# city_num: 677, riv_num: 14.0
# rate 1.0
# discharge 32.667907851
# supply: 32.667907851
# demand: 0.8112646875
# --------------------------------------
# city_num, riv_num, 797, 14
# city_num: 797, prf: 31.437966402, int: 41.93014734
# city_num: 797, INT > prf
# city_num: 797, riv_num: 14.0
# rate 1.0
# discharge 41.93014734
# supply: 41.93014734
# demand: 0.652847375
# --------------------------------------
# city_num, riv_num, 874, 14
# INT only
# city_num: 874, riv_num: 14.0
# rate 0.8270241022109985
# discharge 0.1784292559453125
# supply: 0.1784292559453125
# demand: 0.4965534378304928
# --------------------------------------
# city_num, riv_num, 883, 14
# city_num: 883, prf: 0.06896914730859376, int: 22.908410685
# city_num: 883, INT > prf
# city_num: 883, riv_num: 14.0
# rate 1.0
# discharge 22.908410685
# supply: 22.908410685
# demand: 0.594775375
# --------------------------------------
# city_num, riv_num, 903, 14
# city_num: 903, prf: 6.895955439, int: 41.618386386
# city_num: 903, INT > prf
# city_num: 903, riv_num: 14.0
# rate 1.0
# discharge 41.618386386
# supply: 41.618386386
# demand: 0.5489111875
# --------------------------------------
# city_num, riv_num, 941, 14
# city_num: 941, prf: 0.8571333279375, int: 0.993544882875
# city_num: 941, INT > prf
# city_num: 941, riv_num: 14.0
# rate 1.0
# discharge 0.993544882875
# supply: 0.993544882875
# demand: 0.5468076875
# --------------------------------------
# city_num, riv_num, 983, 14
# city_num: 983, prf: 0.048419474361328124, int: 32.990188032
# city_num: 983, INT > prf
# city_num: 983, riv_num: 14.0
# rate 1.0
# discharge 32.990188032
# supply: 32.990188032
# demand: 0.4931126875
# --------------------------------------
# city_num, riv_num, 1012, 14
# city_num: 1012, prf: 3.04763361975, int: 65.844716076
# city_num: 1012, INT > prf
# city_num: 1012, riv_num: 14.0
# rate 1.0
# discharge 65.844716076
# supply: 65.844716076
# demand: 0.615565125
# --------------------------------------
# city_num, riv_num, 1018, 14
# PRF only
# city_num: 1018, riv_num: 14.0
# rate 0.09329782426357269
# discharge 0.066265420359375
# supply: 0.066265420359375
# demand: 0.036231387865682134
# --------------------------------------
# city_num, riv_num, 1067, 14
# city_num: 1067, prf: 1.418693032125, int: 28.304519877
# city_num: 1067, INT > prf
# city_num: 1067, riv_num: 14.0
# rate 1.0
# discharge 28.304519877
# supply: 28.304519877
# demand: 0.49450671875
# --------------------------------------
# city_num, riv_num, 1089, 14
# city_num: 1089, prf: 0.04395905131640625, int: 18.263201247
# city_num: 1089, INT > prf
# city_num: 1089, riv_num: 14.0
# rate 1.0
# discharge 18.263201247
# supply: 18.263201247
# demand: 0.450800375
# --------------------------------------
# city_num, riv_num, 1181, 14
# city_num: 1181, prf: 4.50879406425, int: 477.148131648
# city_num: 1181, INT > prf
# city_num: 1181, riv_num: 14.0
# rate 1.0
# discharge 477.148131648
# supply: 477.148131648
# demand: 0.47610184375
# --------------------------------------
# city_num, riv_num, 1216, 14
# city_num: 1216, prf: 0.84838917121875, int: 54.376247592
# city_num: 1216, INT > prf
# city_num: 1216, riv_num: 14.0
# rate 1.0
# discharge 54.376247592
# supply: 54.376247592
# demand: 0.47925225
# --------------------------------------
# city_num, riv_num, 1253, 14
# city_num: 1253, prf: 0.2212189576171875, int: 32.667907851
# city_num: 1253, INT > prf
# city_num: 1253, riv_num: 14.0
# rate 1.0
# discharge 32.667907851
# supply: 32.667907851
# demand: 0.3866038125
# --------------------------------------
# city_num, riv_num, 1288, 14
# city_num: 1288, prf: 1.612417941, int: 19.048786659
# city_num: 1288, INT > prf
# city_num: 1288, riv_num: 14.0
# rate 1.0
# discharge 19.048786659
# supply: 19.048786659
# demand: 0.418458875
# --------------------------------------
# city_num, riv_num, 1298, 14
# city_num: 1298, prf: 0.367068291890625, int: 0.09287203405078125
# city_num: 1298, PRF > int
# city_num: 1298, riv_num: 14.0
# rate 1.0
# discharge 0.367068291890625
# supply: 0.367068291890625
# demand: 0.39378015625
# --------------------------------------
# city_num, riv_num, 1337, 14
# city_num: 1337, prf: 1.66044924, int: 1.1367674746875
# city_num: 1337, PRF > int
# city_num: 1337, riv_num: 14.0
# rate 1.0
# discharge 1.66044924
# supply: 1.66044924
# demand: 0.3857621875
# --------------------------------------
# city_num, riv_num, 1371, 14
# city_num: 1371, prf: 0.06634956512109375, int: 42.139175832
# city_num: 1371, INT > prf
# city_num: 1371, riv_num: 14.0
# rate 1.0
# discharge 42.139175832
# supply: 42.139175832
# demand: 0.386752125
# --------------------------------------
# city_num, riv_num, 1422, 14
# city_num: 1422, prf: 0.04071351109570313, int: 0.731685706875
# city_num: 1422, INT > prf
# city_num: 1422, riv_num: 14.0
# rate 1.0
# discharge 0.731685706875
# supply: 0.731685706875
# demand: 0.364646125
# --------------------------------------
# city_num, riv_num, 1578, 14
# city_num: 1578, prf: 0.29364580096875, int: 59.087260836
# city_num: 1578, INT > prf
# city_num: 1578, riv_num: 14.0
# rate 1.0
# discharge 59.087260836
# supply: 59.087260836
# demand: 0.3930796875
# --------------------------------------
# city_num, riv_num, 1620, 14
# city_num: 1620, prf: 0.2005798158984375, int: 18.263201247
# city_num: 1620, INT > prf
# city_num: 1620, riv_num: 14.0
# rate 1.0
# discharge 18.263201247
# supply: 18.263201247
# demand: 0.33221628125
# --------------------------------------
# city_num, riv_num, 1652, 14
# PRF only
# city_num: 1652, riv_num: 14.0
# rate 0.07755784690380096
# discharge 2.25428640975
# supply: 2.25428640975
# demand: 0.02330718002552539
# --------------------------------------
# city_num, riv_num, 1656, 14
# city_num: 1656, prf: 0.0493587828984375, int: 42.139175832
# city_num: 1656, INT > prf
# city_num: 1656, riv_num: 14.0
# rate 1.0
# discharge 42.139175832
# supply: 42.139175832
# demand: 0.35678103125
# --------------------------------------
# city_num, riv_num, 1697, 14
# city_num: 1697, prf: 0.04992697754296875, int: 11.6460999315
# city_num: 1697, INT > prf
# city_num: 1697, riv_num: 14.0
# rate 1.0
# discharge 11.6460999315
# supply: 11.6460999315
# demand: 0.30726871875
# --------------------------------------
# city_num, riv_num, 1712, 14
# city_num: 1712, prf: 3.66539429475, int: 89.842256028
# city_num: 1712, INT > prf
# city_num: 1712, riv_num: 14.0
# rate 1.0
# discharge 89.842256028
# supply: 89.842256028
# demand: 0.3592445625
# --------------------------------------
# city_num, riv_num, 1718, 14
# city_num: 1718, prf: 0.11301882612890625, int: 1.4944801995
# city_num: 1718, INT > prf
# city_num: 1718, riv_num: 14.0
# rate 1.0
# discharge 1.4944801995
# supply: 1.4944801995
# demand: 0.2955934375
# --------------------------------------
# city_num, riv_num, 1824, 14
# city_num: 1824, prf: 0.96825861590625, int: 22.105640124
# city_num: 1824, INT > prf
# city_num: 1824, riv_num: 14.0
# rate 1.0
# discharge 22.105640124
# supply: 22.105640124
# demand: 0.247378125
# --------------------------------------
# **********rivnum14.0: discharge done***************
# --------------------------------------
# city_num: 2, flag: True, uup: [1089 1288 1620], flg_lst: [False, True, 'Done'],
# dem: 22.0583, ava: 19.2487, upstream_dem: 1.2015, ava_mod: 18.0472
# city_num: 11, flag: True, uup: [ 473  673 1181], flg_lst: ['Done', 'Done', False],
# dem: 14.9071, ava: 478.2406, upstream_dem: 2.1167, ava_mod: 476.1239
# city_num: 126, flag: Done, uup: [], flg_lst: [],
# dem: 1.4207, ava: 0.0894, upstream_dem: 0.0, ava_mod: 0.0894
# city_num: 130, flag: True, uup: [ 321  513  526  667  677  797  983 1253 1371 1656], flg_lst: [True, True, True, 'Done', True, True, True, False, True, True],
# dem: 2.9605, ava: 87.1459, upstream_dem: 7.0455, ava_mod: 80.1005
# city_num: 133, flag: True, uup: [ 130  321  513  526  667  677  797  983 1253 1371 1656], flg_lst: ['Done', True, True, True, 'Done', True, True, True, False, True, True],
# dem: 2.8753, ava: 87.1966, upstream_dem: 10.006, ava_mod: 77.1906
# city_num: 188, flag: Done, uup: [], flg_lst: [],
# dem: 2.1746, ava: 0.0565, upstream_dem: 0.0, ava_mod: 0.0565
# city_num: 197, flag: True, uup: [   2  126  130  133  188  217  243  319  321  363  406  455  463  513
#   526  667  669  677  797  874  883  941  983 1012 1018 1067 1089 1253
#  1288 1298 1337 1371 1422 1620 1656 1697 1712 1718 1824], flg_lst: ['Done', 'Done', 'Done', 'Done', 'Done', 'Done', True, False, True, True, 'Done', True, False, True, True, 'Done', True, True, True, 'Done', False, 'Done', True, True, 'Done', True, False, False, True, 'Done', 'Done', True, 'Done', 'Done', True, 'Done', True, False, 'Done'],
# dem: 2.0275, ava: 591.2508, upstream_dem: 45.3767, ava_mod: 545.8741
# city_num: 217, flag: Done, uup: [], flg_lst: [],
# dem: 1.9092, ava: 0.272, upstream_dem: 0.0, ava_mod: 0.272
# city_num: 243, flag: True, uup: [   2 1067 1089 1288 1422 1620], flg_lst: ['Done', True, False, True, 'Done', 'Done'],
# dem: 1.7854, ava: 30.3904, upstream_dem: 20.1078, ava_mod: 10.2826
# city_num: 319, flag: False, uup: [1697], flg_lst: ['Done'],
# dem: 1.6543, ava: 45.8765, upstream_dem: 0.3073, ava_mod: 45.5692
# city_num: 321, flag: True, uup: [ 667  677  983 1253], flg_lst: ['Done', True, True, False],
# dem: 1.4261, ava: 33.8892, upstream_dem: 2.4191, ava_mod: 31.4702
# city_num: 363, flag: True, uup: [   2  126  188  217  243  406  455  874  883  941 1018 1067 1089 1288
#  1298 1337 1422 1620 1718], flg_lst: ['Done', 'Done', 'Done', 'Done', 'Done', 'Done', True, 'Done', False, 'Done', 'Done', True, False, True, 'Done', 'Done', 'Done', 'Done', False],
# dem: 1.3975, ava: 246.5075, upstream_dem: 26.205, ava_mod: 220.3025
# city_num: 398, flag: True, uup: [   2   11  126  130  133  188  197  217  243  319  321  363  406  455
#   463  473  513  526  588  667  669  673  677  797  874  883  941  983
#  1012 1018 1067 1089 1181 1253 1288 1298 1337 1371 1422 1578 1620 1656
#  1697 1712 1718 1824], flg_lst: ['Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', True, False, 'Done', True, True, True, 'Done', True, 'Done', True, True, 'Done', False, 'Done', True, True, 'Done', True, False, False, False, True, 'Done', 'Done', True, 'Done', 'Done', 'Done', True, 'Done', True, False, 'Done'],
# dem: 1.1541, ava: 1333.4213, upstream_dem: 65.6893, ava_mod: 1267.732
# city_num: 406, flag: Done, uup: [], flg_lst: [],
# dem: 0.5054, ava: 6.8336, upstream_dem: 0.0, ava_mod: 6.8336
# city_num: 455, flag: True, uup: [ 188  941 1718], flg_lst: ['Done', 'Done', False],
# dem: 0.9837, ava: 20.4181, upstream_dem: 0.8989, ava_mod: 19.5192
# city_num: 463, flag: False, uup: [1824], flg_lst: ['Done'],
# dem: 0.977, ava: 22.9074, upstream_dem: 0.2474, ava_mod: 22.66
# city_num: 473, flag: Done, uup: [], flg_lst: [],
# dem: 0.9526, ava: 328.8768, upstream_dem: 0.0, ava_mod: 328.8768
# city_num: 513, flag: True, uup: [ 321  526  667  677  983 1253], flg_lst: ['Done', True, 'Done', True, True, False],
# dem: 0.9286, ava: 39.6619, upstream_dem: 4.7205, ava_mod: 34.9415
# city_num: 526, flag: True, uup: [ 321  667  677  983 1253], flg_lst: ['Done', 'Done', True, True, False],
# dem: 0.8753, ava: 39.4962, upstream_dem: 3.8451, ava_mod: 35.6511
# city_num: 588, flag: True, uup: [   2  126  130  133  188  197  217  243  319  321  363  406  455  463
#   513  526  667  669  677  797  874  883  941  983 1012 1018 1067 1089
#  1253 1288 1298 1337 1371 1422 1578 1620 1656 1697 1712 1718 1824], flg_lst: ['Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', True, True, True, 'Done', False, 'Done', True, True, 'Done', True, False, False, True, 'Done', 'Done', True, 'Done', 'Done', 'Done', True, 'Done', True, False, 'Done'],
# dem: 0.8683, ava: 827.4831, upstream_dem: 47.7973, ava_mod: 779.6858
# city_num: 667, flag: Done, uup: [], flg_lst: [],
# dem: 0.7281, ava: 5.7566, upstream_dem: 0.0, ava_mod: 5.7566
# city_num: 669, flag: True, uup: [ 463 1824], flg_lst: ['Done', 'Done'],
# dem: 0.7321, ava: 86.4069, upstream_dem: 1.2244, ava_mod: 85.1825
# city_num: 673, flag: Done, uup: [], flg_lst: [],
# dem: 0.6879, ava: 14.2898, upstream_dem: 0.0, ava_mod: 14.2898
# city_num: 677, flag: True, uup: [ 667 1253], flg_lst: ['Done', False],
# dem: 0.8113, ava: 32.6679, upstream_dem: 1.1147, ava_mod: 31.5532
# city_num: 797, flag: True, uup: [ 321  513  526  667  677  983 1253], flg_lst: ['Done', 'Done', 'Done', 'Done', 'Done', True, False],
# dem: 0.6528, ava: 41.9301, upstream_dem: 5.6491, ava_mod: 36.2811
# city_num: 874, flag: Done, uup: [], flg_lst: [],
# dem: 0.4966, ava: 0.1784, upstream_dem: 0.0, ava_mod: 0.1784
# city_num: 883, flag: False, uup: [217], flg_lst: ['Done'],
# dem: 0.5948, ava: 22.9084, upstream_dem: 0.272, ava_mod: 22.6364
# city_num: 903, flag: False, uup: [1652], flg_lst: ['Done'],
# dem: 0.5489, ava: 41.6184, upstream_dem: 0.0233, ava_mod: 41.5951
# city_num: 941, flag: Done, uup: [], flg_lst: [],
# dem: 0.5468, ava: 0.9935, upstream_dem: 0.0, ava_mod: 0.9935
# city_num: 983, flag: True, uup: [ 667  677 1253], flg_lst: ['Done', 'Done', False],
# dem: 0.4931, ava: 32.9902, upstream_dem: 1.9259, ava_mod: 31.0642
# city_num: 1012, flag: True, uup: [ 319 1697], flg_lst: ['Done', 'Done'],
# dem: 0.6156, ava: 65.8447, upstream_dem: 1.9616, ava_mod: 63.8831
# city_num: 1018, flag: Done, uup: [], flg_lst: [],
# dem: 0.0362, ava: 0.0663, upstream_dem: 0.0, ava_mod: 0.0663
# city_num: 1067, flag: True, uup: [   2 1089 1288 1422 1620], flg_lst: ['Done', False, True, 'Done', 'Done'],
# dem: 0.4945, ava: 28.3045, upstream_dem: 19.6133, ava_mod: 8.6912
# city_num: 1089, flag: False, uup: [1620], flg_lst: ['Done'],
# dem: 0.4508, ava: 18.2632, upstream_dem: 0.3322, ava_mod: 17.931
# city_num: 1181, flag: False, uup: [473 673], flg_lst: ['Done', 'Done'],
# dem: 0.4761, ava: 477.1481, upstream_dem: 1.6406, ava_mod: 475.5076
# city_num: 1216, flag: True, uup: [ 903 1652], flg_lst: ['Done', 'Done'],
# dem: 0.4793, ava: 54.3762, upstream_dem: 0.5722, ava_mod: 53.804
# city_num: 1253, flag: False, uup: [667], flg_lst: ['Done'],
# dem: 0.3866, ava: 32.6679, upstream_dem: 0.7281, ava_mod: 31.9398
# city_num: 1288, flag: True, uup: [1089 1620], flg_lst: ['Done', 'Done'],
# dem: 0.4185, ava: 19.0488, upstream_dem: 0.783, ava_mod: 18.2658
# city_num: 1298, flag: Done, uup: [], flg_lst: [],
# dem: 0.3938, ava: 0.3671, upstream_dem: 0.0, ava_mod: 0.3671
# city_num: 1337, flag: Done, uup: [], flg_lst: [],
# dem: 0.3858, ava: 1.6604, upstream_dem: 0.0, ava_mod: 1.6604
# city_num: 1371, flag: True, uup: [ 321  513  526  667  677  797  983 1253 1656], flg_lst: ['Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', True],
# dem: 0.3868, ava: 42.1392, upstream_dem: 6.6587, ava_mod: 35.4805
# city_num: 1422, flag: Done, uup: [], flg_lst: [],
# dem: 0.3646, ava: 0.7317, upstream_dem: 0.0, ava_mod: 0.7317
# city_num: 1578, flag: Done, uup: [], flg_lst: [],
# dem: 0.3931, ava: 59.0873, upstream_dem: 0.0, ava_mod: 59.0873
# city_num: 1620, flag: Done, uup: [], flg_lst: [],
# dem: 0.3322, ava: 18.2632, upstream_dem: 0.0, ava_mod: 18.2632
# city_num: 1652, flag: Done, uup: [], flg_lst: [],
# dem: 0.0233, ava: 2.2543, upstream_dem: 0.0, ava_mod: 2.2543
# city_num: 1656, flag: True, uup: [ 321  513  526  667  677  797  983 1253], flg_lst: ['Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done'],
# dem: 0.3568, ava: 42.1392, upstream_dem: 6.3019, ava_mod: 35.8372
# city_num: 1697, flag: Done, uup: [], flg_lst: [],
# dem: 0.3073, ava: 11.6461, upstream_dem: 0.0, ava_mod: 11.6461
# city_num: 1712, flag: True, uup: [ 463  669 1824], flg_lst: ['Done', 'Done', 'Done'],
# dem: 0.3592, ava: 89.8423, upstream_dem: 1.9565, ava_mod: 87.8858
# city_num: 1718, flag: False, uup: [188], flg_lst: ['Done'],
# dem: 0.2956, ava: 1.4945, upstream_dem: 0.0565, ava_mod: 1.438
# city_num: 1824, flag: Done, uup: [], flg_lst: [],
# dem: 0.2474, ava: 22.1056, upstream_dem: 0.0, ava_mod: 22.1056
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# city_num: 2, flag: Done, uup: [1089 1288 1620], flg_lst: ['Done', 'Done', 'Done'],
# dem: 18.0472, ava: 18.0472, upstream_dem: 0.0, ava_mod: 18.0472
# city_num: 11, flag: Done, uup: [ 473  673 1181], flg_lst: ['Done', 'Done', 'Done'],
# dem: 14.9071, ava: 476.1239, upstream_dem: 0.0, ava_mod: 476.1239
# city_num: 126, flag: Done, uup: [], flg_lst: [],
# dem: 1.4207, ava: 0.0894, upstream_dem: 0.0, ava_mod: 0.0894
# city_num: 130, flag: Done, uup: [ 321  513  526  667  677  797  983 1253 1371 1656], flg_lst: ['Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done'],
# dem: 2.9605, ava: 80.1005, upstream_dem: 0.0, ava_mod: 80.1005
# city_num: 133, flag: Done, uup: [ 130  321  513  526  667  677  797  983 1253 1371 1656], flg_lst: ['Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done'],
# dem: 2.8753, ava: 77.1906, upstream_dem: 0.0, ava_mod: 77.1906
# city_num: 188, flag: Done, uup: [], flg_lst: [],
# dem: 2.1746, ava: 0.0565, upstream_dem: 0.0, ava_mod: 0.0565
# city_num: 197, flag: Done, uup: [   2  126  130  133  188  217  243  319  321  363  406  455  463  513
#   526  667  669  677  797  874  883  941  983 1012 1018 1067 1089 1253
#  1288 1298 1337 1371 1422 1620 1656 1697 1712 1718 1824], flg_lst: ['Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done'],
# dem: 2.0275, ava: 545.8741, upstream_dem: 0.0, ava_mod: 545.8741
# city_num: 217, flag: Done, uup: [], flg_lst: [],
# dem: 1.9092, ava: 0.272, upstream_dem: 0.0, ava_mod: 0.272
# city_num: 243, flag: Done, uup: [   2 1067 1089 1288 1422 1620], flg_lst: ['Done', 'Done', 'Done', 'Done', 'Done', 'Done'],
# dem: 1.7854, ava: 10.2826, upstream_dem: 0.0, ava_mod: 10.2826
# city_num: 319, flag: Done, uup: [1697], flg_lst: ['Done'],
# dem: 1.6543, ava: 45.5692, upstream_dem: 0.0, ava_mod: 45.5692
# city_num: 321, flag: Done, uup: [ 667  677  983 1253], flg_lst: ['Done', 'Done', 'Done', 'Done'],
# dem: 1.4261, ava: 31.4702, upstream_dem: 0.0, ava_mod: 31.4702
# city_num: 363, flag: Done, uup: [   2  126  188  217  243  406  455  874  883  941 1018 1067 1089 1288
#  1298 1337 1422 1620 1718], flg_lst: ['Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done'],
# dem: 1.3975, ava: 220.3025, upstream_dem: 0.0, ava_mod: 220.3025
# city_num: 398, flag: Done, uup: [   2   11  126  130  133  188  197  217  243  319  321  363  406  455
#   463  473  513  526  588  667  669  673  677  797  874  883  941  983
#  1012 1018 1067 1089 1181 1253 1288 1298 1337 1371 1422 1578 1620 1656
#  1697 1712 1718 1824], flg_lst: ['Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done'],
# dem: 1.1541, ava: 1267.732, upstream_dem: 0.0, ava_mod: 1267.732
# city_num: 406, flag: Done, uup: [], flg_lst: [],
# dem: 0.5054, ava: 6.8336, upstream_dem: 0.0, ava_mod: 6.8336
# city_num: 455, flag: Done, uup: [ 188  941 1718], flg_lst: ['Done', 'Done', 'Done'],
# dem: 0.9837, ava: 19.5192, upstream_dem: 0.0, ava_mod: 19.5192
# city_num: 463, flag: Done, uup: [1824], flg_lst: ['Done'],
# dem: 0.977, ava: 22.66, upstream_dem: 0.0, ava_mod: 22.66
# city_num: 473, flag: Done, uup: [], flg_lst: [],
# dem: 0.9526, ava: 328.8768, upstream_dem: 0.0, ava_mod: 328.8768
# city_num: 513, flag: Done, uup: [ 321  526  667  677  983 1253], flg_lst: ['Done', 'Done', 'Done', 'Done', 'Done', 'Done'],
# dem: 0.9286, ava: 34.9415, upstream_dem: 0.0, ava_mod: 34.9415
# city_num: 526, flag: Done, uup: [ 321  667  677  983 1253], flg_lst: ['Done', 'Done', 'Done', 'Done', 'Done'],
# dem: 0.8753, ava: 35.6511, upstream_dem: 0.0, ava_mod: 35.6511
# city_num: 588, flag: Done, uup: [   2  126  130  133  188  197  217  243  319  321  363  406  455  463
#   513  526  667  669  677  797  874  883  941  983 1012 1018 1067 1089
#  1253 1288 1298 1337 1371 1422 1578 1620 1656 1697 1712 1718 1824], flg_lst: ['Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done'],
# dem: 0.8683, ava: 779.6858, upstream_dem: 0.0, ava_mod: 779.6858
# city_num: 667, flag: Done, uup: [], flg_lst: [],
# dem: 0.7281, ava: 5.7566, upstream_dem: 0.0, ava_mod: 5.7566
# city_num: 669, flag: Done, uup: [ 463 1824], flg_lst: ['Done', 'Done'],
# dem: 0.7321, ava: 85.1825, upstream_dem: 0.0, ava_mod: 85.1825
# city_num: 673, flag: Done, uup: [], flg_lst: [],
# dem: 0.6879, ava: 14.2898, upstream_dem: 0.0, ava_mod: 14.2898
# city_num: 677, flag: Done, uup: [ 667 1253], flg_lst: ['Done', 'Done'],
# dem: 0.8113, ava: 31.5532, upstream_dem: 0.0, ava_mod: 31.5532
# city_num: 797, flag: Done, uup: [ 321  513  526  667  677  983 1253], flg_lst: ['Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done'],
# dem: 0.6528, ava: 36.2811, upstream_dem: 0.0, ava_mod: 36.2811
# city_num: 874, flag: Done, uup: [], flg_lst: [],
# dem: 0.4966, ava: 0.1784, upstream_dem: 0.0, ava_mod: 0.1784
# city_num: 883, flag: Done, uup: [217], flg_lst: ['Done'],
# dem: 0.5948, ava: 22.6364, upstream_dem: 0.0, ava_mod: 22.6364
# city_num: 903, flag: Done, uup: [1652], flg_lst: ['Done'],
# dem: 0.5489, ava: 41.5951, upstream_dem: 0.0, ava_mod: 41.5951
# city_num: 941, flag: Done, uup: [], flg_lst: [],
# dem: 0.5468, ava: 0.9935, upstream_dem: 0.0, ava_mod: 0.9935
# city_num: 983, flag: Done, uup: [ 667  677 1253], flg_lst: ['Done', 'Done', 'Done'],
# dem: 0.4931, ava: 31.0642, upstream_dem: 0.0, ava_mod: 31.0642
# city_num: 1012, flag: Done, uup: [ 319 1697], flg_lst: ['Done', 'Done'],
# dem: 0.6156, ava: 63.8831, upstream_dem: 0.0, ava_mod: 63.8831
# city_num: 1018, flag: Done, uup: [], flg_lst: [],
# dem: 0.0362, ava: 0.0663, upstream_dem: 0.0, ava_mod: 0.0663
# city_num: 1067, flag: Done, uup: [   2 1089 1288 1422 1620], flg_lst: ['Done', 'Done', 'Done', 'Done', 'Done'],
# dem: 0.4945, ava: 8.6912, upstream_dem: 0.0, ava_mod: 8.6912
# city_num: 1089, flag: Done, uup: [1620], flg_lst: ['Done'],
# dem: 0.4508, ava: 17.931, upstream_dem: 0.0, ava_mod: 17.931
# city_num: 1181, flag: Done, uup: [473 673], flg_lst: ['Done', 'Done'],
# dem: 0.4761, ava: 475.5076, upstream_dem: 0.0, ava_mod: 475.5076
# city_num: 1216, flag: Done, uup: [ 903 1652], flg_lst: ['Done', 'Done'],
# dem: 0.4793, ava: 53.804, upstream_dem: 0.0, ava_mod: 53.804
# city_num: 1253, flag: Done, uup: [667], flg_lst: ['Done'],
# dem: 0.3866, ava: 31.9398, upstream_dem: 0.0, ava_mod: 31.9398
# city_num: 1288, flag: Done, uup: [1089 1620], flg_lst: ['Done', 'Done'],
# dem: 0.4185, ava: 18.2658, upstream_dem: 0.0, ava_mod: 18.2658
# city_num: 1298, flag: Done, uup: [], flg_lst: [],
# dem: 0.3938, ava: 0.3671, upstream_dem: 0.0, ava_mod: 0.3671
# city_num: 1337, flag: Done, uup: [], flg_lst: [],
# dem: 0.3858, ava: 1.6604, upstream_dem: 0.0, ava_mod: 1.6604
# city_num: 1371, flag: Done, uup: [ 321  513  526  667  677  797  983 1253 1656], flg_lst: ['Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done'],
# dem: 0.3868, ava: 35.4805, upstream_dem: 0.0, ava_mod: 35.4805
# city_num: 1422, flag: Done, uup: [], flg_lst: [],
# dem: 0.3646, ava: 0.7317, upstream_dem: 0.0, ava_mod: 0.7317
# city_num: 1578, flag: Done, uup: [], flg_lst: [],
# dem: 0.3931, ava: 59.0873, upstream_dem: 0.0, ava_mod: 59.0873
# city_num: 1620, flag: Done, uup: [], flg_lst: [],
# dem: 0.3322, ava: 18.2632, upstream_dem: 0.0, ava_mod: 18.2632
# city_num: 1652, flag: Done, uup: [], flg_lst: [],
# dem: 0.0233, ava: 2.2543, upstream_dem: 0.0, ava_mod: 2.2543
# city_num: 1656, flag: Done, uup: [ 321  513  526  667  677  797  983 1253], flg_lst: ['Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done'],
# dem: 0.3568, ava: 35.8372, upstream_dem: 0.0, ava_mod: 35.8372
# city_num: 1697, flag: Done, uup: [], flg_lst: [],
# dem: 0.3073, ava: 11.6461, upstream_dem: 0.0, ava_mod: 11.6461
# city_num: 1712, flag: Done, uup: [ 463  669 1824], flg_lst: ['Done', 'Done', 'Done'],
# dem: 0.3592, ava: 87.8858, upstream_dem: 0.0, ava_mod: 87.8858
# city_num: 1718, flag: Done, uup: [188], flg_lst: ['Done'],
# dem: 0.2956, ava: 1.438, upstream_dem: 0.0, ava_mod: 1.438
# city_num: 1824, flag: Done, uup: [], flg_lst: [],
# dem: 0.2474, ava: 22.1056, upstream_dem: 0.0, ava_mod: 22.1056
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# ********** explore all done ***************
# int_runout > prf_runout
# city_num: 2
# dis_els:0.0 billion m3/year
# dis_mod:18.04720206375 billion m3/year
# ibt: 0.0 billion m3/year
# availability:18.04720206375 billion m3/year
# new_mpcy: 818.1604314423055
# ava_int: 18.04720206375 billion m3/year
# mpcy_int: 818.1604314423055
# --------------------------------------
# int_runout > prf_runout
# city_num: 11
# dis_els:0.0 billion m3/year
# dis_mod:476.12390331775 billion m3/year
# ibt: 0.0 billion m3/year
# availability:476.12390331775 billion m3/year
# new_mpcy: 31939.50563654332
# ava_int: 476.12390331775 billion m3/year
# mpcy_int: 31939.50563654332
# --------------------------------------
# city_num: 126
# dis_els:0.0 billion m3/year
# dis_mod:0.08944297140234375 billion m3/year
# ibt: 0.09767623876171876 billion m3/year
# availability:0.08944297140234375 billion m3/year
# new_mpcy: 29.34954200775133
# ava_int: 0.1871192101640625 billion m3/year
# mpcy_int: 61.40072308715243
# --------------------------------------
# prf_runout > int_runout
# city_num: 130
# dis_els:0.0 billion m3/year
# dis_mod:80.10048007725 billion m3/year
# ibt: 0.0 billion m3/year
# availability:80.10048007725 billion m3/year
# new_mpcy: 27056.187892867594
# ava_int: 80.10048007725 billion m3/year
# mpcy_int: 27056.187892867594
# --------------------------------------
# int_runout > prf_runout
# city_num: 133
# dis_els:0.0 billion m3/year
# dis_mod:77.19059550925 billion m3/year
# ibt: 0.0 billion m3/year
# availability:77.19059550925 billion m3/year
# new_mpcy: 26845.84235979707
# ava_int: 77.19059550925 billion m3/year
# mpcy_int: 26845.84235979707
# --------------------------------------
# prf_runout > int_runout
# city_num: 188
# dis_els:0.0 billion m3/year
# dis_mod:0.0565119422578125 billion m3/year
# ibt: 0.0 billion m3/year
# availability:0.0565119422578125 billion m3/year
# new_mpcy: 25.9873561477
# ava_int: 0.0565119422578125 billion m3/year
# mpcy_int: 25.9873561477
# --------------------------------------
# prf_runout > int_runout
# city_num: 197
# dis_els:0.0 billion m3/year
# dis_mod:545.8740994158256 billion m3/year
# ibt: 0.0 billion m3/year
# availability:545.8740994158256 billion m3/year
# new_mpcy: 269235.9472769304
# ava_int: 545.8740994158256 billion m3/year
# mpcy_int: 269235.9472769304
# --------------------------------------
# int_runout > prf_runout
# city_num: 217
# dis_els:0.0 billion m3/year
# dis_mod:0.2720333548125 billion m3/year
# ibt: 0.0 billion m3/year
# availability:0.2720333548125 billion m3/year
# new_mpcy: 142.48811348965208
# ava_int: 0.2720333548125 billion m3/year
# mpcy_int: 142.48811348965208
# --------------------------------------
# prf_runout > int_runout
# city_num: 243
# dis_els:0.0 billion m3/year
# dis_mod:10.28255340525 billion m3/year
# ibt: 0.0 billion m3/year
# availability:10.28255340525 billion m3/year
# new_mpcy: 5759.164100948815
# ava_int: 10.28255340525 billion m3/year
# mpcy_int: 5759.164100948815
# --------------------------------------
# int_runout > prf_runout
# city_num: 319
# dis_els:0.0 billion m3/year
# dis_mod:45.56919116925 billion m3/year
# ibt: 0.0 billion m3/year
# availability:45.56919116925 billion m3/year
# new_mpcy: 27545.33294954353
# ava_int: 45.56919116925 billion m3/year
# mpcy_int: 27545.33294954353
# --------------------------------------
# int_runout > prf_runout
# city_num: 321
# dis_els:0.0 billion m3/year
# dis_mod:31.4701694495 billion m3/year
# ibt: 0.0 billion m3/year
# availability:31.4701694495 billion m3/year
# new_mpcy: 22067.41302399853
# ava_int: 31.4701694495 billion m3/year
# mpcy_int: 22067.41302399853
# --------------------------------------
# prf_runout > int_runout
# city_num: 363
# dis_els:0.0 billion m3/year
# dis_mod:220.30246179382573 billion m3/year
# ibt: 0.0 billion m3/year
# availability:220.30246179382573 billion m3/year
# new_mpcy: 157638.32929483
# ava_int: 220.30246179382573 billion m3/year
# mpcy_int: 157638.32929483
# --------------------------------------
# city_num: 398
# dis_els:4.104921135375 billion m3/year
# dis_mod:1267.7320116640756 billion m3/year
# ibt: 0.0 billion m3/year
# availability:1271.8369327994508 billion m3/year
# new_mpcy: 1098631.3788010387
# ava_int: 1271.8369327994508 billion m3/year
# mpcy_int: 1098631.3788010387
# --------------------------------------
# int_runout > prf_runout
# city_num: 406
# dis_els:0.0 billion m3/year
# dis_mod:6.8335545645 billion m3/year
# ibt: 0.0 billion m3/year
# availability:6.8335545645 billion m3/year
# new_mpcy: 13519.968773840152
# ava_int: 6.8335545645 billion m3/year
# mpcy_int: 13519.968773840152
# --------------------------------------
# prf_runout > int_runout
# city_num: 455
# dis_els:0.0 billion m3/year
# dis_mod:19.519204160742188 billion m3/year
# ibt: 0.0 billion m3/year
# availability:19.519204160742188 billion m3/year
# new_mpcy: 19843.594847055065
# ava_int: 19.519204160742188 billion m3/year
# mpcy_int: 19843.594847055065
# --------------------------------------
# int_runout > prf_runout
# city_num: 463
# dis_els:0.0 billion m3/year
# dis_mod:22.659974133 billion m3/year
# ibt: 0.0 billion m3/year
# availability:22.659974133 billion m3/year
# new_mpcy: 23193.185466883657
# ava_int: 22.659974133 billion m3/year
# mpcy_int: 23193.185466883657
# --------------------------------------
# prf_runout > int_runout
# city_num: 473
# dis_els:0.0 billion m3/year
# dis_mod:328.876834176 billion m3/year
# ibt: 0.0 billion m3/year
# availability:328.876834176 billion m3/year
# new_mpcy: 345223.44478040084
# ava_int: 328.876834176 billion m3/year
# mpcy_int: 345223.44478040084
# --------------------------------------
# int_runout > prf_runout
# city_num: 513
# dis_els:0.0 billion m3/year
# dis_mod:34.9414580045 billion m3/year
# ibt: 0.0 billion m3/year
# availability:34.9414580045 billion m3/year
# new_mpcy: 37628.22624292346
# ava_int: 34.9414580045 billion m3/year
# mpcy_int: 37628.22624292346
# --------------------------------------
# int_runout > prf_runout
# city_num: 526
# dis_els:0.0 billion m3/year
# dis_mod:35.6510596145 billion m3/year
# ibt: 0.0 billion m3/year
# availability:35.6510596145 billion m3/year
# new_mpcy: 40728.10271459302
# ava_int: 35.6510596145 billion m3/year
# mpcy_int: 40728.10271459302
# --------------------------------------
# prf_runout > int_runout
# city_num: 588
# dis_els:0.0 billion m3/year
# dis_mod:779.6857918893256 billion m3/year
# ibt: 0.0 billion m3/year
# availability:779.6857918893256 billion m3/year
# new_mpcy: 897956.1587855727
# ava_int: 779.6857918893256 billion m3/year
# mpcy_int: 897956.1587855727
# --------------------------------------
# int_runout > prf_runout
# city_num: 667
# dis_els:0.0 billion m3/year
# dis_mod:5.756583411 billion m3/year
# ibt: 0.0 billion m3/year
# availability:5.756583411 billion m3/year
# new_mpcy: 7906.638614404495
# ava_int: 5.756583411 billion m3/year
# mpcy_int: 7906.638614404495
# --------------------------------------
# int_runout > prf_runout
# city_num: 669
# dis_els:0.0 billion m3/year
# dis_mod:85.182485859 billion m3/year
# ibt: 0.0 billion m3/year
# availability:85.182485859 billion m3/year
# new_mpcy: 116359.18375963884
# ava_int: 85.182485859 billion m3/year
# mpcy_int: 116359.18375963884
# --------------------------------------
# int_runout > prf_runout
# city_num: 673
# dis_els:0.0 billion m3/year
# dis_mod:14.289763797 billion m3/year
# ibt: 0.0 billion m3/year
# availability:14.289763797 billion m3/year
# new_mpcy: 20772.545475854877
# ava_int: 14.289763797 billion m3/year
# mpcy_int: 20772.545475854877
# --------------------------------------
# int_runout > prf_runout
# city_num: 677
# dis_els:0.0 billion m3/year
# dis_mod:31.5532344135 billion m3/year
# ibt: 0.0 billion m3/year
# availability:31.5532344135 billion m3/year
# new_mpcy: 38893.88370980957
# ava_int: 31.5532344135 billion m3/year
# mpcy_int: 38893.88370980957
# --------------------------------------
# int_runout > prf_runout
# city_num: 797
# dis_els:0.0 billion m3/year
# dis_mod:36.2810641525 billion m3/year
# ibt: 0.0 billion m3/year
# availability:36.2810641525 billion m3/year
# new_mpcy: 55573.57744220079
# ava_int: 36.2810641525 billion m3/year
# mpcy_int: 55573.57744220079
# --------------------------------------
# city_num: 874
# dis_els:0.02912754001464844 billion m3/year
# dis_mod:0.1784292559453125 billion m3/year
# ibt: 0.0 billion m3/year
# availability:0.20755679595996093 billion m3/year
# new_mpcy: 345.69184252667554
# ava_int: 0.20755679595996093 billion m3/year
# mpcy_int: 345.69184252667554
# --------------------------------------
# int_runout > prf_runout
# city_num: 883
# dis_els:0.0 billion m3/year
# dis_mod:22.6363773301875 billion m3/year
# ibt: 0.0 billion m3/year
# availability:22.6363773301875 billion m3/year
# new_mpcy: 38058.69960602774
# ava_int: 22.6363773301875 billion m3/year
# mpcy_int: 38058.69960602774
# --------------------------------------
# int_runout > prf_runout
# city_num: 903
# dis_els:0.0 billion m3/year
# dis_mod:41.59507920597447 billion m3/year
# ibt: 0.0 billion m3/year
# availability:41.59507920597447 billion m3/year
# new_mpcy: 75777.43021674972
# ava_int: 41.59507920597447 billion m3/year
# mpcy_int: 75777.43021674972
# --------------------------------------
# int_runout > prf_runout
# city_num: 941
# dis_els:0.0 billion m3/year
# dis_mod:0.993544882875 billion m3/year
# ibt: 0.0 billion m3/year
# availability:0.993544882875 billion m3/year
# new_mpcy: 1816.9914315167707
# ava_int: 0.993544882875 billion m3/year
# mpcy_int: 1816.9914315167707
# --------------------------------------
# int_runout > prf_runout
# city_num: 983
# dis_els:0.0 billion m3/year
# dis_mod:31.064249907 billion m3/year
# ibt: 0.0 billion m3/year
# availability:31.064249907 billion m3/year
# new_mpcy: 62996.2495276498
# ava_int: 31.064249907 billion m3/year
# mpcy_int: 62996.2495276498
# --------------------------------------
# int_runout > prf_runout
# city_num: 1012
# dis_els:0.0 billion m3/year
# dis_mod:63.88311298225 billion m3/year
# ibt: 0.0 billion m3/year
# availability:63.88311298225 billion m3/year
# new_mpcy: 103779.6171156545
# ava_int: 63.88311298225 billion m3/year
# mpcy_int: 103779.6171156545
# --------------------------------------
# city_num: 1018
# dis_els:0.14231131228125 billion m3/year
# dis_mod:0.066265420359375 billion m3/year
# ibt: 0.70942775821875 billion m3/year
# availability:0.208576732640625 billion m3/year
# new_mpcy: 537.0966030756781
# ava_int: 0.918004490859375 billion m3/year
# mpcy_int: 2363.912251412619
# --------------------------------------
# int_runout > prf_runout
# city_num: 1067
# dis_els:0.0 billion m3/year
# dis_mod:8.691196157 billion m3/year
# ibt: 0.0 billion m3/year
# availability:8.691196157 billion m3/year
# new_mpcy: 17575.486494843502
# ava_int: 8.691196157 billion m3/year
# mpcy_int: 17575.486494843502
# --------------------------------------
# int_runout > prf_runout
# city_num: 1089
# dis_els:0.0 billion m3/year
# dis_mod:17.93098496575 billion m3/year
# ibt: 0.0 billion m3/year
# availability:17.93098496575 billion m3/year
# new_mpcy: 39775.88742189933
# ava_int: 17.93098496575 billion m3/year
# mpcy_int: 39775.88742189933
# --------------------------------------
# int_runout > prf_runout
# city_num: 1181
# dis_els:0.0 billion m3/year
# dis_mod:475.5075665855 billion m3/year
# ibt: 0.0 billion m3/year
# availability:475.5075665855 billion m3/year
# new_mpcy: 998751.7856267492
# ava_int: 475.5075665855 billion m3/year
# mpcy_int: 998751.7856267492
# --------------------------------------
# int_runout > prf_runout
# city_num: 1216
# dis_els:0.0 billion m3/year
# dis_mod:53.80402922447447 billion m3/year
# ibt: 0.0 billion m3/year
# availability:53.80402922447447 billion m3/year
# new_mpcy: 112266.61789167285
# ava_int: 53.80402922447447 billion m3/year
# mpcy_int: 112266.61789167285
# --------------------------------------
# int_runout > prf_runout
# city_num: 1253
# dis_els:0.0 billion m3/year
# dis_mod:31.939838226 billion m3/year
# ibt: 0.0 billion m3/year
# availability:31.939838226 billion m3/year
# new_mpcy: 82616.45952081757
# ava_int: 31.939838226 billion m3/year
# mpcy_int: 82616.45952081757
# --------------------------------------
# int_runout > prf_runout
# city_num: 1288
# dis_els:0.0 billion m3/year
# dis_mod:18.26577000275 billion m3/year
# ibt: 0.0 billion m3/year
# availability:18.26577000275 billion m3/year
# new_mpcy: 43650.095849323305
# ava_int: 18.26577000275 billion m3/year
# mpcy_int: 43650.095849323305
# --------------------------------------
# prf_runout > int_runout
# city_num: 1298
# dis_els:0.0 billion m3/year
# dis_mod:0.367068291890625 billion m3/year
# ibt: 0.0 billion m3/year
# availability:0.367068291890625 billion m3/year
# new_mpcy: 932.1655397423928
# ava_int: 0.367068291890625 billion m3/year
# mpcy_int: 932.1655397423928
# --------------------------------------
# prf_runout > int_runout
# city_num: 1337
# dis_els:0.0 billion m3/year
# dis_mod:1.66044924 billion m3/year
# ibt: 0.0 billion m3/year
# availability:1.66044924 billion m3/year
# new_mpcy: 4304.333845576817
# ava_int: 1.66044924 billion m3/year
# mpcy_int: 4304.333845576817
# --------------------------------------
# int_runout > prf_runout
# city_num: 1371
# dis_els:0.0 billion m3/year
# dis_mod:35.48046423825 billion m3/year
# ibt: 0.0 billion m3/year
# availability:35.48046423825 billion m3/year
# new_mpcy: 91739.54567993648
# ava_int: 35.48046423825 billion m3/year
# mpcy_int: 91739.54567993648
# --------------------------------------
# int_runout > prf_runout
# city_num: 1422
# dis_els:0.0 billion m3/year
# dis_mod:0.731685706875 billion m3/year
# ibt: 0.0 billion m3/year
# availability:0.731685706875 billion m3/year
# new_mpcy: 2006.5637798152936
# ava_int: 0.731685706875 billion m3/year
# mpcy_int: 2006.5637798152936
# --------------------------------------
# int_runout > prf_runout
# city_num: 1578
# dis_els:0.0 billion m3/year
# dis_mod:59.087260836 billion m3/year
# ibt: 0.0 billion m3/year
# availability:59.087260836 billion m3/year
# new_mpcy: 150318.78449837223
# ava_int: 59.087260836 billion m3/year
# mpcy_int: 150318.78449837223
# --------------------------------------
# int_runout > prf_runout
# city_num: 1620
# dis_els:0.0 billion m3/year
# dis_mod:18.263201247 billion m3/year
# ibt: 0.0 billion m3/year
# availability:18.263201247 billion m3/year
# new_mpcy: 54973.82963376362
# ava_int: 18.263201247 billion m3/year
# mpcy_int: 54973.82963376362
# --------------------------------------
# city_num: 1652
# dis_els:0.0 billion m3/year
# dis_mod:2.25428640975 billion m3/year
# ibt: 22.802130423 billion m3/year
# availability:2.25428640975 billion m3/year
# new_mpcy: 7501.448053914383
# ava_int: 25.05641683275 billion m3/year
# mpcy_int: 83378.6729473052
# --------------------------------------
# int_runout > prf_runout
# city_num: 1656
# dis_els:0.0 billion m3/year
# dis_mod:35.8372452695 billion m3/year
# ibt: 0.0 billion m3/year
# availability:35.8372452695 billion m3/year
# new_mpcy: 100446.04990333269
# ava_int: 35.8372452695 billion m3/year
# mpcy_int: 100446.04990333269
# --------------------------------------
# int_runout > prf_runout
# city_num: 1697
# dis_els:0.0 billion m3/year
# dis_mod:11.6460999315 billion m3/year
# ibt: 0.0 billion m3/year
# availability:11.6460999315 billion m3/year
# new_mpcy: 37902.003102943585
# ava_int: 11.6460999315 billion m3/year
# mpcy_int: 37902.003102943585
# --------------------------------------
# int_runout > prf_runout
# city_num: 1712
# dis_els:0.0 billion m3/year
# dis_mod:87.885802903 billion m3/year
# ibt: 0.0 billion m3/year
# availability:87.885802903 billion m3/year
# new_mpcy: 244640.59328107437
# ava_int: 87.885802903 billion m3/year
# mpcy_int: 244640.59328107437
# --------------------------------------
# int_runout > prf_runout
# city_num: 1718
# dis_els:0.05782613345507812 billion m3/year
# dis_mod:1.4379682572421875 billion m3/year
# ibt: 0.0 billion m3/year
# availability:1.4957943906972657 billion m3/year
# new_mpcy: 5060.309874765963
# ava_int: 1.4957943906972657 billion m3/year
# mpcy_int: 5060.309874765963
# --------------------------------------
# int_runout > prf_runout
# city_num: 1824
# dis_els:0.0 billion m3/year
# dis_mod:22.105640124 billion m3/year
# ibt: 0.0 billion m3/year
# availability:22.105640124 billion m3/year
# ...
# **********rivnum1471.0: discharge done***************
# --------------------------------------
# city_num: 121, flag: False, uup: [178], flg_lst: ['Done'],
# dem: 1.3736, ava: 13.3598, upstream_dem: 0.0604, ava_mod: 13.2994
# city_num: 178, flag: Done, uup: [], flg_lst: [],
# dem: 0.0604, ava: 10.2455, upstream_dem: 0.0, ava_mod: 10.2455
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# city_num: 121, flag: Done, uup: [178], flg_lst: ['Done'],
# dem: 1.3736, ava: 13.2994, upstream_dem: 0.0, ava_mod: 13.2994
# city_num: 178, flag: Done, uup: [], flg_lst: [],
# dem: 0.0604, ava: 10.2455, upstream_dem: 0.0, ava_mod: 10.2455
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# ********** explore all done ***************
# city_num: 121
# dis_els:2.226533005125 billion m3/year
# dis_mod:13.299402533306113 billion m3/year
# ibt: 0.0 billion m3/year
# availability:15.525935538431112 billion m3/year
# new_mpcy: 9290.759408548562
# ava_int: 15.525935538431112 billion m3/year
# mpcy_int: 9290.759408548562
# --------------------------------------
# city_num: 178
# dis_els:105.1814295 billion m3/year
# dis_mod:10.2454738245 billion m3/year
# ibt: 0.0 billion m3/year
# availability:115.4269033245 billion m3/year
# new_mpcy: 50533.29016290561
# ava_int: 115.4269033245 billion m3/year
# mpcy_int: 50533.29016290561
# --------------------------------------
# **********rivnum1471.0: update done***************
# uid: 203.0
# city_list: [123, 239, 605, 660, 810, 1078, 1455, 1591]
# city_num, riv_num, 239, 203
# city_num: 239, prf: 2.21159257875, int: 2.1424484205
# city_num: 239, PRF > int
# city_num: 239, riv_num: 203.0
# rate 1.0
# discharge 2.21159257875
# supply: 2.21159257875
# demand: 1.752767375
# --------------------------------------
# city_num, riv_num, 660, 203
# INT only
# city_num: 660, riv_num: 203.0
# rate 0.9967244267463684
# discharge 9.521926623
# supply: 9.521926623
# demand: 0.6141644605600275
# --------------------------------------
# **********rivnum203.0: discharge done***************
# --------------------------------------
# city_num: 239, flag: Done, uup: [], flg_lst: [],
# dem: 1.7528, ava: 2.2116, upstream_dem: 0.0, ava_mod: 2.2116
# city_num: 660, flag: False, uup: [239], flg_lst: ['Done'],
# dem: 0.6142, ava: 9.5219, upstream_dem: 1.7528, ava_mod: 7.7692
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# city_num: 239, flag: Done, uup: [], flg_lst: [],
# dem: 1.7528, ava: 2.2116, upstream_dem: 0.0, ava_mod: 2.2116
# city_num: 660, flag: Done, uup: [239], flg_lst: ['Done'],
# dem: 0.6142, ava: 7.7692, upstream_dem: 0.0, ava_mod: 7.7692
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# ********** explore all done ***************
# prf_runout > int_runout
# city_num: 239
# dis_els:0.0 billion m3/year
# dis_mod:2.21159257875 billion m3/year
# ibt: 0.0 billion m3/year
# availability:2.21159257875 billion m3/year
# new_mpcy: 1261.7718758885503
# ava_int: 2.21159257875 billion m3/year
# mpcy_int: 1261.7718758885503
# --------------------------------------
# city_num: 660
# dis_els:0.026678549416992187 billion m3/year
# dis_mod:7.769159248 billion m3/year
# ibt: 0.0 billion m3/year
# availability:7.795837797416993 billion m3/year
# new_mpcy: 12651.826112752848
# ava_int: 7.795837797416993 billion m3/year
# mpcy_int: 12651.826112752848
# --------------------------------------
# **********rivnum203.0: update done***************
# uid: 948.0
# city_list: [124, 379, 768, 793]
# city_num, riv_num, 124, 948
# INT only
# city_num: 124, riv_num: 948.0
# rate 0.984443724155426
# discharge 6.18915730275
# supply: 6.18915730275
# demand: 3.0015536560721694
# --------------------------------------
# city_num, riv_num, 379, 948
# INT only
# city_num: 379, riv_num: 948.0
# rate 0.6453084349632263
# discharge 6.94111548375
# supply: 6.94111548375
# demand: 0.8870279878681973
# --------------------------------------
# city_num, riv_num, 793, 948
# city_num: 793, prf: 0.2047807560234375, int: 0.4575322951875
# city_num: 793, INT > prf
# city_num: 793, riv_num: 948.0
# rate 1.0
# discharge 0.4575322951875
# supply: 0.4575322951875
# demand: 0.5977273125
# --------------------------------------
# **********rivnum948.0: discharge done***************
# --------------------------------------
# city_num: 124, flag: False, uup: [793], flg_lst: ['Done'],
# dem: 3.0016, ava: 6.1892, upstream_dem: 0.4575, ava_mod: 5.7316
# city_num: 379, flag: True, uup: [124 793], flg_lst: ['Done', 'Done'],
# dem: 0.887, ava: 6.9411, upstream_dem: 3.4591, ava_mod: 3.482
# city_num: 793, flag: Done, uup: [], flg_lst: [],
# dem: 0.5977, ava: 0.4575, upstream_dem: 0.0, ava_mod: 0.4575
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# city_num: 124, flag: Done, uup: [793], flg_lst: ['Done'],
# dem: 3.0016, ava: 5.7316, upstream_dem: 0.0, ava_mod: 5.7316
# city_num: 379, flag: Done, uup: [124 793], flg_lst: ['Done', 'Done'],
# dem: 0.887, ava: 3.482, upstream_dem: 0.0, ava_mod: 3.482
# city_num: 793, flag: Done, uup: [], flg_lst: [],
# dem: 0.5977, ava: 0.4575, upstream_dem: 0.0, ava_mod: 0.4575
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# ********** explore all done ***************
# city_num: 124
# dis_els:0.033391176802734374 billion m3/year
# dis_mod:5.7316250075625 billion m3/year
# ibt: 0.0 billion m3/year
# availability:5.765016184365234 billion m3/year
# new_mpcy: 1890.7987837803814
# ava_int: 5.765016184365234 billion m3/year
# mpcy_int: 1890.7987837803814
# --------------------------------------
# city_num: 379
# dis_els:2.470072721625 billion m3/year
# dis_mod:3.4820295324903308 billion m3/year
# ibt: 0.0 billion m3/year
# availability:5.952102254115331 billion m3/year
# new_mpcy: 4330.124689273027
# ava_int: 5.952102254115331 billion m3/year
# mpcy_int: 4330.124689273027
# --------------------------------------
# int_runout > prf_runout
# city_num: 793
# dis_els:0.0 billion m3/year
# dis_mod:0.4575322951875 billion m3/year
# ibt: 0.0 billion m3/year
# availability:0.4575322951875 billion m3/year
# new_mpcy: 765.4532185820102
# ava_int: 0.4575322951875 billion m3/year
# mpcy_int: 765.4532185820102
# --------------------------------------
# **********rivnum948.0: update done***************
# uid: 1829.0
# city_list: [126, 874]
# **********rivnum1829.0: discharge done***************
# --------------------------------------
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# ********** explore all done ***************
# **********rivnum1829.0: update done***************
# uid: 243.0
# city_list: [127, 405, 1020, 1165, 1460, 1480, 1778]
# city_num, riv_num, 127, 243
# city_num: 127, prf: 38.86293627, int: 3.5124905205
# city_num: 127, PRF > int
# city_num: 127, riv_num: 243.0
# rate 1.0
# discharge 38.86293627
# supply: 38.86293627
# demand: 3.01129725
# --------------------------------------
# city_num, riv_num, 405, 243
# INT only
# city_num: 405, riv_num: 243.0
# rate 0.9794174432754517
# discharge 38.594080044
# supply: 38.594080044
# demand: 1.0766743299557864
# --------------------------------------
# city_num, riv_num, 1020, 243
# INT only
# city_num: 1020, riv_num: 243.0
# rate 0.9954590201377869
# discharge 37.320971724
# supply: 37.320971724
# demand: 0.5347892050648481
# --------------------------------------
# city_num, riv_num, 1165, 243
# city_num: 1165, prf: 17.626767318, int: 11.239990164
# city_num: 1165, PRF > int
# city_num: 1165, riv_num: 243.0
# rate 1.0
# discharge 17.626767318
# supply: 17.626767318
# demand: 0.3699914375
# --------------------------------------
# city_num, riv_num, 1460, 243
# city_num: 1460, prf: 6.6579088995, int: 4.63357117575
# city_num: 1460, PRF > int
# city_num: 1460, riv_num: 243.0
# rate 1.0
# discharge 6.6579088995
# supply: 6.6579088995
# demand: 0.3356648125
# --------------------------------------
# city_num, riv_num, 1480, 243
# INT only
# city_num: 1480, riv_num: 243.0
# rate 0.5539347529411316
# discharge 3.09711754575
# supply: 3.09711754575
# demand: 0.18291526215113885
# --------------------------------------
# city_num, riv_num, 1778, 243
# INT only
# city_num: 1778, riv_num: 243.0
# rate 0.9781637787818909
# discharge 3.09711754575
# supply: 3.09711754575
# demand: 0.26896826193157586
# --------------------------------------
# **********rivnum243.0: discharge done***************
# --------------------------------------
# city_num: 127, flag: True, uup: [ 405 1020 1165 1460 1480 1778], flg_lst: [True, True, False, 'Done', False, 'Done'],
# dem: 3.0113, ava: 38.8629, upstream_dem: 2.769, ava_mod: 36.0939
# city_num: 405, flag: True, uup: [1020 1165 1460 1480 1778], flg_lst: [True, False, 'Done', False, 'Done'],
# dem: 1.0767, ava: 38.5941, upstream_dem: 1.6923, ava_mod: 36.9018
# city_num: 1020, flag: True, uup: [1165 1460 1480 1778], flg_lst: [False, 'Done', False, 'Done'],
# dem: 0.5348, ava: 37.321, upstream_dem: 1.1575, ava_mod: 36.1634
# city_num: 1165, flag: False, uup: [1460], flg_lst: ['Done'],
# dem: 0.37, ava: 17.6268, upstream_dem: 0.3357, ava_mod: 17.2911
# city_num: 1460, flag: Done, uup: [], flg_lst: [],
# dem: 0.3357, ava: 6.6579, upstream_dem: 0.0, ava_mod: 6.6579
# city_num: 1480, flag: False, uup: [1778], flg_lst: ['Done'],
# dem: 0.1829, ava: 3.0971, upstream_dem: 0.269, ava_mod: 2.8281
# city_num: 1778, flag: Done, uup: [], flg_lst: [],
# dem: 0.269, ava: 3.0971, upstream_dem: 0.0, ava_mod: 3.0971
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# city_num: 127, flag: Done, uup: [ 405 1020 1165 1460 1480 1778], flg_lst: ['Done', 'Done', 'Done', 'Done', 'Done', 'Done'],
# dem: 3.0113, ava: 36.0939, upstream_dem: 0.0, ava_mod: 36.0939
# city_num: 405, flag: Done, uup: [1020 1165 1460 1480 1778], flg_lst: ['Done', 'Done', 'Done', 'Done', 'Done'],
# dem: 1.0767, ava: 36.9018, upstream_dem: 0.0, ava_mod: 36.9018
# city_num: 1020, flag: Done, uup: [1165 1460 1480 1778], flg_lst: ['Done', 'Done', 'Done', 'Done'],
# dem: 0.5348, ava: 36.1634, upstream_dem: 0.0, ava_mod: 36.1634
# city_num: 1165, flag: Done, uup: [1460], flg_lst: ['Done'],
# dem: 0.37, ava: 17.2911, upstream_dem: 0.0, ava_mod: 17.2911
# city_num: 1460, flag: Done, uup: [], flg_lst: [],
# dem: 0.3357, ava: 6.6579, upstream_dem: 0.0, ava_mod: 6.6579
# city_num: 1480, flag: Done, uup: [1778], flg_lst: ['Done'],
# dem: 0.1829, ava: 2.8281, upstream_dem: 0.0, ava_mod: 2.8281
# city_num: 1778, flag: Done, uup: [], flg_lst: [],
# dem: 0.269, ava: 3.0971, upstream_dem: 0.0, ava_mod: 3.0971
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# ********** explore all done ***************
# prf_runout > int_runout
# city_num: 127
# dis_els:0.0 billion m3/year
# dis_mod:36.093932960896645 billion m3/year
# ibt: 0.0 billion m3/year
# availability:36.093932960896645 billion m3/year
# new_mpcy: 11986.174052029119
# ava_int: 36.093932960896645 billion m3/year
# mpcy_int: 11986.174052029119
# --------------------------------------
# city_num: 405
# dis_els:0.45282252909375 billion m3/year
# dis_mod:36.901751064852434 billion m3/year
# ibt: 0.0 billion m3/year
# availability:37.354573593946185 billion m3/year
# new_mpcy: 33980.30392860751
# ava_int: 37.354573593946185 billion m3/year
# mpcy_int: 33980.30392860751
# --------------------------------------
# city_num: 1020
# dis_els:0.09456596996484375 billion m3/year
# dis_mod:36.16343194991728 billion m3/year
# ibt: 0.0 billion m3/year
# availability:36.25799791988213 billion m3/year
# new_mpcy: 67490.79962656899
# ava_int: 36.25799791988213 billion m3/year
# mpcy_int: 67490.79962656899
# --------------------------------------
# prf_runout > int_runout
# city_num: 1165
# dis_els:0.0 billion m3/year
# dis_mod:17.2911025055 billion m3/year
# ibt: 0.0 billion m3/year
# availability:17.2911025055 billion m3/year
# new_mpcy: 46733.79098266294
# ava_int: 17.2911025055 billion m3/year
# mpcy_int: 46733.79098266294
# --------------------------------------
# prf_runout > int_runout
# city_num: 1460
# dis_els:0.0 billion m3/year
# dis_mod:6.6579088995 billion m3/year
# ibt: 0.0 billion m3/year
# availability:6.6579088995 billion m3/year
# new_mpcy: 19834.99208604119
# ava_int: 6.6579088995 billion m3/year
# mpcy_int: 19834.99208604119
# --------------------------------------
# city_num: 1480
# dis_els:2.7945084375 billion m3/year
# dis_mod:2.828149283818424 billion m3/year
# ibt: 0.0 billion m3/year
# availability:5.622657721318424 billion m3/year
# new_mpcy: 17027.477527586263
# ava_int: 5.622657721318424 billion m3/year
# mpcy_int: 17027.477527586263
# --------------------------------------
# city_num: 1778
# dis_els:0.07443131185546875 billion m3/year
# dis_mod:3.09711754575 billion m3/year
# ibt: 0.0 billion m3/year
# availability:3.171548857605469 billion m3/year
# new_mpcy: 11534.05309930568
# ava_int: 3.171548857605469 billion m3/year
# mpcy_int: 11534.05309930568
# --------------------------------------
# **********rivnum243.0: update done***************
# uid: 2370.0
# city_list: [128, 1691]
# city_num, riv_num, 128, 2370
# PRF only
# city_num: 128, riv_num: 2370.0
# rate 0.5522866249084473
# discharge 0.02771071053222656
# supply: 0.02771071053222656
# demand: 1.639812719617605
# --------------------------------------
# city_num, riv_num, 1691, 2370
# INT only
# city_num: 1691, riv_num: 2370.0
# rate 0.9659527540206909
# discharge 0.057313015171875
# supply: 0.057313015171875
# demand: 0.29214564878427984
# --------------------------------------
# **********rivnum2370.0: discharge done***************
# --------------------------------------
# city_num: 128, flag: Done, uup: [], flg_lst: [],
# dem: 1.6398, ava: 0.0277, upstream_dem: 0.0, ava_mod: 0.0277
# city_num: 1691, flag: False, uup: [128], flg_lst: ['Done'],
# dem: 0.2921, ava: 0.0573, upstream_dem: 0.0277, ava_mod: 0.0296
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# city_num: 128, flag: Done, uup: [], flg_lst: [],
# dem: 1.6398, ava: 0.0277, upstream_dem: 0.0, ava_mod: 0.0277
# city_num: 1691, flag: Done, uup: [128], flg_lst: ['Done'],
# dem: 0.0296, ava: 0.0296, upstream_dem: 0.0, ava_mod: 0.0296
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# ********** explore all done ***************
# city_num: 128
# dis_els:0.014941798760742187 billion m3/year
# dis_mod:0.02771071053222656 billion m3/year
# ibt: 0.11244569628515624 billion m3/year
# availability:0.04265250929296875 billion m3/year
# new_mpcy: 14.365305329978847
# ava_int: 0.155098205578125 billion m3/year
# mpcy_int: 52.23685818711924
# --------------------------------------
# city_num: 1691
# dis_els:0.0021584846381835937 billion m3/year
# dis_mod:0.029602304639648438 billion m3/year
# ibt: 0.0 billion m3/year
# availability:0.03176078927783203 billion m3/year
# new_mpcy: 105.01413250705764
# ava_int: 0.03176078927783203 billion m3/year
# mpcy_int: 105.01413250705764
# --------------------------------------
# **********rivnum2370.0: update done***************
# uid: 4555.0
# city_list: [128]
# **********rivnum4555.0: discharge done***************
# --------------------------------------
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# ********** explore all done ***************
# **********rivnum4555.0: update done***************
# uid: 9930.0
# city_list: [128]
# **********rivnum9930.0: discharge done***************
# --------------------------------------
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# ********** explore all done ***************
# **********rivnum9930.0: update done***************
# uid: 2360.0
# city_list: [129, 1045]

# %%
df_new.head(10)
# Out:
#    index   flag      rate        wup         pop           ava          mpcy  \
# 0      1  False  0.863325  36859.626  31821850.0  1.411216e+10    443.473949
# 1      2  False  1.003201  21987.895  22058268.0  1.804720e+10    818.160431
# 2      3  False  0.715760  20314.309  14540163.0  1.144393e+10    787.056548
# 3      4  False  1.002057  20136.681  20178100.0  3.006577e+08     14.900200
# 4      5  False  0.492121  19659.808   9675000.0  2.057520e+09    212.663566
# 5      6  False  0.489232  19312.646   9448362.0  1.272031e+10   1346.297983
# 6      7  False  0.470956  18365.262   8649229.0  2.462885e+10   2847.519617
# 7      8  False  0.783200  18257.413  14299211.0  9.254411e+09    647.197295
# 8      9  False  1.006426  16899.015  17007614.0  7.005016e+11  41187.531787
# 9     10  False  0.823952  16441.252  13546804.0  7.257918e+08     53.576609
#
#    potential            region                   country  \
# 0       93.0      eastern asia                     Japan
# 1       39.0     southern asia                     India
# 2       17.0      eastern asia                     China
# 3       43.0   central america                    Mexico
# 4       11.0     south america                    Brazil
# 5       24.0      eastern asia                     Japan
# 6       17.0  northern america  United States of America
# 7       12.0     southern asia                     India
# 8       24.0   northern africa                     Egypt
# 9       24.0      eastern asia                     China
#
#                          cityname         12region       ava_int      mpcy_int
# 0                           Tokyo        East Asia  1.740792e+10    547.043103
# 1                           Delhi       South Asia  1.804720e+10    818.160431
# 2                        Shanghai        East Asia  1.167569e+10    802.995767
# 3  Ciudad de México (Mexico City)  Central America  2.428206e+09    120.338678
# 4                       São Paulo    South America  2.057520e+09    212.663566
# 5            Kinki M.M.A. (Osaka)        East Asia  1.515035e+10   1603.489808
# 6                 New York-Newark    North America  2.462885e+10   2847.519617
# 7                 Mumbai (Bombay)       South Asia  1.505662e+10   1052.968744
# 8              Al-Qahirah (Cairo)  Northern Africa  7.005016e+11  41187.531787
# 9                         Beijing        East Asia  7.257918e+08     53.576609

# %%
import pdb
#pdb.set_trace()

def int_update(df_new, distance=100):
    # ava_intが更新されなかった都市=上下流の干渉が存在しない都市
    nan_indexes = df_new[df_new['ava_int'].isna()]['index'].tolist()
    
    # intakeがprfと同じ流域に存在するときprf_intをabandonするべきだろうか？ → 条件を統一するためにabandonするものとする
    
    h08dir = '/mnt/c/Users/tsimk/Downloads/dotfiles/h08'
    rivnum_path = f'{h08dir}/global_city/dat/riv_num_/rivnum.CAMA.gl5'
    rivout_path = f'{h08dir}/wsi/dat/riv_out_/W5E5LR__00000000.gl5'
    overlap_path = f'{h08dir}/global_city/dat/cty_lst_/gpw4/overlap_hidden_only.txt'
    prf_dir = f'{h08dir}/global_city/dat/cty_prf_'
    int_dir = f'{h08dir}/global_city/dat/cty_int_/{distance}km_samebasin'
    
    rivnum_gl5 = np.fromfile(rivnum_path, dtype='float32').reshape(2160, 4320)
    rivout_gl5 = np.fromfile(rivout_path, dtype='float32').reshape(2160, 4320)
    
    with open(overlap_path, 'r') as f:
        numbers = [int(line.strip()) for line in f]
    
    nan_list_removed = [num for num in nan_indexes if num not in numbers]
    nan_list_removed = [int(i) for i in nan_list_removed]

    for city_num in nan_list_removed:
    
        prf_path = f'{prf_dir}/vld_cty_/city_{city_num:08}.gl5'
        int_path = f'{int_dir}/city_{city_num:08}.gl5'
    
        if not os.path.exists(prf_path):
            print(f'{city_num} is invalid prf')

        else:
            prf = np.fromfile(prf_path, dtype='float32').reshape(2160, 4320)
            intake = np.fromfile(int_path, dtype='float32').reshape(2160, 4320)
            
            int_rivnum = rivnum_gl5[intake==1]
            
            if int_rivnum.size != 0:
                
                int_rivnum = rivnum_gl5[intake==1][0]
                
                flag, largest, all_int = prf_int_flag(prf, intake, int_rivnum, rivnum_gl5, rivout_gl5)

                # intakeと同じrivnumのprf
                dis_prf = np.sum(rivout_gl5[prf==1])* 60 * 60 * 24 * 365 / (1000) # m3/year
                # intakeと違うrivnumのprf
                els_prf = np.sum(rivout_gl5[(prf==1) & (rivnum_gl5!=int_rivnum)])* 60 * 60 * 24 * 365 / (1000) # m3/year
                # intake
                dis_int = np.sum(rivout_gl5[intake==1])*60*60*24*365/1000 # m3/year

                if not df_new[df_new['index'] == int(city_num)].empty:
                    
                    if flag == 'both-prf':
                        availability = dis_prf
                        ibt = 0
                    if flag == 'both-intake':
                        availability = els_prf
                        ibt = dis_int
                    if flag == 'prf':
                        availability = dis_prf
                        ibt = dis_int
                    if flag == 'intake':
                        availability = els_prf
                        ibt = dis_int
                else:
                    print(f"No matching index found for city_num: {city_num}")

            # intakeが存在しない場合
            else:
                
                availability = np.sum(rivout_gl5[prf==1])* 60 * 60 * 24 * 365 / (1000) # m3/year
                ibt = 0

            ava_int = availability + ibt
            mpcy_int = (availability+ibt)/float(df_new.loc[df_new['index'] == int(city_num), 'pop'])
            df_new.loc[df_new['index'] == int(city_num), 'ava_int'] = ava_int
            df_new.loc[df_new['index'] == int(city_num), 'mpcy_int'] = mpcy_int
            print(f'city_num: {city_num}, ava: {availability/1e9}, ava_int: {ava_int/1e9}, mpcy_int: {mpcy_int}')

    return df_new

df_new = int_update(df_new)
df_new.head(10)
# Out:
# 152 is invalid prf
# 168 is invalid prf
# 174 is invalid prf
# 225 is invalid prf
# 237 is invalid prf
# 273 is invalid prf
# 278 is invalid prf
# 285 is invalid prf
# 323 is invalid prf
# 393 is invalid prf
# 409 is invalid prf
# 412 is invalid prf
# 415 is invalid prf
# 422 is invalid prf
# 436 is invalid prf
# 449 is invalid prf
# 465 is invalid prf
# 471 is invalid prf
# 474 is invalid prf
# 494 is invalid prf
# 500 is invalid prf
# 528 is invalid prf
# 538 is invalid prf
# 544 is invalid prf
# 551 is invalid prf
# 552 is invalid prf
# 555 is invalid prf
# 562 is invalid prf
# 565 is invalid prf
# 572 is invalid prf
# 574 is invalid prf
# 581 is invalid prf
# 604 is invalid prf
# 614 is invalid prf
# 623 is invalid prf
# 636 is invalid prf
# 638 is invalid prf
# 675 is invalid prf
# 682 is invalid prf
# 684 is invalid prf
# 687 is invalid prf
# 702 is invalid prf
# 704 is invalid prf
# 728 is invalid prf
# 744 is invalid prf
# 755 is invalid prf
# 761 is invalid prf
# 769 is invalid prf
# 780 is invalid prf
# 809 is invalid prf
# 814 is invalid prf
# 823 is invalid prf
# 840 is invalid prf
# 844 is invalid prf
# 845 is invalid prf
# 856 is invalid prf
# 857 is invalid prf
# 860 is invalid prf
# 862 is invalid prf
# 863 is invalid prf
# 884 is invalid prf
# 890 is invalid prf
# 893 is invalid prf
# 896 is invalid prf
# 901 is invalid prf
# 902 is invalid prf
# 913 is invalid prf
# 916 is invalid prf
# 922 is invalid prf
# 927 is invalid prf
# 930 is invalid prf
# 932 is invalid prf
# 948 is invalid prf
# 956 is invalid prf
# 958 is invalid prf
# 963 is invalid prf
# 966 is invalid prf
# 973 is invalid prf
# 993 is invalid prf
# 996 is invalid prf
# 999 is invalid prf
# 1002 is invalid prf
# 1004 is invalid prf
# 1005 is invalid prf
# 1007 is invalid prf
# 1010 is invalid prf
# 1014 is invalid prf
# 1015 is invalid prf
# 1017 is invalid prf
# 1019 is invalid prf
# 1024 is invalid prf
# 1025 is invalid prf
# 1031 is invalid prf
# 1033 is invalid prf
# 1037 is invalid prf
# 1038 is invalid prf
# 1042 is invalid prf
# 1049 is invalid prf
# 1054 is invalid prf
# 1055 is invalid prf
# 1062 is invalid prf
# 1068 is invalid prf
# 1071 is invalid prf
# 1072 is invalid prf
# 1077 is invalid prf
# 1084 is invalid prf
# 1099 is invalid prf
# 1105 is invalid prf
# 1107 is invalid prf
# 1114 is invalid prf
# 1120 is invalid prf
# 1122 is invalid prf
# 1132 is invalid prf
# 1137 is invalid prf
# 1139 is invalid prf
# 1140 is invalid prf
# 1141 is invalid prf
# 1146 is invalid prf
# 1147 is invalid prf
# 1152 is invalid prf
# 1162 is invalid prf
# 1164 is invalid prf
# 1166 is invalid prf
# 1167 is invalid prf
# 1170 is invalid prf
# 1188 is invalid prf
# 1193 is invalid prf
# 1201 is invalid prf
# 1206 is invalid prf
# 1210 is invalid prf
# 1213 is invalid prf
# 1215 is invalid prf
# 1218 is invalid prf
# 1231 is invalid prf
# 1237 is invalid prf
# 1241 is invalid prf
# 1244 is invalid prf
# 1252 is invalid prf
# 1259 is invalid prf
# 1262 is invalid prf
# 1270 is invalid prf
# 1271 is invalid prf
# 1278 is invalid prf
# 1286 is invalid prf
# 1291 is invalid prf
# 1294 is invalid prf
# 1301 is invalid prf
# 1303 is invalid prf
# 1304 is invalid prf
# 1314 is invalid prf
# 1315 is invalid prf
# 1317 is invalid prf
# 1323 is invalid prf
# 1331 is invalid prf
# 1340 is invalid prf
# 1344 is invalid prf
# 1350 is invalid prf
# 1351 is invalid prf
# 1363 is invalid prf
# 1370 is invalid prf
# 1372 is invalid prf
# 1374 is invalid prf
# 1377 is invalid prf
# 1383 is invalid prf
# 1386 is invalid prf
# 1388 is invalid prf
# 1389 is invalid prf
# 1396 is invalid prf
# 1401 is invalid prf
# 1403 is invalid prf
# 1404 is invalid prf
# 1407 is invalid prf
# 1415 is invalid prf
# 1433 is invalid prf
# 1443 is invalid prf
# 1446 is invalid prf
# 1447 is invalid prf
# 1451 is invalid prf
# 1454 is invalid prf
# 1456 is invalid prf
# 1461 is invalid prf
# 1464 is invalid prf
# 1466 is invalid prf
# 1468 is invalid prf
# 1471 is invalid prf
# 1472 is invalid prf
# 1475 is invalid prf
# 1482 is invalid prf
# 1483 is invalid prf
# city_num: 1485, ava: 0.059218829736328124, ava_int: 0.059218829736328124, mpcy_int: 176.8713242373216
# 1486 is invalid prf
# int_runout > prf_runout
# city_num: 1487, ava: 0.525142153125, ava_int: 0.525142153125, mpcy_int: 1963.0301331169912
# 1488 is invalid prf
# 1490 is invalid prf
# int_runout > prf_runout
# city_num: 1492, ava: 4.000192543125, ava_int: 4.000192543125, mpcy_int: 12374.37581335854
# 1499 is invalid prf
# int_runout > prf_runout
# city_num: 1500, ava: 12.956354703, ava_int: 12.956354703, mpcy_int: 40137.94625837689
# 1503 is invalid prf
# 1504 is invalid prf
# 1507 is invalid prf
# city_num: 1511, ava: 10.984982184, ava_int: 38.411868978, mpcy_int: 119159.11826000012
# city_num: 1513, ava: 0.062191174728515625, ava_int: 0.3372292266503906, mpcy_int: 1063.5561501283944
# 1516 is invalid prf
# 1517 is invalid prf
# 1526 is invalid prf
# city_num: 1527, ava: 0.021368661943359374, ava_int: 0.5323783755058594, mpcy_int: 1687.8777554843296
# 1532 is invalid prf
# 1537 is invalid prf
# prf_runout > int_runout
# city_num: 1538, ava: 0.8131260718125, ava_int: 0.8131260718125, mpcy_int: 2592.3195608484943
# city_num: 1540, ava: 0.092580549328125, ava_int: 6.257111685328125, mpcy_int: 31766.896397143213
# 1542 is invalid prf
# city_num: 1545, ava: 45.030132198, ava_int: 51.3060258195, mpcy_int: 161805.53076388154
# city_num: 1552, ava: 0.0596455396875, ava_int: 1.3889016135, mpcy_int: 4492.577304731692
# 1553 is invalid prf
# city_num: 1556, ava: 0.0022817344537353515, ava_int: 0.013091358661743165, mpcy_int: 52.17789750000187
# 1557 is invalid prf
# 1558 is invalid prf
# 1559 is invalid prf
# prf_runout > int_runout
# city_num: 1564, ava: 31.326368382, ava_int: 31.326368382, mpcy_int: 102758.87829847587
# 1566 is invalid prf
# 1567 is invalid prf
# city_num: 1569, ava: 0.01487843996484375, ava_int: 0.8141682149648437, mpcy_int: 2731.0324162247966
# 1570 is invalid prf
# 1571 is invalid prf
# 1572 is invalid prf
# 1580 is invalid prf
# 1583 is invalid prf
# 1586 is invalid prf
# 1587 is invalid prf
# 1592 is invalid prf
# 1594 is invalid prf
# 1595 is invalid prf
# 1596 is invalid prf
# 1599 is invalid prf
# city_num: 1602, ava: 0.004248557386962891, ava_int: 0.006772636059082031, mpcy_int: 22.01181576571995
# city_num: 1603, ava: 2.66300282475, ava_int: 7.100706861, mpcy_int: 23402.38198031182
# 1604 is invalid prf
# 1606 is invalid prf
# 1607 is invalid prf
# 1613 is invalid prf
# 1614 is invalid prf
# city_num: 1615, ava: 1.47990120525, ava_int: 12.59497037475, mpcy_int: 42201.9196549118
# 1616 is invalid prf
# 1618 is invalid prf
# 1619 is invalid prf
# 1622 is invalid prf
# city_num: 1629, ava: 0.05975453752734375, ava_int: 8.375185742027345, mpcy_int: 27682.07181921973
# 1631 is invalid prf
# 1632 is invalid prf
# 1633 is invalid prf
# 1634 is invalid prf
# 1637 is invalid prf
# 1641 is invalid prf
# int_runout > prf_runout
# city_num: 1642, ava: 0.67154587734375, ava_int: 0.67154587734375, mpcy_int: 2136.672903672146
# 1645 is invalid prf
# 1647 is invalid prf
# 1662 is invalid prf
# 1663 is invalid prf
# 1666 is invalid prf
# 1669 is invalid prf
# 1670 is invalid prf
# 1674 is invalid prf
# 1685 is invalid prf
# int_runout > prf_runout
# city_num: 1688, ava: 2.706921878625, ava_int: 2.706921878625, mpcy_int: 9360.812000824326
# 1693 is invalid prf
# 1698 is invalid prf
# city_num: 1701, ava: 0.0188386178203125, ava_int: 1.2303733905703125, mpcy_int: 4339.030273983472
# 1711 is invalid prf
# 1713 is invalid prf
# 1714 is invalid prf
# 1716 is invalid prf
# city_num: 1719, ava: 0.079416671484375, ava_int: 2.131920477984375, mpcy_int: 7579.742287093448
# 1722 is invalid prf
# 1723 is invalid prf
# 1724 is invalid prf
# 1725 is invalid prf
# 1727 is invalid prf
# 1728 is invalid prf
# 1732 is invalid prf
# 1734 is invalid prf
# 1736 is invalid prf
# 1737 is invalid prf
# 1738 is invalid prf
# 1740 is invalid prf
# city_num: 1741, ava: 0.00014550640734100343, ava_int: 0.009404241373649596, mpcy_int: 45.4766630645467
# city_num: 1743, ava: 0.04643065451953125, ava_int: 0.06458636318554688, mpcy_int: 227.29397101010568
# 1745 is invalid prf
# 1746 is invalid prf
# 1748 is invalid prf
# 1749 is invalid prf
# 1752 is invalid prf
# 1757 is invalid prf
# 1759 is invalid prf
# 1760 is invalid prf
# 1767 is invalid prf
# 1768 is invalid prf
# city_num: 1771, ava: 1.5971398576875, ava_int: 8.8024930216875, mpcy_int: 32168.50801226945
# 1772 is invalid prf
# 1773 is invalid prf
# prf_runout > int_runout
# city_num: 1774, ava: 0.3403551133125, ava_int: 0.3403551133125, mpcy_int: 1285.1695752426856
# 1775 is invalid prf
# 1776 is invalid prf
# 1777 is invalid prf
# 1782 is invalid prf
# city_num: 1786, ava: 0.9402127025625, ava_int: 13.5933783305625, mpcy_int: 52069.20684495371
# 1787 is invalid prf
# 1790 is invalid prf
# 1791 is invalid prf
# int_runout > prf_runout
# city_num: 1792, ava: 0.03877976761523438, ava_int: 0.03877976761523438, mpcy_int: 154.33186221474563
# 1793 is invalid prf
# 1796 is invalid prf
# 1797 is invalid prf
# 1799 is invalid prf
# 1801 is invalid prf
# city_num: 1802, ava: 0.165438687515625, ava_int: 11.623000643015626, mpcy_int: 46747.57448348713
# 1806 is invalid prf
# 1807 is invalid prf
# 1810 is invalid prf
# city_num: 1812, ava: 0.717544521, ava_int: 7.9311768705, mpcy_int: 30317.342343408825
# 1814 is invalid prf
# 1815 is invalid prf
# 1816 is invalid prf
# 1817 is invalid prf
# 1820 is invalid prf
# 1823 is invalid prf
# 1830 is invalid prf
# 1832 is invalid prf
# 1839 is invalid prf
# 1841 is invalid prf
# int_runout > prf_runout
# city_num: 1846, ava: 0.0788507019140625, ava_int: 0.0788507019140625, mpcy_int: 357.2883962662902
# 1847 is invalid prf
# 1849 is invalid prf
# 1850 is invalid prf
# 1851 is invalid prf
# 1855 is invalid prf
# int_runout > prf_runout
# city_num: 1856, ava: 0.40414474209375, ava_int: 0.40414474209375, mpcy_int: 2494.0203897227543
# 1858 is invalid prf
# 1859 is invalid prf
# 1860 is invalid prf
#    index   flag      rate        wup         pop           ava          mpcy  \
# 0      1  False  0.863325  36859.626  31821850.0  1.411216e+10    443.473949
# 1      2  False  1.003201  21987.895  22058268.0  1.804720e+10    818.160431
# 2      3  False  0.715760  20314.309  14540163.0  1.144393e+10    787.056548
# 3      4  False  1.002057  20136.681  20178100.0  3.006577e+08     14.900200
# 4      5  False  0.492121  19659.808   9675000.0  2.057520e+09    212.663566
# 5      6  False  0.489232  19312.646   9448362.0  1.272031e+10   1346.297983
# 6      7  False  0.470956  18365.262   8649229.0  2.462885e+10   2847.519617
# 7      8  False  0.783200  18257.413  14299211.0  9.254411e+09    647.197295
# 8      9  False  1.006426  16899.015  17007614.0  7.005016e+11  41187.531787
# 9     10  False  0.823952  16441.252  13546804.0  7.257918e+08     53.576609
#
#    potential            region                   country  \
# 0       93.0      eastern asia                     Japan
# 1       39.0     southern asia                     India
# 2       17.0      eastern asia                     China
# 3       43.0   central america                    Mexico
# 4       11.0     south america                    Brazil
# 5       24.0      eastern asia                     Japan
# 6       17.0  northern america  United States of America
# 7       12.0     southern asia                     India
# 8       24.0   northern africa                     Egypt
# 9       24.0      eastern asia                     China
#
#                          cityname         12region       ava_int      mpcy_int
# 0                           Tokyo        East Asia  1.740792e+10    547.043103
# 1                           Delhi       South Asia  1.804720e+10    818.160431
# 2                        Shanghai        East Asia  1.167569e+10    802.995767
# 3  Ciudad de México (Mexico City)  Central America  2.428206e+09    120.338678
# 4                       São Paulo    South America  2.057520e+09    212.663566
# 5            Kinki M.M.A. (Osaka)        East Asia  1.515035e+10   1603.489808
# 6                 New York-Newark    North America  2.462885e+10   2847.519617
# 7                 Mumbai (Bombay)       South Asia  1.505662e+10   1052.968744
# 8              Al-Qahirah (Cairo)  Northern Africa  7.005016e+11  41187.531787
# 9                         Beijing        East Asia  7.257918e+08     53.576609

# %%
############################################################
# バグがないか確認する(availabilityがnegativeになっていないか)
# NoMASKの部分がNaNになっている -> # global_city/dat/cty_lst_/gpw4/classification.txtをチェック
# Why delhi gets negative value?
###########################################################
df_new['ava'] = pd.to_numeric(df_new['ava'], errors='coerce')
df_filtered = df_new[df_new['flag'] != 'NoMASK']

# NaNが含まれていないか確認
if df_filtered['ava'].isna().any():
    print("▲ The 'ava' column contains non-numeric(NaN) values.")
    non_numeric_values = df_filtered[pd.to_numeric(df_filtered['ava'], errors='coerce').isna()]['ava']
    print("Non-numeric values in 'ava' column:", non_numeric_values)
else:
    if (df_filtered['ava'] >= 0).all():
        print("✓ The 'ava' column contains only non-negative values.")
    else:
        print("▲ The 'ava' column contains negative values.")
        negative_ava_rows = df_filtered[df_filtered['ava'] < 0]
        print(negative_ava_rows)
# Out:
# ✓ The 'ava' column contains only non-negative values.

# %%
######################################################
# 更新したupdown_pathをpandas dfとして保存
#####################################################
h08dir = '/mnt/c/Users/tsimk/Downloads/dotfiles/h08'
updown_path = f'{h08dir}/wsi/dat/availablewater/updown_availability_100km_abandon_revised.txt'
#df_new.to_csv(updown_path, sep='|', index=False)

# %%
######################################################
# 更新した pandas df_newを読み込み
#####################################################
import os
import json
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import cartopy.feature as cfeature
import numpy as np
import pandas as pd
import matplotlib.colors as mcolors

h08dir = '/mnt/c/Users/tsimk/Downloads/dotfiles/h08'
updown_path = f'{h08dir}/wsi/dat/availablewater/updown_availability_100km_abandon.txt'
df_new = pd.read_csv(updown_path, delimiter='|', header=None)
df_new.columns = df_new.iloc[0]
df_new = df_new[1:].reset_index(drop=True)
df_new = df_new.infer_objects()
df_new.head(60)
# Out:
# 0  index   flag                rate        wup          pop  \
# 0      1  False  0.8633253630951112  36859.626   31821850.0
# 1      2  False  1.0032005337482284  21987.895   22058268.0
# 2      3  False   0.715759664776193  20314.309   14540163.0
# 3      4  False  1.0020568930897795  20136.681   20178100.0
# 4      5  False  0.4921207775782957  19659.808    9675000.0
# 5      6  False  0.4892318742858954  19312.646    9448362.0
# 6      7  False  0.4709559275549676  18365.262    8649229.0
# 7      8  False  0.7832002814418451  18257.413   14299211.0
# 8      9  False   1.006426350884948  16899.015   17007614.0
# 9     10  False  0.8239520931860906  16441.252   13546804.0
# 10    11   True  1.0119829983116029  14730.537   14907053.0
# 11    12  False  0.9315084349703856  14245.871   13270149.0
# 12    13  False  1.0331027413235554  14002.798   14466329.0
# 13    14  False    0.92071970937979  12611.924   11612047.0
# 14    15  False  1.0015019604867268  12584.885   12603787.0
# 15    16  False  0.7696195471042075  12373.884    9523183.0
# 16    17  False  0.4335775929098249  12160.151    5272369.0
# 17    18  False   1.041864144668685  11887.189   12384836.0
# 18    19  False  1.0102298489939678  11461.264   11578511.0
# 19    20  False  0.4916269309647822  11243.667    5527689.5
# 20    21  False  0.8403992192057489  10460.118    8790675.0
# 21    22   True  0.8945989065222693  10441.182    9340670.0
# 22    23  False  1.0119857597592263  10278.197   10401389.0
# 23    24  False  0.6909698270043498  10222.916    7063726.5
# 24    25  False   0.574565944136773  10150.076    5831888.0
# 25    26  False   1.063070351350979   9796.045   10413885.0
# 26    27  False  1.0356745292932508   9625.579    9968967.0
# 27    28  False  0.7659907246820477   9381.673    7186274.5
# 28    29  False  0.7164658360857546    9098.05    6518442.0
# 29    30  False  0.9796170501916028   8919.759    8737948.0
# 30    31  False  0.5183694346943082   8615.834    4466185.0
# 31    32  False    1.00876714177541   8506.193    8580768.0
# 32    33  False   1.001565440389216   8432.132    8445332.0
# 33    34  False  0.4424308347702848   8417.705   3724252.25
# 34    35  False  1.0338988403922869   8295.564    8576774.0
# 35    36  False  1.0298641499713692   8269.045    8515993.0
# 36    37  False  1.0190929599976175    8058.52    8212381.0
# 37    38  False  1.0073848585723817   8044.433    8103840.0
# 38    39   True  1.0111772633137892   7573.276    7657924.5
# 39    40  False   1.009376411195262   7531.293    7601909.5
# 40    41  False  1.0018520783185076   7514.801    7528719.0
# 41    42  False  0.6923433744333355    7118.41    4928384.0
# 42    43   True   1.009708449029575   7025.221    7093425.0
# 43    44   True  1.0435752723849072   6653.177    6943091.0
# 44    45  False  1.0017787387168964    6269.33    6280481.5
# 45    46  False  0.9679737937728528   6249.507    6049359.0
# 46    47  False   1.042534054354482    6189.37    6452629.0
# 47    48  False  1.0049127325831515   6162.151    6192424.0
# 48    49  False  0.9791743994025698   5849.051    5727241.0
# 49    50  False   1.000669970996323   5809.953    5813845.5
# 50    51  False   1.004386431746804   5787.392    5812778.0
# 51    52  False  0.7968131126107992   5757.938    4588000.5
# 52    53  False  1.0143914507151357   5651.654    5732989.5
# 53    54  False  1.0117404177193612   5526.294    5591175.0
# 54    55   True  0.3391026902361057   5519.181  1871569.125
# 55    56   True   0.358337877735907   5517.777    1977228.5
# 56    57  False  0.4733568299433757   5499.233    2603099.5
# 57    58  False  0.6089069068495921   5449.069   3317975.75
# 58    59   True  0.8310512952952168   5409.346    4495444.0
# 59    60  False  0.6174516542507772   5300.466    3272781.5
#
# 0                  ava                mpcy potential              region  \
# 0   14112161485.204323   443.4739490382967      93.0        eastern asia
# 1       18047202063.75   818.1604314423055      39.0       southern asia
# 2   11443930498.423656   787.0565480196925      17.0        eastern asia
# 3   300657718.16015625   14.90019963029999      43.0     central america
# 4         2057520001.5  212.66356604651162      11.0       south america
# 5        12720310699.5  1346.2979826026988      24.0        eastern asia
# 6    24628849250.64195  2847.5196171406665      17.0    northern america
# 7         9254410677.0   647.1972948017901      12.0       southern asia
# 8    700501642238.4858   41187.53178655665      24.0     northern africa
# 9    725791815.0862871   53.57660855551517      24.0        eastern asia
# 10     476123903317.75   31939.50563654332      19.0       southern asia
# 11      701119069.3125    52.8343027129914      54.0       south america
# 12   39220930570.85817   2711.187514873896      13.0       southern asia
# 13      448872460.3125    38.6557564150834      37.0       southern asia
# 14   3525892712.239247  279.74867492121587      51.0        western asia
# 15  29676178577.659332  3116.2037501179316      26.0       south america
# 16   527815541.5739496  100.10974982478457      19.0    northern america
# 17   8109386319.546514   654.7835045653018      10.0  south-eastern asia
# 18       2374926392.25   205.1150093695122      29.0      eastern europe
# 19  146173505117.24008  26443.870466537617      16.0        eastern asia
# 20        9282066763.5   1055.899207228114      27.0      western europe
# 21       12616822868.5   1350.740671547116      18.0      western africa
# 22  185173857073.63306   17802.80086377243      16.0        eastern asia
# 23   40172667.92578125   5.687177713602197      11.0        eastern asia
# 24  2046155725.3583302   350.8564851311154      12.0        eastern asia
# 25  32044021539.449223  3077.0477626216557      11.0        eastern asia
# 26   6409502977.528599    642.945550680286       9.0  south-eastern asia
# 27  2890903914392.4976  402281.30923644756      30.0       middle africa
# 28  18149853421.337643  2784.3851983860013      37.0        eastern asia
# 29  2189784734.1210938  250.60629041522034      38.0       south america
# 30   455825696.0659025  102.06153485937158      26.0    northern america
# 31   6200912659.475761   722.6524082081885      18.0       southern asia
# 32  28358538616.275063  3357.8950615884683      33.0       southern asia
# 33      2782788625.125   747.2073421248521      12.0       south america
# 34   66633278.44482422   7.769037454504947      14.0       southern asia
# 35  190292794723.47192  22345.344192212455      15.0  south-eastern asia
# 36   508441700.7421875  61.911606480774275      28.0        western asia
# 37  2407281505.9191504  297.05442184435407      29.0     northern europe
# 38      10117007247.25  1321.1160866433197      20.0        eastern asia
# 39    299694276.421875    39.4235522564265      20.0       southern asia
# 40  420568121679.80597   55861.84338661145      25.0        eastern asia
# 41       22116841317.0  4487.6457104397705      12.0        eastern asia
# 42       36597897.5625    5.15941136510219       8.0        eastern asia
# 43   59324509.21289063   8.544394594985235       6.0        eastern asia
# 44     622449745.59375   99.10860267540792      34.0       south america
# 45  4058989905.2315516   670.9785128030179      11.0       southern asia
# 46    37060885630.8185   5743.532695095053       7.0  south-eastern asia
# 47   635224646936.3407  102580.93550059567      28.0        eastern asia
# 48  1385589849.2737272   241.9297265950092      23.0        eastern asia
# 49     31992557266.125   5502.822059190427      28.0  south-eastern asia
# 50      531696097.6875   91.47022261773975      40.0     southern europe
# 51   42175241296.43502   9192.510178766332      15.0        eastern asia
# 52      32627074511.25   5691.110111269173      28.0        western asia
# 53  12308073799.886679  2201.3393964393313      16.0        eastern asia
# 54  2409439302.8789062  1287.3899610194233      11.0        eastern asia
# 55   76105784.14453125   38.49114259911348      11.0    northern america
# 56   309366346218.4304  118845.37883336016      11.0    northern america
# 57  16743344061.611916   5046.252692356753      28.0    northern america
# 58    456132300.046875  101.46546148653503      18.0       south america
# 59       94479750972.0  28868.334464735883      35.0       middle africa
#
# 0                            country  \
# 0                              Japan
# 1                              India
# 2                              China
# 3                             Mexico
# 4                             Brazil
# 5                              Japan
# 6           United States of America
# 7                              India
# 8                              Egypt
# 9                              China
# 10                        Bangladesh
# 11                         Argentina
# 12                             India
# 13                          Pakistan
# 14                            Turkey
# 15                            Brazil
# 16          United States of America
# 17                       Philippines
# 18                Russian Federation
# 19                             China
# 20                            France
# 21                           Nigeria
# 22                             China
# 23                             China
# 24                             China
# 25                 Republic of Korea
# 26                         Indonesia
# 27  Democratic Republic of the Congo
# 28                             Japan
# 29                              Peru
# 30          United States of America
# 31                             India
# 32                          Pakistan
# 33                          Colombia
# 34                             India
# 35                          Thailand
# 36        Iran (Islamic Republic of)
# 37                    United Kingdom
# 38                             China
# 39                             India
# 40                             China
# 41                             China
# 42              China, Hong Kong SAR
# 43                             China
# 44                             Chile
# 45                             India
# 46                          Viet Nam
# 47                             China
# 48                             China
# 49                          Malaysia
# 50                             Spain
# 51                             China
# 52                              Iraq
# 53                             China
# 54                             Japan
# 55          United States of America
# 56                            Canada
# 57          United States of America
# 58                            Brazil
# 59                            Angola
#
# 0                                   cityname                       12region  \
# 0                                      Tokyo                      East Asia
# 1                                      Delhi                     South Asia
# 2                                   Shanghai                      East Asia
# 3             Ciudad de México (Mexico City)                Central America
# 4                                  São Paulo                  South America
# 5                       Kinki M.M.A. (Osaka)                      East Asia
# 6                            New York-Newark                  North America
# 7                            Mumbai (Bombay)                     South Asia
# 8                         Al-Qahirah (Cairo)                Northern Africa
# 9                                    Beijing                      East Asia
# 10                                     Dhaka                     South Asia
# 11                              Buenos Aires                  South America
# 12                        Kolkata (Calcutta)                     South Asia
# 13                                   Karachi                     South Asia
# 14                                  Istanbul                    Middle East
# 15                            Rio de Janeiro                  South America
# 16          Los Angeles-Long Beach-Santa Ana                  North America
# 17                                    Manila                 Southeast Asia
# 18                           Moskva (Moscow)  Eastern Europe & Central Asia
# 19                                 Chongqing                      East Asia
# 20                                     Paris                    West Europe
# 21                                     Lagos                Southern Africa
# 22                      Guangzhou, Guangdong                      East Asia
# 23                                  Shenzhen                      East Asia
# 24                                   Tianjin                      East Asia
# 25                                     Seoul                      East Asia
# 26                                   Jakarta                 Southeast Asia
# 27                                  Kinshasa                Southern Africa
# 28                    Chukyo M.M.A. (Nagoya)                      East Asia
# 29                                      Lima                  South America
# 30                                   Chicago                  North America
# 31                          Chennai (Madras)                     South Asia
# 32                                    Lahore                     South Asia
# 33                                    Bogotá                  South America
# 34                                 Bangalore                     South Asia
# 35                      Krung Thep (Bangkok)                 Southeast Asia
# 36                                    Tehran                    Middle East
# 37                                    London                    West Europe
# 38                                   Chengdu                      East Asia
# 39                                 Hyderabad                     South Asia
# 40                                     Wuhan                      East Asia
# 41                                  Dongguan                      East Asia
# 42                                 Hong Kong                      East Asia
# 43                                    Foshan                      East Asia
# 44                                  Santiago                  South America
# 45                                 Ahmadabad                     South Asia
# 46  Thành Pho Ho Chí Minh (Ho Chi Minh City)                 Southeast Asia
# 47                          Nanjing, Jiangsu                      East Asia
# 48                                  Shenyang                      East Asia
# 49                              Kuala Lumpur                 Southeast Asia
# 50                                    Madrid                    West Europe
# 51                                  Hangzhou                      East Asia
# 52                                   Baghdad                    Middle East
# 53                            Xi'an, Shaanxi                      East Asia
# 54                 Kitakyushu-Fukuoka M.M.A.                      East Asia
# 55                                     Miami                  North America
# 56                                   Toronto                  North America
# 57                              Philadelphia                  North America
# 58                            Belo Horizonte                  South America
# 59                                    Luanda                Southern Africa
#
# 0              ava_int            mpcy_int
# 0   17407923555.829323   547.0431026426597
# 1       18047202063.75   818.1604314423055
# 2   11675689347.743969   802.9957674988904
# 3   2428205871.4101562  120.33867764606957
# 4         2057520001.5  212.66356604651162
# 5       15150352164.75  1603.4898075190176
# 6    24628849250.64195  2847.5196171406665
# 7       15056622245.25  1052.9687438873375
# 8    700501642238.4858   41187.53178655665
# 9    725791815.0862871   53.57660855551517
# 10     476123903317.75   31939.50563654332
# 11    23537215735.3125  1773.6964170720692
# 12   39220930570.85817   2711.187514873896
# 13     826755105.65625   71.19805023664217
# 14   3525892712.239247  279.74867492121587
# 15  29676178577.659332  3116.2037501179316
# 16   527815541.5739496  100.10974982478457
# 17  24613146822.546513   1987.361546212361
# 18       2374926392.25   205.1150093695122
# 19  146173505117.24008  26443.870466537617
# 20       22632123789.0  2574.5604050883467
# 21       12616822868.5   1350.740671547116
# 22  185173857073.63306   17802.80086377243
# 23     65589059.390625   9.285333936786058
# 24  2046155725.3583302   350.8564851311154
# 25  32044021539.449223  3077.0477626216557
# 26   6409502977.528599    642.945550680286
# 27  2890903914392.4976  402281.30923644756
# 28  18149853421.337643  2784.3851983860013
# 29  2189784734.1210938  250.60629041522034
# 30   8340327808.315903   1867.438945837645
# 31   6200912659.475761   722.6524082081885
# 32  28358538616.275063  3357.8950615884683
# 33      2782788625.125   747.2073421248521
# 34   95420555.33642578  11.125459914931392
# 35  190292794723.47192  22345.344192212455
# 36   508441700.7421875  61.911606480774275
# 37  2407281505.9191504  297.05442184435407
# 38      10117007247.25  1321.1160866433197
# 39   4769863146.421875   627.4559235968114
# 40  420568121679.80597   55861.84338661145
# 41                 NaN                 NaN
# 42                 NaN                 NaN
# 43                 NaN                 NaN
# 44    1210357531.40625   192.7173149711929
# 45  22732478454.231552  3757.8325991615893
# 46    37060885630.8185   5743.532695095053
# 47   635224646936.3407  102580.93550059567
# 48   9701886322.773727  1693.9895357596663
# 49     31992557266.125   5502.822059190427
# 50      531696097.6875   91.47022261773975
# 51   42175241296.43502   9192.510178766332
# 52      32627074511.25   5691.110111269173
# 53  12308073799.886679  2201.3393964393313
# 54  2409439302.8789062  1287.3899610194233
# 55   76105784.14453125   38.49114259911348
# 56   309366346218.4304  118845.37883336016
# 57  16743344061.611916   5046.252692356753
# 58    456132300.046875  101.46546148653503
# 59      99693509649.75  30461.400997820965

# %%
############################################################
# バグがないか確認する(availabilityがnegativeになっていないか)
# global_city/dat/cty_lst_/gpw4/classification.txtをチェック
# NoMASKの部分がNaNになっている
###########################################################
df_new['ava'] = pd.to_numeric(df_new['ava'], errors='coerce')
df_filtered = df_new[df_new['flag'] != 'NoMASK']

# NaNが含まれていないか確認
if df_filtered['ava'].isna().any():
    print("▲ The 'ava' column contains non-numeric(NaN) values.")
    non_numeric_values = df_filtered[pd.to_numeric(df_filtered['ava'], errors='coerce').isna()]['ava']
    print("Non-numeric values in 'ava' column:", non_numeric_values)
else:
    if (df_filtered['ava'] >= 0).all():
        print("✓ The 'ava' column contains only non-negative values.")
    else:
        print("▲ The 'ava' column contains negative values.")
        negative_ava_rows = df_filtered[df_filtered['ava'] < 0]
        print(negative_ava_rows)
# Out:
# ✓ The 'ava' column contains only non-negative values.

# %%
######################################################
# updownで再計算された都市の数と流域の数を確認
# duplicatesは複数の[上下流に都市が存在する流域]に属する都市 # おそらくalgorithmが不十分で流量が過大評価されている
#####################################################
def load_json(distance=100):
    basin_cities_path = f'{h08dir}/global_city/dat/riv_num_/basin_to_cities_{distance}km.json'
    with open(basin_cities_path, 'r') as json_file:
        basin_to_cities = json.load(json_file)
    new_basin_to_cities = {rivnum: cities for rivnum, cities in basin_to_cities.items() if len(cities) > 1}
    return new_basin_to_cities
    
new_basin_to_cities = load_json() # keys = all basins with multiple cities 186?
rivnum_lst = list(new_basin_to_cities.keys())
rivnum_lst = [int(float(i)) for i in rivnum_lst]
#print(rivnum_lst)
#print(f'len(rivnum_lst): {len(rivnum_lst)}')
print('----------------------------------------------------------------------------------------------------------------------------------')

cities_lst = []
for key_index, key in enumerate(new_basin_to_cities.keys()):
    key_city_list = new_basin_to_cities[key]
    key_city_list = [int(i) for i in key_city_list]

    # remove overlap
    overlap_path = f'{h08dir}/global_city/dat/cty_lst_/gpw4/overlap_hidden_only.txt'
    with open(overlap_path, 'r') as f:
        numbers = [int(line.strip()) for line in f]
    key_city_list_removed = [num for num in key_city_list if num not in numbers]
    key_city_list_removed = [int(i) for i in key_city_list_removed]
    
    cities_lst.extend(key_city_list_removed)
    #print(f'{key_index}: rivnum{key} is done')

print('----------------------------------------------------------------------------------------------------------------------------------')
#print(cities_lst)
#print(f'len(cities_lst): {len(cities_lst)}')
print('----------------------------------------------------------------------------------------------------------------------------------')

urivnum = np.unique(rivnum_lst)
uctynum, counts = np.unique(cities_lst, return_counts=True)
print(f'len(urivnum): {len(urivnum)}')
print(f'len(uctynum): {len(uctynum)}')
print('----------------------------------------------------------------------------------------------------------------------------------')

duplicates = uctynum[counts > 1]
print(f'cities located in multiple basins with upstream relation')
# ほんとはこれらの都市に関して，独立した計算が必要
# なぜなら，exploreするとavaが変化するが，現在は1流域でしかexploreを実行していないため
print(f'len(duplicates cities) {len(duplicates)}')
print(f'duplicates cities {duplicates}')
# Out:
# ----------------------------------------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------------------------------------
# len(urivnum): 307
# len(uctynum): 1276
# ----------------------------------------------------------------------------------------------------------------------------------
# cities located in multiple basins with upstream relation
# len(duplicates cities) 336
# duplicates cities [   3    4   12   15   18   21   23   25   31   35   36   37   38   40
#    46   49   52   65   70   72   73   77   78   85   86   87   96   97
#    99  100  107  108  110  117  126  128  129  141  143  149  167  170
#   172  178  179  181  183  184  191  193  207  208  210  219  220  226
#   229  230  232  233  234  246  249  256  263  272  275  280  286  287
#   290  297  311  314  325  328  335  342  344  345  347  348  350  352
#   364  366  388  392  399  408  413  418  419  429  437  444  464  466
#   467  481  482  484  486  487  490  493  502  508  509  521  524  527
#   530  534  543  545  547  550  553  554  569  592  593  598  599  600
#   603  605  612  613  618  625  627  628  637  643  644  654  658  662
#   671  674  693  697  698  700  706  708  714  723  729  738  742  745
#   750  758  763  764  766  767  768  781  783  786  790  791  796  810
#   815  826  830  833  837  848  859  870  871  874  875  876  878  888
#   894  897  900  918  923  924  933  936  939  947  952  965  967  969
#   988  992  995 1018 1026 1030 1032 1044 1045 1050 1063 1064 1070 1078
#  1091 1093 1098 1103 1104 1109 1110 1113 1115 1116 1117 1119 1121 1125
#  1127 1131 1133 1169 1175 1186 1187 1194 1200 1202 1204 1211 1214 1222
#  1224 1226 1234 1242 1245 1246 1248 1251 1255 1265 1267 1272 1279 1280
#  1281 1282 1283 1284 1290 1292 1297 1299 1305 1312 1320 1322 1324 1325
#  1326 1332 1333 1339 1354 1364 1376 1384 1394 1405 1406 1414 1416 1417
#  1426 1429 1432 1435 1440 1441 1442 1450 1455 1458 1463 1502 1515 1524
#  1528 1541 1591 1611 1625 1627 1635 1652 1658 1659 1661 1664 1665 1681
#  1686 1687 1689 1690 1694 1702 1717 1718 1729 1744 1755 1764 1766 1769
#  1779 1783 1784 1798 1800 1805 1819 1826 1831 1833 1843 1845 1848 1852]

# %%
df_new['index'] = df_new['index'].astype(str)
duplicates_lst = list(map(str, duplicates))
mpcy_values = df_new[df_new['index'].isin(duplicates_lst)]['mpcy']
print(mpcy_values)
# Out:
# 2        787.0565480196925
# 3        14.90019963029999
# 11        52.8343027129914
# 14      279.74867492121587
# 17       654.7835045653018
#                ...
# 1832     90721.02049145702
# 1842    23022.045224486308
# 1844    5508.2497607467985
# 1847     40625.20202633521
# 1851    29.392932380977538
# Name: mpcy, Length: 336, dtype: object
