# %%
####################################################################################
# create and save for samebasin intake files
#cityrivnum = f'{h08dir}/global_city/dat/riv_num_/city_basins.json'
#city_basins_list
####################################################################################
    
import os
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import cartopy.feature as cfeature
import numpy as np
import pandas as pd
import matplotlib.colors as mcolors

####################################################################################
city_len = 1860
distance = 100
ex_flg = False
####################################################################################

# paths
h08dir = '/mnt/c/Users/tsimk/Downloads/dotfiles/h08'
pop_path = f'{h08dir}/global_city/dat/pop_tot_/GPW4ag__20100000.gl5'
riv_path = f'{h08dir}/wsi/dat/riv_out_/W5E5LR__00000000.gl5'
rivnum_path = f'{h08dir}/global_city/dat/riv_num_/rivnum.CAMA.gl5'
rivnxl_path = f"{h08dir}/global_city/dat/riv_nxl_/rivnxl.CAMA.gl5"
msk_dir = f'{h08dir}/global_city/dat/vld_cty_'
cnt_dir = f'{h08dir}/global_city/dat/cty_cnt_/gpw4'
prf_dir = f'{h08dir}/global_city/dat/cty_prf_'

# intake
int_dir = f'{h08dir}/global_city/dat/cty_int_/{distance}km_samebasin'

# rivpath
rivnxl_gl5 = np.fromfile(rivnxl_path, 'float32').reshape(2160, 4320)
pop = np.fromfile(pop_path, dtype='float32').reshape(2160, 4320)
rivout = np.fromfile(riv_path, dtype='float32').reshape(2160, 4320)
rivnum_gl5 = np.fromfile(rivnum_path, dtype='float32').reshape(2160, 4320)

# lonlat
lonlat_path = f'{h08dir}/global_city/dat/cty_lst_/gpw4/WUP2018_300k_2010.txt'
with open(lonlat_path, "r") as input_file:
    lines = input_file.readlines()

# identifying same rivnum cities into list?
city_basins = {}
for i in range(city_len):
    city_num = i+1
    ctymsk_path = f'{msk_dir}/city_{city_num:08}.gl5'
    prf_path = f'{prf_dir}/vld_cty_/city_{city_num:08}.gl5'
    int_path = f'{int_dir}/city_{city_num:08}.gl5'

    if not os.path.exists(prf_path):
        print(f'{city_num} is invalid prf')

    else:
        ctymsk = np.fromfile(ctymsk_path, dtype='float32').reshape(2160, 4320)
        prf = np.fromfile(prf_path, dtype='float32').reshape(2160, 4320)
        intake = np.fromfile(int_path, dtype='float32').reshape(2160, 4320)
        rivnum_mask = np.ma.masked_where((intake+prf) == 0, rivnum_gl5)
        rivnum_lst = np.unique(rivnum_mask)[:-1]
        city_basins[city_num] = rivnum_lst.filled(1e20)
        
        print(f'{city_num} done')

print(city_basins)

"""
basin_to_cities = {}
for city, basins in city_basins.items():
    for rivnum in basins:
        if rivnum not in basin_to_cities:
            basin_to_cities[rivnum] = []
        basin_to_cities[rivnum].append(city)

# 集計結果を出力
for rivnum, cities in basin_to_cities.items():
    if len(cities) > 1:  # 複数の都市に共有されている流域番号のみ表示
        print(f"rivnum {rivnum}: {cities}")

import json
city_basins_list = {city: basins.tolist() for city, basins in city_basins.items()}
cityrivnum = f'{h08dir}/global_city/dat/riv_num_/city_basins_{distance}km.json'
with open(cityrivnum, 'w') as json_file:
    json.dump(city_basins_list, json_file)
print(f'{cityrivnum} saved')
"""
# Out:
# 1 done
# 2 done
# 3 done
# 4 done
# 5 done
# 6 done
# 7 done
# 8 done
# 9 done
# 10 done
# 11 done
# 12 done
# 13 done
# 14 done
# 15 done
# 16 done
# 17 done
# 18 done
# 19 done
# 20 done
# 21 done
# 22 done
# 23 done

# %%
####################################################################################
# create and save below files
#basin_cities_path = f'{h08dir}/global_city/dat/riv_num_/basin_to_cities.json'
#new_basin_to_cities
####################################################################################

import os
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import cartopy.feature as cfeature
import numpy as np
import pandas as pd
import matplotlib.colors as mcolors

def l_coordinate_to_tuple(lcoordinate, a=2160, b=4320):
    lat_l = ((lcoordinate - 1) // b)
    lon_l = (lcoordinate) % b - 1
    return (lat_l, lon_l)

def nxtl2nxtxy(rgnfile, upperindex, leftindex):
    vfunc = np.vectorize(l_coordinate_to_tuple, otypes=[tuple])
    riv_nxtxy = np.empty(rgnfile.shape, dtype=tuple)
    mask = ~np.isnan(rgnfile)
    riv_nxtxy[mask] = vfunc(rgnfile[mask])
    riv_nxtxy_shape = (riv_nxtxy.shape[0], riv_nxtxy.shape[1], 2)
    
    riv_nxtxy_lst = []
    for row in riv_nxtxy:
        for y, x in row:
            modified_y = y - upperindex
            modified_x = x - leftindex
            riv_nxtxy_lst.append((modified_y, modified_x))

    riv_nxtxy_cropped = np.array(riv_nxtxy_lst).reshape(riv_nxtxy_shape)
    riv_nxtxy_cropped = riv_nxtxy_cropped.astype(int)
    return riv_nxtxy_cropped
    
################################################################################
# load files
################################################################################
city_len = 1860
distance = 100
ex_flg = False
h08dir = '/mnt/c/Users/tsimk/Downloads/dotfiles/h08'
rivnxl_path = f"{h08dir}/global_city/dat/riv_nxl_/rivnxl.CAMA.gl5"

# rivpath
rivnxl_gl5 = np.fromfile(rivnxl_path, 'float32').reshape(2160, 4320)
################################################################################

# rivnxl in xy coord
riv_nxlonlat_cropped = nxtl2nxtxy(rivnxl_gl5, 0, 0)

# basin at each city
cityrivnum = f'{h08dir}/global_city/dat/riv_num_/city_basins_{distance}km.json'
with open(cityrivnum, 'r') as json_file:
    city_basins = json.load(json_file)
print(len(city_basins.keys()))

# cities at same basin
basin_to_cities = {}
for city, basins in city_basins.items():
    for rivnum in basins:
        if rivnum not in basin_to_cities:
            basin_to_cities[rivnum] = []
        basin_to_cities[rivnum].append(city)
        
for rivnum, cities in basin_to_cities.items():
    if len(cities) > 1:  # 複数の都市に共有されている流域番号のみ表示
        print(f"rivnum {rivnum}: {cities}")
        
new_basin_to_cities = {rivnum: cities for rivnum, cities in basin_to_cities.items() if len(cities) > 1}
basin_cities_path = f'{h08dir}/global_city/dat/riv_num_/basin_to_cities_{distance}km.json
# rivnum 2386.0: ['97', '356', '644']
# rivnum 6026.0: ['97', '530']
# rivnum 667.0: ['100', '364', '1293']
# rivnum 1577.0: ['100', '364']
# rivnum 102.0: ['103', '232', '355', '912', '917']
# rivnum 401.0: ['105', '522']
# rivnum 581.0: ['107', '177', '423', '511', '1406', '1441']
# rivnum 6429.0: ['107', '423', '1441']
# rivnum 278.0: ['109', '938']
# rivnum 338.0: ['110', '322', '592', '1292']
# rivnum 8210.0: ['110', '592']
# rivnum 205.0: ['112', '242', '753', '1279', '1552', '1694']
# rivnum 390.0: ['113', '478']
# rivnum 56.0: ['114', '627', '688', '1681', '1846']
# rivnum 1471.0: ['121', '178']
# rivnum 203.0: ['123', '239', '586', '605', '660', '751', '770', '810', '1078', '1079', '1455', '1484', '1591', '1657']
# rivnum 948.0: ['124', '379', '768', '793', '1128']
# rivnum 1829.0: ['126', '874']
# rivnum 243.0: ['127', '405', '1020', '1165', '1460', '1480', '1778']
# rivnum 2370.0: ['128', '236', '1691']
# rivnum 4555.0: ['128', '236']
# rivnum 9930.0: ['128', '236']
# rivnum 2360.0: ['129', '1045']
# rivnum 7178.0: ['129', '1045']
# rivnum 1770.0: ['131', '417']
# rivnum 103.0: ['136', '517']
# rivnum 178.0: ['137', '1521']
# rivnum 37.0: ['139', '219', '311', '441', '464', '595', '693', '952', '978', '1131', '1134', '1297', '1306', '1316', '1332', '1354', '1463']
# rivnum 2411.0: ['141', '429', '886', '906']
# rivnum 876.0: ['142', '282']
# rivnum 127.0: ['143', '487', '953', '1094', '1109', '1506', '1611']
# rivnum 805.0: ['147', '1630']
# rivnum 748.0: ['149', '567', '651', '1282', '1366', '1644']
# rivnum 1789.0: ['149', '320', '620', '961']
# rivnum 911.0: ['156', '1368']
# rivnum 4424.0: ['159', '1281']
# rivnum 9647.0: ['163', '1565']
# rivnum 318.0: ['166', '1335']
# rivnum 591.0: ['167', '234', '637', '679', '949', '1267', '1281', '1522']
# rivnum 1130.0: ['167', '535', '637', '759', '1321', '1539', '1598']
# rivnum 2502.0: ['167', '1076', '1568']
# rivnum 1511.0: ['170', '1292']
# rivnum 4051.0: ['170', '205', '427']
# rivnum 107.0: ['173', '175', '1416', '1651', '1825']
# rivnum 69.0: ['178', '1391']
# rivnum 48.0: ['180', '722', '1058', '1230']
# rivnum 1945.0: ['181', '1163', '1549']
# rivnum 6057.0: ['181', '1549']
# rivnum 331.0: ['183', '410', '900']
# rivnum 1571.0: ['184', '569', '936', '1408']
# rivnum 1671.0: ['184', '1474']
# rivnum 2927.0: ['190', '658', '925', '991', '1039', '1123', '1385']
# rivnum 1807.0: ['191', '193', '227', '268', '484', '1085', '1398', '1650', '1661']
# rivnum 282.0: ['192', '1852']
# rivnum 1850.0: ['193', '207', '227', '268']
# rivnum 42.0: ['195', '238', '802', '1296', '1798']
# rivnum 588.0: ['201', '1375']
# rivnum 585.0: ['202', '899']
# rivnum 961.0: ['203', '834', '1708']
# rivnum 6278.0: ['207', '227', '268', '1819']
# rivnum 417.0: ['208', '1064', '1378', '1432']
# rivnum 74.0: ['210', '351', '418', '443', '444', '447', '681', '713', '734', '766', '800', '808', '811', '923', '947', '968', '1026', '1061', '1093', '1169', '1226', '1260', '1284', '1345', '1425', '1452', '1509', '1577', '1626']
# rivnum 1298.0: ['210', '447']
# rivnum 25.0: ['212', '240', '244', '333', '337', '361', '670', '766', '859', '947', '1136', '1258', '1392', '1492', '1561', '1584']
# rivnum 10.0: ['213', '223', '224', '451', '469', '598', '627', '680', '783', '935', '989', '1325', '1393', '1416', '1437', '1444', '1655', '1681', '1686', '1729', '1798', '1826', '1857']
# rivnum 3700.0: ['214', '504', '1779']
# rivnum 32.0: ['216', '1219', '1346']
# rivnum 123.0: ['219', '907', '1102', '1442']
# rivnum 358.0: ['220', '493', '512', '654', '662', '671', '697', '723', '876', '992', '1394', '1494', '1845']
# rivnum 244.0: ['222', '246', '293', '347', '348', '388', '456', '515', '602', '603', '643', '706', '707', '747', '815', '1192', '1245', '1328', '1589']
# rivnum 3908.0: ['230', '495', '1309']
# rivnum 359.0: ['232', '870', '915', '1448', '1664']
# rivnum 131.0: ['233', '325']
# rivnum 158.0: ['233', '325', '1487']
# rivnum 4649.0: ['234', '1267']
# rivnum 15.0: ['245', '301', '633', '661', '709', '962', '1065', '1359', '1373', '1818', '1854']
# rivnum 385.0: ['249', '432', '1186']
# rivnum 1257.0: ['249', '1186']
# rivnum 75.0: ['251', '607', '625', '628', '1041', '1300', '1356', '1442', '1525']
# rivnum 323.0: ['255', '714', '1279', '1318', '1694']
# rivnum 18.0: ['259', '408', '596', '615', '1127', '1130', '1690']
# rivnum 98.0: ['263', '1756', '1780']
# rivnum 2025.0: ['264', '969', '1179']
# rivnum 3202.0: ['267', '986']
# rivnum 2430.0: ['270', '752']
# rivnum 49.0: ['272', '387', '466', '735', '764', '874', '1091', '1103', '1405', '1574', '1689']
# rivnum 146.0: ['277', '281', '476', '843', '889', '923', '951', '1073', '1176', '1226', '1280', '1284']
# rivnum 593.0: ['286', '580']
# rivnum 646.0: ['286', '345', '1115']
# rivnum 26.0: ['289', '547', '717', '771', '984', '1144', '1155', '1305', '1795']
# rivnum 1892.0: ['290', '727', '1739']
# rivnum 3036.0: ['292', '591']
# rivnum 1252.0: ['297', '698', '720']
# rivnum 1624.0: ['299', '1781', '1835']
# rivnum 8.0: ['302', '335', '374', '384', '760', '812', '869', '898', '914', '1428']
# rivnum 288.0: ['307', '897', '1548']
# rivnum 111.0: ['308', '550', '837']
# rivnum 706.0: ['309', '776', '885', '1476']
# rivnum 40.0: ['311', '402', '437', '461', '553', '924', '942', '1096', '1194', '1332', '1515']
# rivnum 5127.0: ['314', '708']
# rivnum 555.0: ['315', '468', '508', '1360']
# rivnum 475.0: ['328', '1784', '1802']
# rivnum 1516.0: ['328', '788', '1512']
# rivnum 4017.0: ['328', '1784']
# rivnum 29.0: ['332', '1730']
# rivnum 576.0: ['336', '345', '489', '711', '1112']
# rivnum 696.0: ['342', '392', '848']
# rivnum 978.0: ['346', '796', '1325', '1414', '1783']
# rivnum 143.0: ['349', '1533']
# rivnum 314.0: ['350', '1202', '1524', '1541', '1833', '1834']
# rivnum 374.0: ['350', '861', '864', '1175', '1222', '1833']
# rivnum 5507.0: ['366', '977']
# rivnum 16.0: ['367', '381', '642', '1763']
# rivnum 720.0: ['375', '1081']
# rivnum 7.0: ['380', '462', '799', '1178']
# rivnum 395.0: ['385', '1554']
# rivnum 877.0: ['389', '440', '1627']
# rivnum 311.0: ['392', '871']
# rivnum 334.0: ['399', '529']
# rivnum 17041.0: ['399', '529']
# rivnum 105.0: ['401', '426', '527', '712', '871', '1074', '1312']
# rivnum 740.0: ['404', '430']
# rivnum 763.0: ['408', '1009', '1690']
# rivnum 2571.0: ['413', '969', '1138']
# rivnum 5046.0: ['413', '1138']
# rivnum 608.0: ['414', '1050', '1347']
# rivnum 670.0: ['418', '1026']
# rivnum 320.0: ['419', '974']
# rivnum 421.0: ['419', '974', '1546']
# rivnum 1417.0: ['434', '878', '1034', '1458', '1707']
# rivnum 166.0: ['435', '867', '976']
# rivnum 1207.0: ['438', '943', '1093', '1169', '1336', '1425']
# rivnum 202.0: ['442', '628', '859']
# rivnum 3477.0: ['444', '734']
# rivnum 55.0: ['454', '964']
# rivnum 2152.0: ['464', '1021', '1306']
# rivnum 586.0: ['479', '613', '731', '990']
# rivnum 657.0: ['481', '1364']
# rivnum 2130.0: ['486', '490', '745', '839']
# rivnum 10510.0: ['486', '490', '839']
# rivnum 2753.0: ['496', '1804', '1829']
# rivnum 65.0: ['502', '790', '1098', '1290', '1601', '1766']
# rivnum 394.0: ['502', '790', '1341']
# rivnum 4503.0: ['504', '1779']
# rivnum 577.0: ['508', '1202', '1360', '1524', '1541']
# rivnum 917.0: ['508', '1360']
# rivnum 1720.0: ['509', '1435', '1440', '1458', '1742']
# rivnum 3947.0: ['509', '1435', '1742']
# rivnum 176.0: ['516', '542']
# rivnum 1481.0: ['525', '559', '738', '801', '1097', '1322', '1729', '1769']
# rivnum 2087.0: ['527', '712']
# rivnum 812.0: ['554', '795']
# rivnum 346.0: ['556', '897']
# rivnum 2691.0: ['558', '1334']
# rivnum 317.0: ['568', '1109', '1326', '1506', '1611']
# rivnum 1188.0: ['569', '1121', '1240', '1283', '1400']
# rivnum 558.0: ['575', '918']
# rivnum 632.0: ['590', '1477']
# rivnum 229.0: ['599', '777', '965', '997', '1653']
# rivnum 1812.0: ['599', '1593']
# rivnum 2145.0: ['600', '1423']
# rivnum 3265.0: ['600', '1423']
# rivnum 1356.0: ['605', '668', '1455']
# rivnum 381.0: ['610', '676']
# rivnum 293.0: ['619', '1194']
# rivnum 108.0: ['625', '737', '853', '1150']
# rivnum 4489.0: ['626', '772', '1184']
# rivnum 192.0: ['630', '850']
# rivnum 913.0: ['654', '781']
# rivnum 3464.0: ['658', '991']
# rivnum 10401.0: ['658', '991']
# rivnum 259.0: ['665', '855']
# rivnum 1800.0: ['674', '1211', '1285', '1800']
# rivnum 1833.0: ['674', '1211', '1285', '1658']
# rivnum 231.0: ['693', '952', '1297']
# rivnum 167.0: ['699', '1354']
# rivnum 393.0: ['714', '905', '1827']
# rivnum 2715.0: ['738', '1769']
# rivnum 946.0: ['742', '810', '1078', '1436', '1590', '1591']
# rivnum 1882.0: ['742', '751']
# rivnum 425.0: ['749', '955']
# rivnum 5365.0: ['751', '1436']
# rivnum 3085.0: ['757', '1419']
# rivnum 5545.0: ['763', '1110', '1133']
# rivnum 284.0: ['783', '1266', '1322', '1416', '1421']
# rivnum 1195.0: ['786', '1528']
# rivnum 409.0: ['791', '1113']
# rivnum 1539.0: ['817', '1852']
# rivnum 1368.0: ['854', '937']
# rivnum 1058.0: ['870', '1664']
# rivnum 273.0: ['875', '1409', '1429']
# rivnum 3285.0: ['875', '1063']
# rivnum 758.0: ['918', '1157']
# rivnum 1067.0: ['1030', '1450']
# rivnum 3205.0: ['1032', '1502']
# rivnum 3409.0: ['1035', '1121']
# rivnum 2954.0: ['1044', '1117']
# rivnum 3102.0: ['1050', '1251']
# rivnum 2147.0: ['1069', '1838']
# rivnum 206.0: ['1070', '1171', '1242']
# rivnum 807.0: ['1080', '1665', '1743']
# rivnum 1015.0: ['1104', '1243']
# rivnum 33.0: ['1129', '1688']
# rivnum 630.0: ['1149', '1543']
# rivnum 971.0: ['1160', '1352']
# rivnum 197.0: ['1187', '1774', '1842']
# rivnum 508.0: ['1222', '1744']
# rivnum 3374.0: ['1229', '1324', '1387', '1754']
# rivnum 62.0: ['1233', '1320']
# rivnum 893.0: ['1319', '1395']
# rivnum 644.0: ['1326', '1367']
# rivnum 47.0: ['1362', '1585']
# rivnum 66.0: ['1602', '1665']
# rivnum 1384.0: ['1804', '1829']
# /mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/riv_num_/basin_to_cities_100km.json saved

# %%
####################################################################################
# テストする場合はここから始めてください
# coords_a is multiple city's [prf and int coordinates] in the same basin
# This test code shows how coords_a looks like
####################################################################################
key_index=1
distance=100

import json
import os
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import cartopy.feature as cfeature
import numpy as np
import pandas as pd
import matplotlib.colors as mcolors

h08dir = '/mnt/c/Users/tsimk/Downloads/dotfiles/h08'
basin_cities_path = f'{h08dir}/global_city/dat/riv_num_/basin_to_cities_{distance}km.json'
with open(basin_cities_path, 'r') as json_file:
    new_basin_to_cities = json.load(json_file)

# get uid and city list
keys_list = list(new_basin_to_cities.keys())
uid = keys_list[key_index]
print(f'uid: {uid}')
rivnum_list = new_basin_to_cities[uid]
rivnum_list = [int(i) for i in rivnum_list]

# remove overlap
h08dir = '/mnt/c/Users/tsimk/Downloads/dotfiles/h08'
overlap_path = f'{h08dir}/global_city/dat/cty_lst_/gpw4/overlap_hidden_only.txt'
with open(overlap_path, 'r') as f:
    numbers = [int(line.strip()) for line in f]
rivnum_list_removed = [num for num in rivnum_list if num not in numbers]
rivnum_list_removed = [int(i) for i in rivnum_list_removed]
print('cities in uid')
print(rivnum_list_removed)

# rivout
rivout_path = f'{h08dir}/wsi/dat/riv_out_/W5E5LR__00000000.gl5'
rivout_gl5 = np.fromfile(rivout_path, dtype='float32').reshape(2160, 4320)

# coord of purficication
coords_a = []
for city_num in rivnum_list_removed:
    # rivnum
    rivnum_path = f'{h08dir}/global_city/dat/riv_num_/rivnum.CAMA.gl5'
    rivnum_gl5 = np.fromfile(rivnum_path, dtype='float32').reshape(2160, 4320)

    # prf
    prf_dir = f'{h08dir}/global_city/dat/cty_prf_'
    prf_path = f'{prf_dir}/vld_cty_/city_{city_num:08}.gl5'
    prf = np.fromfile(prf_path, dtype='float32').reshape(2160, 4320)

    # int
    int_dir = f'{h08dir}/global_city/dat/cty_int_/{distance}km_samebasin'
    int_path = f'{int_dir}/city_{city_num:08}.gl5'
    intake = np.fromfile(int_path, dtype='float32').reshape(2160, 4320)

    # 1. prfのみが対象流域内
    # 2. intのみが対象流域内
    # 3. prfとintどちらもが対象領域内 -> runoutの多い方を採用する
    uid = int(float(uid))
    prf_coord = np.where((prf == 1) & (rivnum_gl5 == uid))
    int_coord = np.where((intake==1) & (rivnum_gl5 == uid))

    if prf_coord[0].size != 0 and int_coord[0].size == 0:
        coords_a.append([prf_coord, city_num])
    elif prf_coord[0].size == 0 and int_coord[0].size != 0:
        coords_a.append([int_coord, city_num])
    elif prf_coord[0].size != 0 and int_coord[0].size != 0:
        prf_runout = rivout_gl5[prf_coord][0] * 60 * 60 * 24 * 365 / (1000)
        int_runout = rivout_gl5[int_coord][0] * 60 * 60 * 24 * 365 / (1000)
        print(f"prf: {prf_runout/1e9}, int: {int_runout/1e9}")
        if prf_runout > int_runout:
            larger_coord = prf_coord
        else:
            larger_coord = int_coord
        coords_a.append([larger_coord, city_num])
    else:
        continue
        
print('coords_a')
#print(coords_a)

print(coords_a[0])
print(coords_a[0][0][0][0]) #737
print(coords_a[0][0][1][0]) #3082
print(coords_a[0][1]) # 2
# Out:
# uid: 14.0
# cities in uid
# [2, 11, 126, 130, 133, 188, 197, 217, 243, 319, 321, 363, 398, 406, 455, 463, 473, 513, 526, 588, 667, 669, 673, 677, 797, 874, 883, 903, 941, 983, 1012, 1018, 1067, 1089, 1181, 1216, 1253, 1288, 1298, 1337, 1365, 1371, 1422, 1578, 1620, 1652, 1656, 1697, 1712, 1718, 1824]
# prf: 4.42079778375, int: 19.248677595
# prf: 0.0956541544453125, int: 478.240570224
# prf: 87.145943796, int: 6.65100300825
# prf: 6.701539941, int: 87.196582728
# prf: 0.0565119422578125, int: 0.056030028908203126
# prf: 591.25080384, int: 56.497291938
# prf: 0.25847798709375, int: 0.2720333548125
# prf: 30.390383844, int: 3.641325674625
# prf: 0.1305414087890625, int: 45.876459888
# prf: 0.1861881898359375, int: 33.889220262
# prf: 246.507466968, int: 92.2232871
# prf: 0.1439401436015625, int: 6.8335545645
# prf: 20.418117228, int: 12.1408761195
# prf: 0.07312175173828125, int: 22.907352258
# prf: 328.876834176, int: 19.687177791
# prf: 0.98778654478125, int: 39.661944192
# prf: 0.2345311840078125, int: 39.496202802
# prf: 827.483069376, int: 19.038458619
# prf: 0.51893159371875, int: 5.756583411
# prf: 2.466189851625, int: 86.406873984
# prf: 1.825538229, int: 14.289763797
# prf: 0.08963806960546875, int: 32.667907851
# prf: 31.437966402, int: 41.93014734
# prf: 0.06896914730859376, int: 22.908410685
# prf: 6.895955439, int: 41.618386386
# prf: 0.8571333279375, int: 0.993544882875
# prf: 0.048419474361328124, int: 32.990188032
# prf: 3.04763361975, int: 65.844716076
# prf: 1.418693032125, int: 28.304519877
# prf: 0.04395905131640625, int: 18.263201247
# prf: 4.50879406425, int: 477.148131648
# prf: 0.84838917121875, int: 54.376247592
# prf: 0.2212189576171875, int: 32.667907851
# prf: 1.612417941, int: 19.048786659
# prf: 0.367068291890625, int: 0.09287203405078125
# prf: 1.66044924, int: 1.1367674746875
# prf: 0.174752771203125, int: 1.7296509268125
# prf: 0.06634956512109375, int: 42.139175832
# prf: 0.04071351109570313, int: 0.731685706875
# prf: 0.29364580096875, int: 59.087260836
# prf: 0.2005798158984375, int: 18.263201247
# prf: 0.0493587828984375, int: 42.139175832
# prf: 0.04992697754296875, int: 11.6460999315
# prf: 3.66539429475, int: 89.842256028
# prf: 0.11301882612890625, int: 1.4944801995
# prf: 0.96825861590625, int: 22.105640124
# coords_a
# [(array([732]), array([3086])), 2]
# 732
# 3086
# 2

# %%
####################################################################################
# this test code shows how edges looks like
# edgesは2都市間のupstreamとdownstreamの関係をすべて保存したリスト
####################################################################################

import json

h08dir = '/mnt/c/Users/tsimk/Downloads/dotfiles/h08'
basin_cities_path = f'{h08dir}/global_city/dat/riv_num_/basin_to_cities_{distance}km.json'
with open(basin_cities_path, 'r') as json_file:
    new_basin_to_cities = json.load(json_file)
    
def l_coordinate_to_tuple(lcoordinate, a=2160, b=4320):
    lat_l = ((lcoordinate - 1) // b)
    lon_l = (lcoordinate) % b - 1
    return (lat_l, lon_l)

def nxtl2nxtxy(rgnfile, upperindex, leftindex):
    vfunc = np.vectorize(l_coordinate_to_tuple, otypes=[tuple])
    riv_nxtxy = np.empty(rgnfile.shape, dtype=tuple)
    mask = ~np.isnan(rgnfile)
    riv_nxtxy[mask] = vfunc(rgnfile[mask])
    riv_nxtxy_shape = (riv_nxtxy.shape[0], riv_nxtxy.shape[1], 2)
    
    riv_nxtxy_lst = []
    for row in riv_nxtxy:
        for y, x in row:
            modified_y = y - upperindex
            modified_x = x - leftindex
            riv_nxtxy_lst.append((modified_y, modified_x))

    riv_nxtxy_cropped = np.array(riv_nxtxy_lst).reshape(riv_nxtxy_shape)
    riv_nxtxy_cropped = riv_nxtxy_cropped.astype(int)
    return riv_nxtxy_cropped
    
rivnxl_path = f"{h08dir}/global_city/dat/riv_nxl_/rivnxl.CAMA.gl5"
rivnxl_gl5 = np.fromfile(rivnxl_path, 'float32').reshape(2160, 4320)
riv_nxlonlat_cropped = nxtl2nxtxy(rivnxl_gl5, 0, 0)

def updown(new_basin_to_cities, key_index=0, distance=100):
    # get uid and city list
    keys_list = list(new_basin_to_cities.keys())
    uid = keys_list[key_index]
    print(f'uid: {uid}')
    rivnum_list = new_basin_to_cities[uid]
    rivnum_list = [int(i) for i in rivnum_list]
    
    # remove overlap
    h08dir = '/mnt/c/Users/tsimk/Downloads/dotfiles/h08'
    overlap_path = f'{h08dir}/global_city/dat/cty_lst_/gpw4/overlap_hidden_only.txt'
    with open(overlap_path, 'r') as f:
        numbers = [int(line.strip()) for line in f]
    rivnum_list_removed = [num for num in rivnum_list if num not in numbers]
    rivnum_list_removed = [int(i) for i in rivnum_list_removed]
    print('cities in uid')
    print(rivnum_list_removed)
    
    # rivout
    rivout_path = f'{h08dir}/wsi/dat/riv_out_/W5E5LR__00000000.gl5'
    rivout_gl5 = np.fromfile(rivout_path, dtype='float32').reshape(2160, 4320)
    
    # coord of purficication
    coords_a = []
    for city_num in rivnum_list_removed:
        # rivnum
        rivnum_path = f'{h08dir}/global_city/dat/riv_num_/rivnum.CAMA.gl5'
        rivnum_gl5 = np.fromfile(rivnum_path, dtype='float32').reshape(2160, 4320)

        # prf
        prf_dir = f'{h08dir}/global_city/dat/cty_prf_'
        prf_path = f'{prf_dir}/vld_cty_/city_{city_num:08}.gl5'
        prf = np.fromfile(prf_path, dtype='float32').reshape(2160, 4320)

        # int
        int_dir = f'{h08dir}/global_city/dat/cty_int_/{distance}km_samebasin'
        int_path = f'{int_dir}/city_{city_num:08}.gl5'
        intake = np.fromfile(int_path, dtype='float32').reshape(2160, 4320)
        
        # 1. prfのみが対象流域内
        # 2. intのみが対象流域内
        # 3. prfとintどちらもが対象領域内
        uid = int(float(uid))
        prf_coord = np.where((prf == 1) & (rivnum_gl5 == uid))
        int_coord = np.where((intake==1) & (rivnum_gl5 == uid))
        
        if prf_coord[0].size != 0 and int_coord[0].size == 0:
            coords_a.append([prf_coord, city_num])
        elif prf_coord[0].size == 0 and int_coord[0].size != 0:
            coords_a.append([int_coord, city_num])
        elif prf_coord[0].size != 0 and int_coord[0].size != 0:
            prf_runout = rivout_gl5[prf_coord][0] * 60 * 60 * 24 * 365 / (1000)
            int_runout = rivout_gl5[int_coord][0] * 60 * 60 * 24 * 365 / (1000)
            print(f"city_num: {city_num}, prf: {prf_runout/1e9}, int: {int_runout/1e9}")
            if prf_runout > int_runout:
                larger_coord = prf_coord
            else:
                larger_coord = int_coord
            coords_a.append([larger_coord, city_num])
        else:
            continue
        
    # down
    edges = []
    riv_path_array = np.zeros((2160, 4320))
    for idx in range(len(coords_a)):
        visited_coords = set()
        riv_path_array[coords_a[idx][0][0][0], coords_a[idx][0][1][0]] = idx

        # coordinates of prf and intake
        coords_b = coords_a.copy()
        coords_b.pop(idx) 
        
        if len(coords_a) > 0:
            target_coord = (coords_a[idx][0][0][0], coords_a[idx][0][1][0])
            
            while True:
                if target_coord in visited_coords:
                    break
                visited_coords.add(target_coord)
                
                next_coord = riv_nxlonlat_cropped[target_coord[0], target_coord[1]]
                if next_coord.size == 0 or next_coord.shape != (2,):
                    break
                
                next_coord = (next_coord[0], next_coord[1])
                riv_path_array[next_coord[0], next_coord[1]] = idx
                target_coord = next_coord
        
        for cind, coord in enumerate(coords_b):
            if coord[0][0].size == 0:
                continue
            else:
                standard_coord = (coord[0][0][0], coord[0][1][0])
                if standard_coord in visited_coords:
                    edges.append((coords_a[idx][1], coord[1]))

    # edgesは2都市間のupstreamとdownstreamの関係をすべて保存したリスト
    return edges, riv_path_array, coords_a, rivnum_list_removed
    
# unique_cties_basin: uniqueなすべての都市
# uup: 各都市の上流にあるuniqueな都市
# key_index = city_num like index
edges, riv_path_array, coords_a, rivnum_list_removed = updown(new_basin_to_cities, key_index=1)
unique_cities_basin = np.unique(edges)
print(edges)
# Out:
# uid: 14.0
# cities in uid
# [2, 11, 126, 130, 133, 188, 197, 217, 243, 319, 321, 363, 398, 406, 455, 463, 473, 513, 526, 588, 667, 669, 673, 677, 797, 874, 883, 903, 941, 983, 1012, 1018, 1067, 1089, 1181, 1216, 1253, 1288, 1298, 1337, 1365, 1371, 1422, 1578, 1620, 1652, 1656, 1697, 1712, 1718, 1824]
# city_num: 2, prf: 4.42079778375, int: 19.248677595
# city_num: 11, prf: 0.0956541544453125, int: 478.240570224
# city_num: 130, prf: 87.145943796, int: 6.65100300825
# city_num: 133, prf: 6.701539941, int: 87.196582728
# city_num: 188, prf: 0.0565119422578125, int: 0.056030028908203126
# city_num: 197, prf: 591.25080384, int: 56.497291938
# city_num: 217, prf: 0.25847798709375, int: 0.2720333548125
# city_num: 243, prf: 30.390383844, int: 3.641325674625
# city_num: 319, prf: 0.1305414087890625, int: 45.876459888
# city_num: 321, prf: 0.1861881898359375, int: 33.889220262
# city_num: 363, prf: 246.507466968, int: 92.2232871
# city_num: 406, prf: 0.1439401436015625, int: 6.8335545645
# city_num: 455, prf: 20.418117228, int: 12.1408761195
# city_num: 463, prf: 0.07312175173828125, int: 22.907352258
# city_num: 473, prf: 328.876834176, int: 19.687177791
# city_num: 513, prf: 0.98778654478125, int: 39.661944192
# city_num: 526, prf: 0.2345311840078125, int: 39.496202802
    value = result_dict[rivnum_key]
    print(rivnum_key, value)
# Out:
# 2 [1, True, array([ 667, 1089, 1253, 1288, 1422, 1620])]
# 11 [1, True, array([ 473,  673, 1181, 1365])]
# 126 [1, 'Done', array([], dtype=float64)]
# 130 [1, True, array([ 321,  463,  513,  526,  667,  677,  797,  983, 1253, 1371, 1656,
#        1824])]
# 133 [1, True, array([ 130,  321,  463,  513,  526,  667,  677,  797,  983, 1253, 1371,
#        1656, 1824])]
# 188 [1, 'Done', array([], dtype=float64)]
# 197 [1, True, array([   2,  126,  130,  133,  188,  217,  243,  319,  321,  363,  406,
#         455,  463,  513,  526,  667,  669,  677,  797,  883,  941,  983,
#        1012, 1018, 1067, 1089, 1253, 1288, 1298, 1337, 1371, 1422, 1620,
#        1656, 1697, 1712, 1718, 1824])]
# 217 [1, 'Done', array([], dtype=float64)]
# 243 [1, True, array([   2,  667,  677,  983, 1067, 1089, 1253, 1288, 1422, 1620])]
# 319 [1, False, array([1697])]
# 321 [1, True, array([ 667,  677,  983, 1253])]
# 363 [1, True, array([   2,  126,  130,  133,  188,  217,  243,  321,  406,  455,  463,
#         513,  526,  667,  677,  797,  883,  941,  983, 1018, 1067, 1089,
#        1253, 1288, 1298, 1337, 1371, 1422, 1620, 1656, 1718, 1824])]
# 406 [1, 'Done', array([], dtype=float64)]
# 455 [1, True, array([ 188,  941, 1018, 1337, 1718])]
# 463 [1, False, array([1824])]
# 473 [1, False, array([1365])]
# 513 [1, True, array([ 321,  526,  667,  677,  983, 1253])]
# 526 [1, True, array([ 321,  667,  677,  983, 1253])]
# 588 [1, True, array([   2,  126,  130,  133,  188,  197,  217,  243,  319,  321,  363,
#         406,  455,  463,  513,  526,  667,  669,  673,  677,  797,  883,
#         941,  983, 1012, 1018, 1067, 1089, 1253, 1288, 1298, 1337, 1371,
#        1422, 1578, 1620, 1656, 1697, 1712, 1718, 1824])]
# 667 [1, 'Done', array([], dtype=float64)]
# 669 [1, True, array([ 463, 1824])]
# 673 [1, 'Done', array([], dtype=float64)]
# 677 [1, True, array([ 667, 1253])]
# 797 [1, True, array([   2,  243,  321,  513,  526,  667,  677,  983, 1067, 1089, 1253,
#        1288, 1422, 1620])]
# 883 [1, False, array([217])]
# 903 [1, False, array([1652])]
# 941 [1, 'Done', array([], dtype=float64)]
# 983 [1, True, array([ 667,  677, 1253])]
# 1012 [1, True, array([ 319, 1697])]
# 1018 [1, 'Done', array([], dtype=float64)]
# 1067 [1, True, array([   2,  667,  677,  983, 1089, 1253, 1288, 1422, 1620])]
# 1089 [1, True, array([ 667, 1620])]
# 1181 [1, True, array([ 473,  673, 1365])]
# 1216 [1, True, array([ 903, 1652])]
# 1253 [1, True, array([667, 677])]
# 1288 [1, True, array([ 667, 1089, 1253, 1620])]
# 1298 [1, 'Done', array([], dtype=float64)]
# 1337 [1, False, array([1018])]
# 1365 [1, 'Done', array([], dtype=float64)]
# 1371 [1, True, array([ 321,  513,  526,  667,  677,  797,  983, 1253, 1656])]
# 1422 [1, 'Done', array([], dtype=float64)]
# 1578 [1, 'Done', array([], dtype=float64)]
# 1620 [1, True, array([ 667, 1089])]
# 1652 [1, 'Done', array([], dtype=float64)]
# 1656 [1, True, array([ 321,  513,  526,  667,  677,  797,  983, 1253, 1371])]
# 1697 [1, 'Done', array([], dtype=float64)]
# 1712 [1, True, array([ 463,  669, 1824])]
# 1718 [1, False, array([188, 941])]
# 1824 [1, 'Done', array([], dtype=float64)]

# %%
######################################################################
# JOB START 
#(初めてでなければここまでの計算を飛ばして，ここからスタートしてもよい)
######################################################################

import os
import json
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import cartopy.feature as cfeature
import numpy as np
import pandas as pd
import matplotlib.colors as mcolors

def l_coordinate_to_tuple(lcoordinate, a=2160, b=4320):
    lat_l = ((lcoordinate - 1) // b)
    lon_l = (lcoordinate) % b - 1
    return (lat_l, lon_l)

def nxtl2nxtxy(rgnfile, upperindex, leftindex):
    vfunc = np.vectorize(l_coordinate_to_tuple, otypes=[tuple])
    riv_nxtxy = np.empty(rgnfile.shape, dtype=tuple)
    mask = ~np.isnan(rgnfile)
    riv_nxtxy[mask] = vfunc(rgnfile[mask])
    riv_nxtxy_shape = (riv_nxtxy.shape[0], riv_nxtxy.shape[1], 2)
    
    riv_nxtxy_lst = []
    for row in riv_nxtxy:
        for y, x in row:
            modified_y = y - upperindex
            modified_x = x - leftindex
            riv_nxtxy_lst.append((modified_y, modified_x))

    riv_nxtxy_cropped = np.array(riv_nxtxy_lst).reshape(riv_nxtxy_shape)
    riv_nxtxy_cropped = riv_nxtxy_cropped.astype(int)
    return riv_nxtxy_cropped

# init
h08dir = '/mnt/c/Users/tsimk/Downloads/dotfiles/h08'
pop_path = f'{h08dir}/global_city/dat/pop_tot_/GPW4ag__20100000.gl5'
rivnxl_path = f"{h08dir}/global_city/dat/riv_nxl_/rivnxl.CAMA.gl5"
rivout_path = f'{h08dir}/wsi/dat/riv_out_/W5E5LR__00000000.gl5'
rivnum_path = f'{h08dir}/global_city/dat/riv_num_/rivnum.CAMA.gl5'
rivara_path = f'{h08dir}/global_city/dat/riv_ara_/rivara.CAMA.gl5'
msk_dir = f'{h08dir}/global_city/dat/vld_cty_'
prf_dir = f'{h08dir}/global_city/dat/cty_prf_'

pop_gl5 = np.fromfile(pop_path, dtype='float32').reshape(2160, 4320)
rivout_gl5 = np.fromfile(rivout_path, dtype='float32').reshape(2160, 4320)
rivnum_gl5 = np.fromfile(rivnum_path, dtype='float32').reshape(2160, 4320)
rivara_gl5 = np.fromfile(rivara_path, dtype='float32').reshape(2160, 4320)
rivnxl_gl5 = np.fromfile(rivnxl_path, 'float32').reshape(2160, 4320)
riv_nxlonlat_cropped = nxtl2nxtxy(rivnxl_gl5, 0, 0)


def load_json(distance=100):
    basin_cities_path = f'{h08dir}/global_city/dat/riv_num_/basin_to_cities_{distance}km.json'
    with open(basin_cities_path, 'r') as json_file:
        basin_to_cities = json.load(json_file)
    new_basin_to_cities = {rivnum: cities for rivnum, cities in basin_to_cities.items() if len(cities) > 1}
    return new_basin_to_cities

def updown(new_basin_to_cities, key_index=0, distance=100):
    # get uid and city list
    keys_list = list(new_basin_to_cities.keys())
    uid = keys_list[key_index]
    print(f'uid: {uid}')
    rivnum_list = new_basin_to_cities[uid]
    rivnum_list = [int(i) for i in rivnum_list]
    
    # remove overlap
    h08dir = '/mnt/c/Users/tsimk/Downloads/dotfiles/h08'
    overlap_path = f'{h08dir}/global_city/dat/cty_lst_/gpw4/overlap_hidden_only.txt'
    with open(overlap_path, 'r') as f:
        numbers = [int(line.strip()) for line in f]
    rivnum_list_removed = [num for num in rivnum_list if num not in numbers]
    rivnum_list_removed = [int(i) for i in rivnum_list_removed]
    print('cities in uid')
    print(rivnum_list_removed)
    
    # coord of purficication
    coords_a = []
    for city_num in rivnum_list_removed:
        # rivnum
        rivnum_path = f'{h08dir}/global_city/dat/riv_num_/rivnum.CAMA.gl5'
        rivnum_gl5 = np.fromfile(rivnum_path, dtype='float32').reshape(2160, 4320)

        # prf
        prf_dir = f'{h08dir}/global_city/dat/cty_prf_'
        prf_path = f'{prf_dir}/vld_cty_/city_{city_num:08}.gl5'
        prf = np.fromfile(prf_path, dtype='float32').reshape(2160, 4320)

        # int
        int_dir = f'{h08dir}/global_city/dat/cty_int_/{distance}km_samebasin'
        int_path = f'{int_dir}/city_{city_num:08}.gl5'
        intake = np.fromfile(int_path, dtype='float32').reshape(2160, 4320)
        # don't think about IBT updown at current stage
        intake = np.zeros((2160, 4320))
        
        uid = int(float(uid))
        prf_coord = np.where((prf == 1) & (rivnum_gl5 == uid))
        int_coord = np.where((intake==1) & (rivnum_gl5 == uid))
        
        if prf_coord[0].size != 0 and int_coord[0].size == 0:
            coords_a.append([prf_coord, city_num])
        elif prf_coord[0].size == 0 and int_coord[0].size != 0:
            coords_a.append([int_coord, city_num])
        elif prf_coord[0].size != 0 and int_coord[0].size != 0:
            prf_runout = rivout_gl5[prf_coord][0] * 60 * 60 * 24 * 365 / (1000)
            int_runout = rivout_gl5[int_coord][0] * 60 * 60 * 24 * 365 / (1000)
            print(f"city_num: {city_num}, prf: {prf_runout/1e9}, int: {int_runout/1e9}")
            if prf_runout > int_runout:
                larger_coord = prf_coord
            else:
                larger_coord = int_coord
            coords_a.append([larger_coord, city_num])
        else:
            continue

    # down
    edges = []
    riv_path_array = np.zeros((2160, 4320))
    for idx in range(len(coords_a)):
        visited_coords = set()
        riv_path_array[coords_a[idx][0][0][0], coords_a[idx][0][1][0]] = idx

        # coordinates of prf and intake
        coords_b = coords_a.copy()
        coords_b.pop(idx) 
        
        if len(coords_a) > 0:
            target_coord = (coords_a[idx][0][0][0], coords_a[idx][0][1][0])
            
            while True:
                if target_coord in visited_coords:
                    break
                visited_coords.add(target_coord)
                
                next_coord = riv_nxlonlat_cropped[target_coord[0], target_coord[1]]
                if next_coord.size == 0 or next_coord.shape != (2,):
                    break
                
                next_coord = (next_coord[0], next_coord[1])
                riv_path_array[next_coord[0], next_coord[1]] = idx
                target_coord = next_coord
        
        for cind, coord in enumerate(coords_b):
            if coord[0][0].size == 0:
                continue
            else:
                standard_coord = (coord[0][0][0], coord[0][1][0])
                if standard_coord in visited_coords:
                    edges.append((coords_a[idx][1], coord[1]))

    # edgesは2都市間のupstreamとdownstreamの関係をすべて保存したリスト
    return edges, riv_path_array, coords_a, rivnum_list_removed
    
def find_upstream_cities(edges, city_number):
    cities_with_upstream = []
    cities_without_upstream = []
    upstream_cities = [edge[0] for edge in edges if edge[1] == city_number]
    uup = np.unique(upstream_cities)
    
    for i in uup:
        if any(edge[1] == i for edge in edges):
            # 上流にさらに都市が存在する場合
            cities_with_upstream.append(i)
        else:
            # 上流にこれ以上都市が存在しない場合
            cities_without_upstream.append(i)
    
    return cities_with_upstream, cities_without_upstream, uup
    
mcy_pop_water_path = '/mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city/dat/cty_lst_/gpw4/mcy_pop_water_12region.txt'
column_names = ['index', 'flag', 'rate', 'wup', 'pop', 'ava', 'mpcy', 'potential', 'region', 'country', 'cityname', '12region']
df = pd.read_csv(mcy_pop_water_path, delimiter='|', header=None, names=column_names)
df.head(5)
# Out:
#    index   flag      rate        wup         pop           ava         mpcy  \
# 0      1  False  0.863325  36859.626  31821850.0  1.424091e+10   447.519821
# 1      2  False  1.003201  21987.895  22058268.0  4.420798e+09   200.414547
# 2      3  False  0.715760  20314.309  14540163.0  1.643563e+10  1130.360505
# 3      4  False  1.002057  20136.681  20178100.0  3.006577e+08    14.900200
# 4      5  False  0.492121  19659.808   9675000.0  2.057520e+09   212.663566
#
#    potential           region country                        cityname  \
# 0       93.0     eastern asia   Japan                           Tokyo
# 1       39.0    southern asia   India                           Delhi
# 2       17.0     eastern asia   China                        Shanghai
# 3       43.0  central america  Mexico  Ciudad de México (Mexico City)
# 4       11.0    south america  Brazil                       São Paulo
#
#           12region
# 0        East Asia
# 1       South Asia
# 2        East Asia
# 3  Central America
# 4    South America

# %%
####################################################################################
# key_index(すべての流域を)すべてを探索する
# result_dictのavaの中に1流域からの想定取水量を入力する
# result_dictを作成する
####################################################################################
def make_result_dict(new_basin_to_cities, key_index=1):
    # unique_cties_basin: uniqueなすべての都市
    # uup: 各都市の上流にあるuniqueな都市
    edges, riv_path_array, coords_a, rivnum_list_removed = updown(new_basin_to_cities, key_index=key_index)
    unique_cities_basin = np.unique(edges)
    
    result_dict = {}
    for city_number in unique_cities_basin:
        cities_with_upstream, cities_without_upstream, uup = find_upstream_cities(edges, city_number)
        if cities_with_upstream:
            # [discharge, consumption, flag, uppoer cities]
            result_dict[city_number] = [1, 0.1, True, uup]
        elif not cities_with_upstream and cities_without_upstream:
            result_dict[city_number] = [1, 0.1, False, uup]
        else:
            result_dict[city_number] = [1, 0.1, 'Done', uup]
    
    # 同じ流域に含まれる各都市のwater availability, upstream citiesを保存している．cities_with_upstreamが存在する場合，flag=Trueとなる
    return result_dict
    
####################################################################################
# result_dictのavaの中に1流域からの想定取水量を入力する
# 一つの流域から二つ取水点がある可能性がある→prfかintakeの流量が多い方を選ぶ
####################################################################################
def discharge_rate(city_num, riv_num, distance=100):
    city_num = int(city_num)
    riv_num = int(float(riv_num))
    print(f'city_num, riv_num, {city_num}, {riv_num}')
    
    h08dir = '/mnt/c/Users/tsimk/Downloads/dotfiles/h08'
    msk_dir = f'{h08dir}/global_city/dat/vld_cty_'
    ctymsk_path = f'{msk_dir}/city_{city_num:08}.gl5'
    ctymsk = np.fromfile(ctymsk_path, dtype='float32').reshape(2160, 4320)
    
    prf_dir = f'{h08dir}/global_city/dat/cty_prf_'
    prf_path = f'{prf_dir}/vld_cty_/city_{city_num:08}.gl5'
    prf = np.fromfile(prf_path, dtype='float32').reshape(2160, 4320)
    
    int_dir = f'{h08dir}/global_city/dat/cty_int_/{distance}km_samebasin'
    int_path = f'{int_dir}/city_{city_num:08}.gl5'
    intake = np.fromfile(int_path, dtype='float32').reshape(2160, 4320)

    prf_coord = np.where((prf == 1) & (rivnum_gl5 == riv_num))
    int_coord = np.where((intake==1) & (rivnum_gl5 == riv_num))
    
    if prf_coord[0].size != 0 and int_coord[0].size != 0:
        prf_runout = rivout_gl5[prf_coord][0] * 60 * 60 * 24 * 365 / (1000)
        int_runout = rivout_gl5[int_coord][0] * 60 * 60 * 24 * 365 / (1000)
        print(f"city_num: {city_num}, prf: {prf_runout/1e9}, int: {int_runout/1e9}")
        if prf_runout > int_runout:
            print(f'prf_runout > int_runout')
            largest = prf
        else:
            print(f'int_runout > prf_runout')
            prf[prf_coord] = 0 
            largest = intake + prf
    else:
        print(f'int out of riv_num')
        largest = prf + intake

    rivnum_mask = np.ma.masked_where(largest == 0, rivnum_gl5)
    rivara_mask = np.ma.masked_where(largest == 0, rivara_gl5) # 複数ある
    rate = np.sum(rivara_gl5[rivnum_mask== riv_num])/np.sum(rivara_mask)
    discharge = np.sum(rivout_gl5[(largest!=0) & (rivnum_gl5==riv_num)])* 60 * 60 * 24 * 365 / (1000) # m3/year
    return rate, discharge
    
####################################################################################
# JOB
####################################################################################
key_index = 1
####################################################################################
#
new_basin_to_cities = load_json() # keys = all basins with multiple cities 180?
rate_cities = []
#
# result_dictが更新されないことが大事
result_dict =  make_result_dict(new_basin_to_cities, key_index=key_index) # keys = all cities in key_index basin
#
riv_num = list(new_basin_to_cities.keys())[key_index]
city_num_lst = list(result_dict.keys())

for city_num in city_num_lst:
    #
    rate, discharge = discharge_rate(city_num, riv_num)
    print(f'rate {rate}')
    if rate < 1:
        rate_cities.append(city_num)
    print(f'discharge {discharge/1e9}')
    #
    filtered_df = df[df['index'] == city_num]
    if filtered_df.empty:
        print(f'City number {city_num} not found in the data.')
    #
    mpcy = filtered_df.reset_index(drop=True).loc[0, 'mpcy']
    est_pop = filtered_df.reset_index(drop=True).loc[0, 'pop']
    #
    # take all available water
    if mpcy <= 1000:
        print(f'shortage: mpcy={mpcy}')
        consumption = discharge
    #
    # take population * ratio * 1000m3/year
    else:
        print(f'no shortage: mpcy={mpcy}')
        consumption = 1000*est_pop*rate
        if consumption < discharge:
            consumption = consumption
        else:
            consumption = discharge
    #
    print(f'consumption: {consumption/1e9}')
    result_dict[city_num][0] = discharge
    result_dict[city_num][1] = consumption
    print(f'--------------------------------------')
# Out:
# uid: 14.0
# cities in uid
# [2, 11, 126, 130, 133, 188, 197, 217, 243, 319, 321, 363, 398, 406, 455, 463, 473, 513, 526, 588, 667, 669, 673, 677, 797, 874, 883, 903, 941, 983, 1012, 1018, 1067, 1089, 1181, 1216, 1253, 1288, 1298, 1337, 1365, 1371, 1422, 1578, 1620, 1652, 1656, 1697, 1712, 1718, 1824]
# city_num, riv_num, 2, 14
# city_num: 2, prf: 4.42079778375, int: 19.248677595
# int_runout > prf_runout
# rate 1.0
# discharge 19.248677595
# shortage: mpcy=200.41454676994584
# consumption: 19.248677595
# --------------------------------------
# city_num, riv_num, 126, 14
# int out of riv_num
# rate 0.4661909341812134
# discharge 0.08944297140234375
# shortage: mpcy=29.34954200775133
# consumption: 0.08944297140234375
# --------------------------------------
# city_num, riv_num, 130, 14
# city_num: 130, prf: 87.145943796, int: 6.65100300825
# prf_runout > int_runout
# rate 1.0
# discharge 87.145943796
# no shortage: mpcy=29435.99123465833
# consumption: 2.9605235
# --------------------------------------
# city_num, riv_num, 133, 14
# city_num: 133, prf: 6.701539941, int: 87.196582728
# int_runout > prf_runout
# rate 1.0
# discharge 87.196582728
# no shortage: mpcy=2330.7047139234824
# consumption: 2.87532775
# --------------------------------------
# city_num, riv_num, 188, 14
# city_num: 188, prf: 0.0565119422578125, int: 0.056030028908203126
# prf_runout > int_runout
# rate 1.0
# discharge 0.0565119422578125
# shortage: mpcy=25.9873561477
# consumption: 0.0565119422578125
# --------------------------------------
# city_num, riv_num, 197, 14
# city_num: 197, prf: 591.25080384, int: 56.497291938
# prf_runout > int_runout
# rate 1.0
# discharge 591.25080384
# no shortage: mpcy=291616.63911232265
# consumption: 2.027493375
# --------------------------------------
# city_num, riv_num, 217, 14
# city_num: 217, prf: 0.25847798709375, int: 0.2720333548125
# int_runout > prf_runout
# rate 1.0
# discharge 0.2720333548125
# shortage: mpcy=135.38795926321723
# consumption: 0.2720333548125
# --------------------------------------
# city_num, riv_num, 243, 14
# city_num: 243, prf: 30.390383844, int: 3.641325674625
# prf_runout > int_runout
# rate 1.0
# discharge 30.390383844
# no shortage: mpcy=17021.375990039345
# consumption: 1.785424625
# --------------------------------------
# city_num, riv_num, 319, 14
# city_num: 319, prf: 0.1305414087890625, int: 45.876459888
# int_runout > prf_runout
# rate 1.0
# discharge 45.876459888
# shortage: mpcy=78.90872048709167
# consumption: 45.876459888
# --------------------------------------
# city_num, riv_num, 321, 14
# city_num: 321, prf: 0.1861881898359375, int: 33.889220262
# int_runout > prf_runout
# rate 1.0
# discharge 33.889220262
# shortage: mpcy=130.55829559143214
# consumption: 33.889220262
# --------------------------------------
# city_num, riv_num, 363, 14
# city_num: 363, prf: 246.507466968, int: 92.2232871
# prf_runout > int_runout
# rate 1.0
# discharge 246.507466968
# no shortage: mpcy=176389.42813041725
# consumption: 1.397518375
# --------------------------------------
# city_num, riv_num, 406, 14
# city_num: 406, prf: 0.1439401436015625, int: 6.8335545645
# int_runout > prf_runout
# rate 1.0
# discharge 6.8335545645
# shortage: mpcy=284.78096259081866
# consumption: 6.8335545645
# --------------------------------------
# city_num, riv_num, 455, 14
# city_num: 455, prf: 20.418117228, int: 12.1408761195
# prf_runout > int_runout
# rate 1.0
# discharge 20.418117228
# no shortage: mpcy=20757.446998120908
# consumption: 0.983652625
# --------------------------------------
# city_num, riv_num, 463, 14
# city_num: 463, prf: 0.07312175173828125, int: 22.907352258
# int_runout > prf_runout
# rate 1.0
# discharge 22.907352258
# shortage: mpcy=74.84237800870129
# consumption: 22.907352258
# --------------------------------------
# city_num, riv_num, 473, 14
# city_num: 473, prf: 328.876834176, int: 19.687177791
# prf_runout > int_runout
# rate 1.0
# discharge 328.876834176
# no shortage: mpcy=345223.44478040084
# consumption: 0.9526491875
# --------------------------------------
# city_num, riv_num, 513, 14
# city_num: 513, prf: 0.98778654478125, int: 39.661944192
# int_runout > prf_runout
# rate 1.0
# discharge 39.661944192
# no shortage: mpcy=1063.7408313630672
# consumption: 0.928597
# --------------------------------------
# city_num, riv_num, 526, 14
# city_num: 526, prf: 0.2345311840078125, int: 39.496202802
# int_runout > prf_runout
# rate 1.0
# discharge 39.496202802
# shortage: mpcy=267.9306100669252
# consumption: 39.496202802
# --------------------------------------
# city_num, riv_num, 588, 14
# city_num: 588, prf: 827.483069376, int: 19.038458619
# prf_runout > int_runout
# rate 1.0
# discharge 827.483069376
# no shortage: mpcy=953003.7948189796
# consumption: 0.868289375
# --------------------------------------
# city_num, riv_num, 667, 14
# city_num: 667, prf: 0.51893159371875, int: 5.756583411
# int_runout > prf_runout
# rate 1.0
# discharge 5.756583411
# shortage: mpcy=712.7499567349071
# consumption: 5.756583411
# --------------------------------------
# city_num, riv_num, 669, 14
# city_num: 669, prf: 2.466189851625, int: 86.406873984
# int_runout > prf_runout
# rate 1.0
# discharge 86.406873984
# no shortage: mpcy=3368.812675957736
# consumption: 0.732065
# --------------------------------------
# city_num, riv_num, 673, 14
# city_num: 673, prf: 1.825538229, int: 14.289763797
# int_runout > prf_runout
# rate 1.0
# discharge 14.289763797
# no shortage: mpcy=2653.7230718799738
# consumption: 0.687915875
# --------------------------------------
# city_num, riv_num, 677, 14
# city_num: 677, prf: 0.08963806960546875, int: 32.667907851
# int_runout > prf_runout
# rate 1.0
# discharge 32.667907851
# shortage: mpcy=110.49176796009472
# consumption: 32.667907851
# --------------------------------------
# city_num, riv_num, 797, 14
# city_num: 797, prf: 31.437966402, int: 41.93014734
# int_runout > prf_runout
# rate 1.0
# discharge 41.93014734
# no shortage: mpcy=48155.15479709174
# consumption: 0.652847375
# --------------------------------------
# city_num, riv_num, 883, 14
# city_num: 883, prf: 0.06896914730859376, int: 22.908410685
# int_runout > prf_runout
# rate 1.0
# discharge 22.908410685
# shortage: mpcy=115.95830998987432
# consumption: 22.908410685
# --------------------------------------
# city_num, riv_num, 941, 14
# city_num: 941, prf: 0.8571333279375, int: 0.993544882875
# int_runout > prf_runout
# rate 1.0
# discharge 0.993544882875
# no shortage: mpcy=1567.5224535637128
# consumption: 0.5468076875
# --------------------------------------
# city_num, riv_num, 983, 14
# city_num: 983, prf: 0.048419474361328124, int: 32.990188032
# int_runout > prf_runout
# rate 1.0
# discharge 32.990188032
# shortage: mpcy=98.19149981073672
# consumption: 32.990188032
# --------------------------------------
# city_num, riv_num, 1012, 14
# city_num: 1012, prf: 3.04763361975, int: 65.844716076
# int_runout > prf_runout
# rate 1.0
# discharge 65.844716076
# no shortage: mpcy=4950.952378515596
# consumption: 0.615565125
# --------------------------------------
# city_num, riv_num, 1018, 14
# int out of riv_num
# rate 0.09329782426357269
# discharge 0.066265420359375
# shortage: mpcy=537.0966030756781
# consumption: 0.066265420359375
# --------------------------------------
# city_num, riv_num, 1067, 14
# city_num: 1067, prf: 1.418693032125, int: 28.304519877
# int_runout > prf_runout
# rate 1.0
# discharge 28.304519877
# no shortage: mpcy=2868.9054735416576
# consumption: 0.49450671875
# --------------------------------------
# city_num, riv_num, 1089, 14
# city_num: 1089, prf: 0.04395905131640625, int: 18.263201247
# int_runout > prf_runout
# rate 1.0
# discharge 18.263201247
# shortage: mpcy=97.51334238887056
# consumption: 18.263201247
# --------------------------------------
# city_num, riv_num, 1253, 14
# city_num: 1253, prf: 0.2212189576171875, int: 32.667907851
# int_runout > prf_runout
# rate 1.0
# discharge 32.667907851
# shortage: mpcy=572.2110089568439
# consumption: 32.667907851
# --------------------------------------
# city_num, riv_num, 1288, 14
# city_num: 1288, prf: 1.612417941, int: 19.048786659
# int_runout > prf_runout
# rate 1.0
# discharge 19.048786659
# no shortage: mpcy=3853.229163797757
# consumption: 0.418458875
# --------------------------------------
# city_num, riv_num, 1298, 14
# city_num: 1298, prf: 0.367068291890625, int: 0.09287203405078125
# prf_runout > int_runout
# rate 1.0
# discharge 0.367068291890625
# shortage: mpcy=932.1655397423928
# consumption: 0.367068291890625
# --------------------------------------
# city_num, riv_num, 1337, 14
# city_num: 1337, prf: 1.66044924, int: 1.1367674746875
# prf_runout > int_runout
# rate 1.0
# discharge 1.66044924
# no shortage: mpcy=4304.333845576817
# consumption: 0.3857621875
# --------------------------------------
# city_num, riv_num, 1365, 14
# city_num: 1365, prf: 0.174752771203125, int: 1.7296509268125
# int_runout > prf_runout
# rate 1.0
# discharge 1.7296509268125
# shortage: mpcy=459.0054529426322
# consumption: 1.7296509268125
# --------------------------------------
# city_num, riv_num, 1371, 14
# city_num: 1371, prf: 0.06634956512109375, int: 42.139175832
# int_runout > prf_runout
# rate 1.0
# discharge 42.139175832
# shortage: mpcy=171.55578685209227
# consumption: 42.139175832
# --------------------------------------
# city_num, riv_num, 1422, 14
# city_num: 1422, prf: 0.04071351109570313, int: 0.731685706875
# int_runout > prf_runout
# rate 1.0
# discharge 0.731685706875
# shortage: mpcy=111.65211503537334
# consumption: 0.731685706875
# --------------------------------------
# city_num, riv_num, 1578, 14
# city_num: 1578, prf: 0.29364580096875, int: 59.087260836
# int_runout > prf_runout
# rate 1.0
# discharge 59.087260836
# shortage: mpcy=747.0388582944774
# consumption: 59.087260836
# --------------------------------------
# city_num, riv_num, 1620, 14
# city_num: 1620, prf: 0.2005798158984375, int: 18.263201247
# int_runout > prf_runout
# rate 1.0
# discharge 18.263201247
# shortage: mpcy=603.7627510118832
# consumption: 18.263201247
# --------------------------------------
# city_num, riv_num, 1656, 14
# city_num: 1656, prf: 0.0493587828984375, int: 42.139175832
# int_runout > prf_runout
# rate 1.0
# discharge 42.139175832
# shortage: mpcy=138.3447509120834
# consumption: 42.139175832
# --------------------------------------
# city_num, riv_num, 1697, 14
# city_num: 1697, prf: 0.04992697754296875, int: 11.6460999315
# int_runout > prf_runout
# rate 1.0
# discharge 11.6460999315
# shortage: mpcy=162.48636615558104
# consumption: 11.6460999315
# --------------------------------------
# city_num, riv_num, 1712, 14
# city_num: 1712, prf: 3.66539429475, int: 89.842256028
# int_runout > prf_runout
# rate 1.0
# discharge 89.842256028
# no shortage: mpcy=10203.061305207646
# consumption: 0.3592445625
# --------------------------------------
# city_num, riv_num, 1718, 14
# city_num: 1718, prf: 0.11301882612890625, int: 1.4944801995
# int_runout > prf_runout
# rate 0.9588435888290405
# discharge 1.4944801995
# shortage: mpcy=577.9727627896847
# consumption: 1.4944801995
# --------------------------------------
# city_num, riv_num, 1824, 14
# city_num: 1824, prf: 0.96825861590625, int: 22.105640124
# int_runout > prf_runout
# rate 1.0
# discharge 22.105640124
# no shortage: mpcy=3914.083413423277
# consumption: 0.247378125
# --------------------------------------

# %%
# key_index=1を探索する
####################################################################################
# 上流と下流の取水の関係をrecursiveに探索
# result_dictのavaの部分を更新してreturn
# 二つの都市で，互いが互いの都市の更新を待っている状態だと，whileが無限になる
####################################################################################

def explore(result_dict):
    while True:
        all_done = True  # 全てのflagが'Done'であるかをチェックするためのフラグ
        
        for key in result_dict:
            value = result_dict[key]
            ava = value[0]
            con = value[1]
            flag = value[2]
            uup = value[3]
            
            ava_mod = ava
            
            if flag != 'Done':
                all_done = False  # まだ'Done'でないflagがある場合、all_doneをFalseに設定
        
            if flag is False:
                flg_lst = []
                for kkk in uup:
                    oth_flg = result_dict[kkk][2]
                    flg_lst.append(oth_flg)
                    
                for kkk in uup:
                    oth_con = result_dict[kkk][1]
                    ava_mod = ava_mod - np.abs(oth_con)
                result_dict[key][0] = ava_mod
                
                if con > ava_mod:
                    result_dict[key][1] = ava_mod
                    
                result_dict[key][2] = 'Done'
                
            elif flag is True:
                flg_lst = []
                for kkk in uup:
                    oth_flg = result_dict[kkk][2]
                    flg_lst.append(oth_flg)
                
                if all(item == 'Done' for item in flg_lst):
                    # 重複を削除する
                    all_upstream = []
                    for kkk in uup:
                        all_upstream.extend(result_dict[kkk][2])
                    mod_uup = [city for city in uup if city not in all_upstream]
                    for kkk in mod_uup:
                        oth_con = result_dict[kkk][1]
                        ava_mod = ava_mod - np.abs(oth_con)
                    result_dict[key][0] = ava_mod

                    if con > ava_mod:
                        result_dict[key][1] = ava_mod
                        
                    result_dict[key][2] = 'Done'
    
            else:
                flg_lst = []
                for kkk in uup:
                    oth_flg = result_dict[kkk][2]
                    flg_lst.append(oth_flg)
            print(key, flag, ava, con, flg_lst, uup)
                    
        print('------------------------------------------------------------------------------------------------------------------------------------------------------------------------')
        if all_done:
            print('all_done')
            break  # 全てのflagが'Done'であればループを終了
    return result_dict
    
result_dict_mod = explore(result_dict)
print(f'**********rivnum{list(new_basin_to_cities.keys())[key_index]}: calculation done***************')
print(f'--------------------------------------')

# uupがおかしい(find upstream)
# intakeを有効にすると↓
# 2[1089]
# 1089[1620]
# 1620[[1089]
# 2都市間で同じ流域に二つずつ取水点があり，それぞれで上下流の関係が逆になっている
# Out:
# 2 Done -63564753942.0 -63564753942.0 ['Done', 'Done', 'Done'] [1253 1288 1620]
# 126 Done 89442971.40234375 89442971.40234375 [] []
# 130 Done -93672561315.0 -93672561315.0 ['Done', 'Done', 'Done', 'Done', 'Done', 'Done'] [ 321  463  526 1371 1656 1824]
# 133 Done 87196582728.0 2875327750.0 [] []
# 188 Done 56511942.2578125 56511942.2578125 [] []
# 197 Done -1260923404118.4453 -1260923404118.4453 ['Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done'] [   2  126  130  133  188  217  243  319  321  363  406  455  463  513
#   526  667  669  677  797  883  941  983 1018 1067 1089 1253 1288 1298
#  1337 1371 1422 1620 1656 1697 1712 1718 1824]
# 217 Done 272033354.8125 272033354.8125 [] []
# 243 Done -206891874601.625 -206891874601.625 ['Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done'] [   2  667  677  983 1067 1089 1253 1288 1422 1620]
# 319 Done 45876459888.0 45876459888.0 [] []
# 321 Done 33889220262.0 33889220262.0 [] []
# 363 Done -634843238716.2227 -634843238716.2227 ['Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done'] [   2  126  188  217  243  406  455  513  667  677  797  883  941  983
#  1018 1067 1089 1253 1288 1298 1337 1422 1620 1718]
# 406 Done 6833554564.5 6833554564.5 [] []
# 455 Done 18320317398.742188 983652625.0 ['Done', 'Done', 'Done'] [ 188  941 1718]
# 463 Done 22907352258.0 22907352258.0 [] []
# 473 Done 327147183249.1875 952649187.5 ['Done'] [1365]
# 513 Done 39661944192.0 928597000.0 [] []
# 526 Done 39496202802.0 39496202802.0 [] []
# 588 Done -2346005284536.8906 -2346005284536.8906 ['Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done'] [   2  126  130  133  188  197  217  243  319  321  363  406  455  463
#   513  526  667  669  673  677  797  883  941  983 1012 1018 1067 1089
#  1253 1288 1298 1337 1371 1422 1578 1620 1656 1697 1712 1718 1824]
# 667 Done 5756583411.0 5756583411.0 [] []
# 669 Done 86406873984.0 732065000.0 [] []
# 673 Done 14289763797.0 687915875.0 [] []
# 677 Done 32667907851.0 32667907851.0 [] []
# 797 Done -402243985707.25 -402243985707.25 ['Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done'] [   2  243  667  677  983 1067 1089 1253 1288 1422 1620]
# 883 Done 22908410685.0 22908410685.0 [] []
# 941 Done 993544882.875 546807687.5 [] []
# 983 Done 32990188032.0 32990188032.0 [] []
# 1012 Done 65844716076.0 615565125.0 [] []
# 1018 Done 66265420.359375 66265420.359375 [] []
# 1067 Done 27572834170.125 494506718.75 ['Done'] [1422]
# 1089 Done 18263201247.0 18263201247.0 [] []
# 1253 Done 32667907851.0 32667907851.0 [] []
# 1288 Done -31882322439.0 -31882322439.0 ['Done', 'Done'] [1253 1620]
# 1298 Done 367068291.890625 367068291.890625 [] []
# 1337 Done 1660449240.0 385762187.5 [] []
# 1365 Done 1729650926.8125 1729650926.8125 [] []
# 1371 Done 42139175832.0 42139175832.0 [] []
# 1422 Done 731685706.875 731685706.875 [] []
# 1578 Done 59087260836.0 59087260836.0 [] []
# 1620 Done 18263201247.0 18263201247.0 [] []
# 1656 Done 42139175832.0 42139175832.0 [] []
# 1697 Done 11646099931.5 11646099931.5 [] []
# 1712 Done 89842256028.0 359244562.5 [] []
# 1718 Done 1494480199.5 1494480199.5 [] []
# 1824 Done 22105640124.0 247378125.0 [] []
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# all_done
# **********rivnum14.0: calculation done***************
# --------------------------------------

# %%
####################################################################################
# ここからが本番
# explore all key_index & make df_new
# it takes soooo long time
# df_newを作ってdfのavailabilityの部分を更新する
distance = 100
####################################################################################

df_new = df.copy()
duplicates_citynum = [3, 35, 52, 73, 77, 85, 97, 108, 128, 129, 167, 246, 335, 345, 
                      350, 486, 490, 502, 508, 543, 550, 627, 654, 658, 764, 790, 
                      1018, 1044, 1045, 1098, 1110, 1169, 1202, 1248, 1280, 1416, 
                      1450, 1718]
duplicates_dict = {}

new_basin_to_cities = load_json() # keys = all basins with multiple cities 180?
for key_index in range(len(new_basin_to_cities.keys())):
    #
    # result_dictが更新されないことが大事
    result_dict =  make_result_dict(new_basin_to_cities, key_index=key_index) # keys = all cities in key_index basin
    #
    riv_num = list(new_basin_to_cities.keys())[key_index]
    city_num_lst = list(result_dict.keys())
    
    for city_num in city_num_lst:
        rate, discharge = discharge_rate(city_num, riv_num)
        print(f'rate {rate}')
        if rate < 1:
            rate_cities.append(city_num)
        print(f'discharge {discharge/1e9}')
        #
        filtered_df = df[df['index'] == city_num]
        if filtered_df.empty:
            print(f'City number {city_num} not found in the data.')
        #
        mpcy = filtered_df.reset_index(drop=True).loc[0, 'mpcy']
        est_pop = filtered_df.reset_index(drop=True).loc[0, 'pop']
        #
        # take all available water
        if mpcy <= 1000:
            print(f'shortage: mpcy={mpcy}')
            consumption = discharge
        #
        # take population * ratio * 1000m3/year
        else:
            print(f'no shortage: mpcy={mpcy}')
            consumption = 1000*est_pop*rate
            if consumption < discharge:
                consumption = consumption
            else:
                consumption = discharge
        #
        print(f'consumption: {consumption/1e9}')
        result_dict[city_num][0] = discharge
        result_dict[city_num][1] = consumption
        print(f'--------------------------------------')
        
    print(f'**********rivnum{list(new_basin_to_cities.keys())[key_index]}: calculation done***************')
    print(f'--------------------------------------')

    # explore
    result_dict_mod = explore(result_dict)
    
    for city_num in result_dict_mod:
        city_num = int(city_num)
        riv_num = int(float(riv_num))
        
        h08dir = '/mnt/c/Users/tsimk/Downloads/dotfiles/h08'
        msk_dir = f'{h08dir}/global_city/dat/vld_cty_'
        ctymsk_path = f'{msk_dir}/city_{city_num:08}.gl5'
        ctymsk = np.fromfile(ctymsk_path, dtype='float32').reshape(2160, 4320)
        
        prf_dir = f'{h08dir}/global_city/dat/cty_prf_'
        prf_path = f'{prf_dir}/vld_cty_/city_{city_num:08}.gl5'
        prf = np.fromfile(prf_path, dtype='float32').reshape(2160, 4320)
        
        int_dir = f'{h08dir}/global_city/dat/cty_int_/{distance}km_samebasin'
        int_path = f'{int_dir}/city_{city_num:08}.gl5'
        intake = np.fromfile(int_path, dtype='float32').reshape(2160, 4320)
        ibt = np.sum(rivout_gl5[intake==1])*60*60*24*365/1000 # m3/year
        
        dis_els = np.sum(rivout_gl5[(prf==1) & (rivnum_gl5!=riv_num)])* 60 * 60 * 24 * 365 / (1000) # m3/year
        dis_mod = result_dict_mod[city_num][0]
        if dis_els:
            availability = dis_els + dis_mod
        else:
            availability = dis_mod
        print(f'dis_els:{dis_els}, dis_mod:{dis_mod}, availability:{availability/1e9} billion m3/year')
        print(f"mpcy: {availability/(df_new.loc[df_new['index'] == city_num, 'pop'])}")
        print(f'ava_int: {(availability+ibt)/1e9} billion m3/year')
        print(f"mpcy_int: {(availability+ibt)/df_new.loc[df_new['index'] == city_num, 'pop']}")
        print(f'--------------------------------------')
        
        df_new.loc[df_new['index'] == city_num, 'ava'] = availability
        df_new.loc[df_new['index'] == city_num, 'mpcy'] = availability/df_new.loc[df_new['index'] == city_num, 'pop']
        df_new.loc[df_new['index'] == city_num, 'ava_int'] = availability + ibt
        df_new.loc[df_new['index'] == city_num, 'mpcy_int'] = (availability+ibt)/df_new.loc[df_new['index'] == city_num, 'pop']
        
    df_new.head(10)
# Out:
# uid: 848.0
# cities in uid
# [1, 936, 1283]
# city_num, riv_num, 1, 848
# int out of riv_num
# rate 0.598730742931366
# discharge 11.001185775
# shortage: mpcy=447.5198211291927
# consumption: 11.001185775
# --------------------------------------
# city_num, riv_num, 1283, 848
# int out of riv_num
# rate 0.28908848762512207
# discharge 4.749225021
# no shortage: mpcy=10663.938545482102
# consumption: 0.1287466420456767
# --------------------------------------
# **********rivnum848.0: calculation done***************
# --------------------------------------
# 1 False 11001185775.0 11001185775.0 ['Done'] [1283]
# 1283 Done 4749225021.0 128746642.04567671 [] []
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 1 Done 10872439132.954323 10872439132.954323 ['Done'] [1283]
# 1283 Done 4749225021.0 128746642.04567671 [] []
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# all_done
# dis_els:3239722352.25, dis_mod:10872439132.954323, availability:14.112161485204323 billion m3/year
# mpcy: 0    443.473949
# Name: pop, dtype: float64
# ava_int: 17.407923555829324 billion m3/year
# mpcy_int: 0    547.043103
# Name: pop, dtype: float64
# --------------------------------------
# dis_els:0.0, dis_mod:4749225021.0, availability:4.749225021 billion m3/year
# mpcy: 1282    10663.938545
# Name: pop, dtype: float64
# ava_int: 14.729484042 billion m3/year
# mpcy_int: 1282    33073.672428
# Name: pop, dtype: float64
# --------------------------------------
# uid: 14.0
# cities in uid
# [2, 11, 126, 130, 133, 188, 197, 217, 243, 319, 321, 363, 398, 406, 455, 463, 473, 513, 526, 588, 667, 669, 673, 677, 797, 874, 883, 903, 941, 983, 1012, 1018, 1067, 1089, 1181, 1216, 1253, 1288, 1298, 1337, 1365, 1371, 1422, 1578, 1620, 1652, 1656, 1697, 1712, 1718, 1824]
# city_num, riv_num, 2, 14
# city_num: 2, prf: 4.42079778375, int: 19.248677595
# int_runout > prf_runout
# rate 1.0
# discharge 19.248677595
# shortage: mpcy=200.41454676994584
# consumption: 19.248677595
# --------------------------------------
# city_num, riv_num, 126, 14
# int out of riv_num
# rate 0.4661909341812134
# discharge 0.08944297140234375
# shortage: mpcy=29.34954200775133
# consumption: 0.08944297140234375
# --------------------------------------
# city_num, riv_num, 130, 14
# city_num: 130, prf: 87.145943796, int: 6.65100300825
# prf_runout > int_runout
# rate 1.0
# discharge 87.145943796
# no shortage: mpcy=29435.99123465833
# consumption: 2.9605235
# --------------------------------------
# city_num, riv_num, 133, 14
# city_num: 133, prf: 6.701539941, int: 87.196582728
# int_runout > prf_runout
# rate 1.0
# discharge 87.196582728
# no shortage: mpcy=2330.7047139234824
# consumption: 2.87532775
# --------------------------------------
# city_num, riv_num, 188, 14
# city_num: 188, prf: 0.0565119422578125, int: 0.056030028908203126
# prf_runout > int_runout
# rate 1.0
# discharge 0.0565119422578125
# shortage: mpcy=25.9873561477
# consumption: 0.0565119422578125
# --------------------------------------
# city_num, riv_num, 197, 14
# city_num: 197, prf: 591.25080384, int: 56.497291938
# prf_runout > int_runout
# rate 1.0
# discharge 591.25080384
# no shortage: mpcy=291616.63911232265
# consumption: 2.027493375
# --------------------------------------
# city_num, riv_num, 217, 14
# city_num: 217, prf: 0.25847798709375, int: 0.2720333548125
# int_runout > prf_runout
# rate 1.0
# discharge 0.2720333548125
# shortage: mpcy=135.38795926321723
# consumption: 0.2720333548125
# --------------------------------------
# city_num, riv_num, 243, 14
# city_num: 243, prf: 30.390383844, int: 3.641325674625
# prf_runout > int_runout
# rate 1.0
# discharge 30.390383844
# no shortage: mpcy=17021.375990039345
# consumption: 1.785424625
# --------------------------------------
# city_num, riv_num, 319, 14
# city_num: 319, prf: 0.1305414087890625, int: 45.876459888
# int_runout > prf_runout
# rate 1.0
# discharge 45.876459888
# shortage: mpcy=78.90872048709167
# consumption: 45.876459888
# --------------------------------------
# city_num, riv_num, 321, 14
# city_num: 321, prf: 0.1861881898359375, int: 33.889220262
# int_runout > prf_runout
# rate 1.0
# discharge 33.889220262
# shortage: mpcy=130.55829559143214
# consumption: 33.889220262
# --------------------------------------
# city_num, riv_num, 363, 14
# city_num: 363, prf: 246.507466968, int: 92.2232871
# prf_runout > int_runout
# rate 1.0
# discharge 246.507466968
# no shortage: mpcy=176389.42813041725
# consumption: 1.397518375
# --------------------------------------
# city_num, riv_num, 406, 14
# city_num: 406, prf: 0.1439401436015625, int: 6.8335545645
# int_runout > prf_runout
# rate 1.0
# discharge 6.8335545645
# shortage: mpcy=284.78096259081866
# consumption: 6.8335545645
# --------------------------------------
# city_num, riv_num, 455, 14
# city_num: 455, prf: 20.418117228, int: 12.1408761195
# prf_runout > int_runout
# rate 1.0
# discharge 20.418117228
# no shortage: mpcy=20757.446998120908
# consumption: 0.983652625
# --------------------------------------
# city_num, riv_num, 463, 14
# city_num: 463, prf: 0.07312175173828125, int: 22.907352258
# int_runout > prf_runout
# rate 1.0
# discharge 22.907352258
# shortage: mpcy=74.84237800870129
# consumption: 22.907352258
# --------------------------------------
# city_num, riv_num, 473, 14
# city_num: 473, prf: 328.876834176, int: 19.687177791
# prf_runout > int_runout
# rate 1.0
# discharge 328.876834176
# no shortage: mpcy=345223.44478040084
# consumption: 0.9526491875
# --------------------------------------
# city_num, riv_num, 513, 14
# city_num: 513, prf: 0.98778654478125, int: 39.661944192
# int_runout > prf_runout
# rate 1.0
# discharge 39.661944192
# no shortage: mpcy=1063.7408313630672
# consumption: 0.928597
# --------------------------------------
# city_num, riv_num, 526, 14
# city_num: 526, prf: 0.2345311840078125, int: 39.496202802
# int_runout > prf_runout
# rate 1.0
# discharge 39.496202802
# shortage: mpcy=267.9306100669252
# consumption: 39.496202802
# --------------------------------------
# city_num, riv_num, 588, 14
# city_num: 588, prf: 827.483069376, int: 19.038458619
# prf_runout > int_runout
# rate 1.0
# discharge 827.483069376
# no shortage: mpcy=953003.7948189796
# consumption: 0.868289375
# --------------------------------------
# city_num, riv_num, 667, 14
# city_num: 667, prf: 0.51893159371875, int: 5.756583411
# int_runout > prf_runout
# rate 1.0
# discharge 5.756583411
# shortage: mpcy=712.7499567349071
# consumption: 5.756583411
# --------------------------------------
# city_num, riv_num, 669, 14
# city_num: 669, prf: 2.466189851625, int: 86.406873984
# int_runout > prf_runout
# rate 1.0
# discharge 86.406873984
# no shortage: mpcy=3368.812675957736
# consumption: 0.732065
# --------------------------------------
# city_num, riv_num, 673, 14
# city_num: 673, prf: 1.825538229, int: 14.289763797
# int_runout > prf_runout
# rate 1.0
# discharge 14.289763797
# no shortage: mpcy=2653.7230718799738
# consumption: 0.687915875
# --------------------------------------
# city_num, riv_num, 677, 14
# city_num: 677, prf: 0.08963806960546875, int: 32.667907851
# int_runout > prf_runout
# rate 1.0
# discharge 32.667907851
# shortage: mpcy=110.49176796009472
# consumption: 32.667907851
# --------------------------------------
# city_num, riv_num, 797, 14
# city_num: 797, prf: 31.437966402, int: 41.93014734
# int_runout > prf_runout
# rate 1.0
# discharge 41.93014734
# no shortage: mpcy=48155.15479709174
# consumption: 0.652847375
# --------------------------------------
# city_num, riv_num, 883, 14
# city_num: 883, prf: 0.06896914730859376, int: 22.908410685
# int_runout > prf_runout
# rate 1.0
# discharge 22.908410685
# shortage: mpcy=115.95830998987432
# consumption: 22.908410685
# --------------------------------------
# city_num, riv_num, 941, 14
# city_num: 941, prf: 0.8571333279375, int: 0.993544882875
# int_runout > prf_runout
# rate 1.0
# discharge 0.993544882875
# no shortage: mpcy=1567.5224535637128
# consumption: 0.5468076875
# --------------------------------------
# city_num, riv_num, 983, 14
# city_num: 983, prf: 0.048419474361328124, int: 32.990188032
# int_runout > prf_runout
# rate 1.0
# discharge 32.990188032
# shortage: mpcy=98.19149981073672
# consumption: 32.990188032
# --------------------------------------
# city_num, riv_num, 1012, 14
# city_num: 1012, prf: 3.04763361975, int: 65.844716076
# int_runout > prf_runout
# rate 1.0
# discharge 65.844716076
# no shortage: mpcy=4950.952378515596
# consumption: 0.615565125
# --------------------------------------
# city_num, riv_num, 1018, 14
# int out of riv_num
# rate 0.09329782426357269
# discharge 0.066265420359375
# shortage: mpcy=537.0966030756781
# consumption: 0.066265420359375
# --------------------------------------
# city_num, riv_num, 1067, 14
# city_num: 1067, prf: 1.418693032125, int: 28.304519877
# int_runout > prf_runout
# rate 1.0
# discharge 28.304519877
# no shortage: mpcy=2868.9054735416576
# consumption: 0.49450671875
# --------------------------------------
# city_num, riv_num, 1089, 14
# city_num: 1089, prf: 0.04395905131640625, int: 18.263201247
# int_runout > prf_runout
# rate 1.0
# discharge 18.263201247
# shortage: mpcy=97.51334238887056
# consumption: 18.263201247
# --------------------------------------
# city_num, riv_num, 1253, 14
# city_num: 1253, prf: 0.2212189576171875, int: 32.667907851
# int_runout > prf_runout
# rate 1.0
# discharge 32.667907851
# shortage: mpcy=572.2110089568439
# consumption: 32.667907851
# --------------------------------------
# city_num, riv_num, 1288, 14
# city_num: 1288, prf: 1.612417941, int: 19.048786659
# int_runout > prf_runout
# rate 1.0
# discharge 19.048786659
# no shortage: mpcy=3853.229163797757
# consumption: 0.418458875
# --------------------------------------
# city_num, riv_num, 1298, 14
# city_num: 1298, prf: 0.367068291890625, int: 0.09287203405078125
# prf_runout > int_runout
# rate 1.0
# discharge 0.367068291890625
# shortage: mpcy=932.1655397423928
# consumption: 0.367068291890625
# --------------------------------------
# city_num, riv_num, 1337, 14
# city_num: 1337, prf: 1.66044924, int: 1.1367674746875
# prf_runout > int_runout
# rate 1.0
# discharge 1.66044924
# no shortage: mpcy=4304.333845576817
# consumption: 0.3857621875
# --------------------------------------
# city_num, riv_num, 1365, 14
# city_num: 1365, prf: 0.174752771203125, int: 1.7296509268125
# int_runout > prf_runout
# rate 1.0
# discharge 1.7296509268125
# shortage: mpcy=459.0054529426322
# consumption: 1.7296509268125
# --------------------------------------
# city_num, riv_num, 1371, 14
# city_num: 1371, prf: 0.06634956512109375, int: 42.139175832
# int_runout > prf_runout
# rate 1.0
# discharge 42.139175832
# shortage: mpcy=171.55578685209227
# consumption: 42.139175832
# --------------------------------------
# city_num, riv_num, 1422, 14
# city_num: 1422, prf: 0.04071351109570313, int: 0.731685706875
# int_runout > prf_runout
# rate 1.0
# discharge 0.731685706875
# shortage: mpcy=111.65211503537334
# consumption: 0.731685706875
# --------------------------------------
# city_num, riv_num, 1578, 14
# city_num: 1578, prf: 0.29364580096875, int: 59.087260836
# int_runout > prf_runout
# rate 1.0
# discharge 59.087260836
# shortage: mpcy=747.0388582944774
# consumption: 59.087260836
# --------------------------------------
# city_num, riv_num, 1620, 14
# city_num: 1620, prf: 0.2005798158984375, int: 18.263201247
# int_runout > prf_runout
# rate 1.0
# discharge 18.263201247
# shortage: mpcy=603.7627510118832
# consumption: 18.263201247
# --------------------------------------
# city_num, riv_num, 1656, 14
# city_num: 1656, prf: 0.0493587828984375, int: 42.139175832
# int_runout > prf_runout
# rate 1.0
# discharge 42.139175832
# shortage: mpcy=138.3447509120834
# consumption: 42.139175832
# --------------------------------------
# city_num, riv_num, 1697, 14
# city_num: 1697, prf: 0.04992697754296875, int: 11.6460999315
# int_runout > prf_runout
# rate 1.0
# discharge 11.6460999315
# shortage: mpcy=162.48636615558104
# consumption: 11.6460999315
# --------------------------------------
# city_num, riv_num, 1712, 14
# city_num: 1712, prf: 3.66539429475, int: 89.842256028
# int_runout > prf_runout
# rate 1.0
# discharge 89.842256028
# no shortage: mpcy=10203.061305207646
# consumption: 0.3592445625
# --------------------------------------
# city_num, riv_num, 1718, 14
# city_num: 1718, prf: 0.11301882612890625, int: 1.4944801995
# int_runout > prf_runout
# rate 0.9588435888290405
# discharge 1.4944801995
# shortage: mpcy=577.9727627896847
# consumption: 1.4944801995
# --------------------------------------
# city_num, riv_num, 1824, 14
# city_num: 1824, prf: 0.96825861590625, int: 22.105640124
# int_runout > prf_runout
# rate 1.0
# discharge 22.105640124
# no shortage: mpcy=3914.083413423277
# consumption: 0.247378125
# --------------------------------------
# **********rivnum14.0: calculation done***************
# --------------------------------------
# 2 True 19248677595.0 19248677595.0 ['Done', False, 'Done'] [1253 1288 1620]
# 126 Done 89442971.40234375 89442971.40234375 [] []
# 130 False 87145943796.0 2960523500.0 ['Done', 'Done', 'Done', 'Done', 'Done', 'Done'] [ 321  463  526 1371 1656 1824]
# 133 
# Name: pop, dtype: float64
# --------------------------------------
# dis_els:0.0, dis_mod:87196582728.0, availability:87.196582728 billion m3/year
# mpcy: 132    30325.789026
# Name: pop, dtype: float64
# ava_int: 174.393165456 billion m3/year
# mpcy_int: 132    60651.578053
# Name: pop, dtype: float64
# --------------------------------------
# dis_els:0.0, dis_mod:56511942.2578125, availability:0.0565119422578125 billion m3/year
# mpcy: 187    25.987356
# Name: pop, dtype: float64
# ava_int: 0.11254197116601562 billion m3/year
# mpcy_int: 187    51.753102
# Name: pop, dtype: float64
# --------------------------------------
# dis_els:0.0, dis_mod:-1260923404118.4453, availability:-1260.9234041184452 billion m3/year
# mpcy: 196   -621912.46574
# Name: pop, dtype: float64
# ava_int: -1204.4261121804452 billion m3/year
# mpcy_int: 196   -594046.87928
# Name: pop, dtype: float64
# --------------------------------------
# dis_els:0.0, dis_mod:272033354.8125, availability:0.2720333548125 billion m3/year
# mpcy: 216    142.488113
# Name: pop, dtype: float64
# ava_int: 0.544066709625 billion m3/year
# mpcy_int: 216    284.976227
# Name: pop, dtype: float64
# --------------------------------------
# dis_els:0.0, dis_mod:-206891874601.625, availability:-206.891874601625 billion m3/year
# mpcy: 242   -115878.246387
# Name: pop, dtype: float64
# ava_int: -203.250548927 billion m3/year
# mpcy_int: 242   -113838.773187
# Name: pop, dtype: float64
# --------------------------------------
# dis_els:0.0, dis_mod:45876459888.0, availability:45.876459888 billion m3/year
# mpcy: 318    27731.068508
# Name: pop, dtype: float64
# ava_int: 91.752919776 billion m3/year
# mpcy_int: 318    55462.137016
# Name: pop, dtype: float64
# --------------------------------------
# dis_els:0.0, dis_mod:33889220262.0, availability:33.889220262 billion m3/year
# mpcy: 320    23763.69221
# Name: pop, dtype: float64
# ava_int: 67.778440524 billion m3/year
# mpcy_int: 320    47527.384419
# Name: pop, dtype: float64
# --------------------------------------
# dis_els:0.0, dis_mod:-634843238716.2227, availability:-634.8432387162227 billion m3/year
# mpcy: 362   -454264.680932
# Name: pop, dtype: float64
# ava_int: -542.6199516162227 billion m3/year
# mpcy_int: 362   -388273.929934
# Name: pop, dtype: float64
# --------------------------------------
# dis_els:0.0, dis_mod:6833554564.5, availability:6.8335545645 billion m3/year
# mpcy: 405    13519.968774
# Name: pop, dtype: float64
# ava_int: 13.667109129 billion m3/year
# mpcy_int: 405    27039.937548
# Name: pop, dtype: float64
# --------------------------------------
# dis_els:0.0, dis_mod:18320317398.742188, availability:18.320317398742187 billion m3/year
# mpcy: 454    18624.783723
# Name: pop, dtype: float64
# ava_int: 30.461193518242187 billion m3/year
# mpcy_int: 454    30967.429704
# Name: pop, dtype: float64
# --------------------------------------
# dis_els:0.0, dis_mod:22907352258.0, availability:22.907352258 billion m3/year
# mpcy: 462    23446.384641
# Name: pop, dtype: float64
# ava_int: 45.814704516 billion m3/year
# mpcy_int: 462    46892.769282
# Name: pop, dtype: float64
# --------------------------------------
# dis_els:0.0, dis_mod:327147183249.1875, availability:327.1471832491875 billion m3/year
# mpcy: 472    343407.822672
# Name: pop, dtype: float64
# ava_int: 346.8343610401875 billion m3/year
# mpcy_int: 472    364073.538918
# Name: pop, dtype: float64
# --------------------------------------
# dis_els:0.0, dis_mod:39661944192.0, availability:39.661944192 billion m3/year
# mpcy: 512    42711.686762
# Name: pop, dtype: float64
# ava_int: 79.323888384 billion m3/year
# mpcy_int: 512    85423.373524
# Name: pop, dtype: float64
# --------------------------------------
# dis_els:0.0, dis_mod:39496202802.0, availability:39.496202802 billion m3/year
# mpcy: 525    45120.830123
# Name: pop, dtype: float64
# ava_int: 78.992405604 billion m3/year
# mpcy_int: 525    90241.660245
# Name: pop, dtype: float64
# --------------------------------------
# dis_els:0.0, dis_mod:-2346005284536.8906, availability:-2346.0052845368905 billion m3/year
# mpcy: 587   -2.701870e+06
# Name: pop, dtype: float64
# ava_int: -2326.9668259178907 billion m3/year
# mpcy_int: 587   -2.679944e+06
# Name: pop, dtype: float64
# --------------------------------------
# dis_els:0.0, dis_mod:5756583411.0, availability:5.756583411 billion m3/year
# mpcy: 666    7906.638614
# Name: pop, dtype: float64
# ava_int: 11.513166822 billion m3/year
# mpcy_int: 666    15813.277229
# Name: pop, dtype: float64
# --------------------------------------
# dis_els:0.0, dis_mod:86406873984.0, availability:86.406873984 billion m3/year
# mpcy: 668    118031.696617
# Name: pop, dtype: float64
# ava_int: 172.813747968 billion m3/year
# mpcy_int: 668    236063.393234
# Name: pop, dtype: float64
# --------------------------------------
# dis_els:0.0, dis_mod:14289763797.0, availability:14.289763797 billion m3/year
# mpcy: 672    20772.545476
# Name: pop, dtype: float64
# ava_int: 28.579527594 billion m3/year
# mpcy_int: 672    41545.090952
# Name: pop, dtype: float64
# --------------------------------------
# dis_els:0.0, dis_mod:32667907851.0, availability:32.667907851 billion m3/year
# mpcy: 676    40267.87848
# Name: pop, dtype: float64
# ava_int: 65.335815702 billion m3/year
# mpcy_int: 676    80535.756959
# Name: pop, dtype: float64
# --------------------------------------
# dis_els:0.0, dis_mod:-402243985707.25, availability:-402.24398570725 billion m3/year
# mpcy: 796   -616137.861789
# Name: pop, dtype: float64
# ava_int: -360.31383836725 billion m3/year
# mpcy_int: 796   -551911.292233
# Name: pop, dtype: float64
# --------------------------------------
# dis_els:0.0, dis_mod:22908410685.0, availability:22.908410685 billion m3/year
# mpcy: 882    38516.071189
# Name: pop, dtype: float64
# ava_int: 45.81682137 billion m3/year
# mpcy_int: 882    77032.142378
# Name: pop, dtype: float64
# --------------------------------------
# dis_els:0.0, dis_mod:993544882.875, availability:0.993544882875 billion m3/year
# mpcy: 940    1816.991432
# Name: pop, dtype: float64
# ava_int: 1.98708976575 billion m3/year
# mpcy_int: 940    3633.982863
# Name: pop, dtype: float64
# --------------------------------------
# dis_els:0.0, dis_mod:32990188032.0, availability:32.990188032 billion m3/year
# mpcy: 982    66901.924993
# Name: pop, dtype: float64
# ava_int: 65.980376064 billion m3/year
# mpcy_int: 982    133803.849985
# Name: pop, dtype: float64
# --------------------------------------
# dis_els:0.0, dis_mod:65844716076.0, availability:65.844716076 billion m3/year
# mpcy: 1011    106966.287403
# Name: pop, dtype: float64
# ava_int: 131.689432152 billion m3/year
# mpcy_int: 1011    213932.574806
# Name: pop, dtype: float64
# --------------------------------------
# dis_els:142311312.28125, dis_mod:66265420.359375, availability:0.208576732640625 billion m3/year
# mpcy: 1017    537.096603
# Name: pop, dtype: float64
# ava_int: 0.918004490859375 billion m3/year
# mpcy_int: 1017    2363.912251
# Name: pop, dtype: float64
# --------------------------------------
# dis_els:0.0, dis_mod:27572834170.125, availability:27.572834170125 billion m3/year
# mpcy: 1066    55758.259948
# Name: pop, dtype: float64
# ava_int: 55.877354047125 billion m3/year
# mpcy_int: 1066    112996.147329
# Name: pop, dtype: float64
# --------------------------------------
# dis_els:0.0, dis_mod:18263201247.0, availability:18.263201247 billion m3/year
# mpcy: 1088    40512.835081
# Name: pop, dtype: float64
# ava_int: 36.526402494 billion m3/year
# mpcy_int: 1088    81025.670163
# Name: pop, dtype: float64
# --------------------------------------
# dis_els:0.0, dis_mod:32667907851.0, availability:32.667907851 billion m3/year
# mpcy: 1252    84499.704335
# Name: pop, dtype: float64
# ava_int: 65.335815702 billion m3/year
# mpcy_int: 1252    168999.40867
# Name: pop, dtype: float64
# --------------------------------------
# dis_els:0.0, dis_mod:-31882322439.0, availability:-31.882322439 billion m3/year
# mpcy: 1287   -76189.858416
# Name: pop, dtype: float64
# ava_int: -12.83353578 billion m3/year
# mpcy_int: 1287   -30668.571147
# Name: pop, dtype: float64
# --------------------------------------
# dis_els:0.0, dis_mod:367068291.890625, availability:0.367068291890625 billion m3/year
# mpcy: 1297    932.16554
# Name: pop, dtype: float64
# ava_int: 0.45994032594140627 billion m3/year
# mpcy_int: 1297    1168.01296
# Name: pop, dtype: float64
# --------------------------------------
# dis_els:0.0, dis_mod:1660449240.0, availability:1.66044924 billion m3/year
# mpcy: 1336    4304.333846
# Name: pop, dtype: float64
# ava_int: 2.7972167146875 billion m3/year
# mpcy_int: 1336    7251.142816
# Name: pop, dtype: float64
# --------------------------------------
# dis_els:0.0, dis_mod:1729650926.8125, availability:1.7296509268125 billion m3/year
# mpcy: 1364    4543.099383
# Name: pop, dtype: float64
# ava_int: 3.459301853625 billion m3/year
# mpcy_int: 1364    9086.198767
# Name: pop, dtype: float64
# --------------------------------------
# dis_els:0.0, dis_mod:42139175832.0, availability:42.139175832 billion m3/year
# mpcy: 1370    108956.546346
# Name: pop, dtype: float64
# ava_int: 84.278351664 billion m3/year
# mpcy_int: 1370    217913.092692
# Name: pop, dtype: float64
# --------------------------------------
# dis_els:0.0, dis_mod:731685706.875, availability:0.731685706875 billion m3/year
# mpcy: 1421    2006.56378
# Name: pop, dtype: float64
# ava_int: 1.46337141375 billion m3/year
# mpcy_int: 1421    4013.12756
# Name: pop, dtype: float64
# --------------------------------------
# dis_els:0.0, dis_mod:59087260836.0, availability:59.087260836 billion m3/year
# mpcy: 1577    150318.784498
# Name: pop, dtype: float64
# ava_int: 118.174521672 billion m3/year
# mpcy_int: 1577    300637.568997
# Name: pop, dtype: float64
# --------------------------------------
# dis_els:0.0, dis_mod:18263201247.0, availability:18.263201247 billion m3/year
# mpcy: 1619    54973.829634
# Name: pop, dtype: float64
# ava_int: 36.526402494 billion m3/year
# mpcy_int: 1619    109947.659268
# Name: pop, dtype: float64
# --------------------------------------
# dis_els:0.0, dis_mod:42139175832.0, availability:42.139175832 billion m3/year
# mpcy: 1655    118109.350389
# Name: pop, dtype: float64
# ava_int: 84.278351664 billion m3/year
# mpcy_int: 1655    236218.700778
# Name: pop, dtype: float64
# --------------------------------------
# dis_els:0.0, dis_mod:11646099931.5, availability:11.6460999315 billion m3/year
# mpcy: 1696    37902.003103
# Name: pop, dtype: float64
# ava_int: 23.292199863 billion m3/year
# mpcy_int: 1696    75804.006206
# Name: pop, dtype: float64
# --------------------------------------
# dis_els:0.0, dis_mod:89842256028.0, availability:89.842256028 billion m3/year
# mpcy: 1711    250086.613428
# Name: pop, dtype: float64
# ava_int: 179.684512056 billion m3/year
# mpcy_int: 1711    500173.226856
# Name: pop, dtype: float64
# --------------------------------------
# dis_els:57826133.455078125, dis_mod:1494480199.5, availability:1.5523063329550781 billion m3/year
# mpcy: 1717    5251.49119
# Name: pop, dtype: float64
# ava_int: 3.0467865324550782 billion m3/year
# mpcy_int: 1717    10307.355123
# Name: pop, dtype: float64
# --------------------------------------
# dis_els:0.0, dis_mod:22105640124.0, availability:22.105640124 billion m3/year
# mpcy: 1823    89359.720565
# Name: pop, dtype: float64
# ava_int: 44.211280248 billion m3/year
# mpcy_int: 1823    178719.441131
# Name: pop, dtype: float64
# --------------------------------------
# uid: 480.0
# cities in uid
# [3, 52, 85, 144, 275, 612, 618, 967, 1200, 1299, 1376, 1687]
# city_num, riv_num, 3, 480
# int out of riv_num
# rate 0.9814369082450867
# discharge 16.411618224
# no shortage: mpcy=1130.3605048650418
# consumption: 14.270252620099603
# --------------------------------------
# city_num, riv_num, 52, 480
# int out of riv_num
# rate 0.0013098912313580513
# discharge 0.0585579634453125
# no shortage: mpcy=8677.524169842614
# consumption: 0.006009781624416355
# --------------------------------------
# city_num, riv_num, 85, 480
# city_num: 85, prf: 0.0273896781328125, int: 1.8747330339375
# int_runout > prf_runout
# rate 0.9894720911979675
# discharge 1.8747330339375
# shortage: mpcy=19.346184564626085
# consumption: 1.8747330339375
# --------------------------------------
# city_num, riv_num, 144, 480
# city_num: 144, prf: 0.2660981810625, int: 1.8625803406875
# int_runout > prf_runout
# rate 1.0
# discharge 1.8625803406875
# shortage: mpcy=96.16828772566588
# consumption: 1.8625803406875
# --------------------------------------
# city_num, riv_num, 612, 480
# int out of riv_num
# rate 0.01773487590253353
# discharge 0.03525960781054688
# shortage: mpcy=40.854525246521376
# consumption: 0.03525960781054688
# --------------------------------------
# city_num, riv_num, 618, 480
# int out of riv_num
# rate 0.0728432834148407
# discharge 2.0830385385
# no shortage: mpcy=2728.579748938957
# consumption: 0.0556096506554354
# --------------------------------------
# city_num, riv_num, 967, 480
# int out of riv_num
# rate 0.08505168557167053
# discharge 0.58605763275
# no shortage: mpcy=1017.8487147504404
# consumption: 0.04897111799149029
# --------------------------------------
# city_num, riv_num, 1200, 480
# int out of riv_num
# rate 0.015322946012020111
# discharge 0.03828777598828125
# shortage: mpcy=78.29521836584769
# consumption: 0.03828777598828125
# --------------------------------------
# city_num, riv_num, 1299, 480
# int out of riv_num
# rate 0.09814029186964035
# discharge 0.70344257034375
# no shortage: mpcy=1826.039644730364
# consumption: 0.03780644049338787
# --------------------------------------
# city_num, riv_num, 1376, 480
# int out of riv_num
# rate 0.42974182963371277
# discharge 3.936215854125
# no shortage: mpcy=10788.970189343958
# consumption: 0.15678573332750706
# --------------------------------------
# city_num, riv_num, 1687, 480
# int out of riv_num
# rate 0.10129843652248383
# discharge 0.27818564653125
# shortage: mpcy=837.8920905076321
# consumption: 0.27818564653125
# --------------------------------------
# **********rivnum480.0: calculation done***************
# --------------------------------------
# 3 True 16411618224.0 14270252620.099604 ['Done', 'Done', 'Done', 'Done', False, 'Done', 'Done', 'Done', False, 'Done'] [  52   85  144  612  618  967 1200 1299 1376 1687]
# 52 Done 58557963.4453125 6009781.624416355 [] []
# 85 Done 1874733033.9375 1874733033.9375 [] []
# 144 Done 1862580340.6875 1862580340.6875 [] []
# 612 Done 35259607.810546875 35259607.810546875 [] []
# 618 False 2083038538.5 55609650.6554354 ['Done', 'Done'] [  52 1200]
# 967 Done 586057632.75 48971117.99149029 [] []
# 1200 Done 38287775.98828125 38287775.98828125 [] []
# 1299 Done 703442570.34375 37806440.49338787 [] []
# 1376 False 3936215854.125 156785733.32750705 ['Done', 'Done'] [ 967 1299]
# 1687 Done 278185646.53125 278185646.53125 [] []
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 3 True 16411618224.0 14270252620.099604 ['Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done', 'Done'] [  52   85  144  612  618  967 1200 1299 1376 1687]
# 52 Done 58557963.4453125 6009781.624416355 [] []
# 85 Done 1874733033.9375 1874733033.9375 [] []
# 144 Done 1862580340.6875 1862580340.6875 [] []
# 612 Done 35259607.810546875 35259607.810546875 [] []
# 618 Done 2038740980.8873024 55609650.6554354 ['Done', 'Done'] [  52 1200]
# 967 Done 586057632.75 48971117.99149029 [] []
# 1200 Done 38287775.98828125 38287775.98828125 [] []
# 1299 Done 703442570.34375 37806440.49338787 [] []
# 1376 Done 3849438295.640122 156785733.32750705 ['Done', 'Done'] [ 967 1299]
# 1687 Done 278185646.53125 278185646.53125 [] []
# ...
# 1110 Done 25089340.201171875 25089340.201171875 [] []
# 1204 Done 43840571.888671875 43840571.888671875 [] []
# 1272 Done 870801843.375 103127515.33806324 [] []
# 1379 Done 11518627797.5 287923625.0 ['Done'] [640]
# 1427 Done 1055474934.75 346214343.75 [] []
# 1445 Done 1074049269.1875 1074049269.1875 [] []
# 1555 Done 35133114487.51172 326179093.75 ['Done', 'Done', 'Done', 'Done', 'Done'] [ 736 1110 1204 1427 1831]
# 1612 Done 606414551.90625 606414551.90625 [] []
# 1638 Done 23919220296.0 293987937.5 [] []
# 1682 Done 2226573903.375 324285781.25 [] []
# 1831 Done 139119323.9765625 139119323.9765625 [] []
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# all_done
# dis_els:0.0, dis_mod:40079942046.0, availability:40.079942046 billion m3/year
# mpcy: 137    14219.599304
# Name: pop, dtype: float64
# ava_int: 66.874147695 billion m3/year
# mpcy_int: 137    23725.67263
# Name: pop, dtype: float64
# --------------------------------------
# dis_els:0.0, dis_mod:32646733907.5, availability:32.6467339075 billion m3/year
# mpcy: 270    20006.672974
# Name: pop, dtype: float64
# ava_int: 65.5874557525 billion m3/year
# mpcy_int: 270    40193.50855
# Name: pop, dtype: float64
# --------------------------------------
# dis_els:0.0, dis_mod:1642215395.8125, availability:1.6422153958125 billion m3/year
# mpcy: 466    1706.835771
# Name: pop, dtype: float64
# ava_int: 4.7532777665625 billion m3/year
# mpcy_int: 466    4940.31693
# Name: pop, dtype: float64
# --------------------------------------
# dis_els:0.0, dis_mod:152430422399.39023, availability:152.43042239939024 billion m3/year
# mpcy: 593    189245.569469
# Name: pop, dtype: float64
# ava_int: 181.55500047839024 billion m3/year
# mpcy_int: 593    225404.344583
# Name: pop, dtype: float64
# --------------------------------------
# dis_els:0.0, dis_mod:10153913976.0, availability:10.153913976 billion m3/year
# mpcy: 639    13688.203961
# Name: pop, dtype: float64
# ava_int: 14.110891605 billion m3/year
# mpcy_int: 639    19022.493476
# Name: pop, dtype: float64
# --------------------------------------
# dis_els:0.0, dis_mod:66508390822.0, availability:66.508390822 billion m3/year
# mpcy: 715    100359.489981
# Name: pop, dtype: float64
# ava_int: 135.835422394 billion m3/year
# mpcy_int: 715    204972.238003
# Name: pop, dtype: float64
# --------------------------------------
# dis_els:0.0, dis_mod:25964883136.5, availability:25.9648831365 billion m3/year
# mpcy: 725    39871.445124
# Name: pop, dtype: float64
# ava_int: 29.945469157125 billion m3/year
# mpcy_int: 725    45983.997846
# Name: pop, dtype: float64
# --------------------------------------
# dis_els:0.0, dis_mod:244850708.671875, availability:0.244850708671875 billion m3/year
# mpcy: 735    375.65637
# Name: pop, dtype: float64
# ava_int: 0.48970141734375 billion m3/year
# mpcy_int: 735    751.312739
# Name: pop, dtype: float64
# --------------------------------------
# dis_els:0.0, dis_mod:127324776688.82422, availability:127.32477668882422 billion m3/year
# mpcy: 907    232653.157071
# Name: pop, dtype: float64
# ava_int: 140.43328864982422 billion m3/year
# mpcy_int: 907    256605.578363
# Name: pop, dtype: float64
# --------------------------------------
# dis_els:0.0, dis_mod:67530113186.26172, availability:67.53011318626172 billion m3/year
# mpcy: 958    135401.887648
# Name: pop, dtype: float64
# ava_int: 119.97579781426172 billion m3/year
# mpcy_int: 958    240558.600151
# Name: pop, dtype: float64
# --------------------------------------
# dis_els:24752714.958984375, dis_mod:25089340.201171875, availability:0.04984205516015625 billion m3/year
# mpcy: 1109    107.845216
# Name: pop, dtype: float64
# ava_int: 0.37769982739453123 billion m3/year
# mpcy_int: 1109    817.24398
# Name: pop, dtype: float64
# --------------------------------------
# dis_els:0.0, dis_mod:43840571.888671875, availability:0.043840571888671874 billion m3/year
# mpcy: 1203    103.267061
# Name: pop, dtype: float64
# ava_int: 0.8285110703261719 billion m3/year
# mpcy_int: 1203    1951.569041
# Name: pop, dtype: float64
# --------------------------------------
# dis_els:0.0, dis_mod:870801843.375, availability:0.870801843375 billion m3/year
# mpcy: 1271    2132.092089
# Name: pop, dtype: float64
# ava_int: 3.7953329625 billion m3/year
# mpcy_int: 1271    9292.584122
# Name: pop, dtype: float64
# --------------------------------------
# dis_els:0.0, dis_mod:11518627797.5, availability:11.5186277975 billion m3/year
# mpcy: 1378    40005.844597
# Name: pop, dtype: float64
# ava_int: 18.019984109 billion m3/year
# mpcy_int: 1378    62585.986506
# Name: pop, dtype: float64
# --------------------------------------
# dis_els:0.0, dis_mod:1055474934.75, availability:1.05547493475 billion m3/year
# mpcy: 1426    3048.617002
# Name: pop, dtype: float64
# ava_int: 2.1109498695 billion m3/year
# mpcy_int: 1426    6097.234004
# Name: pop, dtype: float64
# --------------------------------------
# dis_els:0.0, dis_mod:1074049269.1875, availability:1.0740492691875 billion m3/year
# mpcy: 1444    3097.698357
# Name: pop, dtype: float64
# ava_int: 2.148098538375 billion m3/year
# mpcy_int: 1444    6195.396714
# Name: pop, dtype: float64
# --------------------------------------
# dis_els:0.0, dis_mod:35133114487.51172, availability:35.13311448751172 billion m3/year
# mpcy: 1554    107711.11687
# Name: pop, dtype: float64
# ava_int: 66.69957826351173 billion m3/year
# mpcy_int: 1554    204487.59452
# Name: pop, dtype: float64
# --------------------------------------
# dis_els:0.0, dis_mod:606414551.90625, availability:0.60641455190625 billion m3/year
# mpcy: 1611    1948.472828
# Name: pop, dtype: float64
# ava_int: 1.2128291038125 billion m3/year
# mpcy_int: 1611    3896.945656
# Name: pop, dtype: float64
# --------------------------------------
# dis_els:0.0, dis_mod:23919220296.0, availability:23.919220296 billion m3/year
# mpcy: 1637    81361.230326
# Name: pop, dtype: float64
# ava_int: 47.838440592 billion m3/year
# mpcy_int: 1637    162722.460652
# Name: pop, dtype: float64
# --------------------------------------
# dis_els:0.0, dis_mod:2226573903.375, availability:2.226573903375 billion m3/year
# mpcy: 1681    6866.085509
# Name: pop, dtype: float64
# ava_int: 4.45314780675 billion m3/year
# mpcy_int: 1681    13732.171018
# Name: pop, dtype: float64
# --------------------------------------
# dis_els:0.0, dis_mod:139119323.9765625, availability:0.1391193239765625 billion m3/year
# mpcy: 1830    606.82661
# Name: pop, dtype: float64
# ava_int: 0.3435053718515625 billion m3/year
# mpcy_int: 1830    1498.341096
# Name: pop, dtype: float64
# --------------------------------------
# uid: 382.0
# cities in uid
# [23, 24, 231, 1086, 1287]
# city_num, riv_num, 231, 382
# city_num: 231, prf: 15.850563219, int: 2.46768559425
# prf_runout > int_runout
# rate 1.0
# discharge 15.850563219
# no shortage: mpcy=10341.829841186782
# consumption: 1.53266525
# --------------------------------------
# city_num, riv_num, 1086, 382
# city_num: 1086, prf: 7.0583076945, int: 4.5802048725
# prf_runout > int_runout
# rate 1.0
# discharge 7.0583076945
# no shortage: mpcy=15613.300522056656
# consumption: 0.4520701875
# --------------------------------------
# **********rivnum382.0: calculation done***************
# --------------------------------------
# 231 False 15850563219.0 1532665250.0 ['Done'] [1086]
# 1086 Done 7058307694.5 452070187.5 [] []
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 231 Done 15398493031.5 1532665250.0 ['Done'] [1086]
# 1086 Done 7058307694.5 452070187.5 [] []
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# all_done
# dis_els:0.0, dis_mod:15398493031.5, availability:15.3984930315 billion m3/year
# mpcy: 230    10046.872943
# Name: pop, dtype: float64
# ava_int: 17.86617862575 billion m3/year
# mpcy_int: 230    11656.934628
# Name: pop, dtype: float64
# --------------------------------------
# dis_els:0.0, dis_mod:7058307694.5, availability:7.0583076945 billion m3/year
# mpcy: 1085    15613.300522
# Name: pop, dtype: float64
# ava_int: 11.638512567 billion m3/year
# mpcy_int: 1085    25744.923883
# Name: pop, dtype: float64
# --------------------------------------
# uid: 220.0
# cities in uid
# [25, 108, 117, 220, 280, 697, 750, 876, 960, 1116, 1214, 1702, 1764, 1770, 1805]
# city_num, riv_num, 108, 220
# int out of riv_num
# rate 0.8490192890167236
# discharge 5.699357397
# no shortage: mpcy=1683.1125016842063
# consumption: 2.8923107119095324
# --------------------------------------
# city_num, riv_num, 220, 220
# int out of riv_num
# rate 0.11326594650745392
# discharge 0.5784856666875
# shortage: mpcy=313.3944598707683
# consumption: 0.5784856666875
# --------------------------------------
# city_num, riv_num, 697, 220
# int out of riv_num
# rate 0.020137084648013115
# discharge 0.1121630656640625
# shortage: mpcy=155.3990148435358
# consumption: 0.1121630656640625
# --------------------------------------
# city_num, riv_num, 750, 220
# int out of riv_num
# rate 0.030236702412366867
# discharge 0.146043801140625
# shortage: mpcy=218.1941388603933
# consumption: 0.146043801140625
# --------------------------------------
# city_num, riv_num, 876, 220
# int out of riv_num
# rate 0.3273261785507202
# discharge 3.5051958495
# no shortage: mpcy=6064.837972761661
# consumption: 0.1891793923665583
# --------------------------------------
# city_num, riv_num, 1702, 220
# int out of riv_num
# rate 0.11162420362234116
# discharge 0.1204650408515625
# shortage: mpcy=422.3269504217812
# consumption: 0.1204650408515625
# --------------------------------------
# **********rivnum220.0: calculation done***************
# --------------------------------------
# 108 False 5699357397.0 2892310711.9095325 ['Done', 'Done'] [ 750 1702]
# 220 Done 578485666.6875 578485666.6875 [] []
# 697 Done 112163065.6640625 112163065.6640625 [] []
# 750 Done 146043801.140625 146043801.140625 [] []
# 876 False 3505195849.5 189179392.3665583 ['Done', 'Done'] [220 697]
# 1702 Done 120465040.8515625 120465040.8515625 [] []
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 108 Done 5432848555.0078125 2892310711.9095325 ['Done', 'Done'] [ 750 1702]
# 220 Done 578485666.6875 578485666.6875 [] []
# 697 Done 112163065.6640625 112163065.6640625 [] []
# 750 Done 146043801.140625 146043801.140625 [] []
# 876 Done 2814547117.1484375 189179392.3665583 ['Done', 'Done'] [220 697]
# 1702 Done 120465040.8515625 120465040.8515625 [] []
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# all_done
# dis_els:34416139.1484375, dis_mod:5432848555.0078125, availability:5.46726469415625 billion m3/year
# mpcy: 107    1604.880542
# Name: pop, dtype: float64
# ava_int: 6.52694290959375 billion m3/year
# mpcy_int: 107    1915.942297
# Name: pop, dtype: float64
# --------------------------------------
# dis_els:0.0, dis_mod:578485666.6875, availability:0.5784856666875 billion m3/year
# mpcy: 219    313.39446
# Name: pop, dtype: float64
# ava_int: 5.2357822621875 billion m3/year
# mpcy_int: 219    2836.483682
# Name: pop, dtype: float64
# --------------------------------------
# dis_els:0.0, dis_mod:112163065.6640625, availability:0.1121630656640625 billion m3/year
# mpcy: 696    155.399015
# Name: pop, dtype: float64
# ava_int: 4.758099802664063 billion m3/year
# mpcy_int: 696    6592.223719
# Name: pop, dtype: float64
# --------------------------------------
# dis_els:0.0, dis_mod:146043801.140625, availability:0.146043801140625 billion m3/year
# mpcy: 749    218.194139
# Name: pop, dtype: float64
# ava_int: 2.477569758890625 billion m3/year
# mpcy_int: 749    3701.568953
# Name: pop, dtype: float64
# --------------------------------------
# dis_els:0.0, dis_mod:2814547117.1484375, availability:2.8145471171484373 billion m3/year
# mpcy: 875    4869.848352
# Name: pop, dtype: float64
# ava_int: 10.784173270148438 billion m3/year
# mpcy_int: 875    18659.232283
# Name: pop, dtype: float64
# --------------------------------------
# dis_els:0.0, dis_mod:120465040.8515625, availability:0.1204650408515625 billion m3/year
# mpcy: 1701    422.32695
# Name: pop, dtype: float64
# ava_int: 1.1885945347265625 billion m3/year
# mpcy_int: 1701    4166.980741
# Name: pop, dtype: float64
# --------------------------------------
# uid: 376.0
# cities in uid
# [25, 108, 280, 1116, 1214, 1755, 1764, 1805]
# city_num, riv_num, 108, 376
# city_num: 108, prf: 0.0344161391484375, int: 1.0596782154375
# int_runout > prf_runout
# rate 0.14593102037906647
# discharge 1.0596782154375
# no shortage: mpcy=1683.1125016842063
# consumption: 0.4971357646433264
# --------------------------------------
# city_num, riv_num, 1116, 376
# int out of riv_num
# rate 0.18458689749240875
# discharge 2.206078459875
# no shortage: mpcy=4707.37054281203
# consumption: 0.08650544392664312
# --------------------------------------
# city_num, riv_num, 1214, 376
# int out of riv_num
# rate 0.17892977595329285
# discharge 1.2338508043125
# no shortage: mpcy=2782.421083475608
# consumption: 0.07934552008916346
# --------------------------------------
# city_num, riv_num, 1755, 376
# int out of riv_num
# rate 0.0007649671752005816
# discharge 0.008475791787597657
# shortage: mpcy=25.48243095118898
# consumption: 0.008475791787597657
# --------------------------------------
# **********rivnum376.0: calculation done***************
# --------------------------------------
# 108 Done 1059678215.4375 497135764.6433264 [] []
# 1116 False 2206078459.875 86505443.92664312 ['Done'] [108]
# 1214 False 1233850804.3125 79345520.08916345 ['Done'] [1755]
# 1755 Done 8475791.787597656 8475791.787597656 [] []
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 108 Done 1059678215.4375 497135764.6433264 [] []
# 1116 Done 1708942695.2316737 86505443.92664312 ['Done'] [108]
# 1214 Done 1225375012.5249023 79345520.08916345 ['Done'] [1755]
# 1755 Done 8475791.787597656 8475791.787597656 [] []
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# all_done
# dis_els:5699357397.0, dis_mod:1059678215.4375, availability:6.7590356124375 billion m3/year
# mpcy: 107    1984.071624
# Name: pop, dtype: float64
# ava_int: 7.818713827875 billion m3/year
# mpcy_int: 107    2295.133378
# Name: pop, dtype: float64
# --------------------------------------
# dis_els:0.0, dis_mod:1708942695.2316737, availability:1.7089426952316737 billion m3/year
# mpcy: 1115    3646.573161
# Name: pop, dtype: float64
# ava_int: 11.409244818231674 billion m3/year
# mpcy_int: 1115    24345.255144
# Name: pop, dtype: float64
# --------------------------------------
# dis_els:0.0, dis_mod:1225375012.5249023, availability:1.2253750125249023 billion m3/year
# mpcy: 1213    2763.307572
# Name: pop, dtype: float64
# ava_int: 10.925677135524902 billion m3/year
# mpcy_int: 1213    24638.176923
# Name: pop, dtype: float64
# --------------------------------------
# dis_els:0.0, dis_mod:8475791.787597656, availability:0.008475791787597657 billion m3/year
# mpcy: 1754    25.482431
# Name: pop, dtype: float64
# ava_int: 2.4103987246625977 billion m3/year
# mpcy_int: 1754    7246.853227
# Name: pop, dtype: float64
# --------------------------------------
# uid: 413.0
# cities in uid
# [26, 297, 698, 827, 1406, 1438]
# **********rivnum413.0: calculation done***************
# --------------------------------------
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# all_done
# uid: 1818.0
# cities in uid
# [27, 171, 807]
# **********rivnum1818.0: calculation done***************
# --------------------------------------
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# all_done
# uid: 2.0
# cities in uid
# [28, 261, 480, 650, 729, 1101, 1333, 1434, 1491]

# %%
def int_update(df_new, distance=100):
    nan_indexes = df_new[df_new['ava_int'].isna()]['index'].tolist()
    
    h08dir = '/mnt/c/Users/tsimk/Downloads/dotfiles/h08'
    rivout_path = f'{h08dir}/wsi/dat/riv_out_/W5E5LR__00000000.gl5'
    overlap_path = f'{h08dir}/global_city/dat/cty_lst_/gpw4/overlap_hidden_only.txt'
    prf_dir = f'{h08dir}/global_city/dat/cty_prf_'
    int_dir = f'{h08dir}/global_city/dat/cty_int_/{distance}km_samebasin'
    
    rivout_gl5 = np.fromfile(rivout_path, dtype='float32').reshape(2160, 4320)
    
    with open(overlap_path, 'r') as f:
        numbers = [int(line.strip()) for line in f]
    
    nan_list_removed = [num for num in nan_indexes if num not in numbers]
    nan_list_removed = [int(i) for i in nan_list_removed]

    for city_num in nan_list_removed:
    
        prf_path = f'{prf_dir}/vld_cty_/city_{city_num:08}.gl5'
        int_path = f'{int_dir}/city_{city_num:08}.gl5'
    
        if not os.path.exists(prf_path):
            print(f'{city_num} is invalid prf')
    
        else:
            intake = np.fromfile(int_path, dtype='float32').reshape(2160, 4320)
            ibt = np.sum(rivout_gl5[intake==1])*60*60*24*365/1000 # m3/year

            if not df_new[df_new['index'] == str(city_num)].empty:
                
                availability = float(df_new.loc[df_new['index'] == str(city_num), 'ava'])
                ava_int = availability + ibt
                mpcy_int = (availability+ibt)/float(df_new.loc[df_new['index'] == str(city_num), 'pop'])
                df_new.loc[df_new['index'] == str(city_num), 'ava_int'] = ava_int
                df_new.loc[df_new['index'] == str(city_num), 'mpcy_int'] = mpcy_int
                print(city_num, availability/1e9, ava_int/1e9, mpcy_int)

            else:
                print(f"No matching index found for city_num: {city_num}")
    
    return df_new

df_new = int_update(df_new)
df_new.head(10)
# Out:
# 152 is invalid prf
# 168 is invalid prf
# 174 is invalid prf
# 225 is invalid prf
# 237 is invalid prf
# 273 is invalid prf
# 278 is invalid prf
# 285 is invalid prf
# 323 is invalid prf
# 393 is invalid prf
# 409 is invalid prf
# 412 is invalid prf
# 415 is invalid prf
# 422 is invalid prf
# 436 is invalid prf
# 449 is invalid prf
# 465 is invalid prf
# 471 is invalid prf
# 474 is invalid prf
# 494 is invalid prf
# 500 is invalid prf
# 528 is invalid prf
# 538 is invalid prf
# 544 is invalid prf
# 551 is invalid prf
# 552 is invalid prf
# 555 is invalid prf
# 562 is invalid prf
# 565 is invalid prf
# 572 is invalid prf
# 574 is invalid prf
# 581 is invalid prf
# 604 is invalid prf
# 614 is invalid prf
# 623 is invalid prf
# 636 is invalid prf
# 638 is invalid prf
# 675 is invalid prf
# 682 is invalid prf
# 684 is invalid prf
# 687 is invalid prf
# 694 0.0257334991875 0.6452256976875 946.536737259231
# 695 0.116272000125 1.792798194375 2637.725216265768
# 698 1.509782797125 19.676838664125 28886.393094228097
# 702 is invalid prf
# 704 is invalid prf
# 705 0.3705973981875 1.38431540446875 2046.0290889965822
# 707 0.0679020740859375 0.6730991023359375 998.8792678921046
# 708 0.005888335071533203 79.19193286307153 109483.91513036104
# 711 0.1358974165078125 7.2920662465078125 10766.911201578201
# 712 0.2508279355546875 143.3019713275547 151796.40317656318
# 718 0.74923629159375 13.85961380409375 13929.981103638782
# 719 0.18843443690625 16.00286528390625 36840.97233580088
# 720 0.80988543984375 8.91000164784375 13030.737981075086
# 722 1.1856071300625 7.6163932648125 11699.789418984754
# 724 0.10294278155859377 0.4424867667773438 643.8040525983181
# 725 0.1444327858125 35.1952185358125 48820.80664221365
# 727 0.06665774175 1.6291609700625 3485.8631845624577
# 728 is invalid prf
# 731 0.1739085518671875 2.3211292561171875 3319.2774876101566
# 734 0.068111754609375 79.52342641860938 116954.91169313509
# 735 0.07059037180078125 0.9558182105507812 1481.7273165996746
# 738 0.1842416117578125 3.0114839245078127 4398.512508325305
# 742 1.078769691 8.0019180315 12606.842092545323
# 743 24.296836302 121.751464878 184344.60349003287
# 744 is invalid prf
# 749 0.1732034882109375 2.8184596753359377 4510.222838498087
# 751 0.33368223121875 39.20101383121875 58956.91089751585
# 752 3.649854438 13.960600884 21130.47669934516
# 753 0.0433535770546875 1.3878929080546876 1839.6462027134555
# 754 0.0633704063203125 6.561071991070312 10168.235872386727
# 755 is invalid prf
# 757 0.1516929643125 0.50036711428125 811.6480352860572
# 759 0.682506793125 4.00468124925 6432.710081947283
# 1855 is invalid prf
# 1856 0.06407035384570313 0.46821509593945315 2889.4053897603594
# 1857 0.04397699049609375 19.905164516496093 99553.69761781345
# 1858 is invalid prf
# 1859 is invalid prf
# 1860 is invalid prf
# 0 index   flag                rate        wup         pop                 ava  \
# 0     1  False  0.8633253630951112  36859.626  31821850.0      13795554377.25
# 1     2  False  1.0032005337482284  21987.895  22058268.0   3580540135.234375
# 2     3  False   0.715759664776193  20314.309  14540163.0  13694695860.777102
# 3     4  False  1.0020568930897795  20136.681  20178100.0    300657725.859375
# 4     5  False  0.4921207775782957  19659.808   9675000.0        2057520001.5
# 5     6  False  0.4892318742858954  19312.646   9448362.0       12720310699.5
# 6     7  False  0.4709559275549676  18365.262   8649229.0     632926103.34375
# 7     8  False  0.7832002814418451  18257.413  14299211.0        9254410677.0
# 8     9  False   1.006426350884948  16899.015  17007614.0   705930828950.2577
# 9    10  False  0.8239520931860906  16441.252  13546804.0  1971521745.2578125
#
# 0                mpcy potential            region                   country  \
# 0  433.52458695047585      93.0      eastern asia                     Japan
# 1  162.32190737887376      39.0     southern asia                     India
# 2   941.8529806562074      17.0      eastern asia                     China
# 3   14.90020001186311      43.0   central america                    Mexico
# 4  212.66356604651162      11.0     south america                    Brazil
# 5  1346.2979826026988      24.0      eastern asia                     Japan
# 6    73.1771702823165      17.0  northern america  United States of America
# 7   647.1972948017901      12.0     southern asia                     India
# 8  41506.752737347975      24.0   northern africa                     Egypt
# 9   145.5340865090993      24.0      eastern asia                     China
#
# 0                        cityname         12region             ava_int  \
# 0                           Tokyo        East Asia     17091316447.875
# 1                           Delhi       South Asia  22829217730.234375
# 2                        Shanghai        East Asia  13926454710.097414
# 3  Ciudad de México (Mexico City)  Central America   2428205879.109375
# 4                       São Paulo    South America      3775628136.375
# 5            Kinki M.M.A. (Osaka)        East Asia      15150352164.75
# 6                 New York-Newark    North America   25415389211.34375
# 7                 Mumbai (Bombay)       South Asia      15056622245.25
# 8              Al-Qahirah (Cairo)  Northern Africa   705948440199.0458
# 9                         Beijing        East Asia  3857525573.1328125
#
# 0            mpcy_int
# 0   537.0937405548389
# 1  1034.9506012999016
# 2   957.7922001354052
# 3          120.338678
# 4   390.2458022093023
# 5         1603.489808
# 6         2938.457198
# 7         1052.968744
# 8   41507.78822938043
# 9   284.7553986263338

# %%
######################################################
# 更新したupdown_pathをpandas dfとして保存
#####################################################
h08dir = '/mnt/c/Users/tsimk/Downloads/dotfiles/h08'
updown_path = f'{h08dir}/wsi/dat/availablewater/updown_availability_100km.txt'
#df_new.to_csv(updown_path, sep='|', index=False)

# %%
######################################################
# 更新した pandas df_newを読み込み
#####################################################
import os
import json
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import cartopy.feature as cfeature
import numpy as np
import pandas as pd
import matplotlib.colors as mcolors

h08dir = '/mnt/c/Users/tsimk/Downloads/dotfiles/h08'
updown_path = f'{h08dir}/wsi/dat/availablewater/updown_availability_100km.txt'
df_new = pd.read_csv(updown_path, delimiter='|', header=None)
df_new.columns = df_new.iloc[0]
df_new = df_new[1:].reset_index(drop=True)
df_new = df_new.infer_objects()
df_new.head(60)
# Out:
# 0  index   flag                rate        wup          pop  \
# 0      1  False  0.8633253630951112  36859.626   31821850.0
# 50    776917662.328125   133.6568611992622
# 51    39624169375.8457   8636.478870446004
# 52  60699602727.694824  10587.774969358452
# 53       22745447930.0   4068.098016964234
# 54  2409439302.8789062  1287.3899610194233
# 55  122296611.84960938   61.85254352221272
# 56   318572037778.6406  122381.81359515479
# 57  31320208606.640625   9439.553199459226
# 58    560617227.421875  124.70786587973846
# 59      99693509649.75  30461.400997820965

# %%
############################################################
# バグがないか確認する(availabilityがnegativeになっていないか)
# global_city/dat/cty_lst_/gpw4/classification.txtをチェック
# NoMASKの部分がNaNになっている
###########################################################
df_new['ava'] = pd.to_numeric(df_new['ava'], errors='coerce')
df_filtered = df_new[df_new['flag'] != 'NoMASK']

# NaNが含まれていないか確認
if df_filtered['ava'].isna().any():
    print("▲ The 'ava' column contains non-numeric(NaN) values.")
    non_numeric_values = df_filtered[pd.to_numeric(df_filtered['ava'], errors='coerce').isna()]['ava']
    print("Non-numeric values in 'ava' column:", non_numeric_values)
else:
    if (df_filtered['ava'] >= 0).all():
        print("✓ The 'ava' column contains only non-negative values.")
    else:
        print("▲ The 'ava' column contains negative values.")
        negative_ava_rows = df_filtered[df_filtered['ava'] < 0]
        print(negative_ava_rows)
# Out:
# ✓ The 'ava' column contains only non-negative values.

# %%
######################################################
# updownで再計算された都市の数と流域の数を確認
# duplicatesは複数の[上下流に都市が存在する流域]に属する都市
#####################################################
new_basin_to_cities = load_json() # keys = all basins with multiple cities 186?
rivnum_lst = list(new_basin_to_cities.keys())
rivnum_lst = [int(float(i)) for i in rivnum_lst]
print(rivnum_lst)
print(f'len(rivnum_lst): {len(rivnum_lst)}')
print('----------------------------------------------------------------------------------------------------------------------------------')

cities_lst = []
for key_index, key in enumerate(new_basin_to_cities.keys()):
    key_city_list = new_basin_to_cities[key]
    key_city_list = [int(i) for i in key_city_list]

    # remove overlap
    overlap_path = f'{h08dir}/global_city/dat/cty_lst_/gpw4/overlap_hidden_only.txt'
    with open(overlap_path, 'r') as f:
        numbers = [int(line.strip()) for line in f]
    key_city_list_removed = [num for num in key_city_list if num not in numbers]
    key_city_list_removed = [int(i) for i in key_city_list_removed]
    
    cities_lst.extend(key_city_list_removed)
    #print(f'{key_index}: rivnum{key} is done')

print('----------------------------------------------------------------------------------------------------------------------------------')
print(cities_lst)
print(f'len(cities_lst): {len(cities_lst)}')
print('----------------------------------------------------------------------------------------------------------------------------------')

urivnum = np.unique(rivnum_lst)
uctynum, counts = np.unique(cities_lst, return_counts=True)
print(f'len(urivnum): {len(urivnum)}')
print(f'len(uctynum): {len(uctynum)}')
print('----------------------------------------------------------------------------------------------------------------------------------')

duplicates = uctynum[counts > 1]
print(f'duplicates cities {duplicates}')
# Out:
# [848, 14, 480, 5438, 9439, 112, 164, 1366, 5, 528, 4, 172, 81, 11240, 189, 23, 234, 7763, 261, 1744, 1503, 2583, 3, 11, 118, 191, 138, 45, 382, 220, 376, 413, 1818, 2, 2113, 1, 6, 17, 750, 63, 182, 970, 88, 501, 325, 955, 5869, 53, 64, 864, 416, 492, 328, 78, 494, 485, 177, 343, 1830, 27, 28, 3431, 498, 34, 326, 12, 1220, 441, 126, 392, 1749