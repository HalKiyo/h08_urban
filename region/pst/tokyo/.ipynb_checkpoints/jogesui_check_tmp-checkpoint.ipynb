# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import pprint
import cartopy.crs as ccrs
import cartopy.feature as cfea
import matplotlib.colors as colors
import matplotlib.gridspec as gridspec

# %%
#
rgndir = '/mnt/c/Users/tsimk/Downloads/dotfiles/h08/region'
glbdir = '/mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city'
#
city_num = 3
tag = '.sh5'
#
resolution = 12
POP='gpw4'
#
SUF = '.gl5'
dtype = 'float32'
gl5shape = (2160, 4320)
#
# region
left = 119
right = 123
bottom = 30
top = 33
#
nx, ny = (right - left)*resolution, (top - bottom)*resolution
rgnshape = (ny, nx)
img_extent = (left, right, bottom, top)
#
upperindex = (90-top)*resolution
lowerindex = (90-bottom)*resolution
leftindex = (180+left)*resolution
rightindex = (180+right)*resolution

# city mask file
citymask = np.fromfile(f'{glbdir}/dat/cty_msk_/{POP}/city_{city_num:08}.gl5', dtype='float32').reshape(gl5shape)

# crop
citymask_cropped = citymask[int(upperindex):int(lowerindex), int(leftindex):int(rightindex)]

projection = ccrs.PlateCarree(central_longitude=0)
fig = plt.figure()
ax = plt.subplot(projection=projection)
ax.coastlines()
im = ax.imshow(citymask_cropped, extent=img_extent, transform=projection, cmap='gray_r', vmin=0, vmax=3)
plt.show()

# intake file
josui = np.fromfile(f'{glbdir}/dat/cty_prf_/{POP}/city_{city_num:08}.gl5', dtype='float32').reshape(gl5shape)

# crop
josui_cropped = josui[int(upperindex):int(lowerindex), int(leftindex):int(rightindex)]

projection = ccrs.PlateCarree(central_longitude=0)
fig = plt.figure()
ax = plt.subplot(projection=projection)
ax.coastlines()
josui_cmap = plt.cm.colors.ListedColormap(['white', 'blue'])
im = ax.imshow(josui_cropped, extent=img_extent, transform=projection, cmap=josui_cmap)
plt.show()

# gesui file
gesui = np.fromfile(f'{glbdir}/dat/cty_swg_/{POP}/city_{city_num:08}.gl5', dtype='float32').reshape(gl5shape)

# crop
gesui_cropped = gesui[int(upperindex):int(lowerindex), int(leftindex):int(rightindex)]

projection = ccrs.PlateCarree(central_longitude=0)
fig = plt.figure()
ax = plt.subplot(projection=projection)
ax.coastlines()
gesui_cmap = plt.cm.colors.ListedColormap(['white', 'red'])
im = ax.imshow(gesui_cropped, extent=img_extent, transform=projection, cmap=gesui_cmap)
plt.show()

# intake file
intake = np.fromfile(f'{glbdir}/dat/cty_int_/{POP}/city_{city_num:08}.gl5', dtype='float32').reshape(gl5shape)

# crop
intake_cropped = intake[int(upperindex):int(lowerindex), int(leftindex):int(rightindex)]
print(np.where(intake_cropped==1))

projection = ccrs.PlateCarree(central_longitude=0)
fig = plt.figure()
ax = plt.subplot(projection=projection)
ax.coastlines()
intake_cmap = plt.cm.colors.ListedColormap(['white', 'green'])
im = ax.imshow(intake_cropped, extent=img_extent, transform=projection, cmap=intake_cmap)
plt.show()

# intake file
rivout = np.fromfile(f'{glbdir}/dat/riv_out_/W5E5LR__20190000{SUF}', dtype='float32').reshape(gl5shape)

# crop
rivout_cropped = rivout[int(upperindex):int(lowerindex), int(leftindex):int(rightindex)]

projection = ccrs.PlateCarree(central_longitude=0)
fig = plt.figure()
ax = plt.subplot(projection=projection)
ax.coastlines()
im = ax.imshow(rivout_cropped, extent=img_extent, transform=projection, cmap='ocean_r')
plt.show()
# Out:
# (array([9]), array([10]))

# %%
#
rgndir = '/mnt/c/Users/tsimk/Downloads/dotfiles/h08/region'
glbdir = '/mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city'
#
city_num = 4
tag = '.mx5'
#
resolution = 12
POP='gpw4'
#
SUF = '.gl5'
dtype = 'float32'
gl5shape = (2160, 4320)
#
# region
left = -101
right = -98
bottom = 18
top = 21
#
nx, ny = (right - left)*resolution, (top - bottom)*resolution
rgnshape = (ny, nx)
img_extent = (left, right, bottom, top)
#
upperindex = (90-top)*resolution
lowerindex = (90-bottom)*resolution
leftindex = (180+left)*resolution
rightindex = (180+right)*resolution

# city mask file
citymask = np.fromfile(f'{glbdir}/dat/cty_msk_/{POP}/city_{city_num:08}.gl5', dtype='float32').reshape(gl5shape)

# crop
citymask_cropped = citymask[int(upperindex):int(lowerindex), int(leftindex):int(rightindex)]

projection = ccrs.PlateCarree(central_longitude=0)
fig = plt.figure()
ax = plt.subplot(projection=projection)
ax.coastlines()
im = ax.imshow(citymask_cropped, extent=img_extent, transform=projection, cmap='gray_r', vmin=0, vmax=3)
plt.show()

# intake file
josui = np.fromfile(f'{glbdir}/dat/cty_prf_/{POP}/city_{city_num:08}.gl5', dtype='float32').reshape(gl5shape)

# crop
josui_cropped = josui[int(upperindex):int(lowerindex), int(leftindex):int(rightindex)]

projection = ccrs.PlateCarree(central_longitude=0)
fig = plt.figure()
ax = plt.subplot(projection=projection)
ax.coastlines()
josui_cmap = plt.cm.colors.ListedColormap(['white', 'blue'])
im = ax.imshow(josui_cropped, extent=img_extent, transform=projection, cmap=josui_cmap)
plt.show()

# gesui file
gesui = np.fromfile(f'{glbdir}/dat/cty_swg_/{POP}/city_{city_num:08}.gl5', dtype='float32').reshape(gl5shape)

# crop
gesui_cropped = gesui[int(upperindex):int(lowerindex), int(leftindex):int(rightindex)]

projection = ccrs.PlateCarree(central_longitude=0)
fig = plt.figure()
ax = plt.subplot(projection=projection)
ax.coastlines()
gesui_cmap = plt.cm.colors.ListedColormap(['white', 'red'])
im = ax.imshow(gesui_cropped, extent=img_extent, transform=projection, cmap=gesui_cmap)
plt.show()

# intake file
intake = np.fromfile(f'{glbdir}/dat/cty_int_/{POP}/city_{city_num:08}.gl5', dtype='float32').reshape(gl5shape)

# crop
intake_cropped = intake[int(upperindex):int(lowerindex), int(leftindex):int(rightindex)]
print(np.where(intake_cropped==1))

projection = ccrs.PlateCarree(central_longitude=0)
fig = plt.figure()
ax = plt.subplot(projection=projection)
ax.coastlines()
intake_cmap = plt.cm.colors.ListedColormap(['white', 'green'])
im = ax.imshow(intake_cropped, extent=img_extent, transform=projection, cmap=intake_cmap)
plt.show()

# intake file
rivout = np.fromfile(f'{glbdir}/dat/riv_out_/W5E5LR__20190000{SUF}', dtype='float32').reshape(gl5shape)

# crop
rivout_cropped = rivout[int(upperindex):int(lowerindex), int(leftindex):int(rightindex)]

projection = ccrs.PlateCarree(central_longitude=0)
fig = plt.figure()
ax = plt.subplot(projection=projection)
ax.coastlines()
im = ax.imshow(rivout_cropped, extent=img_extent, transform=projection, cmap='ocean_r')
plt.show()
# Out:
# (array([20]), array([4]))

# %%
#
rgndir = '/mnt/c/Users/tsimk/Downloads/dotfiles/h08/region'
glbdir = '/mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city'
#
city_num = 5
tag = '.sp5'
#
resolution = 12
POP='gpw4'
#
SUF = '.gl5'
dtype = 'float32'
gl5shape = (2160, 4320)
#
# region
left = -48
right = -45
bottom = -25
top = -22
#
nx, ny = (right - left)*resolution, (top - bottom)*resolution
rgnshape = (ny, nx)
img_extent = (left, right, bottom, top)
#
upperindex = (90-top)*resolution
lowerindex = (90-bottom)*resolution
leftindex = (180+left)*resolution
rightindex = (180+right)*resolution

# city mask file
citymask = np.fromfile(f'{glbdir}/dat/cty_msk_/{POP}/city_{city_num:08}.gl5', dtype='float32').reshape(gl5shape)

# crop
citymask_cropped = citymask[int(upperindex):int(lowerindex), int(leftindex):int(rightindex)]

projection = ccrs.PlateCarree(central_longitude=0)
fig = plt.figure()
ax = plt.subplot(projection=projection)
ax.coastlines()
im = ax.imshow(citymask_cropped, extent=img_extent, transform=projection, cmap='gray_r', vmin=0, vmax=3)
plt.show()

# intake file
josui = np.fromfile(f'{glbdir}/dat/cty_prf_/{POP}/city_{city_num:08}.gl5', dtype='float32').reshape(gl5shape)

# crop
josui_cropped = josui[int(upperindex):int(lowerindex), int(leftindex):int(rightindex)]

projection = ccrs.PlateCarree(central_longitude=0)
fig = plt.figure()
ax = plt.subplot(projection=projection)
ax.coastlines()
josui_cmap = plt.cm.colors.ListedColormap(['white', 'blue'])
im = ax.imshow(josui_cropped, extent=img_extent, transform=projection, cmap=josui_cmap)
plt.show()

# gesui file
gesui = np.fromfile(f'{glbdir}/dat/cty_swg_/{POP}/city_{city_num:08}.gl5', dtype='float32').reshape(gl5shape)

# crop
gesui_cropped = gesui[int(upperindex):int(lowerindex), int(leftindex):int(rightindex)]

projection = ccrs.PlateCarree(central_longitude=0)
fig = plt.figure()
ax = plt.subplot(projection=projection)
ax.coastlines()
gesui_cmap = plt.cm.colors.ListedColormap(['white', 'red'])
im = ax.imshow(gesui_cropped, extent=img_extent, transform=projection, cmap=gesui_cmap)
plt.show()

# intake file
intake = np.fromfile(f'{glbdir}/dat/cty_int_/{POP}/city_{city_num:08}.gl5', dtype='float32').reshape(gl5shape)

# crop
intake_cropped = intake[int(upperindex):int(lowerindex), int(leftindex):int(rightindex)]
print(np.where(intake_cropped==1))

projection = ccrs.PlateCarree(central_longitude=0)
fig = plt.figure()
ax = plt.subplot(projection=projection)
ax.coastlines()
intake_cmap = plt.cm.colors.ListedColormap(['white', 'green'])
im = ax.imshow(intake_cropped, extent=img_extent, transform=projection, cmap=intake_cmap)
plt.show()

# intake file
rivout = np.fromfile(f'{glbdir}/dat/riv_out_/W5E5LR__20190000{SUF}', dtype='float32').reshape(gl5shape)

# crop
rivout_cropped = rivout[int(upperindex):int(lowerindex), int(leftindex):int(rightindex)]

projection = ccrs.PlateCarree(central_longitude=0)
fig = plt.figure()
ax = plt.subplot(projection=projection)
ax.coastlines()
im = ax.imshow(rivout_cropped, extent=img_extent, transform=projection, cmap='ocean_r')
plt.show()
# Out:
# (array([19]), array([23]))

# %%
#
rgndir = '/mnt/c/Users/tsimk/Downloads/dotfiles/h08/region'
glbdir = '/mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city'
#
city_num = 7
tag = '.ny5'
#
resolution = 12
POP='gpw4'
#
SUF = '.gl5'
dtype = 'float32'
gl5shape = (2160, 4320)
#
# region
left = -76
right = -73
bottom = 39
top = 42
#
nx, ny = (right - left)*resolution, (top - bottom)*resolution
rgnshape = (ny, nx)
img_extent = (left, right, bottom, top)
#
upperindex = (90-top)*resolution
lowerindex = (90-bottom)*resolution
leftindex = (180+left)*resolution
rightindex = (180+right)*resolution

# city mask file
citymask = np.fromfile(f'{glbdir}/dat/cty_msk_/{POP}/city_{city_num:08}.gl5', dtype='float32').reshape(gl5shape)

# crop
citymask_cropped = citymask[int(upperindex):int(lowerindex), int(leftindex):int(rightindex)]

projection = ccrs.PlateCarree(central_longitude=0)
fig = plt.figure()
ax = plt.subplot(projection=projection)
ax.coastlines()
im = ax.imshow(citymask_cropped, extent=img_extent, transform=projection, cmap='gray_r', vmin=0, vmax=3)
plt.show()

# intake file
josui = np.fromfile(f'{glbdir}/dat/cty_prf_/{POP}/city_{city_num:08}.gl5', dtype='float32').reshape(gl5shape)
josui_cropped = josui[int(upperindex):int(lowerindex), int(leftindex):int(rightindex)]
print(np.where(josui_cropped==1))

projection = ccrs.PlateCarree(central_longitude=0)
fig = plt.figure()
ax = plt.subplot(projection=projection)
ax.coastlines()
josui_cmap = plt.cm.colors.ListedColormap(['white', 'blue'])
im = ax.imshow(josui_cropped, extent=img_extent, transform=projection, cmap=josui_cmap)
plt.show()

# gesui file
gesui = np.fromfile(f'{glbdir}/dat/cty_swg_/{POP}/city_{city_num:08}.gl5', dtype='float32').reshape(gl5shape)

# crop
gesui_cropped = gesui[int(upperindex):int(lowerindex), int(leftindex):int(rightindex)]
print(np.where(gesui_cropped==1))

projection = ccrs.PlateCarree(central_longitude=0)
fig = plt.figure()
ax = plt.subplot(projection=projection)
ax.coastlines()
gesui_cmap = plt.cm.colors.ListedColormap(['white', 'red'])
im = ax.imshow(gesui_cropped, extent=img_extent, transform=projection, cmap=gesui_cmap)
plt.show()

# intake file
intake = np.fromfile(f'{glbdir}/dat/cty_int_/{POP}/city_{city_num:08}.gl5', dtype='float32').reshape(gl5shape)

# crop
intake_cropped = intake[int(upperindex):int(lowerindex), int(leftindex):int(rightindex)]
print(np.where(intake_cropped==1))

projection = ccrs.PlateCarree(central_longitude=0)
fig = plt.figure()
ax = plt.subplot(projection=projection)
ax.coastlines()
intake_cmap = plt.cm.colors.ListedColormap(['white', 'green'])
im = ax.imshow(intake_cropped, extent=img_extent, transform=projection, cmap=intake_cmap)
plt.show()

# intake file
rivout = np.fromfile(f'{glbdir}/dat/riv_out_/W5E5LR__20190000{SUF}', dtype='float32').reshape(gl5shape)

# crop
rivout_cropped = rivout[int(upperindex):int(lowerindex), int(leftindex):int(rightindex)]

projection = ccrs.PlateCarree(central_longitude=0)
fig = plt.figure()
ax = plt.subplot(projection=projection)
ax.coastlines()
im = ax.imshow(rivout_cropped, extent=img_extent, transform=projection, cmap='ocean_r')
plt.show()
# Out:
# (array([], dtype=int64), array([], dtype=int64))
# (array([], dtype=int64), array([], dtype=int64))
# (array([], dtype=int64), array([], dtype=int64))

# %%
#
rgndir = '/mnt/c/Users/tsimk/Downloads/dotfiles/h08/region'
glbdir = '/mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city'
#
city_num = 8
tag = '.mb'
#
resolution = 12
POP='gpw4'
#
SUF = '.gl5'
dtype = 'float32'
gl5shape = (2160, 4320)
#
# region
left = 71
right = 74
bottom = 18
top = 21
#
nx, ny = (right - left)*resolution, (top - bottom)*resolution
rgnshape = (ny, nx)
img_extent = (left, right, bottom, top)
#
upperindex = (90-top)*resolution
lowerindex = (90-bottom)*resolution
leftindex = (180+left)*resolution
rightindex = (180+right)*resolution

# city mask file
citymask = np.fromfile(f'{glbdir}/dat/cty_msk_/{POP}/city_{city_num:08}.gl5', dtype='float32').reshape(gl5shape)

# crop
citymask_cropped = citymask[int(upperindex):int(lowerindex), int(leftindex):int(rightindex)]

projection = ccrs.PlateCarree(central_longitude=0)
fig = plt.figure()
ax = plt.subplot(projection=projection)
ax.coastlines()
im = ax.imshow(citymask_cropped, extent=img_extent, transform=projection, cmap='gray_r', vmin=0, vmax=3)
plt.show()

# intake file
josui = np.fromfile(f'{glbdir}/dat/cty_prf_/{POP}/city_{city_num:08}.gl5', dtype='float32').reshape(gl5shape)
josui_cropped = josui[int(upperindex):int(lowerindex), int(leftindex):int(rightindex)]
print(np.where(josui_cropped==1))

projection = ccrs.PlateCarree(central_longitude=0)
fig = plt.figure()
ax = plt.subplot(projection=projection)
ax.coastlines()
josui_cmap = plt.cm.colors.ListedColormap(['white', 'blue'])
im = ax.imshow(josui_cropped, extent=img_extent, transform=projection, cmap=josui_cmap)
plt.show()

# gesui file
gesui = np.fromfile(f'{glbdir}/dat/cty_swg_/{POP}/city_{city_num:08}.gl5', dtype='float32').reshape(gl5shape)

# crop
gesui_cropped = gesui[int(upperindex):int(lowerindex), int(leftindex):int(rightindex)]
print(np.where(gesui_cropped==1))

projection = ccrs.PlateCarree(central_longitude=0)
fig = plt.figure()
ax = plt.subplot(projection=projection)
ax.coastlines()
gesui_cmap = plt.cm.colors.ListedColormap(['white', 'red'])
im = ax.imshow(gesui_cropped, extent=img_extent, transform=projection, cmap=gesui_cmap)
plt.show()

# intake file
intake = np.fromfile(f'{glbdir}/dat/cty_int_/{POP}/city_{city_num:08}.gl5', dtype='float32').reshape(gl5shape)

# crop
intake_cropped = intake[int(upperindex):int(lowerindex), int(leftindex):int(rightindex)]
print(np.where(intake_cropped==1))

projection = ccrs.PlateCarree(central_longitude=0)
fig = plt.figure()
ax = plt.subplot(projection=projection)
ax.coastlines()
intake_cmap = plt.cm.colors.ListedColormap(['white', 'green'])
im = ax.imshow(intake_cropped, extent=img_extent, transform=projection, cmap=intake_cmap)
plt.show()

# intake file
rivout = np.fromfile(f'{glbdir}/dat/riv_out_/W5E5LR__20190000{SUF}', dtype='float32').reshape(gl5shape)

# crop
rivout_cropped = rivout[int(upperindex):int(lowerindex), int(leftindex):int(rightindex)]

projection = ccrs.PlateCarree(central_longitude=0)
fig = plt.figure()
ax = plt.subplot(projection=projection)
ax.coastlines()
im = ax.imshow(rivout_cropped, extent=img_extent, transform=projection, cmap='ocean_r')
plt.show()
# Out:
# (array([], dtype=int64), array([], dtype=int64))
# (array([], dtype=int64), array([], dtype=int64))
# (array([], dtype=int64), array([], dtype=int64))

# %%
#
rgndir = '/mnt/c/Users/tsimk/Downloads/dotfiles/h08/region'
glbdir = '/mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city'
#
city_num = 10
tag = '.bj5'
#
resolution = 12
POP='gpw4'
#
SUF = '.gl5'
dtype = 'float32'
gl5shape = (2160, 4320)
#
# region
left = 115
right = 118
bottom = 38
top = 41
#
nx, ny = (right - left)*resolution, (top - bottom)*resolution
rgnshape = (ny, nx)
img_extent = (left, right, bottom, top)
#
upperindex = (90-top)*resolution
lowerindex = (90-bottom)*resolution
leftindex = (180+left)*resolution
rightindex = (180+right)*resolution

# city mask file
citymask = np.fromfile(f'{glbdir}/dat/cty_msk_/{POP}/city_{city_num:08}.gl5', dtype='float32').reshape(gl5shape)

# crop
citymask_cropped = citymask[int(upperindex):int(lowerindex), int(leftindex):int(rightindex)]

projection = ccrs.PlateCarree(central_longitude=0)
fig = plt.figure()
ax = plt.subplot(projection=projection)
ax.coastlines()
im = ax.imshow(citymask_cropped, extent=img_extent, transform=projection, cmap='gray_r', vmin=0, vmax=3)
plt.show()

# intake file
josui = np.fromfile(f'{glbdir}/dat/cty_prf_/{POP}/city_{city_num:08}.gl5', dtype='float32').reshape(gl5shape)
josui_cropped = josui[int(upperindex):int(lowerindex), int(leftindex):int(rightindex)]
print(np.where(josui_cropped==1))

projection = ccrs.PlateCarree(central_longitude=0)
fig = plt.figure()
ax = plt.subplot(projection=projection)
ax.coastlines()
josui_cmap = plt.cm.colors.ListedColormap(['white', 'blue'])
im = ax.imshow(josui_cropped, extent=img_extent, transform=projection, cmap=josui_cmap)
plt.show()

# gesui file
gesui = np.fromfile(f'{glbdir}/dat/cty_swg_/{POP}/city_{city_num:08}.gl5', dtype='float32').reshape(gl5shape)

# crop
gesui_cropped = gesui[int(upperindex):int(lowerindex), int(leftindex):int(rightindex)]
print(np.where(gesui_cropped==1))

projection = ccrs.PlateCarree(central_longitude=0)
fig = plt.figure()
ax = plt.subplot(projection=projection)
ax.coastlines()
gesui_cmap = plt.cm.colors.ListedColormap(['white', 'red'])
im = ax.imshow(gesui_cropped, extent=img_extent, transform=projection, cmap=gesui_cmap)
plt.show()

# intake file
intake = np.fromfile(f'{glbdir}/dat/cty_int_/{POP}/city_{city_num:08}.gl5', dtype='float32').reshape(gl5shape)

# crop
intake_cropped = intake[int(upperindex):int(lowerindex), int(leftindex):int(rightindex)]
print(np.where(intake_cropped==1))

projection = ccrs.PlateCarree(central_longitude=0)
fig = plt.figure()
ax = plt.subplot(projection=projection)
ax.coastlines()
intake_cmap = plt.cm.colors.ListedColormap(['white', 'green'])
im = ax.imshow(intake_cropped, extent=img_extent, transform=projection, cmap=intake_cmap)
plt.show()

# intake file
rivout = np.fromfile(f'{glbdir}/dat/riv_out_/W5E5LR__20190000{SUF}', dtype='float32').reshape(gl5shape)

# crop
rivout_cropped = rivout[int(upperindex):int(lowerindex), int(leftindex):int(rightindex)]

projection = ccrs.PlateCarree(central_longitude=0)
fig = plt.figure()
ax = plt.subplot(projection=projection)
ax.coastlines()
im = ax.imshow(rivout_cropped, extent=img_extent, transform=projection, cmap='ocean_r')
plt.show()
# Out:
# (array([], dtype=int64), array([], dtype=int64))
# (array([], dtype=int64), array([], dtype=int64))
# (array([], dtype=int64), array([], dtype=int64))

# %%
#
rgndir = '/mnt/c/Users/tsimk/Downloads/dotfiles/h08/region'
glbdir = '/mnt/c/Users/tsimk/Downloads/dotfiles/h08/global_city'
#
city_num = 11
tag = '.bj5'
#
resolution = 12
POP='gpw4'
#
SUF = '.gl5'
dtype = 'float32'
gl5shape = (2160, 4320)
#
# region
left = 89
right = 92
bottom = 22
top = 25
#
nx, ny = (right - left)*resolution, (top - bottom)*resolution
rgnshape = (ny, nx)
img_extent = (left, right, bottom, top)
#
upperindex = (90-top)*resolution
lowerindex = (90-bottom)*resolution
leftindex = (180+left)*resolution
rightindex = (180+right)*resolution

# city mask file
citymask = np.fromfile(f'{glbdir}/dat/cty_msk_/{POP}/city_{city_num:08}.gl5', dtype='float32').reshape(gl5shape)

# crop
citymask_cropped = citymask[int(upperindex):int(lowerindex), int(leftindex):int(rightindex)]

projection = ccrs.PlateCarree(central_longitude=0)
fig = plt.figure()
ax = plt.subplot(projection=projection)
ax.coastlines()
im = ax.imshow(citymask_cropped, extent=img_extent, transform=projection, cmap='gray_r', vmin=0, vmax=3)
plt.show()

# intake file
josui = np.fromfile(f'{glbdir}/dat/cty_prf_/{POP}/city_{city_num:08}.gl5', dtype='float32').reshape(gl5shape)
josui_cropped = josui[int(upperindex):int(lowerindex), int(leftindex):int(rightindex)]
print(np.where(josui_cropped==1))

projection = ccrs.PlateCarree(central_longitude=0)
fig = plt.figure()
ax = plt.subplot(projection=projection)
ax.coastlines()
josui_cmap = plt.cm.colors.ListedColormap(['white', 'blue'])
im = ax.imshow(josui_cropped, extent=img_extent, transform=projection, cmap=josui_cmap)
plt.show()

# gesui file
gesui = np.fromfile(f'{glbdir}/dat/cty_swg_/{POP}/city_{city_num:08}.gl5', dtype='float32').reshape(gl5shape)

# crop
gesui_cropped = gesui[int(upperindex):int(lowerindex), int(leftindex):int(rightindex)]
print(np.where(gesui_cropped==1))

projection = ccrs.PlateCarree(central_longitude=0)
fig = plt.figure()
ax = plt.subplot(projection=projection)
ax.coastlines()
gesui_cmap = plt.cm.colors.ListedColormap(['white', 'red'])
im = ax.imshow(gesui_cropped, extent=img_extent, transform=projection, cmap=gesui_cmap)
plt.show()

# intake file
intake = np.fromfile(f'{glbdir}/dat/cty_int_/{POP}/city_{city_num:08}.gl5', dtype='float32').reshape(gl5shape)

# crop
intake_cropped = intake[int(upperindex):int(lowerindex), int(leftindex):int(rightindex)]
print(np.where(intake_cropped==1))

projection = ccrs.PlateCarree(central_longitude=0)
fig = plt.figure()
ax = plt.subplot(projection=projection)
ax.coastlines()
intake_cmap = plt.cm.colors.ListedColormap(['white', 'green'])
im = ax.imshow(intake_cropped, extent=img_extent, transform=projection, cmap=intake_cmap)
plt.show()

# intake file
rivout = np.fromfile(f'{glbdir}/dat/riv_out_/W5E5LR__20190000{SUF}', dtype='float32').reshape(gl5shape)

# crop
rivout_cropped = rivout[int(upperindex):int(lowerindex), int(leftindex):int(rightindex)]

projection = ccrs.PlateCarree(central_longitude=0)
fig = plt.figure()
ax = plt.subplot(projection=projection)
ax.coastlines()
im = ax.imshow(rivout_cropped, extent=img_extent, transform=projection, cmap='ocean_r')
plt.show()
# Out:
# (array([], dtype=int64), array([], dtype=int64))
# (array([], dtype=int64), array([], dtype=int64))
# (array([], dtype=int64), array([], dtype=int64))
